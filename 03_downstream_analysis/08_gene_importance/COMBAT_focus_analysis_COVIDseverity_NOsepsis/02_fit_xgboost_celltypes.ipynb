# %%
CELL_TYPE = 'pDC'
N_TRIALS: int = 50
SPLIT_IDX = 0

# %%
import os
import sys
from pyprojroot.here import here

import pandas as pd
import anndata as ad
import numpy as np
import math
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import product

import optuna

import joblib
import pickle
import datetime

import collections

import xgboost
from sklearn.preprocessing import LabelEncoder

import scipy.sparse as ssp
import joblib

from dotenv import load_dotenv

# %%
assert load_dotenv()

# %% [markdown]
# # LOAD DATASET

# %%
adata_ct = ad.read_h5ad(here(f'03_downstream_analysis/08_gene_importance/COMBAT_focus_analysis_COVIDseverity_NOsepsis/data/{CELL_TYPE}_COMBAT2022_spectraGenes_log1p.h5ad'))

# %%
adata_ct
# Out:
# AnnData object with n_obs × n_vars = 1676 × 935
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'disease', 'sex', 'binned_age', 'Level1', 'Level2', 'batch', 'COVID_severity'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'highly_variable'
#     uns: 'log1p'

# %%
adata_ct.obs.studyID.unique(), adata_ct.obs.Level1.unique()
# Out:
# (['COMBAT2022']
#  Categories (1, object): ['COMBAT2022'],
#  ['pDC']
#  Categories (1, object): ['pDC'])

# %% [markdown]
# ### Generate traint - test - validation splits (5-fold cross validation setting)

# %%
N_SPLITS = 5

# %%
left_out_splits = [s[1] for s in StratifiedGroupKFold(n_splits=N_SPLITS).split(X = adata_ct.obs.index, y=adata_ct.obs.disease, groups=adata_ct.obs.batch)]

# %%
test_split_n = SPLIT_IDX
validation_split_n = (SPLIT_IDX + 1) % N_SPLITS

test_idxs = left_out_splits[test_split_n]
val_idxs = left_out_splits[validation_split_n]

train_idxs = list()

for idx in np.setdiff1d(range(N_SPLITS), np.array([test_split_n,validation_split_n])):
    train_idxs.append(left_out_splits[idx])
train_idxs = np.concatenate(train_idxs)

# %%
train_idxs.shape, test_idxs.shape, val_idxs.shape, train_idxs.shape[0]+val_idxs.shape[0]+test_idxs.shape[0]
# Out:
# ((1023,), (389,), (264,), 1676)

# %%
X_train = adata_ct[train_idxs,:].X
X_test = adata_ct[test_idxs, :].X
X_val = adata_ct[val_idxs, :].X
X_train.shape, X_test.shape, X_val.shape
# Out:
# ((1023, 935), (389, 935), (264, 935))

# %%
y_train = adata_ct.obs.iloc[train_idxs].disease.values.astype(str)
y_test = adata_ct.obs.iloc[test_idxs].disease.values.astype(str)
y_val = adata_ct.obs.iloc[val_idxs].disease.values.astype(str)
y_train.shape, y_test.shape, y_val.shape
# Out:
# ((1023,), (389,), (264,))

# %%
np.unique(y_train), np.unique(y_val), np.unique(y_test)
# Out:
# (array(['COVID_CRIT', 'COVID_MILD', 'COVID_SEV', 'Flu', 'healthy'],
#        dtype='<U10'),
#  array(['COVID_CRIT', 'COVID_MILD', 'COVID_SEV', 'Flu', 'healthy'],
#        dtype='<U10'),
#  array(['COVID_CRIT', 'COVID_MILD', 'COVID_SEV', 'Flu', 'healthy'],
#        dtype='<U10'))

# %%
lenc = LabelEncoder()
y_train_enc = lenc.fit_transform(y_train)
y_val_enc = lenc.transform(y_val)
y_test_enc = lenc.transform(y_test)

# %% [markdown]
# ### GENERATE F1

# %%
def custom_f1_score(y_true, y_pred):
    return -f1_score(y_true, y_pred.argmax(1), average='weighted')

# %%
eval_metric=custom_f1_score
eval_metric_name='custom_f1_score'

def objective(trial):
    params = {
        'sampling_method': 'gradient_based',
        'n_estimators': 1500,
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 250),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.1, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 1e-3, 5e-1, log=True),
    }
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, f'validation_0-{eval_metric_name}')
    xgb = xgboost.XGBClassifier(
        device='gpu',
        eval_metric=eval_metric,
        early_stopping_rounds=20,
        callbacks=[pruning_callback],
        **params
    )
    xgb.fit(
        X_train, 
        y_train_enc, 
        verbose=0,
        eval_set=[(X_val, y_val_enc)],
    )
    trial.set_user_attr('best_iteration', xgb.best_iteration)

    return xgb.best_score

# %%
sampler = optuna.samplers.TPESampler(seed=42)
study = optuna.create_study(direction='minimize', sampler=sampler)
study.optimize(objective, n_trials=N_TRIALS, gc_after_trial=True)
# Out:
# [I 2025-04-02 20:08:54,455] A new study created in memory with name: no-name-f2e3aa13-8bc5-4ecf-8bce-6a21c7775619
# [I 2025-04-02 20:10:58,892] Trial 0 finished with value: -0.745543 and parameters: {'max_depth': 9, 'min_child_weight': 238, 'subsample': 0.7587945476302645, 'colsample_bynode': 0.6387926357773329, 'learning_rate': 0.0026368755339723046}. Best is trial 0 with value: -0.745543.

# %%
joblib.dump(study, here(f'03_downstream_analysis/08_gene_importance/COMBAT_focus_analysis_COVIDseverity_NOsepsis/results/study/{SPLIT_IDX}_{CELL_TYPE}_xgboost.pkl'))
# Out:
# ['/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/03_downstream_analysis/08_gene_importance/COMBAT_focus_analysis/results/study/0_Mono_xgboost.pkl']

# %%
n_estimators = int(study.best_trial.user_attrs['best_iteration']*1.2)
xgb = xgboost.XGBClassifier(
        device='gpu',
        eval_metric=eval_metric,
        n_estimators=n_estimators,
        **study.best_trial.params
    )
xgb.fit(
    ssp.vstack((X_train, X_val)), 
    np.concatenate((y_train_enc, y_val_enc)), 
    eval_set=[(X_test, y_test_enc)],
    verbose=1,
)
# Out:
# [0]	validation_0-mlogloss:1.38401	validation_0-custom_f1_score:-0.69994
# [1]	validation_0-mlogloss:1.38172	validation_0-custom_f1_score:-0.71104
# [2]	validation_0-mlogloss:1.37942	validation_0-custom_f1_score:-0.72432
# [3]	validation_0-mlogloss:1.37714	validation_0-custom_f1_score:-0.72384
# [4]	validation_0-mlogloss:1.37491	validation_0-custom_f1_score:-0.72638
# [5]	validation_0-mlogloss:1.37265	validation_0-custom_f1_score:-0.72637
# [6]	validation_0-mlogloss:1.37039	validation_0-custom_f1_score:-0.72621
# [7]	validation_0-mlogloss:1.36817	validation_0-custom_f1_score:-0.72612
# [8]	validation_0-mlogloss:1.36591	validation_0-custom_f1_score:-0.72513
# [9]	validation_0-mlogloss:1.36373	validation_0-custom_f1_score:-0.72547
# [10]	validation_0-mlogloss:1.36148	validation_0-custom_f1_score:-0.72589
# [11]	validation_0-mlogloss:1.35930	validation_0-custom_f1_score:-0.72487
# [12]	validation_0-mlogloss:1.35717	validation_0-custom_f1_score:-0.72532
# [13]	validation_0-mlogloss:1.35504	validation_0-custom_f1_score:-0.72469
# [14]	validation_0-mlogloss:1.35285	validation_0-custom_f1_score:-0.72483
# [15]	validation_0-mlogloss:1.35072	validation_0-custom_f1_score:-0.72441
# [16]	validation_0-mlogloss:1.34859	validation_0-custom_f1_score:-0.72403
# [17]	validation_0-mlogloss:1.34645	validation_0-custom_f1_score:-0.72471
# [18]	validation_0-mlogloss:1.34433	validation_0-custom_f1_score:-0.72581
# [19]	validation_0-mlogloss:1.34223	validation_0-custom_f1_score:-0.72546
# [20]	validation_0-mlogloss:1.34011	validation_0-custom_f1_score:-0.72464
# [21]	validation_0-mlogloss:1.33805	validation_0-custom_f1_score:-0.72407
# [22]	validation_0-mlogloss:1.33597	validation_0-custom_f1_score:-0.72366
# [23]	validation_0-mlogloss:1.33388	validation_0-custom_f1_score:-0.72537
# [24]	validation_0-mlogloss:1.33184	validation_0-custom_f1_score:-0.72483
# [25]	validation_0-mlogloss:1.32979	validation_0-custom_f1_score:-0.72454
# [26]	validation_0-mlogloss:1.32780	validation_0-custom_f1_score:-0.72487
# [27]	validation_0-mlogloss:1.32577	validation_0-custom_f1_score:-0.72516
# [28]	validation_0-mlogloss:1.32374	validation_0-custom_f1_score:-0.72520
# [29]	validation_0-mlogloss:1.32176	validation_0-custom_f1_score:-0.72527
# [30]	validation_0-mlogloss:1.31975	validation_0-custom_f1_score:-0.72575
# [31]	validation_0-mlogloss:1.31778	validation_0-custom_f1_score:-0.72593
# [32]	validation_0-mlogloss:1.31578	validation_0-custom_f1_score:-0.72571
# [33]	validation_0-mlogloss:1.31385	validation_0-custom_f1_score:-0.72560
# [34]	validation_0-mlogloss:1.31186	validation_0-custom_f1_score:-0.72562
# [35]	validation_0-mlogloss:1.30991	validation_0-custom_f1_score:-0.72579
# [36]	validation_0-mlogloss:1.30797	validation_0-custom_f1_score:-0.72610
# [37]	validation_0-mlogloss:1.30602	validation_0-custom_f1_score:-0.72623
# [38]	validation_0-mlogloss:1.30409	validation_0-custom_f1_score:-0.72616
# [39]	validation_0-mlogloss:1.30215	validation_0-custom_f1_score:-0.72611
# [40]	validation_0-mlogloss:1.30026	validation_0-custom_f1_score:-0.72623
# [41]	validation_0-mlogloss:1.29838	validation_0-custom_f1_score:-0.72589
# [42]	validation_0-mlogloss:1.29650	validation_0-custom_f1_score:-0.72611
# [43]	validation_0-mlogloss:1.29458	validation_0-custom_f1_score:-0.72642
# [44]	validation_0-mlogloss:1.29269	validation_0-custom_f1_score:-0.72630
# [45]	validation_0-mlogloss:1.29077	validation_0-custom_f1_score:-0.72671
# [46]	validation_0-mlogloss:1.28890	validation_0-custom_f1_score:-0.72659
# [47]	validation_0-mlogloss:1.28700	validation_0-custom_f1_score:-0.72664
# [48]	validation_0-mlogloss:1.28515	validation_0-custom_f1_score:-0.72649
# [49]	validation_0-mlogloss:1.28328	validation_0-custom_f1_score:-0.72695
# [50]	validation_0-mlogloss:1.28144	validation_0-custom_f1_score:-0.72685
# [51]	validation_0-mlogloss:1.27961	validation_0-custom_f1_score:-0.72660
# [52]	validation_0-mlogloss:1.27780	validation_0-custom_f1_score:-0.72659
# [53]	validation_0-mlogloss:1.27600	validation_0-custom_f1_score:-0.72653
# [54]	validation_0-mlogloss:1.27420	validation_0-custom_f1_score:-0.72635
# [55]	validation_0-mlogloss:1.27239	validation_0-custom_f1_score:-0.72681
# [56]	validation_0-mlogloss:1.27062	validation_0-custom_f1_score:-0.72661
# [57]	validation_0-mlogloss:1.26879	validation_0-custom_f1_score:-0.72724
# [58]	validation_0-mlogloss:1.26703	validation_0-custom_f1_score:-0.72760
# [59]	validation_0-mlogloss:1.26521	validation_0-custom_f1_score:-0.72753
# [60]	validation_0-mlogloss:1.26340	validation_0-custom_f1_score:-0.72811
# [61]	validation_0-mlogloss:1.26162	validation_0-custom_f1_score:-0.72828
# [62]	validation_0-mlogloss:1.25987	validation_0-custom_f1_score:-0.72815
# [63]	validation_0-mlogloss:1.25809	validation_0-custom_f1_score:-0.72847
# [64]	validation_0-mlogloss:1.25635	validation_0-custom_f1_score:-0.72842
# [65]	validation_0-mlogloss:1.25463	validation_0-custom_f1_score:-0.72835
# [66]	validation_0-mlogloss:1.25294	validation_0-custom_f1_score:-0.72862
# [67]	validation_0-mlogloss:1.25126	validation_0-custom_f1_score:-0.72870
# [68]	validation_0-mlogloss:1.24957	validation_0-custom_f1_score:-0.72846
# [69]	validation_0-mlogloss:1.24788	validation_0-custom_f1_score:-0.72838
# [70]	validation_0-mlogloss:1.24622	validation_0-custom_f1_score:-0.72875
# [71]	validation_0-mlogloss:1.24452	validation_0-custom_f1_score:-0.72828
# [72]	validation_0-mlogloss:1.24278	validation_0-custom_f1_score:-0.72898
# [73]	validation_0-mlogloss:1.24110	validation_0-custom_f1_score:-0.72879
# [74]	validation_0-mlogloss:1.23943	validation_0-custom_f1_score:-0.72857
# [75]	validation_0-mlogloss:1.23774	validation_0-custom_f1_score:-0.72866
# [76]	validation_0-mlogloss:1.23607	validation_0-custom_f1_score:-0.72888
# [77]	validation_0-mlogloss:1.23444	validation_0-custom_f1_score:-0.72873
# [78]	validation_0-mlogloss:1.23281	validation_0-custom_f1_score:-0.72908
# [79]	validation_0-mlogloss:1.23113	validation_0-custom_f1_score:-0.72938
# [80]	validation_0-mlogloss:1.22949	validation_0-custom_f1_score:-0.72909
# [81]	validation_0-mlogloss:1.22785	validation_0-custom_f1_score:-0.72936
# [82]	validation_0-mlogloss:1.22621	validation_0-custom_f1_score:-0.72952
# [83]	validation_0-mlogloss:1.22463	validation_0-custom_f1_score:-0.72944
# [84]	validation_0-mlogloss:1.22298	validation_0-custom_f1_score:-0.72938
# [85]	validation_0-mlogloss:1.22136	validation_0-custom_f1_score:-0.72926
# [86]	validation_0-mlogloss:1.21977	validation_0-custom_f1_score:-0.72957
# [87]	validation_0-mlogloss:1.21820	validation_0-custom_f1_score:-0.72966
# [88]	validation_0-mlogloss:1.21661	validation_0-custom_f1_score:-0.72971
# [89]	validation_0-mlogloss:1.21504	validation_0-custom_f1_score:-0.72987
# [90]	validation_0-mlogloss:1.21352	validation_0-custom_f1_score:-0.72986
# [91]	validation_0-mlogloss:1.21198	validation_0-custom_f1_score:-0.72979
# [92]	validation_0-mlogloss:1.21040	validation_0-custom_f1_score:-0.72959
# [93]	validation_0-mlogloss:1.20885	validation_0-custom_f1_score:-0.72991
# [94]	validation_0-mlogloss:1.20732	validation_0-custom_f1_score:-0.72986
# [95]	validation_0-mlogloss:1.20578	validation_0-custom_f1_score:-0.72982
# [96]	validation_0-mlogloss:1.20425	validation_0-custom_f1_score:-0.72994
# [97]	validation_0-mlogloss:1.20267	validation_0-custom_f1_score:-0.73022
# [98]	validation_0-mlogloss:1.20111	validation_0-custom_f1_score:-0.73028
# [99]	validation_0-mlogloss:1.19962	validation_0-custom_f1_score:-0.73047
# [100]	validation_0-mlogloss:1.19810	validation_0-custom_f1_score:-0.73080
# [101]	validation_0-mlogloss:1.19659	validation_0-custom_f1_score:-0.73090
# [102]	validation_0-mlogloss:1.19512	validation_0-custom_f1_score:-0.73110
# [103]	validation_0-mlogloss:1.19359	validation_0-custom_f1_score:-0.73088
# [104]	validation_0-mlogloss:1.19211	validation_0-custom_f1_score:-0.73068
# [105]	validation_0-mlogloss:1.19063	validation_0-custom_f1_score:-0.73066
# [106]	validation_0-mlogloss:1.18914	validation_0-custom_f1_score:-0.73058
# [107]	validation_0-mlogloss:1.18766	validation_0-custom_f1_score:-0.73061
# [108]	validation_0-mlogloss:1.18616	validation_0-custom_f1_score:-0.73092
# [109]	validation_0-mlogloss:1.18468	validation_0-custom_f1_score:-0.73087
# [110]	validation_0-mlogloss:1.18324	validation_0-custom_f1_score:-0.73079
# [111]	validation_0-mlogloss:1.18184	validation_0-custom_f1_score:-0.73079
# [112]	validation_0-mlogloss:1.18040	validation_0-custom_f1_score:-0.73083
# [113]	validation_0-mlogloss:1.17895	validation_0-custom_f1_score:-0.73066
# [114]	validation_0-mlogloss:1.17755	validation_0-custom_f1_score:-0.73096
# [115]	validation_0-mlogloss:1.17610	validation_0-custom_f1_score:-0.73117
# [116]	validation_0-mlogloss:1.17468	validation_0-custom_f1_score:-0.73111
# [117]	validation_0-mlogloss:1.17323	validation_0-custom_f1_score:-0.73101
# [118]	validation_0-mlogloss:1.17181	validation_0-custom_f1_score:-0.73120
# [119]	validation_0-mlogloss:1.17037	validation_0-custom_f1_score:-0.73143
# [120]	validation_0-mlogloss:1.16897	validation_0-custom_f1_score:-0.73140
# [121]	validation_0-mlogloss:1.16758	validation_0-custom_f1_score:-0.73141
# [122]	validation_0-mlogloss:1.16621	validation_0-custom_f1_score:-0.73124
# [123]	validation_0-mlogloss:1.16481	validation_0-custom_f1_score:-0.73145
# [124]	validation_0-mlogloss:1.16340	validation_0-custom_f1_score:-0.73146
# [125]	validation_0-mlogloss:1.16200	validation_0-custom_f1_score:-0.73171
# [126]	validation_0-mlogloss:1.16061	validation_0-custom_f1_score:-0.73194
# [127]	validation_0-mlogloss:1.15920	validation_0-custom_f1_score:-0.73181
# [128]	validation_0-mlogloss:1.15784	validation_0-custom_f1_score:-0.73189
# [129]	validation_0-mlogloss:1.15652	validation_0-custom_f1_score:-0.73227
# [130]	validation_0-mlogloss:1.15517	validation_0-custom_f1_score:-0.73236
# [131]	validation_0-mlogloss:1.15380	validation_0-custom_f1_score:-0.73226
# [132]	validation_0-mlogloss:1.15244	validation_0-custom_f1_score:-0.73223
# [133]	validation_0-mlogloss:1.15115	validation_0-custom_f1_score:-0.73218
# [134]	validation_0-mlogloss:1.14983	validation_0-custom_f1_score:-0.73232
# [135]	validation_0-mlogloss:1.14856	validation_0-custom_f1_score:-0.73238
# [136]	validation_0-mlogloss:1.14726	validation_0-custom_f1_score:-0.73231
# [137]	validation_0-mlogloss:1.14591	validation_0-custom_f1_score:-0.73262
# [138]	validation_0-mlogloss:1.14463	validation_0-custom_f1_score:-0.73261
# [139]	validation_0-mlogloss:1.14333	validation_0-custom_f1_score:-0.73280
# [140]	validation_0-mlogloss:1.14202	validation_0-custom_f1_score:-0.73270
# [141]	validation_0-mlogloss:1.14075	validation_0-custom_f1_score:-0.73291
# [142]	validation_0-mlogloss:1.13940	validation_0-custom_f1_score:-0.73295
# [143]	validation_0-mlogloss:1.13808	validation_0-custom_f1_score:-0.73283
# [144]	validation_0-mlogloss:1.13679	validation_0-custom_f1_score:-0.73271
# [145]	validation_0-mlogloss:1.13552	validation_0-custom_f1_score:-0.73277
# [146]	validation_0-mlogloss:1.13423	validation_0-custom_f1_score:-0.73288
# [147]	validation_0-mlogloss:1.13293	validation_0-custom_f1_score:-0.73286
# [148]	validation_0-mlogloss:1.13170	validation_0-custom_f1_score:-0.73279
# [149]	validation_0-mlogloss:1.13041	validation_0-custom_f1_score:-0.73324
# [150]	validation_0-mlogloss:1.12917	validation_0-custom_f1_score:-0.73314
# [151]	validation_0-mlogloss:1.12794	validation_0-custom_f1_score:-0.73347
# [152]	validation_0-mlogloss:1.12667	validation_0-custom_f1_score:-0.73336
# [153]	validation_0-mlogloss:1.12540	validation_0-custom_f1_score:-0.73348
# [154]	validation_0-mlogloss:1.12416	validation_0-custom_f1_score:-0.73343
# [155]	validation_0-mlogloss:1.12294	validation_0-custom_f1_score:-0.73341
# [156]	validation_0-mlogloss:1.12168	validation_0-custom_f1_score:-0.73337
# [157]	validation_0-mlogloss:1.12044	validation_0-custom_f1_score:-0.73357
# [158]	validation_0-mlogloss:1.11916	validation_0-custom_f1_score:-0.73356
# [159]	validation_0-mlogloss:1.11796	validation_0-custom_f1_score:-0.73367
# [160]	validation_0-mlogloss:1.11673	validation_0-custom_f1_score:-0.73374
# [161]	validation_0-mlogloss:1.11553	validation_0-custom_f1_score:-0.73374
# [162]	validation_0-mlogloss:1.11435	validation_0-custom_f1_score:-0.73391
# [163]	validation_0-mlogloss:1.11312	validation_0-custom_f1_score:-0.73374
# [164]	validation_0-mlogloss:1.11189	validation_0-custom_f1_score:-0.73405
# [165]	validation_0-mlogloss:1.11070	validation_0-custom_f1_score:-0.73398
# [166]	validation_0-mlogloss:1.10951	validation_0-custom_f1_score:-0.73396
# [167]	validation_0-mlogloss:1.10831	validation_0-custom_f1_score:-0.73404
# [168]	validation_0-mlogloss:1.10710	validation_0-custom_f1_score:-0.73406
# [169]	validation_0-mlogloss:1.10590	validation_0-custom_f1_score:-0.73424
# [170]	validation_0-mlogloss:1.10473	validation_0-custom_f1_score:-0.73428
# [171]	validation_0-mlogloss:1.10354	validation_0-custom_f1_score:-0.73430
# [172]	validation_0-mlogloss:1.10236	validation_0-custom_f1_score:-0.73445
# [173]	validation_0-mlogloss:1.10117	validation_0-custom_f1_score:-0.73447
# [174]	validation_0-mlogloss:1.10000	validation_0-custom_f1_score:-0.73445
# [175]	validation_0-mlogloss:1.09881	validation_0-custom_f1_score:-0.73444
# [176]	validation_0-mlogloss:1.09762	validation_0-custom_f1_score:-0.73456
# [177]	validation_0-mlogloss:1.09644	validation_0-custom_f1_score:-0.73456
# [178]	validation_0-mlogloss:1.09530	validation_0-custom_f1_score:-0.73476
# [179]	validation_0-mlogloss:1.09417	validation_0-custom_f1_score:-0.73494
# [180]	validation_0-mlogloss:1.09301	validation_0-custom_f1_score:-0.73478
# [181]	validation_0-mlogloss:1.09187	validation_0-custom_f1_score:-0.73478
# [182]	validation_0-mlogloss:1.09068	validation_0-custom_f1_score:-0.73493
# [183]	validation_0-mlogloss:1.08951	validation_0-custom_f1_score:-0.73485
# [184]	validation_0-mlogloss:1.08837	validation_0-custom_f1_score:-0.73498
# [185]	validation_0-mlogloss:1.08720	validation_0-custom_f1_score:-0.73499
# [186]	validation_0-mlogloss:1.08607	validation_0-custom_f1_score:-0.73515
# [187]	validation_0-mlogloss:1.08494	validation_0-custom_f1_score:-0.73508
# [188]	validation_0-mlogloss:1.08380	validation_0-custom_f1_score:-0.73530
# [189]	validation_0-mlogloss:1.08267	validation_0-custom_f1_score:-0.73561
# [190]	validation_0-mlogloss:1.08154	validation_0-custom_f1_score:-0.73559
# [191]	validation_0-mlogloss:1.08044	validation_0-custom_f1_score:-0.73564
# [192]	validation_0-mlogloss:1.07936	validation_0-custom_f1_score:-0.73563
# [193]	validation_0-mlogloss:1.07827	validation_0-custom_f1_score:-0.73595
# [194]	validation_0-mlogloss:1.07717	validation_0-custom_f1_score:-0.73577
# [195]	validation_0-mlogloss:1.07611	validation_0-custom_f1_score:-0.73563
# [196]	validation_0-mlogloss:1.07505	validation_0-custom_f1_score:-0.73593
# [197]	validation_0-mlogloss:1.07394	validation_0-custom_f1_score:-0.73603
# [198]	validation_0-mlogloss:1.07287	validation_0-custom_f1_score:-0.73595
# [199]	validation_0-mlogloss:1.07178	validation_0-custom_f1_score:-0.73601
# [200]	validation_0-mlogloss:1.07078	validation_0-custom_f1_score:-0.73604
# [201]	validation_0-mlogloss:1.06969	validation_0-custom_f1_score:-0.73619
# [202]	validation_0-mlogloss:1.06863	validation_0-custom_f1_score:-0.73604
# [203]	validation_0-mlogloss:1.06757	validation_0-custom_f1_score:-0.73611
# [204]	validation_0-mlogloss:1.06651	validation_0-custom_f1_score:-0.73610
# [205]	validation_0-mlogloss:1.06547	validation_0-custom_f1_score:-0.73603
# [206]	validation_0-mlogloss:1.06441	validation_0-custom_f1_score:-0.73604
# [207]	validation_0-mlogloss:1.06338	validation_0-custom_f1_score:-0.73594
# [208]	validation_0-mlogloss:1.06233	validation_0-custom_f1_score:-0.73609
# [209]	validation_0-mlogloss:1.06128	validation_0-custom_f1_score:-0.73628
# [210]	validation_0-mlogloss:1.06024	validation_0-custom_f1_score:-0.73639
# [211]	validation_0-mlogloss:1.05921	validation_0-custom_f1_score:-0.73634
# [212]	validation_0-mlogloss:1.05818	validation_0-custom_f1_score:-0.73650
# [213]	validation_0-mlogloss:1.05717	validation_0-custom_f1_score:-0.73649
# [214]	validation_0-mlogloss:1.05613	validation_0-custom_f1_score:-0.73678
# [215]	validation_0-mlogloss:1.05508	validation_0-custom_f1_score:-0.73674
# [216]	validation_0-mlogloss:1.05409	validation_0-custom_f1_score:-0.73687
# [217]	validation_0-mlogloss:1.05302	validation_0-custom_f1_score:-0.73685
# [218]	validation_0-mlogloss:1.05203	validation_0-custom_f1_score:-0.73674
# [219]	validation_0-mlogloss:1.05094	validation_0-custom_f1_score:-0.73681
# [220]	validation_0-mlogloss:1.04990	validation_0-custom_f1_score:-0.73695
# [221]	validation_0-mlogloss:1.04890	validation_0-custom_f1_score:-0.73702
# [222]	validation_0-mlogloss:1.04788	validation_0-custom_f1_score:-0.73689
# [223]	validation_0-mlogloss:1.04689	validation_0-custom_f1_score:-0.73699
# [224]	validation_0-mlogloss:1.04589	validation_0-custom_f1_score:-0.73707
# [225]	validation_0-mlogloss:1.04488	validation_0-custom_f1_score:-0.73722
# [226]	validation_0-mlogloss:1.04390	validation_0-custom_f1_score:-0.73702
# [227]	validation_0-mlogloss:1.04290	validation_0-custom_f1_score:-0.73741
# [228]	validation_0-mlogloss:1.04192	validation_0-custom_f1_score:-0.73723
# [229]	validation_0-mlogloss:1.04095	validation_0-custom_f1_score:-0.73735
# [230]	validation_0-mlogloss:1.03997	validation_0-custom_f1_score:-0.73750
# [231]	validation_0-mlogloss:1.03900	validation_0-custom_f1_score:-0.73750
# [232]	validation_0-mlogloss:1.03804	validation_0-custom_f1_score:-0.73772
# [233]	validation_0-mlogloss:1.03706	validation_0-custom_f1_score:-0.73772
# [234]	validation_0-mlogloss:1.03613	validation_0-custom_f1_score:-0.73766
# [235]	validation_0-mlogloss:1.03516	validation_0-custom_f1_score:-0.73769
# [236]	validation_0-mlogloss:1.03420	validation_0-custom_f1_score:-0.73775
# [237]	validation_0-mlogloss:1.03324	validation_0-custom_f1_score:-0.73784
# [238]	validation_0-mlogloss:1.03228	validation_0-custom_f1_score:-0.73789
# [239]	validation_0-mlogloss:1.03135	validation_0-custom_f1_score:-0.73783
# [240]	validation_0-mlogloss:1.03042	validation_0-custom_f1_score:-0.73794
# [241]	validation_0-mlogloss:1.02948	validation_0-custom_f1_score:-0.73804
# [242]	validation_0-mlogloss:1.02856	validation_0-custom_f1_score:-0.73803
# [243]	validation_0-mlogloss:1.02762	validation_0-custom_f1_score:-0.73823
# [244]	validation_0-mlogloss:1.02672	validation_0-custom_f1_score:-0.73847
# [245]	validation_0-mlogloss:1.02574	validation_0-custom_f1_score:-0.73842
# [246]	validation_0-mlogloss:1.02483	validation_0-custom_f1_score:-0.73842
# [247]	validation_0-mlogloss:1.02389	validation_0-custom_f1_score:-0.73843
# [248]	validation_0-mlogloss:1.02295	validation_0-custom_f1_score:-0.73858
# [249]	validation_0-mlogloss:1.02197	validation_0-custom_f1_score:-0.73878
# [250]	validation_0-mlogloss:1.02108	validation_0-custom_f1_score:-0.73884
# [251]	validation_0-mlogloss:1.02017	validation_0-custom_f1_score:-0.73887
# [252]	validation_0-mlogloss:1.01923	validation_0-custom_f1_score:-0.73882
# [253]	validation_0-mlogloss:1.01832	validation_0-custom_f1_score:-0.73885
# [254]	validation_0-mlogloss:1.01741	validation_0-custom_f1_score:-0.73888
# [255]	validation_0-mlogloss:1.01649	validation_0-custom_f1_score:-0.73898
# [256]	validation_0-mlogloss:1.01557	validation_0-custom_f1_score:-0.73908
# [257]	validation_0-mlogloss:1.01472	validation_0-custom_f1_score:-0.73899
# [258]	validation_0-mlogloss:1.01384	validation_0-custom_f1_score:-0.73902
# [259]	validation_0-mlogloss:1.01296	validation_0-custom_f1_score:-0.73912
# [260]	validation_0-mlogloss:1.01205	validation_0-custom_f1_score:-0.73915
# [261]	validation_0-mlogloss:1.01114	validation_0-custom_f1_score:-0.73912
# [262]	validation_0-mlogloss:1.01024	validation_0-custom_f1_score:-0.73928
# [263]	validation_0-mlogloss:1.00937	validation_0-custom_f1_score:-0.73926
# [264]	validation_0-mlogloss:1.00845	validation_0-custom_f1_score:-0.73939
# [265]	validation_0-mlogloss:1.00756	validation_0-custom_f1_score:-0.73947
# [266]	validation_0-mlogloss:1.00668	validation_0-custom_f1_score:-0.73943
# [267]	validation_0-mlogloss:1.00578	validation_0-custom_f1_score:-0.73943
# [268]	validation_0-mlogloss:1.00487	validation_0-custom_f1_score:-0.73968
# [269]	validation_0-mlogloss:1.00402	validation_0-custom_f1_score:-0.73972
# [270]	validation_0-mlogloss:1.00312	validation_0-custom_f1_score:-0.74000
# [271]	validation_0-mlogloss:1.00223	validation_0-custom_f1_score:-0.74020
# [272]	validation_0-mlogloss:1.00135	validation_0-custom_f1_score:-0.74030
# [273]	validation_0-mlogloss:1.00051	validation_0-custom_f1_score:-0.74034
# [274]	validation_0-mlogloss:0.99965	validation_0-custom_f1_score:-0.74054
# [275]	validation_0-mlogloss:0.99881	validation_0-custom_f1_score:-0.74074
# [276]	validation_0-mlogloss:0.99794	validation_0-custom_f1_score:-0.74065
# [277]	validation_0-mlogloss:0.99708	validation_0-custom_f1_score:-0.74061
# [278]	validation_0-mlogloss:0.99623	validation_0-custom_f1_score:-0.74068
# [279]	validation_0-mlogloss:0.99540	validation_0-custom_f1_score:-0.74061
# [280]	validation_0-mlogloss:0.99458	validation_0-custom_f1_score:-0.74052
# [281]	validation_0-mlogloss:0.99375	validation_0-custom_f1_score:-0.74073
# [282]	validation_0-mlogloss:0.99294	validation_0-custom_f1_score:-0.74074
# [283]	validation_0-mlogloss:0.99209	validation_0-custom_f1_score:-0.74083
# [284]	validation_0-mlogloss:0.99127	validation_0-custom_f1_score:-0.74082
# [285]	validation_0-mlogloss:0.99039	validation_0-custom_f1_score:-0.74095
# [286]	validation_0-mlogloss:0.98955	validation_0-custom_f1_score:-0.74089
# [287]	validation_0-mlogloss:0.98873	validation_0-custom_f1_score:-0.74094
# [288]	validation_0-mlogloss:0.98792	validation_0-custom_f1_score:-0.74108
# [289]	validation_0-mlogloss:0.98709	validation_0-custom_f1_score:-0.74113
# [290]	validation_0-mlogloss:0.98623	validation_0-custom_f1_score:-0.74115
# [291]	validation_0-mlogloss:0.98542	validation_0-custom_f1_score:-0.74124
# [292]	validation_0-mlogloss:0.98462	validation_0-custom_f1_score:-0.74126
# [293]	validation_0-mlogloss:0.98382	validation_0-custom_f1_score:-0.74150
# [294]	validation_0-mlogloss:0.98304	validation_0-custom_f1_score:-0.74153
# [295]	validation_0-mlogloss:0.98220	validation_0-custom_f1_score:-0.74154
# [296]	validation_0-mlogloss:0.98139	validation_0-custom_f1_score:-0.74150
# [297]	validation_0-mlogloss:0.98059	validation_0-custom_f1_score:-0.74162
# [298]	validation_0-mlogloss:0.97980	validation_0-custom_f1_score:-0.74178
# [299]	validation_0-mlogloss:0.97901	validation_0-custom_f1_score:-0.74165
# [300]	validation_0-mlogloss:0.97820	validation_0-custom_f1_score:-0.74169
# [301]	validation_0-mlogloss:0.97741	validation_0-custom_f1_score:-0.74171
# [302]	validation_0-mlogloss:0.97663	validation_0-custom_f1_score:-0.74176
# [303]	validation_0-mlogloss:0.97579	validation_0-custom_f1_score:-0.74186
# [304]	validation_0-mlogloss:0.97499	validation_0-custom_f1_score:-0.74196
# [305]	validation_0-mlogloss:0.97419	validation_0-custom_f1_score:-0.74203
# [306]	validation_0-mlogloss:0.97340	validation_0-custom_f1_score:-0.74209
# [307]	validation_0-mlogloss:0.97264	validation_0-custom_f1_score:-0.74217
# [308]	validation_0-mlogloss:0.97186	validation_0-custom_f1_score:-0.74227
# [309]	validation_0-mlogloss:0.97112	validation_0-custom_f1_score:-0.74217
# [310]	validation_0-mlogloss:0.97032	validation_0-custom_f1_score:-0.74238
# [311]	validation_0-mlogloss:0.96957	validation_0-custom_f1_score:-0.74242
# [312]	validation_0-mlogloss:0.96878	validation_0-custom_f1_score:-0.74252
# [313]	validation_0-mlogloss:0.96803	validation_0-custom_f1_score:-0.74266
# [314]	validation_0-mlogloss:0.96726	validation_0-custom_f1_score:-0.74265
# [315]	validation_0-mlogloss:0.96649	validation_0-custom_f1_score:-0.74282
# [316]	validation_0-mlogloss:0.96573	validation_0-custom_f1_score:-0.74265
# [317]	validation_0-mlogloss:0.96495	validation_0-custom_f1_score:-0.74282
# [318]	validation_0-mlogloss:0.96420	validation_0-custom_f1_score:-0.74291
# [319]	validation_0-mlogloss:0.96346	validation_0-custom_f1_score:-0.74285
# [320]	validation_0-mlogloss:0.96269	validation_0-custom_f1_score:-0.74302
# [321]	validation_0-mlogloss:0.96195	validation_0-custom_f1_score:-0.74304
# [322]	validation_0-mlogloss:0.96118	validation_0-custom_f1_score:-0.74315
# [323]	validation_0-mlogloss:0.96042	validation_0-custom_f1_score:-0.74328
# [324]	validation_0-mlogloss:0.95966	validation_0-custom_f1_score:-0.74343
# [325]	validation_0-mlogloss:0.95892	validation_0-custom_f1_score:-0.74346
# [326]	validation_0-mlogloss:0.95819	validation_0-custom_f1_score:-0.74348
# [327]	validation_0-mlogloss:0.95747	validation_0-custom_f1_score:-0.74345
# [328]	validation_0-mlogloss:0.95673	validation_0-custom_f1_score:-0.74341
# [329]	validation_0-mlogloss:0.95603	validation_0-custom_f1_score:-0.74348
# [330]	validation_0-mlogloss:0.95532	validation_0-custom_f1_score:-0.74325
# [331]	validation_0-mlogloss:0.95460	validation_0-custom_f1_score:-0.74344
# [332]	validation_0-mlogloss:0.95390	validation_0-custom_f1_score:-0.74339
# [333]	validation_0-mlogloss:0.95313	validation_0-custom_f1_score:-0.74360
# [334]	validation_0-mlogloss:0.95242	validation_0-custom_f1_score:-0.74367
# [335]	validation_0-mlogloss:0.95171	validation_0-custom_f1_score:-0.74366
# [336]	validation_0-mlogloss:0.95099	validation_0-custom_f1_score:-0.74372
# [337]	validation_0-mlogloss:0.95030	validation_0-custom_f1_score:-0.74376
# [338]	validation_0-mlogloss:0.94956	validation_0-custom_f1_score:-0.74390
# [339]	validation_0-mlogloss:0.94881	validation_0-custom_f1_score:-0.74389
# [340]	validation_0-mlogloss:0.94806	validation_0-custom_f1_score:-0.74397
# [341]	validation_0-mlogloss:0.94736	validation_0-custom_f1_score:-0.74408
# [342]	validation_0-mlogloss:0.94666	validation_0-custom_f1_score:-0.74430
# [343]	validation_0-mlogloss:0.94600	validation_0-custom_f1_score:-0.74421
# [344]	validation_0-mlogloss:0.94527	validation_0-custom_f1_score:-0.74428
# [345]	validation_0-mlogloss:0.94457	validation_0-custom_f1_score:-0.74433
# [346]	validation_0-mlogloss:0.94387	validation_0-custom_f1_score:-0.74440
# [347]	validation_0-mlogloss:0.94316	validation_0-custom_f1_score:-0.74457
# [348]	validation_0-mlogloss:0.94247	validation_0-custom_f1_score:-0.74455
# [349]	validation_0-mlogloss:0.94178	validation_0-custom_f1_score:-0.74462
# [350]	validation_0-mlogloss:0.94108	validation_0-custom_f1_score:-0.74466
# [351]	validation_0-mlogloss:0.94039	validation_0-custom_f1_score:-0.74455
# [352]	validation_0-mlogloss:0.93970	validation_0-custom_f1_score:-0.74467
# [353]	validation_0-mlogloss:0.93901	validation_0-custom_f1_score:-0.74473
# [354]	validation_0-mlogloss:0.93835	validation_0-custom_f1_score:-0.74481
# [355]	validation_0-mlogloss:0.93765	validation_0-custom_f1_score:-0.74480
# [356]	validation_0-mlogloss:0.93700	validation_0-custom_f1_score:-0.74470
# [357]	validation_0-mlogloss:0.93634	validation_0-custom_f1_score:-0.74461
# [358]	validation_0-mlogloss:0.93565	validation_0-custom_f1_score:-0.74479
# [359]	validation_0-mlogloss:0.93498	validation_0-custom_f1_score:-0.74504
# [360]	validation_0-mlogloss:0.93432	validation_0-custom_f1_score:-0.74502
# [361]	validation_0-mlogloss:0.93367	validation_0-custom_f1_score:-0.74516
# [362]	validation_0-mlogloss:0.93298	validation_0-custom_f1_score:-0.74522
# [363]	validation_0-mlogloss:0.93229	validation_0-custom_f1_score:-0.74536
# [364]	validation_0-mlogloss:0.93163	validation_0-custom_f1_score:-0.74525
# [365]	validation_0-mlogloss:0.93098	validation_0-custom_f1_score:-0.74542
# [366]	validation_0-mlogloss:0.93031	validation_0-custom_f1_score:-0.74543
# [367]	validation_0-mlogloss:0.92966	validation_0-custom_f1_score:-0.74545
# [368]	validation_0-mlogloss:0.92902	validation_0-custom_f1_score:-0.74549
# [369]	validation_0-mlogloss:0.92836	validation_0-custom_f1_score:-0.74549
# [370]	validation_0-mlogloss:0.92773	validation_0-custom_f1_score:-0.74566
# [371]	validation_0-mlogloss:0.92710	validation_0-custom_f1_score:-0.74579
# [372]	validation_0-mlogloss:0.92646	validation_0-custom_f1_score:-0.74570
# [373]	validation_0-mlogloss:0.92580	validation_0-custom_f1_score:-0.74579
# [374]	validation_0-mlogloss:0.92516	validation_0-custom_f1_score:-0.74577
# [375]	validation_0-mlogloss:0.92453	validation_0-custom_f1_score:-0.74575
# [376]	validation_0-mlogloss:0.92389	validation_0-custom_f1_score:-0.74578
# [377]	validation_0-mlogloss:0.92327	validation_0-custom_f1_score:-0.74571
# [378]	validation_0-mlogloss:0.92268	validation_0-custom_f1_score:-0.74589
# [379]	validation_0-mlogloss:0.92205	validation_0-custom_f1_score:-0.74587
# [380]	validation_0-mlogloss:0.92142	validation_0-custom_f1_score:-0.74594
# [381]	validation_0-mlogloss:0.92082	validation_0-custom_f1_score:-0.74598
# [382]	validation_0-mlogloss:0.92019	validation_0-custom_f1_score:-0.74602
# [383]	validation_0-mlogloss:0.91954	validation_0-custom_f1_score:-0.74605
# [384]	validation_0-mlogloss:0.91891	validation_0-custom_f1_score:-0.74600
# [385]	validation_0-mlogloss:0.91828	validation_0-custom_f1_score:-0.74594
# [386]	validation_0-mlogloss:0.91765	validation_0-custom_f1_score:-0.74589
# [387]	validation_0-mlogloss:0.91699	validation_0-custom_f1_score:-0.74611
# [388]	validation_0-mlogloss:0.91641	validation_0-custom_f1_score:-0.74610
# [389]	validation_0-mlogloss:0.91578	validation_0-custom_f1_score:-0.74615
# [390]	validation_0-mlogloss:0.91520	validation_0-custom_f1_score:-0.74618
# [391]	validation_0-mlogloss:0.91452	validation_0-custom_f1_score:-0.74647
# [392]	validation_0-mlogloss:0.91393	validation_0-custom_f1_score:-0.74651
# [393]	validation_0-mlogloss:0.91328	validation_0-custom_f1_score:-0.74657
# [394]	validation_0-mlogloss:0.91264	validation_0-custom_f1_score:-0.74670
# [395]	validation_0-mlogloss:0.91203	validation_0-custom_f1_score:-0.74667
# [396]	validation_0-mlogloss:0.91143	validation_0-custom_f1_score:-0.74668
# [397]	validation_0-mlogloss:0.91084	validation_0-custom_f1_score:-0.74669
# [398]	validation_0-mlogloss:0.91025	validation_0-custom_f1_score:-0.74679
# [399]	validation_0-mlogloss:0.90967	validation_0-custom_f1_score:-0.74694
# [400]	validation_0-mlogloss:0.90906	validation_0-custom_f1_score:-0.74706
# [401]	validation_0-mlogloss:0.90848	validation_0-custom_f1_score:-0.74703
# [402]	validation_0-mlogloss:0.90785	validation_0-custom_f1_score:-0.74707
# [403]	validation_0-mlogloss:0.90728	validation_0-custom_f1_score:-0.74705
# [404]	validation_0-mlogloss:0.90669	validation_0-custom_f1_score:-0.74710
# [405]	validation_0-mlogloss:0.90609	validation_0-custom_f1_score:-0.74720
# [406]	validation_0-mlogloss:0.90550	validation_0-custom_f1_score:-0.74726
# [407]	validation_0-mlogloss:0.90491	validation_0-custom_f1_score:-0.74735
# [408]	validation_0-mlogloss:0.90435	validation_0-custom_f1_score:-0.74728
# [409]	validation_0-mlogloss:0.90375	validation_0-custom_f1_score:-0.74746
# [410]	validation_0-mlogloss:0.90318	validation_0-custom_f1_score:-0.74757
# [411]	validation_0-mlogloss:0.90257	validation_0-custom_f1_score:-0.74783
# [412]	validation_0-mlogloss:0.90200	validation_0-custom_f1_score:-0.74801
# [413]	validation_0-mlogloss:0.90141	validation_0-custom_f1_score:-0.74799
# [414]	validation_0-mlogloss:0.90083	validation_0-custom_f1_score:-0.74798
# [415]	validation_0-mlogloss:0.90024	validation_0-custom_f1_score:-0.74797
# [416]	validation_0-mlogloss:0.89966	validation_0-custom_f1_score:-0.74806
# [417]	validation_0-mlogloss:0.89907	validation_0-custom_f1_score:-0.74813
# [418]	validation_0-mlogloss:0.89849	validation_0-custom_f1_score:-0.74827
# [419]	validation_0-mlogloss:0.89790	validation_0-custom_f1_score:-0.74823
# [420]	validation_0-mlogloss:0.89733	validation_0-custom_f1_score:-0.74849
# [421]	validation_0-mlogloss:0.89680	validation_0-custom_f1_score:-0.74834
# [422]	validation_0-mlogloss:0.89622	validation_0-custom_f1_score:-0.74838
# [423]	validation_0-mlogloss:0.89565	validation_0-custom_f1_score:-0.74839
# [424]	validation_0-mlogloss:0.89507	validation_0-custom_f1_score:-0.74852
# [425]	validation_0-mlogloss:0.89454	validation_0-custom_f1_score:-0.74857
# [426]	validation_0-mlogloss:0.89397	validation_0-custom_f1_score:-0.74855
# [427]	validation_0-mlogloss:0.89338	validation_0-custom_f1_score:-0.74869
# [428]	validation_0-mlogloss:0.89281	validation_0-custom_f1_score:-0.74867
# [429]	validation_0-mlogloss:0.89226	validation_0-custom_f1_score:-0.74883
# [430]	validation_0-mlogloss:0.89170	validation_0-custom_f1_score:-0.74877
# [431]	validation_0-mlogloss:0.89116	validation_0-custom_f1_score:-0.74878
# [432]	validation_0-mlogloss:0.89062	validation_0-custom_f1_score:-0.74889
# [433]	validation_0-mlogloss:0.89010	validation_0-custom_f1_score:-0.74891
# [434]	validation_0-mlogloss:0.88954	validation_0-custom_f1_score:-0.74897
# [435]	validation_0-mlogloss:0.88898	validation_0-custom_f1_score:-0.74898
# [436]	validation_0-mlogloss:0.88841	validation_0-custom_f1_score:-0.74916
# [437]	validation_0-mlogloss:0.88784	validation_0-custom_f1_score:-0.74922
# [438]	validation_0-mlogloss:0.88729	validation_0-custom_f1_score:-0.74932
# [439]	validation_0-mlogloss:0.88679	validation_0-custom_f1_score:-0.74933
# [440]	validation_0-mlogloss:0.88627	validation_0-custom_f1_score:-0.74933
# [441]	validation_0-mlogloss:0.88572	validation_0-custom_f1_score:-0.74922
# [442]	validation_0-mlogloss:0.88518	validation_0-custom_f1_score:-0.74935
# [443]	validation_0-mlogloss:0.88466	validation_0-custom_f1_score:-0.74937
# [444]	validation_0-mlogloss:0.88410	validation_0-custom_f1_score:-0.74964
# [445]	validation_0-mlogloss:0.88358	validation_0-custom_f1_score:-0.74953
# [446]	validation_0-mlogloss:0.88306	validation_0-custom_f1_score:-0.74951
# [447]	validation_0-mlogloss:0.88253	validation_0-custom_f1_score:-0.74960
# [448]	validation_0-mlogloss:0.88202	validation_0-custom_f1_score:-0.74956
# [449]	validation_0-mlogloss:0.88153	validation_0-custom_f1_score:-0.74954
# [450]	validation_0-mlogloss:0.88104	validation_0-custom_f1_score:-0.74971
# [451]	validation_0-mlogloss:0.88054	validation_0-custom_f1_score:-0.74969
# [452]	validation_0-mlogloss:0.88003	validation_0-custom_f1_score:-0.74978
# [453]	validation_0-mlogloss:0.87951	validation_0-custom_f1_score:-0.74973
# [454]	validation_0-mlogloss:0.87897	validation_0-custom_f1_score:-0.74982
# [455]	validation_0-mlogloss:0.87843	validation_0-custom_f1_score:-0.74989
# [456]	validation_0-mlogloss:0.87792	validation_0-custom_f1_score:-0.74996
# [457]	validation_0-mlogloss:0.87739	validation_0-custom_f1_score:-0.74998
# [458]	validation_0-mlogloss:0.87691	validation_0-custom_f1_score:-0.75007
# [459]	validation_0-mlogloss:0.87640	validation_0-custom_f1_score:-0.74994
# [460]	validation_0-mlogloss:0.87589	validation_0-custom_f1_score:-0.74998
# [461]	validation_0-mlogloss:0.87539	validation_0-custom_f1_score:-0.75015
# [462]	validation_0-mlogloss:0.87488	validation_0-custom_f1_score:-0.75007
# [463]	validation_0-mlogloss:0.87437	validation_0-custom_f1_score:-0.75025
# [464]	validation_0-mlogloss:0.87386	validation_0-custom_f1_score:-0.75026
# [465]	validation_0-mlogloss:0.87336	validation_0-custom_f1_score:-0.75015
# [466]	validation_0-mlogloss:0.87286	validation_0-custom_f1_score:-0.75017
# [467]	validation_0-mlogloss:0.87236	validation_0-custom_f1_score:-0.75042
# [468]	validation_0-mlogloss:0.87185	validation_0-custom_f1_score:-0.75045
# [469]	validation_0-mlogloss:0.87134	validation_0-custom_f1_score:-0.75047
# [470]	validation_0-mlogloss:0.87086	validation_0-custom_f1_score:-0.75048
# [471]	validation_0-mlogloss:0.87036	validation_0-custom_f1_score:-0.75052
# [472]	validation_0-mlogloss:0.86985	validation_0-custom_f1_score:-0.75062
# [473]	validation_0-mlogloss:0.86935	validation_0-custom_f1_score:-0.75060
# [474]	validation_0-mlogloss:0.86885	validation_0-custom_f1_score:-0.75063
# [475]	validation_0-mlogloss:0.86835	validation_0-custom_f1_score:-0.75055
# [476]	validation_0-mlogloss:0.86789	validation_0-custom_f1_score:-0.75055
# [477]	validation_0-mlogloss:0.86740	validation_0-custom_f1_score:-0.75050
# [478]	validation_0-mlogloss:0.86691	validation_0-custom_f1_score:-0.75064
# [479]	validation_0-mlogloss:0.86646	validation_0-custom_f1_score:-0.75076
# [480]	validation_0-mlogloss:0.86597	validation_0-custom_f1_score:-0.75079
# [481]	validation_0-mlogloss:0.86549	validation_0-custom_f1_score:-0.75079
# [482]	validation_0-mlogloss:0.86499	validation_0-custom_f1_score:-0.75079
# [483]	validation_0-mlogloss:0.86451	validation_0-custom_f1_score:-0.75095
# [484]	validation_0-mlogloss:0.86405	validation_0-custom_f1_score:-0.75087
# [485]	validation_0-mlogloss:0.86354	validation_0-custom_f1_score:-0.75106
# [486]	validation_0-mlogloss:0.86308	validation_0-custom_f1_score:-0.75105
# [487]	validation_0-mlogloss:0.86262	validation_0-custom_f1_score:-0.75113
# [488]	validation_0-mlogloss:0.86215	validation_0-custom_f1_score:-0.75121
# [489]	validation_0-mlogloss:0.86168	validation_0-custom_f1_score:-0.75135
# [490]	validation_0-mlogloss:0.86122	validation_0-custom_f1_score:-0.75136
# [491]	validation_0-mlogloss:0.86076	validation_0-custom_f1_score:-0.75140
# [492]	validation_0-mlogloss:0.86030	validation_0-custom_f1_score:-0.75152
# [493]	validation_0-mlogloss:0.85980	validation_0-custom_f1_score:-0.75149
# [494]	validation_0-mlogloss:0.85932	validation_0-custom_f1_score:-0.75156
# [495]	validation_0-mlogloss:0.85887	validation_0-custom_f1_score:-0.75158
# [496]	validation_0-mlogloss:0.85838	validation_0-custom_f1_score:-0.75165
# [497]	validation_0-mlogloss:0.85790	validation_0-custom_f1_score:-0.75167
# [498]	validation_0-mlogloss:0.85745	validation_0-custom_f1_score:-0.75168
# [499]	validation_0-mlogloss:0.85700	validation_0-custom_f1_score:-0.75166
# [500]	validation_0-mlogloss:0.85655	validation_0-custom_f1_score:-0.75154
# [501]	validation_0-mlogloss:0.85607	validation_0-custom_f1_score:-0.75169
# [502]	validation_0-mlogloss:0.85561	validation_0-custom_f1_score:-0.75165
# [503]	validation_0-mlogloss:0.85517	validation_0-custom_f1_score:-0.75182
# [504]	validation_0-mlogloss:0.85470	validation_0-custom_f1_score:-0.75178
# [505]	validation_0-mlogloss:0.85423	validation_0-custom_f1_score:-0.75184
# [506]	validation_0-mlogloss:0.85376	validation_0-custom_f1_score:-0.75183
# [507]	validation_0-mlogloss:0.85329	validation_0-custom_f1_score:-0.75189
# [508]	validation_0-mlogloss:0.85282	validation_0-custom_f1_score:-0.75176
# [509]	validation_0-mlogloss:0.85236	validation_0-custom_f1_score:-0.75192
# [510]	validation_0-mlogloss:0.85189	validation_0-custom_f1_score:-0.75191
# [511]	validation_0-mlogloss:0.85140	validation_0-custom_f1_score:-0.75184
# [512]	validation_0-mlogloss:0.85096	validation_0-custom_f1_score:-0.75211
# [513]	validation_0-mlogloss:0.85050	validation_0-custom_f1_score:-0.75201
# [514]	validation_0-mlogloss:0.85006	validation_0-custom_f1_score:-0.75210
# [515]	validation_0-mlogloss:0.84959	validation_0-custom_f1_score:-0.75219
# [516]	validation_0-mlogloss:0.84916	validation_0-custom_f1_score:-0.75220
# [517]	validation_0-mlogloss:0.84874	validation_0-custom_f1_score:-0.75223
# [518]	validation_0-mlogloss:0.84833	validation_0-custom_f1_score:-0.75222
# [519]	validation_0-mlogloss:0.84786	validation_0-custom_f1_score:-0.75223
# [520]	validation_0-mlogloss:0.84741	validation_0-custom_f1_score:-0.75246
# [521]	validation_0-mlogloss:0.84694	validation_0-custom_f1_score:-0.75246
# [522]	validation_0-mlogloss:0.84650	validation_0-custom_f1_score:-0.75245
# [523]	validation_0-mlogloss:0.84606	validation_0-custom_f1_score:-0.75244
# [524]	validation_0-mlogloss:0.84566	validation_0-custom_f1_score:-0.75253
# [525]	validation_0-mlogloss:0.84524	validation_0-custom_f1_score:-0.75243
# [526]	validation_0-mlogloss:0.84482	validation_0-custom_f1_score:-0.75248
# [527]	validation_0-mlogloss:0.84439	validation_0-custom_f1_score:-0.75251
# [528]	validation_0-mlogloss:0.84394	validation_0-custom_f1_score:-0.75253
# [529]	validation_0-mlogloss:0.84352	validation_0-custom_f1_score:-0.75255
# [530]	validation_0-mlogloss:0.84309	validation_0-custom_f1_score:-0.75263
# [531]	validation_0-mlogloss:0.84266	validation_0-custom_f1_score:-0.75264
# [532]	validation_0-mlogloss:0.84222	validation_0-custom_f1_score:-0.75277
# [533]	validation_0-mlogloss:0.84178	validation_0-custom_f1_score:-0.75288
# [534]	validation_0-mlogloss:0.84135	validation_0-custom_f1_score:-0.75286
# [535]	validation_0-mlogloss:0.84091	validation_0-custom_f1_score:-0.75295
# [536]	validation_0-mlogloss:0.84049	validation_0-custom_f1_score:-0.75305
# [537]	validation_0-mlogloss:0.84009	validation_0-custom_f1_score:-0.75302
# [538]	validation_0-mlogloss:0.83966	validation_0-custom_f1_score:-0.75311
# [539]	validation_0-mlogloss:0.83925	validation_0-custom_f1_score:-0.75319
# [540]	validation_0-mlogloss:0.83886	validation_0-custom_f1_score:-0.75319
# [541]	validation_0-mlogloss:0.83843	validation_0-custom_f1_score:-0.75325
# [542]	validation_0-mlogloss:0.83802	validation_0-custom_f1_score:-0.75332
# [543]	validation_0-mlogloss:0.83759	validation_0-custom_f1_score:-0.75336
# [544]	validation_0-mlogloss:0.83717	validation_0-custom_f1_score:-0.75340
# [545]	validation_0-mlogloss:0.83677	validation_0-custom_f1_score:-0.75336
# [546]	validation_0-mlogloss:0.83638	validation_0-custom_f1_score:-0.75343
# [547]	validation_0-mlogloss:0.83598	validation_0-custom_f1_score:-0.75339
# [548]	validation_0-mlogloss:0.83557	validation_0-custom_f1_score:-0.75353
# [549]	validation_0-mlogloss:0.83515	validation_0-custom_f1_score:-0.75365
# [550]	validation_0-mlogloss:0.83473	validation_0-custom_f1_score:-0.75366
# [551]	validation_0-mlogloss:0.83430	validation_0-custom_f1_score:-0.75383
# [552]	validation_0-mlogloss:0.83390	validation_0-custom_f1_score:-0.75376
# [553]	validation_0-mlogloss:0.83348	validation_0-custom_f1_score:-0.75388
# [554]	validation_0-mlogloss:0.83307	validation_0-custom_f1_score:-0.75382
# [555]	validation_0-mlogloss:0.83270	validation_0-custom_f1_score:-0.75394
# [556]	validation_0-mlogloss:0.83232	validation_0-custom_f1_score:-0.75395
# [557]	validation_0-mlogloss:0.83190	validation_0-custom_f1_score:-0.75385
# [558]	validation_0-mlogloss:0.83149	validation_0-custom_f1_score:-0.75410
# [559]	validation_0-mlogloss:0.83106	validation_0-custom_f1_score:-0.75417
# [560]	validation_0-mlogloss:0.83066	validation_0-custom_f1_score:-0.75429
# [561]	validation_0-mlogloss:0.83024	validation_0-custom_f1_score:-0.75435
# [562]	validation_0-mlogloss:0.82982	validation_0-custom_f1_score:-0.75445
# [563]	validation_0-mlogloss:0.82944	validation_0-custom_f1_score:-0.75454
# [564]	validation_0-mlogloss:0.82905	validation_0-custom_f1_score:-0.75468
# [565]	validation_0-mlogloss:0.82862	validation_0-custom_f1_score:-0.75465
# [566]	validation_0-mlogloss:0.82825	validation_0-custom_f1_score:-0.75469
# [567]	validation_0-mlogloss:0.82787	validation_0-custom_f1_score:-0.75475
# [568]	validation_0-mlogloss:0.82752	validation_0-custom_f1_score:-0.75478
# [569]	validation_0-mlogloss:0.82715	validation_0-custom_f1_score:-0.75468
# [570]	validation_0-mlogloss:0.82678	validation_0-custom_f1_score:-0.75482
# [571]	validation_0-mlogloss:0.82638	validation_0-custom_f1_score:-0.75491
# [572]	validation_0-mlogloss:0.82599	validation_0-custom_f1_score:-0.75510
# [573]	validation_0-mlogloss:0.82563	validation_0-custom_f1_score:-0.75509
# [574]	validation_0-mlogloss:0.82526	validation_0-custom_f1_score:-0.75516
# [575]	validation_0-mlogloss:0.82488	validation_0-custom_f1_score:-0.75519
# [576]	validation_0-mlogloss:0.82446	validation_0-custom_f1_score:-0.75541
# [577]	validation_0-mlogloss:0.82411	validation_0-custom_f1_score:-0.75536
# [578]	validation_0-mlogloss:0.82369	validation_0-custom_f1_score:-0.75530
# [579]	validation_0-mlogloss:0.82331	validation_0-custom_f1_score:-0.75543
# [580]	validation_0-mlogloss:0.82294	validation_0-custom_f1_score:-0.75547
# [581]	validation_0-mlogloss:0.82259	validation_0-custom_f1_score:-0.75547
# [582]	validation_0-mlogloss:0.82219	validation_0-custom_f1_score:-0.75573
# [583]	validation_0-mlogloss:0.82182	validation_0-custom_f1_score:-0.75569
# [584]	validation_0-mlogloss:0.82142	validation_0-custom_f1_score:-0.75565
# [585]	validation_0-mlogloss:0.82106	validation_0-custom_f1_score:-0.75543
# [586]	validation_0-mlogloss:0.82068	validation_0-custom_f1_score:-0.75567
# [587]	validation_0-mlogloss:0.82033	validation_0-custom_f1_score:-0.75563
# [588]	validation_0-mlogloss:0.81997	validation_0-custom_f1_score:-0.75570
# [589]	validation_0-mlogloss:0.81959	validation_0-custom_f1_score:-0.75582
# [590]	validation_0-mlogloss:0.81921	validation_0-custom_f1_score:-0.75587
# [591]	validation_0-mlogloss:0.81883	validation_0-custom_f1_score:-0.75595
# [592]	validation_0-mlogloss:0.81845	validation_0-custom_f1_score:-0.75605
# [593]	validation_0-mlogloss:0.81807	validation_0-custom_f1_score:-0.75599
# [594]	validation_0-mlogloss:0.81770	validation_0-custom_f1_score:-0.75612
# [595]	validation_0-mlogloss:0.81730	validation_0-custom_f1_score:-0.75631
# [596]	validation_0-mlogloss:0.81695	validation_0-custom_f1_score:-0.75632
# [597]	validation_0-mlogloss:0.81662	validation_0-custom_f1_score:-0.75640
# [598]	validation_0-mlogloss:0.81626	validation_0-custom_f1_score:-0.75639
# [599]	validation_0-mlogloss:0.81589	validation_0-custom_f1_score:-0.75657
# [600]	validation_0-mlogloss:0.81550	validation_0-custom_f1_score:-0.75657
# [601]	validation_0-mlogloss:0.81514	validation_0-custom_f1_score:-0.75662
# [602]	validation_0-mlogloss:0.81479	validation_0-custom_f1_score:-0.75654
# [603]	validation_0-mlogloss:0.81444	validation_0-custom_f1_score:-0.75645
# [604]	validation_0-mlogloss:0.81405	validation_0-custom_f1_score:-0.75664
# [605]	validation_0-mlogloss:0.81368	validation_0-custom_f1_score:-0.75660
# [606]	validation_0-mlogloss:0.81333	validation_0-custom_f1_score:-0.75671
# [607]	validation_0-mlogloss:0.81292	validation_0-custom_f1_score:-0.75670
# [608]	validation_0-mlogloss:0.81258	validation_0-custom_f1_score:-0.75670
# [609]	validation_0-mlogloss:0.81224	validation_0-custom_f1_score:-0.75669
# [610]	validation_0-mlogloss:0.81191	validation_0-custom_f1_score:-0.75671
# [611]	validation_0-mlogloss:0.81156	validation_0-custom_f1_score:-0.75681
# [612]	validation_0-mlogloss:0.81121	validation_0-custom_f1_score:-0.75683
# [613]	validation_0-mlogloss:0.81086	validation_0-custom_f1_score:-0.75696
# [614]	validation_0-mlogloss:0.81052	validation_0-custom_f1_score:-0.75693
# [615]	validation_0-mlogloss:0.81015	validation_0-custom_f1_score:-0.75701
# [616]	validation_0-mlogloss:0.80980	validation_0-custom_f1_score:-0.75702
# [617]	validation_0-mlogloss:0.80947	validation_0-custom_f1_score:-0.75695
# [618]	validation_0-mlogloss:0.80912	validation_0-custom_f1_score:-0.75712
# [619]	validation_0-mlogloss:0.80877	validation_0-custom_f1_score:-0.75728
# [620]	validation_0-mlogloss:0.80844	validation_0-custom_f1_score:-0.75719
# [621]	validation_0-mlogloss:0.80807	validation_0-custom_f1_score:-0.75721
# [622]	validation_0-mlogloss:0.80773	validation_0-custom_f1_score:-0.75723
# [623]	validation_0-mlogloss:0.80741	validation_0-custom_f1_score:-0.75723
# [624]	validation_0-mlogloss:0.80706	validation_0-custom_f1_score:-0.75729
# [625]	validation_0-mlogloss:0.80671	validation_0-custom_f1_score:-0.75727
# [626]	validation_0-mlogloss:0.80639	validation_0-custom_f1_score:-0.75734
# [627]	validation_0-mlogloss:0.80604	validation_0-custom_f1_score:-0.75741
# [628]	validation_0-mlogloss:0.80573	validation_0-custom_f1_score:-0.75744
# [629]	validation_0-mlogloss:0.80539	validation_0-custom_f1_score:-0.75748
# [630]	validation_0-mlogloss:0.80508	validation_0-custom_f1_score:-0.75755
# [631]	validation_0-mlogloss:0.80475	validation_0-custom_f1_score:-0.75756
# [632]	validation_0-mlogloss:0.80441	validation_0-custom_f1_score:-0.75757
# [633]	validation_0-mlogloss:0.80409	validation_0-custom_f1_score:-0.75764
# [634]	validation_0-mlogloss:0.80376	validation_0-custom_f1_score:-0.75760
# [635]	validation_0-mlogloss:0.80343	validation_0-custom_f1_score:-0.75764
# [636]	validation_0-mlogloss:0.80308	validation_0-custom_f1_score:-0.75769
# [637]	validation_0-mlogloss:0.80271	validation_0-custom_f1_score:-0.75777
# [638]	validation_0-mlogloss:0.80239	validation_0-custom_f1_score:-0.75784
# [639]	validation_0-mlogloss:0.80205	validation_0-custom_f1_score:-0.75795
# [640]	validation_0-mlogloss:0.80173	validation_0-custom_f1_score:-0.75796
# [641]	validation_0-mlogloss:0.80140	validation_0-custom_f1_score:-0.75806
# [642]	validation_0-mlogloss:0.80109	validation_0-custom_f1_score:-0.75797
# [643]	validation_0-mlogloss:0.80073	validation_0-custom_f1_score:-0.75804
# [644]	validation_0-mlogloss:0.80039	validation_0-custom_f1_score:-0.75807
# [645]	validation_0-mlogloss:0.80007	validation_0-custom_f1_score:-0.75813
# [646]	validation_0-mlogloss:0.79974	validation_0-custom_f1_score:-0.75821
# [647]	validation_0-mlogloss:0.79941	validation_0-custom_f1_score:-0.75821
# [648]	validation_0-mlogloss:0.79909	validation_0-custom_f1_score:-0.75827
# [649]	validation_0-mlogloss:0.79876	validation_0-custom_f1_score:-0.75825
# ...
# [1597]	validation_0-mlogloss:0.66421	validation_0-custom_f1_score:-0.79119
# [1598]	validation_0-mlogloss:0.66418	validation_0-custom_f1_score:-0.79124
# [1599]	validation_0-mlogloss:0.66413	validation_0-custom_f1_score:-0.79127
# [1600]	validation_0-mlogloss:0.66407	validation_0-custom_f1_score:-0.79122
# [1601]	validation_0-mlogloss:0.66402	validation_0-custom_f1_score:-0.79129
# [1602]	validation_0-mlogloss:0.66393	validation_0-custom_f1_score:-0.79122
# [1603]	validation_0-mlogloss:0.66390	validation_0-custom_f1_score:-0.79134
# [1604]	validation_0-mlogloss:0.66384	validation_0-custom_f1_score:-0.79131
# [1605]	validation_0-mlogloss:0.66380	validation_0-custom_f1_score:-0.79132
# [1606]	validation_0-mlogloss:0.66373	validation_0-custom_f1_score:-0.79140
# [1607]	validation_0-mlogloss:0.66369	validation_0-custom_f1_score:-0.79136
# [1608]	validation_0-mlogloss:0.66359	validation_0-custom_f1_score:-0.79144
# [1609]	validation_0-mlogloss:0.66353	validation_0-custom_f1_score:-0.79148
# [1610]	validation_0-mlogloss:0.66349	validation_0-custom_f1_score:-0.79147
# [1611]	validation_0-mlogloss:0.66346	validation_0-custom_f1_score:-0.79148
# [1612]	validation_0-mlogloss:0.66338	validation_0-custom_f1_score:-0.79157
# [1613]	validation_0-mlogloss:0.66332	validation_0-custom_f1_score:-0.79152
# [1614]	validation_0-mlogloss:0.66324	validation_0-custom_f1_score:-0.79157
# [1615]	validation_0-mlogloss:0.66319	validation_0-custom_f1_score:-0.79163
# [1616]	validation_0-mlogloss:0.66309	validation_0-custom_f1_score:-0.79170
# [1617]	validation_0-mlogloss:0.66302	validation_0-custom_f1_score:-0.79170
# [1618]	validation_0-mlogloss:0.66297	validation_0-custom_f1_score:-0.79168
# [1619]	validation_0-mlogloss:0.66292	validation_0-custom_f1_score:-0.79168
# [1620]	validation_0-mlogloss:0.66285	validation_0-custom_f1_score:-0.79174
# [1621]	validation_0-mlogloss:0.66279	validation_0-custom_f1_score:-0.79169
# [1622]	validation_0-mlogloss:0.66273	validation_0-custom_f1_score:-0.79174
# [1623]	validation_0-mlogloss:0.66269	validation_0-custom_f1_score:-0.79185
# [1624]	validation_0-mlogloss:0.66265	validation_0-custom_f1_score:-0.79187
# [1625]	validation_0-mlogloss:0.66261	validation_0-custom_f1_score:-0.79188
# [1626]	validation_0-mlogloss:0.66255	validation_0-custom_f1_score:-0.79191
# [1627]	validation_0-mlogloss:0.66246	validation_0-custom_f1_score:-0.79187
# [1628]	validation_0-mlogloss:0.66239	validation_0-custom_f1_score:-0.79196
# [1629]	validation_0-mlogloss:0.66235	validation_0-custom_f1_score:-0.79203
# [1630]	validation_0-mlogloss:0.66230	validation_0-custom_f1_score:-0.79202
# [1631]	validation_0-mlogloss:0.66223	validation_0-custom_f1_score:-0.79210
# [1632]	validation_0-mlogloss:0.66219	validation_0-custom_f1_score:-0.79222
# [1633]	validation_0-mlogloss:0.66214	validation_0-custom_f1_score:-0.79222
# [1634]	validation_0-mlogloss:0.66205	validation_0-custom_f1_score:-0.79222
# [1635]	validation_0-mlogloss:0.66197	validation_0-custom_f1_score:-0.79216
# [1636]	validation_0-mlogloss:0.66189	validation_0-custom_f1_score:-0.79223
# [1637]	validation_0-mlogloss:0.66183	validation_0-custom_f1_score:-0.79222
# [1638]	validation_0-mlogloss:0.66181	validation_0-custom_f1_score:-0.79220
# [1639]	validation_0-mlogloss:0.66176	validation_0-custom_f1_score:-0.79231
# [1640]	validation_0-mlogloss:0.66170	validation_0-custom_f1_score:-0.79234
# [1641]	validation_0-mlogloss:0.66166	validation_0-custom_f1_score:-0.79238
# [1642]	validation_0-mlogloss:0.66157	validation_0-custom_f1_score:-0.79236
# [1643]	validation_0-mlogloss:0.66151	validation_0-custom_f1_score:-0.79236
# [1644]	validation_0-mlogloss:0.66148	validation_0-custom_f1_score:-0.79243
# [1645]	validation_0-mlogloss:0.66142	validation_0-custom_f1_score:-0.79237
# [1646]	validation_0-mlogloss:0.66136	validation_0-custom_f1_score:-0.79239
# [1647]	validation_0-mlogloss:0.66131	validation_0-custom_f1_score:-0.79243
# [1648]	validation_0-mlogloss:0.66128	validation_0-custom_f1_score:-0.79238
# [1649]	validation_0-mlogloss:0.66118	validation_0-custom_f1_score:-0.79240
# [1650]	validation_0-mlogloss:0.66114	validation_0-custom_f1_score:-0.79247
# [1651]	validation_0-mlogloss:0.66108	validation_0-custom_f1_score:-0.79250
# [1652]	validation_0-mlogloss:0.66103	validation_0-custom_f1_score:-0.79254
# [1653]	validation_0-mlogloss:0.66097	validation_0-custom_f1_score:-0.79253
# [1654]	validation_0-mlogloss:0.66091	validation_0-custom_f1_score:-0.79252
# [1655]	validation_0-mlogloss:0.66086	validation_0-custom_f1_score:-0.79255
# [1656]	validation_0-mlogloss:0.66081	validation_0-custom_f1_score:-0.79259
# [1657]	validation_0-mlogloss:0.66076	validation_0-custom_f1_score:-0.79263
# [1658]	validation_0-mlogloss:0.66073	validation_0-custom_f1_score:-0.79268
# [1659]	validation_0-mlogloss:0.66068	validation_0-custom_f1_score:-0.79275
# [1660]	validation_0-mlogloss:0.66065	validation_0-custom_f1_score:-0.79279
# [1661]	validation_0-mlogloss:0.66054	validation_0-custom_f1_score:-0.79278
# [1662]	validation_0-mlogloss:0.66049	validation_0-custom_f1_score:-0.79271
# [1663]	validation_0-mlogloss:0.66044	validation_0-custom_f1_score:-0.79279
# [1664]	validation_0-mlogloss:0.66036	validation_0-custom_f1_score:-0.79285
# [1665]	validation_0-mlogloss:0.66033	validation_0-custom_f1_score:-0.79284
# [1666]	validation_0-mlogloss:0.66031	validation_0-custom_f1_score:-0.79288
# [1667]	validation_0-mlogloss:0.66027	validation_0-custom_f1_score:-0.79290
# [1668]	validation_0-mlogloss:0.66021	validation_0-custom_f1_score:-0.79292
# [1669]	validation_0-mlogloss:0.66015	validation_0-custom_f1_score:-0.79304
# [1670]	validation_0-mlogloss:0.66008	validation_0-custom_f1_score:-0.79305
# [1671]	validation_0-mlogloss:0.66000	validation_0-custom_f1_score:-0.79304
# [1672]	validation_0-mlogloss:0.65993	validation_0-custom_f1_score:-0.79318
# [1673]	validation_0-mlogloss:0.65989	validation_0-custom_f1_score:-0.79321
# [1674]	validation_0-mlogloss:0.65984	validation_0-custom_f1_score:-0.79322
# [1675]	validation_0-mlogloss:0.65980	validation_0-custom_f1_score:-0.79327
# [1676]	validation_0-mlogloss:0.65973	validation_0-custom_f1_score:-0.79335
# [1677]	validation_0-mlogloss:0.65966	validation_0-custom_f1_score:-0.79340
# [1678]	validation_0-mlogloss:0.65962	validation_0-custom_f1_score:-0.79338
# [1679]	validation_0-mlogloss:0.65955	validation_0-custom_f1_score:-0.79342
# [1680]	validation_0-mlogloss:0.65950	validation_0-custom_f1_score:-0.79348
# [1681]	validation_0-mlogloss:0.65945	validation_0-custom_f1_score:-0.79351
# [1682]	validation_0-mlogloss:0.65939	validation_0-custom_f1_score:-0.79373
# [1683]	validation_0-mlogloss:0.65937	validation_0-custom_f1_score:-0.79370
# [1684]	validation_0-mlogloss:0.65928	validation_0-custom_f1_score:-0.79378
# [1685]	validation_0-mlogloss:0.65926	validation_0-custom_f1_score:-0.79366
# [1686]	validation_0-mlogloss:0.65920	validation_0-custom_f1_score:-0.79366
# [1687]	validation_0-mlogloss:0.65917	validation_0-custom_f1_score:-0.79375
# [1688]	validation_0-mlogloss:0.65912	validation_0-custom_f1_score:-0.79379
# [1689]	validation_0-mlogloss:0.65909	validation_0-custom_f1_score:-0.79381
# [1690]	validation_0-mlogloss:0.65902	validation_0-custom_f1_score:-0.79379
# [1691]	validation_0-mlogloss:0.65896	validation_0-custom_f1_score:-0.79386
# [1692]	validation_0-mlogloss:0.65892	validation_0-custom_f1_score:-0.79391
# [1693]	validation_0-mlogloss:0.65884	validation_0-custom_f1_score:-0.79401
# [1694]	validation_0-mlogloss:0.65877	validation_0-custom_f1_score:-0.79404
# [1695]	validation_0-mlogloss:0.65869	validation_0-custom_f1_score:-0.79407
# [1696]	validation_0-mlogloss:0.65865	validation_0-custom_f1_score:-0.79406
# [1697]	validation_0-mlogloss:0.65859	validation_0-custom_f1_score:-0.79409
# [1698]	validation_0-mlogloss:0.65854	validation_0-custom_f1_score:-0.79414
# [1699]	validation_0-mlogloss:0.65845	validation_0-custom_f1_score:-0.79405
# [1700]	validation_0-mlogloss:0.65843	validation_0-custom_f1_score:-0.79418
# [1701]	validation_0-mlogloss:0.65840	validation_0-custom_f1_score:-0.79423
# [1702]	validation_0-mlogloss:0.65833	validation_0-custom_f1_score:-0.79419
# [1703]	validation_0-mlogloss:0.65831	validation_0-custom_f1_score:-0.79421
# [1704]	validation_0-mlogloss:0.65825	validation_0-custom_f1_score:-0.79433
# [1705]	validation_0-mlogloss:0.65821	validation_0-custom_f1_score:-0.79437
# [1706]	validation_0-mlogloss:0.65815	validation_0-custom_f1_score:-0.79434
# [1707]	validation_0-mlogloss:0.65811	validation_0-custom_f1_score:-0.79425
# [1708]	validation_0-mlogloss:0.65809	validation_0-custom_f1_score:-0.79425
# [1709]	validation_0-mlogloss:0.65801	validation_0-custom_f1_score:-0.79433
# [1710]	validation_0-mlogloss:0.65794	validation_0-custom_f1_score:-0.79436
# [1711]	validation_0-mlogloss:0.65792	validation_0-custom_f1_score:-0.79440
# [1712]	validation_0-mlogloss:0.65787	validation_0-custom_f1_score:-0.79440
# [1713]	validation_0-mlogloss:0.65782	validation_0-custom_f1_score:-0.79442
# [1714]	validation_0-mlogloss:0.65776	validation_0-custom_f1_score:-0.79437
# [1715]	validation_0-mlogloss:0.65775	validation_0-custom_f1_score:-0.79442
# [1716]	validation_0-mlogloss:0.65768	validation_0-custom_f1_score:-0.79443
# [1717]	validation_0-mlogloss:0.65763	validation_0-custom_f1_score:-0.79453
# [1718]	validation_0-mlogloss:0.65760	validation_0-custom_f1_score:-0.79464
# [1719]	validation_0-mlogloss:0.65756	validation_0-custom_f1_score:-0.79468
# [1720]	validation_0-mlogloss:0.65749	validation_0-custom_f1_score:-0.79463
# [1721]	validation_0-mlogloss:0.65743	validation_0-custom_f1_score:-0.79467
# [1722]	validation_0-mlogloss:0.65736	validation_0-custom_f1_score:-0.79471
# [1723]	validation_0-mlogloss:0.65731	validation_0-custom_f1_score:-0.79480
# [1724]	validation_0-mlogloss:0.65726	validation_0-custom_f1_score:-0.79483
# [1725]	validation_0-mlogloss:0.65720	validation_0-custom_f1_score:-0.79474
# [1726]	validation_0-mlogloss:0.65716	validation_0-custom_f1_score:-0.79479
# [1727]	validation_0-mlogloss:0.65711	validation_0-custom_f1_score:-0.79479
# [1728]	validation_0-mlogloss:0.65709	validation_0-custom_f1_score:-0.79477
# [1729]	validation_0-mlogloss:0.65702	validation_0-custom_f1_score:-0.79476
# [1730]	validation_0-mlogloss:0.65698	validation_0-custom_f1_score:-0.79478
# [1731]	validation_0-mlogloss:0.65692	validation_0-custom_f1_score:-0.79479
# [1732]	validation_0-mlogloss:0.65684	validation_0-custom_f1_score:-0.79482
# [1733]	validation_0-mlogloss:0.65676	validation_0-custom_f1_score:-0.79480
# [1734]	validation_0-mlogloss:0.65670	validation_0-custom_f1_score:-0.79480
# [1735]	validation_0-mlogloss:0.65663	validation_0-custom_f1_score:-0.79475
# [1736]	validation_0-mlogloss:0.65655	validation_0-custom_f1_score:-0.79481
# [1737]	validation_0-mlogloss:0.65653	validation_0-custom_f1_score:-0.79477
# [1738]	validation_0-mlogloss:0.65652	validation_0-custom_f1_score:-0.79481
# [1739]	validation_0-mlogloss:0.65647	validation_0-custom_f1_score:-0.79482
# [1740]	validation_0-mlogloss:0.65643	validation_0-custom_f1_score:-0.79484
# [1741]	validation_0-mlogloss:0.65637	validation_0-custom_f1_score:-0.79483
# [1742]	validation_0-mlogloss:0.65629	validation_0-custom_f1_score:-0.79492
# [1743]	validation_0-mlogloss:0.65626	validation_0-custom_f1_score:-0.79493
# [1744]	validation_0-mlogloss:0.65622	validation_0-custom_f1_score:-0.79498
# [1745]	validation_0-mlogloss:0.65616	validation_0-custom_f1_score:-0.79492
# [1746]	validation_0-mlogloss:0.65608	validation_0-custom_f1_score:-0.79497
# [1747]	validation_0-mlogloss:0.65601	validation_0-custom_f1_score:-0.79510
# [1748]	validation_0-mlogloss:0.65598	validation_0-custom_f1_score:-0.79510
# [1749]	validation_0-mlogloss:0.65592	validation_0-custom_f1_score:-0.79511
# [1750]	validation_0-mlogloss:0.65584	validation_0-custom_f1_score:-0.79510
# [1751]	validation_0-mlogloss:0.65582	validation_0-custom_f1_score:-0.79520
# [1752]	validation_0-mlogloss:0.65575	validation_0-custom_f1_score:-0.79525
# [1753]	validation_0-mlogloss:0.65575	validation_0-custom_f1_score:-0.79524
# [1754]	validation_0-mlogloss:0.65570	validation_0-custom_f1_score:-0.79534
# [1755]	validation_0-mlogloss:0.65562	validation_0-custom_f1_score:-0.79541
# [1756]	validation_0-mlogloss:0.65560	validation_0-custom_f1_score:-0.79541
# [1757]	validation_0-mlogloss:0.65557	validation_0-custom_f1_score:-0.79543
# [1758]	validation_0-mlogloss:0.65554	validation_0-custom_f1_score:-0.79548
# [1759]	validation_0-mlogloss:0.65548	validation_0-custom_f1_score:-0.79548
# [1760]	validation_0-mlogloss:0.65546	validation_0-custom_f1_score:-0.79542
# [1761]	validation_0-mlogloss:0.65541	validation_0-custom_f1_score:-0.79545
# [1762]	validation_0-mlogloss:0.65536	validation_0-custom_f1_score:-0.79546
# [1763]	validation_0-mlogloss:0.65529	validation_0-custom_f1_score:-0.79541
# [1764]	validation_0-mlogloss:0.65520	validation_0-custom_f1_score:-0.79550
# [1765]	validation_0-mlogloss:0.65516	validation_0-custom_f1_score:-0.79555
# [1766]	validation_0-mlogloss:0.65510	validation_0-custom_f1_score:-0.79559
# [1767]	validation_0-mlogloss:0.65505	validation_0-custom_f1_score:-0.79565
# [1768]	validation_0-mlogloss:0.65500	validation_0-custom_f1_score:-0.79568
# [1769]	validation_0-mlogloss:0.65495	validation_0-custom_f1_score:-0.79578
# [1770]	validation_0-mlogloss:0.65490	validation_0-custom_f1_score:-0.79577
# [1771]	validation_0-mlogloss:0.65483	validation_0-custom_f1_score:-0.79585
# [1772]	validation_0-mlogloss:0.65481	validation_0-custom_f1_score:-0.79583
# [1773]	validation_0-mlogloss:0.65479	validation_0-custom_f1_score:-0.79592
# [1774]	validation_0-mlogloss:0.65472	validation_0-custom_f1_score:-0.79595
# [1775]	validation_0-mlogloss:0.65466	validation_0-custom_f1_score:-0.79591
# [1776]	validation_0-mlogloss:0.65465	validation_0-custom_f1_score:-0.79601
# [1777]	validation_0-mlogloss:0.65460	validation_0-custom_f1_score:-0.79602
# [1778]	validation_0-mlogloss:0.65454	validation_0-custom_f1_score:-0.79606
# [1779]	validation_0-mlogloss:0.65451	validation_0-custom_f1_score:-0.79606
# [1780]	validation_0-mlogloss:0.65443	validation_0-custom_f1_score:-0.79608
# [1781]	validation_0-mlogloss:0.65438	validation_0-custom_f1_score:-0.79607
# [1782]	validation_0-mlogloss:0.65435	validation_0-custom_f1_score:-0.79611
# [1783]	validation_0-mlogloss:0.65433	validation_0-custom_f1_score:-0.79616
# [1784]	validation_0-mlogloss:0.65430	validation_0-custom_f1_score:-0.79615
# [1785]	validation_0-mlogloss:0.65427	validation_0-custom_f1_score:-0.79615
# [1786]	validation_0-mlogloss:0.65423	validation_0-custom_f1_score:-0.79632
# [1787]	validation_0-mlogloss:0.65417	validation_0-custom_f1_score:-0.79634
# [1788]	validation_0-mlogloss:0.65413	validation_0-custom_f1_score:-0.79635
# [1789]	validation_0-mlogloss:0.65410	validation_0-custom_f1_score:-0.79629
# [1790]	validation_0-mlogloss:0.65404	validation_0-custom_f1_score:-0.79634
# [1791]	validation_0-mlogloss:0.65400	validation_0-custom_f1_score:-0.79635
# [1792]	validation_0-mlogloss:0.65393	validation_0-custom_f1_score:-0.79637
# [1793]	validation_0-mlogloss:0.65386	validation_0-custom_f1_score:-0.79638
# [1794]	validation_0-mlogloss:0.65379	validation_0-custom_f1_score:-0.79638
# [1795]	validation_0-mlogloss:0.65376	validation_0-custom_f1_score:-0.79640
# [1796]	validation_0-mlogloss:0.65368	validation_0-custom_f1_score:-0.79643
# [1797]	validation_0-mlogloss:0.65364	validation_0-custom_f1_score:-0.79643
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=0.6387926357773329,
#               colsample_bytree=None, device='gpu', early_stopping_rounds=None,
#               enable_categorical=False,
#               eval_metric=<function custom_f1_score at 0x752214615940>,
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.0026368755339723046, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=238, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1798, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
joblib.dump(xgb, (here(f'03_downstream_analysis/08_gene_importance/COMBAT_focus_analysis_COVIDseverity_NOsepsis/results/best_model/{SPLIT_IDX}_{CELL_TYPE}_xgb.json')))
# Out:
# ['/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/03_downstream_analysis/08_gene_importance/COMBAT_focus_analysis/results/best_model/0_Mono_xgb.json']

# %%
(pd.DataFrame(np.array((y_test, y_test_enc, xgb.predict(X_test))).T, columns=['y_true', 'y_true_code', 'y_pred'])
 .to_csv(here(f'03_downstream_analysis/08_gene_importance/COMBAT_focus_analysis_COVIDseverity_NOsepsis/results/predictions/{SPLIT_IDX}_{CELL_TYPE}_pred_test.zip')))
(pd.DataFrame(np.array((y_train, y_train_enc, xgb.predict(X_train))).T, columns=['y_true', 'y_true_code', 'y_pred'])
 .to_csv(here(f'03_downstream_analysis/08_gene_importance/COMBAT_focus_analysis_COVIDseverity_NOsepsis/results/predictions/{SPLIT_IDX}_{CELL_TYPE}_pred_train.zip')))
