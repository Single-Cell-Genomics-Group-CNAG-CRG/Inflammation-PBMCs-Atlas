# %%
import os
import sys
from pyprojroot.here import here

import pandas as pd
import anndata as ad
import numpy as np
import math
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import product

import optuna

import joblib
import pickle
import datetime

import collections

import xgboost
from sklearn.preprocessing import LabelEncoder

import scipy.sparse as ssp
import joblib

from tqdm.auto import tqdm

from dotenv import load_dotenv

# %%
assert load_dotenv()

# %% [markdown]
# # LOAD DATASET

# %%
# we are loading one dataset only to extract the spectra genes
adata_int_ct = ad.read_h5ad(
    here(f'03_downstream_analysis/08_gene_importance/data/pDC_adataMerged_SPECTRAgenes.log1p.h5ad'),
    backed='r',
    chunk_size=25000
)

adata_unint = ad.read_h5ad(
    here('03_downstream_analysis/08_gene_importance/data/04_MAIN_geneUniverse_noRBCnPlatelets.log1p.h5ad'),
    backed='r',
    chunk_size=25000
)

# %%
var_names_mask = adata_unint.var_names.isin(adata_int_ct.var_names).nonzero()[0]

# %%
adata_unint = adata_unint[(adata_unint.obs.studyID=='COMBAT2022'), var_names_mask].to_memory()
adata_unint.shape
# Out:
# (583184, 935)

# %% [markdown]
# #### Loading further metadata

# %%
with open(here("01_data_processing/results/extended_obs/COMBAT2022_obs.pkl"), 'rb') as file:
    COMBATmetadata = pickle.load(file)

# Subset columns of interest
COMBATmetadata = COMBATmetadata[["batch", "COVID_severity"]]
COMBATmetadata
# Out:
#                                              batch  COVID_severity
# cellID
# COMBAT2022_L000_S00109_T0_AAACCTGAGAAAGTGG  gPlexA       COVID_SEV
# COMBAT2022_L000_S00112_T0_AAACCTGAGCGGATCA  gPlexA      COVID_MILD
# COMBAT2022_L000_G05153_T0_AAACCTGAGGACATTA  gPlexA  COVID_HCW_MILD
# COMBAT2022_L000_S00005_T1_AAACCTGAGGCGACAT  gPlexA      COVID_CRIT
# COMBAT2022_L000_S00061_T0_AAACCTGAGGGAACGG  gPlexA       COVID_SEV
# ...                                            ...             ...
# COMBAT2022_L069_H00064_T0_TTTGTCAGTGGCAAAC  gPlexK              HV
# COMBAT2022_L069_U00501_T0_TTTGTCAGTTACCGAT  gPlexK             Flu
# COMBAT2022_L069_G05112_T0_TTTGTCATCCTCTAGC  gPlexK  COVID_HCW_MILD
# COMBAT2022_L069_S00045_T0_TTTGTCATCGAGGTAG  gPlexK       COVID_SEV
# COMBAT2022_L069_S00045_T0_TTTGTCATCTCCCTGA  gPlexK       COVID_SEV
#
# [836148 rows x 2 columns]

# %%
adata_unint.obs = adata_unint.obs.merge(COMBATmetadata, left_index=True, right_index=True, how='left')
adata_unint.obs.head()
# Out:
#                                                studyID        libraryID  \
# cellID
# COMBAT2022_L000_S00112_T0_AAACCTGAGCGGATCA  COMBAT2022  COMBAT2022_L000
# COMBAT2022_L000_G05153_T0_AAACCTGAGGACATTA  COMBAT2022  COMBAT2022_L000
# COMBAT2022_L000_S00061_T0_AAACCTGAGGGAACGG  COMBAT2022  COMBAT2022_L000
# COMBAT2022_L000_S00056_T0_AAACCTGCACATGTGT  COMBAT2022  COMBAT2022_L000
# COMBAT2022_L000_H00067_T0_AAACCTGCATCTATGG  COMBAT2022  COMBAT2022_L000
#
#                                                         sampleID chemistry  \
# cellID
# COMBAT2022_L000_S00112_T0_AAACCTGAGCGGATCA  COMBAT2022_S00112_T0  5_GEX_V1
# COMBAT2022_L000_G05153_T0_AAACCTGAGGACATTA  COMBAT2022_G05153_T0  5_GEX_V1
# COMBAT2022_L000_S00061_T0_AAACCTGAGGGAACGG  COMBAT2022_S00061_T0  5_GEX_V1
# COMBAT2022_L000_S00056_T0_AAACCTGCACATGTGT  COMBAT2022_S00056_T0  5_GEX_V1
# COMBAT2022_L000_H00067_T0_AAACCTGCATCTATGG  COMBAT2022_H00067_T0  5_GEX_V1
#
#                                             disease     sex binned_age  \
# cellID
# COMBAT2022_L000_S00112_T0_AAACCTGAGCGGATCA    COVID  female      51-60
# COMBAT2022_L000_G05153_T0_AAACCTGAGGACATTA    COVID    male      41-50
# COMBAT2022_L000_S00061_T0_AAACCTGAGGGAACGG    COVID  female      51-60
# COMBAT2022_L000_S00056_T0_AAACCTGCACATGTGT    COVID    male      71-80
# COMBAT2022_L000_H00067_T0_AAACCTGCATCTATGG  healthy    male      71-80
#
#                                                     Level1            Level2  \
# cellID
# COMBAT2022_L000_S00112_T0_AAACCTGAGCGGATCA  T_CD4_NonNaive        T_CD4_EMRA
# COMBAT2022_L000_G05153_T0_AAACCTGAGGACATTA               B           B_Naive
# COMBAT2022_L000_S00061_T0_AAACCTGAGGGAACGG            Mono  Mono_IFNresponse
# COMBAT2022_L000_S00056_T0_AAACCTGCACATGTGT            Mono    Mono_classical
# COMBAT2022_L000_H00067_T0_AAACCTGCATCTATGG  T_CD8_NonNaive          T_CD8_CM
#
#                                              batch  COVID_severity
# cellID
# COMBAT2022_L000_S00112_T0_AAACCTGAGCGGATCA  gPlexA      COVID_MILD
# COMBAT2022_L000_G05153_T0_AAACCTGAGGACATTA  gPlexA  COVID_HCW_MILD
# COMBAT2022_L000_S00061_T0_AAACCTGAGGGAACGG  gPlexA       COVID_SEV
# COMBAT2022_L000_S00056_T0_AAACCTGCACATGTGT  gPlexA       COVID_SEV
# COMBAT2022_L000_H00067_T0_AAACCTGCATCTATGG  gPlexA              HV

# %%
adata_unint.obs[['batch', 'disease', 'sampleID']].drop_duplicates().groupby(['batch', 'disease'], observed=True).size().reset_index(name='count')
# Out:
#      batch  disease  count
# 0   gPlexA    COVID      7
# 1   gPlexA      flu      1
# 2   gPlexA  healthy      1
# 3   gPlexA   sepsis      1
# 4   gPlexB    COVID      7
# 5   gPlexB      flu      1
# 6   gPlexB  healthy      1
# 7   gPlexB   sepsis      2
# 8   gPlexC    COVID      7
# 9   gPlexC      flu      1
# 10  gPlexC  healthy      1
# 11  gPlexC   sepsis      2
# 12  gPlexD    COVID      7
# 13  gPlexD      flu      1
# 14  gPlexD  healthy      1
# 15  gPlexD   sepsis      2
# 16  gPlexE    COVID      6
# 17  gPlexE      flu      1
# 18  gPlexE  healthy      1
# 19  gPlexE   sepsis      2
# 20  gPlexF    COVID      5
# 21  gPlexF      flu      1
# 22  gPlexF  healthy      1
# 23  gPlexF   sepsis      3
# 24  gPlexG    COVID      6
# 25  gPlexG      flu      1
# 26  gPlexG  healthy      1
# 27  gPlexG   sepsis      1
# 28  gPlexH    COVID      8
# 29  gPlexH      flu      1
# 30  gPlexH  healthy      1
# 31  gPlexH   sepsis      1
# 32  gPlexJ    COVID      3
# 33  gPlexJ      flu      1
# 34  gPlexJ  healthy      1
# 35  gPlexJ   sepsis      2
# 36  gPlexK    COVID      6
# 37  gPlexK      flu      2
# 38  gPlexK  healthy      1
# 39  gPlexK   sepsis      2

# %% [markdown]
# ### Saving one object for each cell-types

# %%
for ct in tqdm(['T_CD4_NonNaive','B','Mono','T_CD8_NonNaive','T_CD4_Naive','UTC','ILC','T_CD8_Naive','Plasma','DC','pDC']):
    adata_ct = adata_unint[adata_unint.obs.Level1 == ct]
    adata_ct.write(here(f'03_downstream_analysis/08_gene_importance/COMBAT_focus_analysis/data/{ct}_COMBAT2022_spectraGenes_log1p.h5ad'))
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
