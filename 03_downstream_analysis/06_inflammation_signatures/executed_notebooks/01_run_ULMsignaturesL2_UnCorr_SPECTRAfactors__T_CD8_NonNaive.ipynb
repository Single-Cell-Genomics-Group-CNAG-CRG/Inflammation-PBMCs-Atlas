# %%
# Parameters
celltype = "T_CD8_NonNaive"

# %%
for v in ['celltype']:
    if (v not in locals()) or (v not in globals()):
        raise TypeError(f"{v} not defined")
    else:
        print(f"{v} = {eval(v)}")
# Out:
# celltype = T_CD8_NonNaive

# %%
# General modules
import sys
import os
import session_info
import warnings
from pyprojroot.here import here
import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as plines
import matplotlib.colors as mcolors
from IPython.display import display
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.lines import Line2D  # for legend handle

# Specific modules
import scanpy as sc
import decoupler as dc
import anndata as ad
import scienceplots

# Setting some parameters
warnings.filterwarnings("ignore")

# Import functions
sys.path.insert(1, str(here('bin')))
from customPalette import *
from customPythonFunctions import mean_by_category, filter_low_represented_cell_group, RelativeDiff_mean_by_category, mscatter, aggregating_features

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

overwriteFigures = True
overwriteData = True

pd.options.display.max_columns = 300
pd.options.display.max_rows = 1000

# %%
print("Main directory path: {}".format(here()))
# Out:
# Main directory path: /scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas

# %% [markdown]
# **Load data**

# %%
inputfile_path = here("03_downstream_analysis/02_gene_universe_definition/results/04_MAIN_geneUniverse_noRBCnPlatelets.h5ad")
# Loading scanpy (Anndata) object
adata = sc.read_h5ad(inputfile_path)

# Subset by celltype
adata = adata[adata.obs["Level1"] == celltype].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 523322 × 8253
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'disease', 'sex', 'binned_age', 'Level1', 'Level2'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'highly_variable'

# %% [markdown]
# **Generate new variables**

# %%
# Generate new variables for CELL level1
adata.obs["disease_level1"] = ["{}__{}".format(disease, level1)
                                           for disease, level1 in zip(adata.obs["disease"], adata.obs["Level1"])]
adata.obs["disease_level1"] = adata.obs["disease_level1"].astype('category')

adata.obs["disease_studyID"] = ["{}_{}".format(disease, studyID)
                                           for disease, studyID in zip(adata.obs["disease"], adata.obs["studyID"])]
adata.obs["disease_studyID_level1"] = ["{}__{}".format(adata.obs["disease_studyID"][i], level1) if disease == "healthy"
                                                  else "{}__{}".format(disease, level1) 
                                                  for i, (disease, level1) 
                                                  in enumerate(zip(adata.obs["disease"], adata.obs["Level1"]))]
adata.obs["disease_studyID_level1"] = adata.obs["disease_studyID_level1"].astype('category')


# Generate new variables for CELL TYPE  
adata.obs["disease_level2"] = ["{}__{}".format(disease, level2)
                                           for disease, level2 in zip(adata.obs["disease"], adata.obs["Level2"])]
adata.obs["disease_level2"] = adata.obs["disease_level2"].astype('category')

adata.obs["disease_studyID"] = ["{}_{}".format(disease, studyID)
                                           for disease, studyID in zip(adata.obs["disease"], adata.obs["studyID"])]
adata.obs["disease_studyID_level2"] = ["{}__{}".format(adata.obs["disease_studyID"][i], level2) if disease == "healthy"
                                                  else "{}__{}".format(disease, level2) 
                                                  for i, (disease, level2) 
                                                  in enumerate(zip(adata.obs["disease"], adata.obs["Level2"]))]
adata.obs["disease_studyID_level2"] = adata.obs["disease_studyID_level2"].astype('category')

adata
# Out:
# AnnData object with n_obs × n_vars = 523322 × 8253
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'disease', 'sex', 'binned_age', 'Level1', 'Level2', 'disease_level1', 'disease_studyID', 'disease_studyID_level1', 'disease_level2', 'disease_studyID_level2'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'highly_variable'

# %% [markdown]
# **Load SPECTRA Gene Weights**

# %%
geneWeights = pd.read_csv(here('03_downstream_analysis/05_SPECTRA/results/SPECTRAFactor_Renamed_Processed_LAM0.001_S0.6_GeneWeights.csv'), 
                          index_col='Unnamed: 0')
geneWeights.head()
# Out:
#                                            ENSG00000000003  ENSG00000000457  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.662220e-15     3.255362e-14
# 1-X-global-X-all_JAK-STAT_signaling           1.108171e-15     2.299332e-14
# 2-X-global-X-all_type-IandII-ifn-response     2.737120e-15     5.744951e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       8.518205e-16     1.570927e-14
# 4-X-global-X-all_MHC-II-Ipresentation         2.003873e-15     5.072165e-14
#
#                                            ENSG00000000938  ENSG00000000971  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.108393e-15     4.331535e-17
# 1-X-global-X-all_JAK-STAT_signaling           4.758343e-15     3.819025e-17
# 2-X-global-X-all_type-IandII-ifn-response     1.259858e-14     5.163268e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.516911e-15     3.303363e-17
# 4-X-global-X-all_MHC-II-Ipresentation         1.220851e-14     4.364942e-17
#
#                                            ENSG00000001036  ENSG00000001084  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.497816e-16     3.206445e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.985897e-16     2.137640e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.113090e-15     5.587422e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.045630e-16     1.666658e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.004335e-15     4.993081e-15
#
#                                            ENSG00000001167  ENSG00000001460  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.057057e-15     4.152293e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.022476e-17     3.077916e-15
# 2-X-global-X-all_type-IandII-ifn-response     4.612209e-20     7.008616e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       9.245895e-20     2.090478e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.373877e-03     5.995152e-15
#
#                                            ENSG00000001461  ENSG00000001561  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.354309e-15     7.388704e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.422393e-15     6.019337e-15
# 2-X-global-X-all_type-IandII-ifn-response     3.292712e-15     1.330521e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       8.147142e-16     4.175936e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.772227e-15     1.293963e-14
#
#                                            ENSG00000001630  ENSG00000001631  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.925771e-14     2.214693e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.175481e-14     2.047948e-15
# 2-X-global-X-all_type-IandII-ifn-response     3.830525e-14     2.419155e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.106037e-14     1.814194e-15
# 4-X-global-X-all_MHC-II-Ipresentation         3.285941e-14     2.689005e-15
#
#                                            ENSG00000002016  ENSG00000002330  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.712155e-15     9.305980e-17
# 1-X-global-X-all_JAK-STAT_signaling           1.608910e-15     7.660323e-17
# 2-X-global-X-all_type-IandII-ifn-response     4.482577e-15     8.793617e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.387727e-15     4.354169e-17
# 4-X-global-X-all_MHC-II-Ipresentation         3.884560e-15     5.481054e-17
#
#                                            ENSG00000002549  ENSG00000002586  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.402679e-15     1.026012e-15
# 1-X-global-X-all_JAK-STAT_signaling           4.314491e-15     7.025332e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.321619e-14     1.966470e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.262960e-15     5.552844e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.201393e-14     2.167673e-15
#
#                                            ENSG00000002587  ENSG00000002822  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.450719e-15     9.784722e-16
# 1-X-global-X-all_JAK-STAT_signaling           2.407704e-15     1.009024e-15
# 2-X-global-X-all_type-IandII-ifn-response     6.705790e-15     2.624803e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.713050e-15     7.158314e-16
# 4-X-global-X-all_MHC-II-Ipresentation         4.883179e-15     1.917551e-15
#
#                                            ENSG00000002933  ENSG00000003147  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.306471e-15     1.791004e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.956402e-15     1.309719e-15
# 2-X-global-X-all_type-IandII-ifn-response     5.661512e-15     2.749719e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.694304e-15     9.871374e-16
# 4-X-global-X-all_MHC-II-Ipresentation         4.103691e-15     2.738183e-15
#
#                                            ENSG00000003249  ENSG00000003400  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.249072e-16     9.095464e-16
# 1-X-global-X-all_JAK-STAT_signaling           8.795213e-17     6.125022e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.074780e-16     1.727027e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.701189e-17     4.908815e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.736873e-16     1.551762e-15
#
#                                            ENSG00000003402  ENSG00000003436  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.303878e-15     9.911320e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.297789e-15     4.633865e-15
# 2-X-global-X-all_type-IandII-ifn-response     5.366734e-15     1.836575e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.196287e-02     4.443596e-15
# 4-X-global-X-all_MHC-II-Ipresentation         4.805225e-15     8.679454e-15
#
#                                            ENSG00000004059  ENSG00000004139  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      8.343250e-16     1.954510e-15
# 1-X-global-X-all_JAK-STAT_signaling           5.832843e-16     1.416043e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.757488e-15     3.390515e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.941989e-16     1.042244e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.554731e-15     3.016340e-15
#
#                                            ENSG00000004142  ENSG00000004399  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.370393e-15     2.402237e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.632212e-15     2.270985e-15
# 2-X-global-X-all_type-IandII-ifn-response     4.250693e-15     3.363310e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.242361e-15     7.485002e-16
# 4-X-global-X-all_MHC-II-Ipresentation         3.933836e-15     3.173591e-15
#
#                                            ENSG00000004468  ENSG00000004478  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.196725e-02     4.528516e-17
# 1-X-global-X-all_JAK-STAT_signaling           5.586794e-18     3.709570e-17
# 2-X-global-X-all_type-IandII-ifn-response     3.151981e-11     8.904162e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.752569e-18     2.736591e-17
# 4-X-global-X-all_MHC-II-Ipresentation         1.361805e-14     7.987335e-17
#
#                                            ENSG00000004487  ENSG00000004700  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.586870e-15     1.456114e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.932940e-15     1.033952e-15
# 2-X-global-X-all_type-IandII-ifn-response     5.038657e-15     2.392461e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.505800e-15     7.425194e-16
# 4-X-global-X-all_MHC-II-Ipresentation         4.466889e-15     2.398643e-15
#
#                                            ENSG00000004766  ENSG00000004799  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.640458e-15     5.379918e-16
# 1-X-global-X-all_JAK-STAT_signaling           1.183827e-15     3.902081e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.927318e-15     5.921365e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       8.559195e-16     2.717889e-16
# 4-X-global-X-all_MHC-II-Ipresentation         2.651268e-15     7.964299e-16
#
#                                            ENSG00000004846  ENSG00000004939  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.361758e-15     3.980211e-15
# 1-X-global-X-all_JAK-STAT_signaling           9.704760e-16     3.131955e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.325677e-15     6.996676e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.676545e-16     2.275386e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.113453e-15     4.957555e-15
#
#                                            ENSG00000004975  ENSG00000005007  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.385579e-15     1.250043e-14
# 1-X-global-X-all_JAK-STAT_signaling           1.809674e-15     8.896026e-15
# 2-X-global-X-all_type-IandII-ifn-response     3.524823e-15     2.220610e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.326924e-15     6.406760e-15
# 4-X-global-X-all_MHC-II-Ipresentation         3.862734e-15     1.874212e-14
#
#                                            ENSG00000005020  ENSG00000005059  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.015653e-16     8.096925e-16
# 1-X-global-X-all_JAK-STAT_signaling           3.146234e-16     7.661031e-16
# 2-X-global-X-all_type-IandII-ifn-response     8.677294e-16     1.166847e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.323638e-16     5.091165e-16
# 4-X-global-X-all_MHC-II-Ipresentation         7.950394e-16     8.347706e-16
#
#                                            ENSG00000005102  ENSG00000005187  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      8.274931e-17     1.879736e-15
# 1-X-global-X-all_JAK-STAT_signaling           5.139894e-17     1.352617e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.303134e-16     3.143700e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.626409e-17     9.852585e-16
# 4-X-global-X-all_MHC-II-Ipresentation         8.550969e-17     2.180216e-15
#
#                                            ENSG00000005206  ENSG00000005243  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.121586e-14     8.415847e-17
# 1-X-global-X-all_JAK-STAT_signaling           7.904008e-15     7.636133e-17
# 2-X-global-X-all_type-IandII-ifn-response     1.940234e-14     1.642236e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.575672e-15     4.119597e-17
# 4-X-global-X-all_MHC-II-Ipresentation         1.432009e-14     1.538671e-16
#
#                                            ENSG00000005249  ENSG00000005339  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.116134e-15     5.211838e-14
# 1-X-global-X-all_JAK-STAT_signaling           4.414682e-15     1.008696e-01
# 2-X-global-X-all_type-IandII-ifn-response     1.054052e-14     5.280419e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.002495e-15     1.486037e-14
# 4-X-global-X-all_MHC-II-Ipresentation         8.748835e-15     4.633534e-14
#
#                                            ENSG00000005379  ENSG00000005381  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.067790e-14     6.254960e-16
# 1-X-global-X-all_JAK-STAT_signaling           8.121502e-15     4.531279e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.944045e-14     9.776620e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.418637e-15     2.618315e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.691008e-14     8.681486e-16
#
#                                            ENSG00000005436  ENSG00000005469  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      8.426759e-16     1.959988e-16
# 1-X-global-X-all_JAK-STAT_signaling           4.566108e-16     1.323775e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.466429e-15     3.454126e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.364547e-16     1.037200e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.270757e-15     3.117931e-16
#
#                                            ENSG00000005471  ENSG00000005486  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.583387e-15     1.198831e-14
# 1-X-global-X-all_JAK-STAT_signaling           1.175402e-15     9.028325e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.533283e-15     2.326690e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.656074e-16     6.653325e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.501679e-15     2.162600e-14
#
#                                            ENSG00000005812  ENSG00000005844  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.219445e-14     3.888262e-15
# 1-X-global-X-all_JAK-STAT_signaling           8.991485e-15     2.771807e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.202312e-14     8.232801e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.423632e-15     2.013682e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.018417e-14     7.374375e-15
#
#                                            ENSG00000005882  ENSG00000005884  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.702024e-17     2.976140e-15
# 1-X-global-X-all_JAK-STAT_signaling           4.174906e-17     2.094296e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.009290e-16     4.810836e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.033612e-17     1.541556e-15
# 4-X-global-X-all_MHC-II-Ipresentation         8.025820e-17     4.447921e-15
#
#                                            ENSG00000005961  ENSG00000006015  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.878907e-15     2.387412e-16
# 1-X-global-X-all_JAK-STAT_signaling           4.778780e-15     1.664096e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.018949e-14     3.687237e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.114054e-15     1.217518e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.266529e-14     3.930692e-16
#
#                                            ENSG00000006025  ENSG00000006125  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.846390e-15     2.264102e-17
# 1-X-global-X-all_JAK-STAT_signaling           1.768723e-15     2.184842e-16
# 2-X-global-X-all_type-IandII-ifn-response     4.413976e-15     4.614934e-18
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.592389e-15     4.309272e-17
# 4-X-global-X-all_MHC-II-Ipresentation         2.448664e-15     2.994553e-03
#
#                                            ENSG00000006194  ENSG00000006210  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.499267e-15     1.401709e-15
# 1-X-global-X-all_JAK-STAT_signaling           4.151857e-15     1.228794e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.287190e-14     2.770341e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.028795e-15     8.584980e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.108840e-14     2.495320e-15
#
#                                            ENSG00000006282  ENSG00000006327  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.115561e-15     2.605132e-01
# 1-X-global-X-all_JAK-STAT_signaling           2.277981e-15     4.837139e-14
# 2-X-global-X-all_type-IandII-ifn-response     4.350043e-15     2.217007e-08
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.623556e-15     1.015855e-15
# 4-X-global-X-all_MHC-II-Ipresentation         4.689267e-15     2.409934e-11
#
#                                            ENSG00000006432  ENSG00000006459  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.770276e-15     1.745986e-14
# 1-X-global-X-all_JAK-STAT_signaling           4.953448e-15     1.196207e-14
# 2-X-global-X-all_type-IandII-ifn-response     1.179982e-14     3.073445e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.297606e-15     8.336943e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.051515e-14     2.688048e-14
#
#                                            ENSG00000006530  ENSG00000006534  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.936444e-15     3.330752e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.661866e-15     2.408955e-15
# 2-X-global-X-all_type-IandII-ifn-response     6.885430e-15     5.601886e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.486323e-15     1.755953e-15
# 4-X-global-X-all_MHC-II-Ipresentation         5.993838e-15     5.258702e-15
#
#                                            ENSG00000006555  ENSG00000006576  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.675945e-16     6.609198e-15
# 1-X-global-X-all_JAK-STAT_signaling           6.939263e-16     4.351116e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.284953e-15     1.076103e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.384015e-16     3.092680e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.128003e-15     1.161863e-14
#
#                                            ENSG00000006607  ENSG00000006625  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.233752e-14     3.800504e-17
# 1-X-global-X-all_JAK-STAT_signaling           8.795324e-15     2.771153e-17
# 2-X-global-X-all_type-IandII-ifn-response     2.133945e-14     7.481115e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.268195e-15     1.994830e-17
# 4-X-global-X-all_MHC-II-Ipresentation         1.473173e-14     5.725433e-17
#
#                                            ENSG00000006634  ENSG00000006638  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.406582e-14     9.944059e-16
# 1-X-global-X-all_JAK-STAT_signaling           8.824353e-15     6.760777e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.559902e-14     1.757057e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.389692e-15     5.171816e-16
# 4-X-global-X-all_MHC-II-Ipresentation         2.200616e-14     1.503633e-15
#
#                                            ENSG00000006652  ENSG00000006715  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.590217e-14     1.427437e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.752862e-14     8.901598e-16
# 2-X-global-X-all_type-IandII-ifn-response     4.653839e-14     2.597381e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.265988e-14     7.315484e-16
# 4-X-global-X-all_MHC-II-Ipresentation         4.200209e-14     2.303497e-15
#
#                                            ENSG00000006740  ENSG00000006757  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.816414e-15     4.181476e-17
# 1-X-global-X-all_JAK-STAT_signaling           1.659589e-15     3.211728e-17
# 2-X-global-X-all_type-IandII-ifn-response     4.662091e-15     7.094449e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.422454e-15     1.261164e-17
# 4-X-global-X-all_MHC-II-Ipresentation         4.064921e-15     6.059795e-17
#
#                                            ENSG00000006837  ENSG00000007038  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.253172e-15     3.487565e-16
# 1-X-global-X-all_JAK-STAT_signaling           8.291337e-16     2.506351e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.687765e-15     6.081812e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.751914e-16     1.828168e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.910159e-15     5.377755e-16
#
#                                            ENSG00000007047  ENSG00000007129  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.219750e-15     6.929374e-17
# 1-X-global-X-all_JAK-STAT_signaling           4.269072e-15     5.207770e-17
# 2-X-global-X-all_type-IandII-ifn-response     1.063863e-14     1.191484e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.687964e-15     3.582570e-17
# 4-X-global-X-all_MHC-II-Ipresentation         6.687317e-15     1.028452e-16
#
#                                            ENSG00000007202  ENSG00000007237  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.102185e-15     8.671913e-15
# 1-X-global-X-all_JAK-STAT_signaling           5.093936e-15     6.140915e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.178924e-14     1.597179e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.680175e-15     4.631835e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.133446e-14     1.396383e-14
#
#                                            ENSG00000007255  ENSG00000007264  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.971910e-16     2.304761e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.410449e-16     1.514321e-15
# 2-X-global-X-all_type-IandII-ifn-response     3.647043e-16     4.014767e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.004958e-16     1.174808e-15
# 4-X-global-X-all_MHC-II-Ipresentation         3.214792e-16     3.193052e-15
#
#                                            ENSG00000007312  ENSG00000007350  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.475876e-16     2.187312e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.046599e-16     1.612737e-15
# 2-X-global-X-all_type-IandII-ifn-response     3.050533e-16     3.152422e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.710507e-17     1.128572e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.878941e-16     2.737634e-15
#
#                                            ENSG00000007376  ENSG00000007392  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.149091e-17     1.059582e-14
# 1-X-global-X-all_JAK-STAT_signaling           4.982051e-17     7.523127e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.176047e-16     1.947855e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.376842e-17     5.495467e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.057393e-16     1.562494e-14
#
#                                            ENSG00000007402  ENSG00000007516  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.618459e-15     2.684729e-15
# 1-X-global-X-all_JAK-STAT_signaling           9.036248e-16     2.017815e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.608613e-15     4.653924e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       9.775920e-16     1.412798e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.595308e-15     4.042481e-15
#
#                                            ENSG00000007520  ENSG00000007541  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.317224e-17     1.744720e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.068204e-17     1.417217e-15
# 2-X-global-X-all_type-IandII-ifn-response     7.720176e-17     3.384510e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.056381e-17     1.065763e-15
# 4-X-global-X-all_MHC-II-Ipresentation         6.587138e-17     2.851767e-15
#
#                                            ENSG00000007545  ENSG00000007944  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.320686e-15     1.453829e-14
# 1-X-global-X-all_JAK-STAT_signaling           5.334259e-15     1.044688e-14
# 2-X-global-X-all_type-IandII-ifn-response     1.243661e-14     2.621575e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.970244e-15     7.563758e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.170263e-14     2.393003e-14
#
#                                            ENSG00000007968  ENSG00000008056  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.046433e-16     5.234373e-15
# 1-X-global-X-all_JAK-STAT_signaling           4.816755e-16     3.495321e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.126893e-15     8.009771e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.933845e-16     2.673314e-15
# 4-X-global-X-all_MHC-II-Ipresentation         8.205462e-16     6.898101e-15
#
#                                            ENSG00000008083  ENSG00000008086  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.887557e-14     3.512438e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.081171e-14     2.614607e-15
# 2-X-global-X-all_type-IandII-ifn-response     4.821059e-14     6.048217e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.524134e-14     1.905968e-15
# 4-X-global-X-all_MHC-II-Ipresentation         4.620927e-14     5.288345e-15
#
#                                            ENSG00000008130  ENSG00000008226  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.077412e-16     1.177785e-15
# 1-X-global-X-all_JAK-STAT_signaling           7.496041e-17     8.713213e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.921472e-16     1.994204e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.439758e-17     4.854594e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.508497e-16     1.560392e-15
#
#                                            ENSG00000008256  ENSG00000008277  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.877852e-15     8.167988e-16
# 1-X-global-X-all_JAK-STAT_signaling           3.720264e-15     6.048622e-16
# 2-X-global-X-all_type-IandII-ifn-response     6.997897e-15     1.366884e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.640972e-15     2.739860e-16
# 4-X-global-X-all_MHC-II-Ipresentation         7.514653e-15     1.148236e-15
#
#                                            ENSG00000008283  ENSG00000008294  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.055324e-15     3.892477e-14
# 1-X-global-X-all_JAK-STAT_signaling           4.152696e-15     2.685667e-14
# 2-X-global-X-all_type-IandII-ifn-response     1.053087e-14     7.219891e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.468895e-15     1.992380e-14
# 4-X-global-X-all_MHC-II-Ipresentation         8.907177e-15     6.226452e-14
#
#                                            ENSG00000008300  ENSG00000008311  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.715024e-16     7.798457e-16
# 1-X-global-X-all_JAK-STAT_signaling           2.100919e-16     6.413722e-16
# 2-X-global-X-all_type-IandII-ifn-response     9.878625e-16     1.370610e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.825150e-16     4.411573e-16
# 4-X-global-X-all_MHC-II-Ipresentation         5.235293e-16     6.015913e-16
#
#                                            ENSG00000008382  ENSG00000008394  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      9.010229e-17     1.508707e-15
# 1-X-global-X-all_JAK-STAT_signaling           6.497231e-17     1.043250e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.518390e-16     2.631249e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.325399e-17     7.272303e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.361780e-16     2.389172e-15
#
#                                            ENSG00000008441  ENSG00000008513  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.829867e-15     1.383510e-14
# 1-X-global-X-all_JAK-STAT_signaling           2.558884e-15     9.417133e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.913155e-15     1.897982e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.204122e-15     6.812766e-15
# 4-X-global-X-all_MHC-II-Ipresentation         3.530395e-15     2.351244e-14
#
#                                            ENSG00000008517  ENSG00000008710  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.454752e-16     1.138381e-14
# 1-X-global-X-all_JAK-STAT_signaling           1.006734e-16     5.870108e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.153982e-16     1.913347e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.609890e-17     5.934536e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.983780e-16     1.581761e-14
#
#                                            ENSG00000008869  ENSG00000009335  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.378645e-15     2.743568e-15
# 1-X-global-X-all_JAK-STAT_signaling           9.796100e-16     1.981141e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.528302e-15     4.706855e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.849341e-16     1.417655e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.872832e-15     3.980653e-15
#
#                                            ENSG00000009413  ENSG00000009694  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.980539e-15     3.432914e-15
# 1-X-global-X-all_JAK-STAT_signaling           5.299404e-15     2.639643e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.318729e-14     5.913538e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.818204e-15     1.983668e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.177268e-14     2.822568e-15
#
#                                            ENSG00000009790  ENSG00000009950  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.202595e-16     6.092810e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.930830e-16     6.069577e-15
# 2-X-global-X-all_type-IandII-ifn-response     7.959258e-16     1.307891e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.188923e-16     3.291900e-15
# 4-X-global-X-all_MHC-II-Ipresentation         8.407246e-16     1.024689e-14
#
#                                            ENSG00000010030  ENSG00000010165  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.207022e-16     6.689480e-17
# 1-X-global-X-all_JAK-STAT_signaling           4.134497e-16     5.083161e-17
# 2-X-global-X-all_type-IandII-ifn-response     8.018059e-16     1.241203e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.710758e-16     3.702083e-17
# 4-X-global-X-all_MHC-II-Ipresentation         3.721759e-16     1.066125e-16
#
#                                            ENSG00000010219  ENSG00000010270  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.258082e-17     2.818278e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.931718e-17     1.722799e-15
# 2-X-global-X-all_type-IandII-ifn-response     8.521840e-17     4.781231e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.778159e-17     1.471512e-15
# 4-X-global-X-all_MHC-II-Ipresentation         6.644909e-17     4.139271e-15
#
#                                            ENSG00000010278  ENSG00000010292  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.391967e-01     5.005098e-17
# 1-X-global-X-all_JAK-STAT_signaling           1.356751e-14     3.091024e-17
# 2-X-global-X-all_type-IandII-ifn-response     4.042667e-11     7.826256e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.013742e-18     2.093128e-17
# 4-X-global-X-all_MHC-II-Ipresentation         2.927474e-13     5.511503e-17
#
#                                            ENSG00000010295  ENSG00000010310  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.060938e-16     2.898303e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.684439e-16     2.086344e-15
# 2-X-global-X-all_type-IandII-ifn-response     4.066039e-16     3.220145e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.997274e-16     1.298788e-15
# 4-X-global-X-all_MHC-II-Ipresentation         3.097701e-16     4.445788e-15
#
#                                            ENSG00000010318  ENSG00000010319  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.796428e-15     9.402709e-17
# 1-X-global-X-all_JAK-STAT_signaling           3.209610e-15     7.252739e-17
# 2-X-global-X-all_type-IandII-ifn-response     8.368845e-15     1.512734e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.550786e-15     4.926073e-17
# 4-X-global-X-all_MHC-II-Ipresentation         7.516106e-15     1.307460e-16
#
#                                            ENSG00000010327  ENSG00000010404  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.298777e-15     5.965437e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.685817e-15     6.343347e-15
# 2-X-global-X-all_type-IandII-ifn-response     9.123738e-15     1.233619e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.810099e-15     5.579149e-15
# 4-X-global-X-all_MHC-II-Ipresentation         8.231016e-15     9.416274e-15
#
#                                            ENSG00000010539  ENSG00000010610  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.359931e-15     2.261084e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.229710e-15     1.702354e-15
# 2-X-global-X-all_type-IandII-ifn-response     5.402575e-15     4.519514e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.726101e-15     1.281465e-15
# 4-X-global-X-all_MHC-II-Ipresentation         3.785161e-15     4.013985e-15
#
#                                            ENSG00000010671  ENSG00000010704  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      9.429645e-16     6.608518e-16
# 1-X-global-X-all_JAK-STAT_signaling           6.288883e-16     5.453570e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.691937e-15     6.996381e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.793308e-16     2.903665e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.481292e-15     7.955461e-16
#
#                                            ENSG00000010803  ENSG00000010810  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.369699e-15     6.994850e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.151942e-15     4.957972e-15
# 2-X-global-X-all_type-IandII-ifn-response     7.113695e-15     1.612753e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.298541e-15     3.688235e-15
# 4-X-global-X-all_MHC-II-Ipresentation         6.622806e-15     1.318995e-14
#
#                                            ENSG00000010818  ENSG00000011028  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.258453e-15     6.488179e-16
# 1-X-global-X-all_JAK-STAT_signaling           4.293926e-15     5.121415e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.171390e-14     1.226038e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.650921e-15     5.518800e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.144602e-14     1.037950e-15
#
#                                            ENSG00000011105  ENSG00000011114  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.232954e-15     8.259225e-15
# 1-X-global-X-all_JAK-STAT_signaling           8.346084e-16     5.822851e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.971074e-15     1.505265e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.462715e-16     4.194466e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.891287e-15     1.369794e-14
#
#                                            ENSG00000011143  ENSG00000011198  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.529452e-17     1.334629e-14
# 1-X-global-X-all_JAK-STAT_signaling           1.852773e-17     1.074456e-14
# 2-X-global-X-all_type-IandII-ifn-response     1.108921e-17     1.706682e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.576347e-17     5.628425e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.295553e-17     1.937989e-14
#
#                                            ENSG00000011258  ENSG00000011295  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.513301e-15     1.096484e-14
# 1-X-global-X-all_JAK-STAT_signaling           6.000131e-15     6.742806e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.096346e-14     2.251534e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.749025e-15     5.536345e-15
# 4-X-global-X-all_MHC-II-Ipresentation         6.460461e-15     1.797639e-14
#
#                                            ENSG00000011376  ENSG00000011422  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.295159e-15     1.218516e-14
# 1-X-global-X-all_JAK-STAT_signaling           3.886795e-15     8.244659e-15
# 2-X-global-X-all_type-IandII-ifn-response     8.587518e-15     2.145734e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.756503e-15     4.592841e-02
# 4-X-global-X-all_MHC-II-Ipresentation         8.104657e-15     1.896766e-14
#
#                                            ENSG00000011451  ENSG00000011523  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.266947e-15     8.141386e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.331358e-15     5.934128e-15
# 2-X-global-X-all_type-IandII-ifn-response     7.629934e-15     1.335859e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.444979e-15     3.444854e-15
# 4-X-global-X-all_MHC-II-Ipresentation         6.746673e-15     1.005801e-14
#
#                                            ...  ENSG00000258366  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling   ...     3.645871e-15
# 1-X-global-X-all_JAK-STAT_signaling        ...     2.607242e-15
# 2-X-global-X-all_type-IandII-ifn-response  ...     6.046338e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling    ...     1.877862e-15
# 4-X-global-X-all_MHC-II-Ipresentation      ...     4.087748e-15
#
#                                            ENSG00000258429  ENSG00000258472  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.401408e-16     3.342676e-15
# 1-X-global-X-all_JAK-STAT_signaling           9.505292e-17     2.483478e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.123906e-16     5.546975e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.305900e-17     1.416931e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.193207e-16     5.056535e-15
#
#                                            ENSG00000258484  ENSG00000258659  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.525901e-16     9.102033e-17
# 1-X-global-X-all_JAK-STAT_signaling           7.534274e-17     6.349615e-17
# 2-X-global-X-all_type-IandII-ifn-response     2.419647e-16     1.622767e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.712223e-17     3.893402e-17
# 4-X-global-X-all_MHC-II-Ipresentation         2.070941e-16     9.555364e-17
#
#                                            ENSG00000258818  ENSG00000258839  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.948101e-16     3.610575e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.110167e-16     2.635112e-15
# 2-X-global-X-all_type-IandII-ifn-response     4.868939e-16     6.388320e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.547596e-16     1.916352e-15
# 4-X-global-X-all_MHC-II-Ipresentation         4.292638e-16     4.296243e-15
#
#                                            ENSG00000258890  ENSG00000259207  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.220158e-14     8.549272e-02
# 1-X-global-X-all_JAK-STAT_signaling           8.782767e-15     7.473783e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.256476e-14     1.334128e-12
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.521547e-15     5.780070e-18
# 4-X-global-X-all_MHC-II-Ipresentation         1.920247e-14     1.954287e-14
#
#                                            ENSG00000259431  ENSG00000259956  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      8.723647e-17     3.414395e-15
# 1-X-global-X-all_JAK-STAT_signaling           6.794515e-17     2.903801e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.651314e-16     7.391788e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.881590e-17     1.920240e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.481355e-16     6.375876e-15
#
#                                            ENSG00000260001  ENSG00000260314  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.535458e-16     1.464874e-16
# 1-X-global-X-all_JAK-STAT_signaling           2.559804e-16     1.029663e-16
# 2-X-global-X-all_type-IandII-ifn-response     5.468393e-16     2.397672e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.821485e-16     7.234602e-17
# 4-X-global-X-all_MHC-II-Ipresentation         5.274301e-16     2.245931e-16
#
#                                            ENSG00000260456  ENSG00000261052  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.485363e-17     6.012634e-15
# 1-X-global-X-all_JAK-STAT_signaling           6.594303e-17     4.491897e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.513144e-16     9.202406e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.776062e-17     3.264414e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.427632e-16     7.973914e-15
#
#                                            ENSG00000261150  ENSG00000261221  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.721938e-15     5.667378e-16
# 1-X-global-X-all_JAK-STAT_signaling           1.225061e-15     4.062656e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.574863e-15     9.714571e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       8.243155e-16     2.920930e-16
# 4-X-global-X-all_MHC-II-Ipresentation         2.561329e-15     8.926536e-16
#
#                                            ENSG00000261236  ENSG00000261371  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.033656e-17     2.643482e-15
# 1-X-global-X-all_JAK-STAT_signaling           5.188554e-17     1.763678e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.304188e-16     5.205148e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.719852e-17     1.326053e-15
# 4-X-global-X-all_MHC-II-Ipresentation         8.962590e-17     4.570211e-15
#
#                                            ENSG00000261609  ENSG00000262246  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.226436e-15     1.978499e-14
# 1-X-global-X-all_JAK-STAT_signaling           4.521308e-15     1.408427e-14
# 2-X-global-X-all_type-IandII-ifn-response     1.250974e-14     3.455341e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.877776e-15     1.010040e-14
# 4-X-global-X-all_MHC-II-Ipresentation         1.106371e-14     3.228525e-14
#
#                                            ENSG00000262655  ENSG00000262814  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.362208e-15     7.741773e-17
# 1-X-global-X-all_JAK-STAT_signaling           3.149769e-15     5.540135e-17
# 2-X-global-X-all_type-IandII-ifn-response     7.129307e-15     1.344167e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.224609e-15     3.944755e-17
# 4-X-global-X-all_MHC-II-Ipresentation         6.564457e-15     1.155080e-16
#
#                                            ENSG00000262919  ENSG00000263002  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.111617e-17     9.578402e-17
# 1-X-global-X-all_JAK-STAT_signaling           3.738734e-17     7.021771e-17
# 2-X-global-X-all_type-IandII-ifn-response     8.768200e-17     1.512192e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.825527e-17     5.109446e-17
# 4-X-global-X-all_MHC-II-Ipresentation         8.388902e-17     1.493551e-16
#
#                                            ENSG00000263155  ENSG00000263465  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.546607e-16     3.822585e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.993654e-16     2.406891e-15
# 2-X-global-X-all_type-IandII-ifn-response     8.369960e-16     6.928094e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.798350e-16     1.935663e-15
# 4-X-global-X-all_MHC-II-Ipresentation         5.596948e-16     5.971046e-15
#
#                                            ENSG00000263528  ENSG00000263874  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.018995e-15     6.512864e-15
# 1-X-global-X-all_JAK-STAT_signaling           7.293796e-16     4.087012e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.748436e-15     1.087550e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.133579e-16     3.408027e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.349745e-15     9.888631e-15
#
#                                            ENSG00000263961  ENSG00000264343  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.505194e-16     2.567227e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.636235e-16     1.799015e-15
# 2-X-global-X-all_type-IandII-ifn-response     9.172354e-16     4.480445e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.689566e-16     1.270593e-15
# 4-X-global-X-all_MHC-II-Ipresentation         8.254209e-16     3.994335e-15
#
#                                            ENSG00000264364  ENSG00000264522  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.213103e-14     4.251839e-15
# 1-X-global-X-all_JAK-STAT_signaling           9.278553e-15     3.175389e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.113424e-14     7.303293e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.594744e-15     2.295704e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.688768e-14     6.273860e-15
#
#                                            ENSG00000265491  ENSG00000265808  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.121996e-14     2.219049e-15
# 1-X-global-X-all_JAK-STAT_signaling           7.926377e-15     1.528014e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.047997e-14     4.126417e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.792229e-15     1.149764e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.804189e-14     3.624649e-15
#
#                                            ENSG00000265972  ENSG00000266028  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.464094e-21     4.843549e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.478781e-21     2.745412e-15
# 2-X-global-X-all_type-IandII-ifn-response     3.890777e-14     8.808792e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.577669e-19     2.264400e-15
# 4-X-global-X-all_MHC-II-Ipresentation         4.077153e-12     7.948250e-15
#
#                                            ENSG00000266094  ENSG00000266173  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.225243e-14     5.706092e-15
# 1-X-global-X-all_JAK-STAT_signaling           8.463842e-15     5.625122e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.200497e-14     1.352081e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.326297e-15     4.315580e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.137793e-14     1.057881e-14
#
#                                            ENSG00000266338  ENSG00000266412  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      2.140595e-16     6.619803e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.521338e-16     3.832995e-15
# 2-X-global-X-all_type-IandII-ifn-response     3.747257e-16     1.216888e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.100926e-16     3.332992e-15
# 4-X-global-X-all_MHC-II-Ipresentation         3.369183e-16     1.062247e-14
#
#                                            ENSG00000266714  ENSG00000266964  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.552149e-14     1.908879e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.089786e-14     1.439505e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.679025e-14     2.880407e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       8.041040e-15     9.944855e-16
# 4-X-global-X-all_MHC-II-Ipresentation         2.217143e-14     2.941983e-15
#
#                                            ENSG00000266967  ENSG00000267041  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.015366e-15     3.046391e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.734205e-15     2.232630e-15
# 2-X-global-X-all_type-IandII-ifn-response     8.678579e-15     5.069106e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.704169e-15     1.600880e-15
# 4-X-global-X-all_MHC-II-Ipresentation         6.336982e-15     4.479977e-15
#
#                                            ENSG00000267368  ENSG00000267534  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.406247e-15     5.373119e-15
# 1-X-global-X-all_JAK-STAT_signaling           4.290141e-15     3.835332e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.045486e-14     8.955988e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.148652e-15     2.841633e-15
# 4-X-global-X-all_MHC-II-Ipresentation         9.517968e-15     6.854350e-15
#
#                                            ENSG00000267673  ENSG00000267680  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      8.150167e-17     3.055246e-15
# 1-X-global-X-all_JAK-STAT_signaling           5.776800e-17     3.080137e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.378369e-16     7.418208e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.124478e-17     2.278279e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.271420e-16     6.562097e-15
#
#                                            ENSG00000267796  ENSG00000267855  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.654028e-15     1.522567e-17
# 1-X-global-X-all_JAK-STAT_signaling           1.072495e-15     1.824514e-17
# 2-X-global-X-all_type-IandII-ifn-response     2.779135e-15     3.082870e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.708377e-16     1.632759e-17
# 4-X-global-X-all_MHC-II-Ipresentation         2.440074e-15     1.442654e-17
#
#                                            ENSG00000268350  ENSG00000269028  \
# ...
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.026419e-15     5.645237e-15
# 1-X-global-X-all_JAK-STAT_signaling           7.452339e-16     3.960354e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.660307e-15     9.449035e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.405077e-16     2.917905e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.470555e-15     8.454437e-15
#
#                                            ENSG00000274211  ENSG00000274290  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.795582e-14     2.702434e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.586842e-02     1.814415e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.877398e-14     4.457812e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.215267e-15     1.414278e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.699981e-14     3.647664e-15
#
#                                            ENSG00000274349  ENSG00000274523  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.430626e-16     1.189656e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.226036e-16     8.523518e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.633935e-16     2.134063e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.924431e-17     6.187411e-16
# 4-X-global-X-all_MHC-II-Ipresentation         1.992294e-16     1.594284e-15
#
#                                            ENSG00000274588  ENSG00000274618  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.536729e-17     1.416133e-15
# 1-X-global-X-all_JAK-STAT_signaling           4.819035e-17     1.015853e-15
# 2-X-global-X-all_type-IandII-ifn-response     4.223110e-17     2.209380e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.695911e-17     7.183008e-16
# 4-X-global-X-all_MHC-II-Ipresentation         8.232207e-17     1.494044e-15
#
#                                            ENSG00000274736  ENSG00000274847  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.400865e-16     5.195221e-16
# 1-X-global-X-all_JAK-STAT_signaling           9.575068e-17     3.222299e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.233611e-16     8.540675e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.000434e-17     2.756505e-16
# 4-X-global-X-all_MHC-II-Ipresentation         2.140591e-16     7.419333e-16
#
#                                            ENSG00000274997  ENSG00000275004  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.350010e-15     8.089051e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.554174e-15     5.626779e-15
# 2-X-global-X-all_type-IandII-ifn-response     5.849194e-15     1.231996e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.565886e-15     4.284418e-15
# 4-X-global-X-all_MHC-II-Ipresentation         5.371199e-15     1.208896e-14
#
#                                            ENSG00000275023  ENSG00000275063  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.293131e-14     1.671981e-16
# 1-X-global-X-all_JAK-STAT_signaling           8.377969e-15     1.220996e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.332406e-14     2.738222e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.415221e-15     8.565777e-17
# 4-X-global-X-all_MHC-II-Ipresentation         2.061811e-14     2.600618e-16
#
#                                            ENSG00000275066  ENSG00000275074  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.797019e-15     7.900086e-17
# 1-X-global-X-all_JAK-STAT_signaling           3.787461e-15     5.792419e-17
# 2-X-global-X-all_type-IandII-ifn-response     1.034807e-14     1.350817e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.958439e-15     4.013432e-17
# 4-X-global-X-all_MHC-II-Ipresentation         8.655608e-15     1.210998e-16
#
#                                            ENSG00000275111  ENSG00000275152  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.409229e-16     1.114659e-15
# 1-X-global-X-all_JAK-STAT_signaling           5.407849e-16     7.823435e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.187123e-15     1.899515e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.583285e-16     5.392410e-16
# 4-X-global-X-all_MHC-II-Ipresentation         9.576444e-16     1.582549e-15
#
#                                            ENSG00000275183  ENSG00000275302  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      9.597484e-15     7.978631e-17
# 1-X-global-X-all_JAK-STAT_signaling           7.277106e-15     5.393723e-17
# 2-X-global-X-all_type-IandII-ifn-response     1.700016e-14     1.208248e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       5.235837e-15     2.654216e-04
# 4-X-global-X-all_MHC-II-Ipresentation         1.345470e-14     1.169025e-16
#
#                                            ENSG00000275342  ENSG00000275379  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      6.914698e-17     8.909297e-16
# 1-X-global-X-all_JAK-STAT_signaling           5.099035e-17     8.525603e-16
# 2-X-global-X-all_type-IandII-ifn-response     1.047446e-16     1.559446e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.670569e-17     3.248954e-16
# 4-X-global-X-all_MHC-II-Ipresentation         8.369881e-17     7.183852e-16
#
#                                            ENSG00000275385  ENSG00000275395  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.453773e-16     1.981579e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.076939e-16     1.525151e-15
# 2-X-global-X-all_type-IandII-ifn-response     8.857598e-17     3.470616e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.156638e-17     1.003231e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.510365e-16     3.393169e-15
#
#                                            ENSG00000275713  ENSG00000275714  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.921179e-15     4.137639e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.280801e-15     2.943616e-15
# 2-X-global-X-all_type-IandII-ifn-response     8.363291e-15     5.567122e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.336888e-15     2.203910e-15
# 4-X-global-X-all_MHC-II-Ipresentation         7.038341e-15     6.262280e-15
#
#                                            ENSG00000275718  ENSG00000275835  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.839552e-16     5.105388e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.293213e-16     4.088695e-15
# 2-X-global-X-all_type-IandII-ifn-response     7.351687e-16     9.777562e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.862222e-16     2.805088e-15
# 4-X-global-X-all_MHC-II-Ipresentation         5.464008e-16     8.407109e-15
#
#                                            ENSG00000276023  ENSG00000276045  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.663651e-15     1.326233e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.268471e-15     1.084237e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.890149e-15     2.831091e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.466038e-16     8.076631e-16
# 4-X-global-X-all_MHC-II-Ipresentation         2.596749e-15     2.487853e-15
#
#                                            ENSG00000276070  ENSG00000276085  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.878752e-16     2.563560e-15
# 1-X-global-X-all_JAK-STAT_signaling           4.450871e-16     2.227770e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.384054e-15     5.624248e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.892795e-16     1.527555e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.239088e-15     3.778954e-15
#
#                                            ENSG00000276293  ENSG00000276368  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.658064e-16     5.565667e-16
# 1-X-global-X-all_JAK-STAT_signaling           9.743461e-17     5.918319e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.897647e-16     1.324226e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       8.528487e-17     4.304186e-16
# 4-X-global-X-all_MHC-II-Ipresentation         2.497380e-16     1.117075e-15
#
#                                            ENSG00000276600  ENSG00000276644  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.789763e-17     4.143002e-16
# 1-X-global-X-all_JAK-STAT_signaling           1.474736e-16     3.151830e-16
# 2-X-global-X-all_type-IandII-ifn-response     2.160315e-20     6.975163e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.529014e-17     2.249635e-16
# 4-X-global-X-all_MHC-II-Ipresentation         9.567059e-04     6.661691e-16
#
#                                            ENSG00000276903  ENSG00000276966  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      9.396409e-15     6.506600e-15
# 1-X-global-X-all_JAK-STAT_signaling           7.196580e-15     6.551331e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.648898e-14     1.547315e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.582424e-15     3.713669e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.383280e-14     1.265829e-14
#
#                                            ENSG00000277075  ENSG00000277150  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.849476e-15     1.134380e-16
# 1-X-global-X-all_JAK-STAT_signaling           3.357743e-15     9.169022e-17
# 2-X-global-X-all_type-IandII-ifn-response     7.433115e-15     1.657189e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.849991e-15     5.599931e-17
# 4-X-global-X-all_MHC-II-Ipresentation         7.354873e-15     7.661399e-17
#
#                                            ENSG00000277157  ENSG00000277224  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.396085e-15     4.231323e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.012232e-15     3.071628e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.335377e-15     7.323323e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       7.427176e-16     2.278213e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.003120e-15     5.712741e-15
#
#                                            ENSG00000277443  ENSG00000277586  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.941427e-15     6.919937e-17
# 1-X-global-X-all_JAK-STAT_signaling           5.613717e-15     5.575331e-17
# 2-X-global-X-all_type-IandII-ifn-response     1.256958e-14     1.652334e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.811076e-02     4.866787e-17
# 4-X-global-X-all_MHC-II-Ipresentation         1.192768e-14     1.488145e-16
#
#                                            ENSG00000277632  ENSG00000277734  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.946152e-15     1.990871e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.801145e-15     1.498526e-15
# 2-X-global-X-all_type-IandII-ifn-response     7.198016e-15     3.960437e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.033421e-15     1.074724e-15
# 4-X-global-X-all_MHC-II-Ipresentation         6.192392e-15     3.681148e-15
#
#                                            ENSG00000277791  ENSG00000277856  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.517424e-16     1.031648e-16
# 1-X-global-X-all_JAK-STAT_signaling           1.031221e-16     9.340810e-17
# 2-X-global-X-all_type-IandII-ifn-response     1.539193e-16     2.008659e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       8.176931e-17     7.076371e-17
# 4-X-global-X-all_MHC-II-Ipresentation         3.179130e-16     7.606854e-17
#
#                                            ENSG00000277972  ENSG00000278195  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.887768e-17     6.866217e-16
# 1-X-global-X-all_JAK-STAT_signaling           2.848147e-17     4.457259e-16
# 2-X-global-X-all_type-IandII-ifn-response     7.072772e-17     1.184375e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.024212e-17     3.590044e-16
# 4-X-global-X-all_MHC-II-Ipresentation         6.345811e-17     9.783239e-16
#
#                                            ENSG00000278196  ENSG00000278259  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      7.750860e-17     7.269628e-15
# 1-X-global-X-all_JAK-STAT_signaling           5.614986e-17     5.109722e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.312159e-16     1.319864e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.967430e-17     2.992973e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.202516e-16     1.211293e-14
#
#                                            ENSG00000278384  ENSG00000278463  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      4.167619e-15     2.094728e-15
# 1-X-global-X-all_JAK-STAT_signaling           3.155481e-15     1.391950e-15
# 2-X-global-X-all_type-IandII-ifn-response     6.846608e-15     3.988576e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       2.517382e-15     1.353261e-15
# 4-X-global-X-all_MHC-II-Ipresentation         6.619590e-15     3.241762e-15
#
#                                            ENSG00000278535  ENSG00000278558  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      9.358473e-17     9.303257e-17
# 1-X-global-X-all_JAK-STAT_signaling           6.801328e-17     6.614296e-17
# 2-X-global-X-all_type-IandII-ifn-response     1.574773e-16     1.338650e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.856344e-17     4.742648e-17
# 4-X-global-X-all_MHC-II-Ipresentation         1.387026e-16     1.469283e-16
#
#                                            ENSG00000278615  ENSG00000278619  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      5.389548e-17     8.076534e-17
# 1-X-global-X-all_JAK-STAT_signaling           3.682292e-17     6.932764e-17
# 2-X-global-X-all_type-IandII-ifn-response     9.768614e-17     1.408319e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       3.002872e-17     4.329238e-17
# 4-X-global-X-all_MHC-II-Ipresentation         9.186501e-17     9.679482e-17
#
#                                            ENSG00000278637  ENSG00000278662  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.604406e-15     2.332613e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.214989e-15     1.637209e-15
# 2-X-global-X-all_type-IandII-ifn-response     2.763175e-15     3.994905e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       9.039299e-16     1.197679e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.463584e-15     3.413538e-15
#
#                                            ENSG00000278677  ENSG00000278705  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.923066e-15     1.979497e-15
# 1-X-global-X-all_JAK-STAT_signaling           1.386650e-15     1.631433e-15
# 2-X-global-X-all_type-IandII-ifn-response     3.144978e-15     3.659637e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.025573e-15     1.188532e-15
# 4-X-global-X-all_MHC-II-Ipresentation         2.854015e-15     1.960062e-15
#
#                                            ENSG00000278817  ENSG00000278828  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      3.506886e-16     5.575245e-15
# 1-X-global-X-all_JAK-STAT_signaling           2.437689e-16     4.031500e-15
# 2-X-global-X-all_type-IandII-ifn-response     5.858709e-16     6.734683e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       1.864964e-16     2.036101e-15
# 4-X-global-X-all_MHC-II-Ipresentation         5.124434e-16     7.823581e-15
#
#                                            ENSG00000280670  ENSG00000280789  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      8.837729e-17     2.977278e-15
# 1-X-global-X-all_JAK-STAT_signaling           6.686839e-17     2.288526e-15
# 2-X-global-X-all_type-IandII-ifn-response     1.542614e-16     4.606112e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling       4.384817e-17     1.668691e-15
# 4-X-global-X-all_MHC-II-Ipresentation         1.331931e-16     5.220355e-15
#
#                                            ENSG00000282608
# 0-X-global-X-all_IL6-JAK-STAT3_signaling      1.527173e-16
# 1-X-global-X-all_JAK-STAT_signaling           9.870781e-17
# 2-X-global-X-all_type-IandII-ifn-response     2.549332e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling       6.243284e-17
# 4-X-global-X-all_MHC-II-Ipresentation         1.964017e-16
#
# [5 rows x 8253 columns]

# %%
# Subset to consider only GLOBAL & cell-type specific

geneWeights['SPECTRA_CellTypeFactor'] = geneWeights.index.str.split('-X-').str[1]
geneWeights = geneWeights[geneWeights['SPECTRA_CellTypeFactor'].isin(['global'] + [celltype])]
geneWeights.drop(columns=['SPECTRA_CellTypeFactor'], inplace=True)
geneWeights
# Out:
#                                                     ENSG00000000003  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.662220e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.108171e-15
# 2-X-global-X-all_type-IandII-ifn-response              2.737120e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                8.518205e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  2.003873e-15
# 5-X-global-X-all_complement_production                 6.696203e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.090489e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.350206e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      6.070895e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             8.660105e-15
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     5.357709e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     6.415568e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             7.481043e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    4.491818e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           8.822021e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              5.199877e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     4.218337e-15
#
#                                                     ENSG00000000457  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               3.255362e-14
# 1-X-global-X-all_JAK-STAT_signaling                    2.299332e-14
# 2-X-global-X-all_type-IandII-ifn-response              5.744951e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.570927e-14
# 4-X-global-X-all_MHC-II-Ipresentation                  5.072165e-14
# 5-X-global-X-all_complement_production                 1.248215e-13
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 7.335108e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.200517e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      7.128549e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             8.053797e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     5.523729e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     7.207641e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             5.862107e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    5.750084e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           9.893028e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              3.555914e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     3.567333e-14
#
#                                                     ENSG00000000938  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               7.108393e-15
# 1-X-global-X-all_JAK-STAT_signaling                    4.758343e-15
# 2-X-global-X-all_type-IandII-ifn-response              1.259858e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling                3.516911e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  1.220851e-14
# 5-X-global-X-all_complement_production                 3.086303e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 5.474603e-12
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.179893e-12
# 105-X-T_CD8_NonNaive-X-chemokines                      2.989456e-12
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.016615e-12
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     3.349086e-12
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     3.547921e-12
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.755761e-10
# 110-X-T_CD8_NonNaive-X-IFN_response                    1.912745e-12
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           4.311457e-12
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.802999e-12
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.660089e-12
#
#                                                     ENSG00000000971  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               4.331535e-17
# 1-X-global-X-all_JAK-STAT_signaling                    3.819025e-17
# 2-X-global-X-all_type-IandII-ifn-response              5.163268e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling                3.303363e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  4.364942e-17
# 5-X-global-X-all_complement_production                 6.847235e-04
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 6.107178e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             2.842475e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      1.115421e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             7.611938e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     3.283033e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     9.569131e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             4.706201e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    1.075839e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.123531e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              5.995352e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     6.736797e-14
#
#                                                     ENSG00000001036  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               5.497816e-16
# 1-X-global-X-all_JAK-STAT_signaling                    3.985897e-16
# 2-X-global-X-all_type-IandII-ifn-response              1.113090e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                3.045630e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  1.004335e-15
# 5-X-global-X-all_complement_production                 2.436982e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.245685e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.920222e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      5.380194e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.306371e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     8.402289e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     3.703685e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             9.674037e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    7.942665e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           8.404100e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              3.682996e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     4.250202e-14
#
#                                                     ENSG00000001084  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               3.206445e-15
# 1-X-global-X-all_JAK-STAT_signaling                    2.137640e-15
# 2-X-global-X-all_type-IandII-ifn-response              5.587422e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.666658e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  4.993081e-15
# 5-X-global-X-all_complement_production                 1.181108e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 4.929860e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             6.288068e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      2.864340e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             9.292347e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     3.797067e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     5.285095e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.654137e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    8.493520e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           6.427726e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              4.131390e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     2.246009e-14
#
#                                                     ENSG00000001167  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.057057e-15
# 1-X-global-X-all_JAK-STAT_signaling                    3.022476e-17
# 2-X-global-X-all_type-IandII-ifn-response              4.612209e-20
# 3-X-global-X-all_TNF-via-NFkB_signaling                9.245895e-20
# 4-X-global-X-all_MHC-II-Ipresentation                  1.373877e-03
# 5-X-global-X-all_complement_production                 3.295747e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 9.713088e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             4.299122e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      4.530898e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             8.282287e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     3.496142e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     7.248452e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             8.054230e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    6.193889e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           5.884884e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              4.301255e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     3.679851e-14
#
#                                                     ENSG00000001460  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               4.152293e-15
# 1-X-global-X-all_JAK-STAT_signaling                    3.077916e-15
# 2-X-global-X-all_type-IandII-ifn-response              7.008616e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                2.090478e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  5.995152e-15
# 5-X-global-X-all_complement_production                 1.351449e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 3.232459e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             2.593453e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      3.931388e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             4.389537e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     8.326601e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     2.103598e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             3.588983e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    8.598441e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           9.559487e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.899598e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     9.457780e-15
#
#                                                     ENSG00000001461  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.354309e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.422393e-15
# 2-X-global-X-all_type-IandII-ifn-response              3.292712e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                8.147142e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  1.772227e-15
# 5-X-global-X-all_complement_production                 6.277006e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.034619e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             7.898642e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      9.356140e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.504498e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.062084e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     5.741010e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.504739e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    1.413949e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.089085e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              6.246183e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     5.471897e-14
#
#                                                     ENSG00000001561  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               7.388704e-15
# 1-X-global-X-all_JAK-STAT_signaling                    6.019337e-15
# 2-X-global-X-all_type-IandII-ifn-response              1.330521e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling                4.175936e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  1.293963e-14
# 5-X-global-X-all_complement_production                 2.110639e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 2.245131e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.609691e-13
# 105-X-T_CD8_NonNaive-X-chemokines                      1.732895e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             2.242679e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.747663e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     6.616953e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             7.081364e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    3.431782e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.413485e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.094895e-13
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     9.317953e-14
#
#                                                     ENSG00000001630  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.925771e-14
# 1-X-global-X-all_JAK-STAT_signaling                    1.175481e-14
# 2-X-global-X-all_type-IandII-ifn-response              3.830525e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.106037e-14
# 4-X-global-X-all_MHC-II-Ipresentation                  3.285941e-14
# 5-X-global-X-all_complement_production                 5.986645e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.386669e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             2.715689e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      1.170955e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.398403e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.049065e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     9.569879e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.123155e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    7.730274e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           8.892011e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              4.290663e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     2.272894e-14
#
#                                                     ENSG00000001631  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.214693e-15
# 1-X-global-X-all_JAK-STAT_signaling                    2.047948e-15
# 2-X-global-X-all_type-IandII-ifn-response              2.419155e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.814194e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  2.689005e-15
# 5-X-global-X-all_complement_production                 3.683554e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.903473e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.019458e-13
# 105-X-T_CD8_NonNaive-X-chemokines                      1.519327e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.584764e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.001494e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.032304e-13
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             7.763489e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    7.502876e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.483000e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              6.375410e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     6.041162e-14
#
#                                                     ENSG00000002016  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.712155e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.608910e-15
# 2-X-global-X-all_type-IandII-ifn-response              4.482577e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.387727e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  3.884560e-15
# 5-X-global-X-all_complement_production                 7.648966e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 2.730581e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             2.390315e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      2.064259e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             3.059115e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.742126e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     3.464376e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             2.033539e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    3.250342e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           4.536644e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.171116e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.814236e-14
#
#                                                     ENSG00000002330  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               9.305980e-17
# 1-X-global-X-all_JAK-STAT_signaling                    7.660323e-17
# 2-X-global-X-all_type-IandII-ifn-response              8.793617e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling                4.354169e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  5.481054e-17
# 5-X-global-X-all_complement_production                 1.341158e-16
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.275993e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.971888e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      1.765631e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.496207e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.170640e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     2.284155e-13
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             5.976175e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    3.164909e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.738791e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              9.183607e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     7.587484e-14
#
#                                                     ENSG00000002549  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               6.402679e-15
# 1-X-global-X-all_JAK-STAT_signaling                    4.314491e-15
# 2-X-global-X-all_type-IandII-ifn-response              1.321619e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling                3.262960e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  1.201393e-14
# 5-X-global-X-all_complement_production                 2.726748e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 3.372324e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.102808e-13
# 105-X-T_CD8_NonNaive-X-chemokines                      1.359064e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             6.424776e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.264991e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.354257e-13
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             3.809721e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.306482e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.702819e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              7.026984e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     6.305162e-14
#
#                                                     ENSG00000002586  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.026012e-15
# 1-X-global-X-all_JAK-STAT_signaling                    7.025332e-16
# 2-X-global-X-all_type-IandII-ifn-response              1.966470e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                5.552844e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  2.167673e-15
# 5-X-global-X-all_complement_production                 2.910159e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 5.664745e-18
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             2.146647e-12
# 105-X-T_CD8_NonNaive-X-chemokines                      3.996628e-16
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.081919e-16
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.105763e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     2.637309e-17
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.876679e-16
# 110-X-T_CD8_NonNaive-X-IFN_response                    8.673850e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.693950e-17
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              9.663559e-02
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.588577e-18
#
#                                                     ENSG00000002587  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.450719e-15
# 1-X-global-X-all_JAK-STAT_signaling                    2.407704e-15
# 2-X-global-X-all_type-IandII-ifn-response              6.705790e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                2.713050e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  4.883179e-15
# 5-X-global-X-all_complement_production                 9.775420e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 7.980189e-16
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             4.349492e-16
# 105-X-T_CD8_NonNaive-X-chemokines                      9.907005e-16
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             2.366754e-16
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     5.480881e-16
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     5.939282e-16
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             7.712479e-16
# 110-X-T_CD8_NonNaive-X-IFN_response                    8.660795e-16
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.243779e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              6.343907e-16
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     5.122433e-16
#
#                                                     ENSG00000002822  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               9.784722e-16
# 1-X-global-X-all_JAK-STAT_signaling                    1.009024e-15
# 2-X-global-X-all_type-IandII-ifn-response              2.624803e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                7.158314e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  1.917551e-15
# 5-X-global-X-all_complement_production                 6.090094e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 3.441501e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.764734e-13
# 105-X-T_CD8_NonNaive-X-chemokines                      2.288536e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.945232e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.335312e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     2.500832e-13
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             3.485484e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    1.717680e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           3.025429e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.204094e-13
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     9.945609e-14
#
#                                                     ENSG00000002933  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               3.306471e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.956402e-15
# 2-X-global-X-all_type-IandII-ifn-response              5.661512e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.694304e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  4.103691e-15
# 5-X-global-X-all_complement_production                 1.246441e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 4.463966e-15
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             2.516305e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      8.831061e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             7.506841e-15
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     6.930852e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     8.003423e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.269736e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    6.745782e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           4.181176e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              4.896380e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     4.615076e-15
#
#                                                     ENSG00000003147  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.791004e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.309719e-15
# 2-X-global-X-all_type-IandII-ifn-response              2.749719e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                9.871374e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  2.738183e-15
# 5-X-global-X-all_complement_production                 5.711776e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.417673e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.451959e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      1.575167e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.055154e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.596339e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     8.329919e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.487926e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    1.059803e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           2.109966e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              9.729046e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     6.165596e-15
#
#                                                     ENSG00000003249  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.249072e-16
# 1-X-global-X-all_JAK-STAT_signaling                    8.795213e-17
# 2-X-global-X-all_type-IandII-ifn-response              2.074780e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling                5.701189e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  1.736873e-16
# 5-X-global-X-all_complement_production                 2.453138e-16
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 6.643336e-15
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.195817e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      6.283237e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             9.193622e-15
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     5.041958e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     7.632911e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             8.512269e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    5.615074e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           5.781471e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              3.832019e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     2.743598e-15
#
#                                                     ENSG00000003400  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               9.095464e-16
# 1-X-global-X-all_JAK-STAT_signaling                    6.125022e-16
# 2-X-global-X-all_type-IandII-ifn-response              1.727027e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                4.908815e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  1.551762e-15
# 5-X-global-X-all_complement_production                 3.549141e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 2.787905e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.988990e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      7.173167e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             6.915282e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     5.762934e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     6.168343e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             3.618941e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    4.710707e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           3.142110e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              3.431910e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     2.983595e-14
#
#                                                     ENSG00000003402  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               3.303878e-15
# 1-X-global-X-all_JAK-STAT_signaling                    2.297789e-15
# 2-X-global-X-all_type-IandII-ifn-response              5.366734e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.196287e-02
# 4-X-global-X-all_MHC-II-Ipresentation                  4.805225e-15
# 5-X-global-X-all_complement_production                 1.290195e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.470553e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.033994e-13
# 105-X-T_CD8_NonNaive-X-chemokines                      1.016720e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.451474e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     3.250546e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     3.417671e-13
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             4.013229e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    3.017488e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           4.182645e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.551629e-13
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.612726e-13
#
#                                                     ENSG00000003436  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               9.911320e-15
# 1-X-global-X-all_JAK-STAT_signaling                    4.633865e-15
# 2-X-global-X-all_type-IandII-ifn-response              1.836575e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling                4.443596e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  8.679454e-15
# 5-X-global-X-all_complement_production                 3.530132e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 2.485938e-15
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.446281e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      1.046796e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             2.142927e-15
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.336531e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.267569e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             3.929151e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.582858e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.189799e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.210081e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     5.934281e-16
#
#                                                     ENSG00000004059  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               8.343250e-16
# 1-X-global-X-all_JAK-STAT_signaling                    5.832843e-16
# 2-X-global-X-all_type-IandII-ifn-response              1.757488e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                3.941989e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  1.554731e-15
# 5-X-global-X-all_complement_production                 3.210347e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 4.649040e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.414312e-13
# 105-X-T_CD8_NonNaive-X-chemokines                      3.093976e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             3.889259e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.503028e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.343654e-13
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             3.871888e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    3.925629e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           2.491990e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.420086e-13
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.082985e-13
#
#                                                     ENSG00000004139  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.954510e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.416043e-15
# 2-X-global-X-all_type-IandII-ifn-response              3.390515e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.042244e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  3.016340e-15
# 5-X-global-X-all_complement_production                 7.251616e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 5.241836e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.551414e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      4.009897e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.715052e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     3.507000e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     4.666643e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             2.774393e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    5.570675e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           6.035296e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              2.698282e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     2.162406e-14
#
#                                                     ENSG00000004142  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.370393e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.632212e-15
# 2-X-global-X-all_type-IandII-ifn-response              4.250693e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.242361e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  3.933836e-15
# 5-X-global-X-all_complement_production                 9.033076e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.326704e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             8.120164e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      1.001212e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.296893e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     7.071425e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     7.519643e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.141903e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    8.923616e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           6.657842e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              4.340405e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     4.280839e-14
#
#                                                     ENSG00000004399  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.402237e-15
# 1-X-global-X-all_JAK-STAT_signaling                    2.270985e-15
# 2-X-global-X-all_type-IandII-ifn-response              3.363310e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                7.485002e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  3.173591e-15
# 5-X-global-X-all_complement_production                 4.758086e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 6.074297e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.431195e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      5.119267e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.367832e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     5.692251e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.952346e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.251334e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.009546e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           7.534408e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              3.505276e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     3.118061e-14
#
#                                                     ENSG00000004468  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               6.196725e-02
# 1-X-global-X-all_JAK-STAT_signaling                    5.586794e-18
# 2-X-global-X-all_type-IandII-ifn-response              3.151981e-11
# 3-X-global-X-all_TNF-via-NFkB_signaling                4.752569e-18
# 4-X-global-X-all_MHC-II-Ipresentation                  1.361805e-14
# 5-X-global-X-all_complement_production                 1.575401e-06
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 6.506790e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             7.882398e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      9.147823e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.419007e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.277699e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     6.189125e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.480497e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.797703e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.033020e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              4.447032e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     5.519093e-14
#
#                                                     ENSG00000004478  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               4.528516e-17
# 1-X-global-X-all_JAK-STAT_signaling                    3.709570e-17
# 2-X-global-X-all_type-IandII-ifn-response              8.904162e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling                2.736591e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  7.987335e-17
# 5-X-global-X-all_complement_production                 1.523579e-16
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.713954e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             4.894254e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      9.802656e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.887469e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.206490e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.254571e-13
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             2.127111e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    1.757343e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           3.726094e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              7.337174e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     2.810019e-14
#
#                                                     ENSG00000004487  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.586870e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.932940e-15
# 2-X-global-X-all_type-IandII-ifn-response              5.038657e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.505800e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  4.466889e-15
# 5-X-global-X-all_complement_production                 1.109747e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 8.360693e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             6.943894e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      5.901035e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.162653e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     4.403734e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     8.706522e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             8.176291e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    5.299187e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           3.923955e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.097069e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     3.553711e-14
#
#                                                     ENSG00000004700  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.456114e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.033952e-15
# 2-X-global-X-all_type-IandII-ifn-response              2.392461e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                7.425194e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  2.398643e-15
# 5-X-global-X-all_complement_production                 6.085927e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 2.379055e-13
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.839334e-13
# 105-X-T_CD8_NonNaive-X-chemokines                      1.929706e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             2.509435e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.795453e-13
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     2.779413e-13
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             5.874620e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    4.023518e-13
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           3.296174e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.403842e-13
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.264357e-13
#
#                                                     ENSG00000004766  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.640458e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.183827e-15
# 2-X-global-X-all_type-IandII-ifn-response              2.927318e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                8.559195e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  2.651268e-15
# 5-X-global-X-all_complement_production                 4.506718e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 7.859296e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.873802e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      4.560966e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             3.080076e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     4.376135e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     6.308477e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             4.921826e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    3.996878e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           7.772757e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              3.766863e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     2.467727e-14
#
#                                                     ENSG00000004799  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               5.379918e-16
# 1-X-global-X-all_JAK-STAT_signaling                    3.902081e-16
# 2-X-global-X-all_type-IandII-ifn-response              5.921365e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling                2.717889e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  7.964299e-16
# 5-X-global-X-all_complement_production                 1.861149e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 3.300547e-15
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.738268e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      1.840001e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             2.662368e-15
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.005452e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     2.363307e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             2.161296e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.971202e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.995992e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.784891e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.473162e-15
#
#                                                     ENSG00000004846  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.361758e-15
# 1-X-global-X-all_JAK-STAT_signaling                    9.704760e-16
# 2-X-global-X-all_type-IandII-ifn-response              2.325677e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                6.676545e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  2.113453e-15
# 5-X-global-X-all_complement_production                 5.521978e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 6.527994e-15
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.717305e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      4.664920e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             6.647992e-15
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.787571e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     3.570059e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.068616e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    5.032891e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           5.100490e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              2.610362e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     9.802352e-04
#
#                                                     ENSG00000004939  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               3.980211e-15
# 1-X-global-X-all_JAK-STAT_signaling                    3.131955e-15
# 2-X-global-X-all_type-IandII-ifn-response              6.996676e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                2.275386e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  4.957555e-15
# 5-X-global-X-all_complement_production                 1.344497e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.367326e-15
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.000624e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      2.890292e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.698415e-15
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     6.042860e-16
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.637255e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             2.723628e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    1.713977e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           2.569718e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.524574e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.231798e-15
#
#                                                     ENSG00000004975  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.385579e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.809674e-15
# 2-X-global-X-all_type-IandII-ifn-response              3.524823e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.326924e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  3.862734e-15
# 5-X-global-X-all_complement_production                 9.574355e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 2.674875e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.463097e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      5.157993e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             4.756345e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     6.370267e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     6.992514e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.609418e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    7.704305e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           8.121320e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              4.516179e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     3.523025e-14
#
#                                                     ENSG00000005007  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.250043e-14
# 1-X-global-X-all_JAK-STAT_signaling                    8.896026e-15
# 2-X-global-X-all_type-IandII-ifn-response              2.220610e-14
# 3-X-global-X-all_TNF-via-NFkB_signaling                6.406760e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  1.874212e-14
# 5-X-global-X-all_complement_production                 4.758742e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 4.506948e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.849596e-14
# ...
# 105-X-T_CD8_NonNaive-X-chemokines                      2.489119e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.771569e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     7.148114e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.620044e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             3.566383e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.371223e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           2.592504e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.134683e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.100418e-14
#
#                                                     ENSG00000278558  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               9.303257e-17
# 1-X-global-X-all_JAK-STAT_signaling                    6.614296e-17
# 2-X-global-X-all_type-IandII-ifn-response              1.338650e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling                4.742648e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  1.469283e-16
# 5-X-global-X-all_complement_production                 3.490947e-16
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 9.336884e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             4.415490e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      3.599696e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.024543e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     5.717285e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     6.231128e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             7.977643e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    7.570446e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.487491e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              3.233142e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     3.764557e-14
#
#                                                     ENSG00000278615  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               5.389548e-17
# 1-X-global-X-all_JAK-STAT_signaling                    3.682292e-17
# 2-X-global-X-all_type-IandII-ifn-response              9.768614e-17
# 3-X-global-X-all_TNF-via-NFkB_signaling                3.002872e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  9.186501e-17
# 5-X-global-X-all_complement_production                 2.216644e-16
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 5.931307e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.884184e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      1.138018e-13
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.196175e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     9.494377e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     7.934680e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             6.187623e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    4.725361e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.120593e-13
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              4.208502e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     4.823636e-14
#
#                                                     ENSG00000278619  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               8.076534e-17
# 1-X-global-X-all_JAK-STAT_signaling                    6.932764e-17
# 2-X-global-X-all_type-IandII-ifn-response              1.408319e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling                4.329238e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  9.679482e-17
# 5-X-global-X-all_complement_production                 2.379869e-16
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 4.529050e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             2.674365e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      2.547127e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             2.081856e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     3.142961e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     2.507212e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             3.176136e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    3.862952e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.621178e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.931622e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.365940e-14
#
#                                                     ENSG00000278637  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.604406e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.214989e-15
# 2-X-global-X-all_type-IandII-ifn-response              2.763175e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                9.039299e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  2.463584e-15
# 5-X-global-X-all_complement_production                 4.565082e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.554753e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.728472e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      7.377240e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.696175e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.154291e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.133250e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             5.995114e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    8.988976e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.267018e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              7.619000e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     5.811673e-15
#
#                                                     ENSG00000278662  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.332613e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.637209e-15
# 2-X-global-X-all_type-IandII-ifn-response              3.994905e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.197679e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  3.413538e-15
# 5-X-global-X-all_complement_production                 9.167147e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.051389e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.716007e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      5.373431e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.054805e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     3.952881e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     5.914586e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             6.712877e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.204289e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.180718e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              5.703592e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     4.642385e-15
#
#                                                     ENSG00000278677  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.923066e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.386650e-15
# 2-X-global-X-all_type-IandII-ifn-response              3.144978e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.025573e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  2.854015e-15
# 5-X-global-X-all_complement_production                 6.837343e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 6.585678e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.497020e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      3.757355e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             4.786830e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.392821e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     4.790091e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             4.049664e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    5.130330e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           6.187746e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              2.628812e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     2.236360e-14
#
#                                                     ENSG00000278705  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.979497e-15
# 1-X-global-X-all_JAK-STAT_signaling                    1.631433e-15
# 2-X-global-X-all_type-IandII-ifn-response              3.659637e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.188532e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  1.960062e-15
# 5-X-global-X-all_complement_production                 7.231743e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.536657e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.105524e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      1.441531e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.162872e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     8.778301e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     8.767441e-15
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.275672e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    7.113333e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           1.483709e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              7.774400e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     5.607225e-15
#
#                                                     ENSG00000278817  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               3.506886e-16
# 1-X-global-X-all_JAK-STAT_signaling                    2.437689e-16
# 2-X-global-X-all_type-IandII-ifn-response              5.858709e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.864964e-16
# 4-X-global-X-all_MHC-II-Ipresentation                  5.124434e-16
# 5-X-global-X-all_complement_production                 1.240104e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.807992e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             1.232316e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      1.732380e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.061579e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.406946e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.034984e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             2.878662e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    1.209989e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           8.370645e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              8.694685e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     6.457103e-15
#
#                                                     ENSG00000278828  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               5.575245e-15
# 1-X-global-X-all_JAK-STAT_signaling                    4.031500e-15
# 2-X-global-X-all_type-IandII-ifn-response              6.734683e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                2.036101e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  7.823581e-15
# 5-X-global-X-all_complement_production                 1.960833e-14
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 2.419969e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             3.404492e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      4.188196e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             4.150850e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.135249e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     1.646003e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             9.706486e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    3.030971e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           2.748614e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              2.469596e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.801297e-14
#
#                                                     ENSG00000280670  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               8.837729e-17
# 1-X-global-X-all_JAK-STAT_signaling                    6.686839e-17
# 2-X-global-X-all_type-IandII-ifn-response              1.542614e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling                4.384817e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  1.331931e-16
# 5-X-global-X-all_complement_production                 2.953142e-16
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 6.025706e-15
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             5.542603e-15
# 105-X-T_CD8_NonNaive-X-chemokines                      3.722897e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             5.005541e-14
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     2.377805e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     4.255463e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             6.663190e-14
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.735736e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           2.972810e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              2.303918e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.804569e-14
#
#                                                     ENSG00000280789  \
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               2.977278e-15
# 1-X-global-X-all_JAK-STAT_signaling                    2.288526e-15
# 2-X-global-X-all_type-IandII-ifn-response              4.606112e-15
# 3-X-global-X-all_TNF-via-NFkB_signaling                1.668691e-15
# 4-X-global-X-all_MHC-II-Ipresentation                  5.220355e-15
# 5-X-global-X-all_complement_production                 8.987713e-15
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.573660e-14
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             6.751610e-14
# 105-X-T_CD8_NonNaive-X-chemokines                      7.637936e-14
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             1.050261e-13
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     4.533785e-14
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     8.748889e-14
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             2.309413e-13
# 110-X-T_CD8_NonNaive-X-IFN_response                    6.926091e-14
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           5.730258e-14
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              7.125180e-14
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     5.916386e-14
#
#                                                     ENSG00000282608
# 0-X-global-X-all_IL6-JAK-STAT3_signaling               1.527173e-16
# 1-X-global-X-all_JAK-STAT_signaling                    9.870781e-17
# 2-X-global-X-all_type-IandII-ifn-response              2.549332e-16
# 3-X-global-X-all_TNF-via-NFkB_signaling                6.243284e-17
# 4-X-global-X-all_MHC-II-Ipresentation                  1.964017e-16
# 5-X-global-X-all_complement_production                 3.794691e-16
# 103-X-T_CD8_NonNaive-X-CD8T_exhaustion                 1.934374e-15
# 104-X-T_CD8_NonNaive-X-CD8T_tcr_activation             9.030350e-16
# 105-X-T_CD8_NonNaive-X-chemokines                      2.708629e-15
# 106-X-T_CD8_NonNaive-X-chemokine_receptors             8.290636e-16
# 107-X-T_CD8_NonNaive-X-cytokine_and_receptors_p...     1.103115e-15
# 108-X-T_CD8_NonNaive-X-cytokine_andreceptors_an...     2.234555e-16
# 109-X-T_CD8_NonNaive-X-IFN_Type_1_2_Lambda             1.751102e-15
# 110-X-T_CD8_NonNaive-X-IFN_response                    2.154089e-15
# 111-X-T_CD8_NonNaive-X-TNF_receptors_ligands           2.989602e-15
# 112-X-T_CD8_NonNaive-X-adhesion_molecules              1.417709e-15
# 113-X-T_CD8_NonNaive-X-antigen_presentation_mol...     1.223294e-15
#
# [17 rows x 8253 columns]

# %% [markdown]
# **Load SPECTRA GeneSet Factors**

# %% [raw]
# geneSetFactors = pd.read_csv(here('03_downstream_analysis/05_SPECTRA/results/SPECTRAFactor_Renamed_Processed_LAM0.001_S0.6_NonCellIdentitymarkersDF.csv'),
#                           index_col=0)
# geneSetFactors.head()

# %% [markdown]
# **Converting 'geneWeights' to match with DecoupleR 'net' format**

# %%
geneWeights_netDF = geneWeights.reset_index().melt(id_vars='index', var_name='source', value_name='weight')
geneWeights_netDF = geneWeights_netDF.rename(columns={'index': 'source', 'source':'target'})
geneWeights_netDF.head()
# Out:
#                                       source           target        weight
# 0   0-X-global-X-all_IL6-JAK-STAT3_signaling  ENSG00000000003  1.662220e-15
# 1        1-X-global-X-all_JAK-STAT_signaling  ENSG00000000003  1.108171e-15
# 2  2-X-global-X-all_type-IandII-ifn-response  ENSG00000000003  2.737120e-15
# 3    3-X-global-X-all_TNF-via-NFkB_signaling  ENSG00000000003  8.518205e-16
# 4      4-X-global-X-all_MHC-II-Ipresentation  ENSG00000000003  2.003873e-15

# %% [raw]
# def get_true_column_positions(factor_name):
#     # Check if the factor exists in geneSetFactors
#     if factor_name in geneSetFactors.T.index:
#         # Get the boolean mask for "True" values
#         mask = geneSetFactors.T.loc[factor_name]
#         # Get the column positions where the mask is True
#         true_column_positions = mask[mask].index
#         return true_column_positions
#     else:
#         # If the factor does not exist in geneSetFactors, return an empty list
#         return []

# %% [raw]
# # Create a new dataframe to store the result
# geneWeights_netDF = pd.DataFrame(columns=['source', 'target', 'weight'])
#
# # Iterate over each geneset to find the top 50 genes
# for FactorName in geneWeights.index:
#     # Subset only genes of interest for each Factor
#     gene_set_indexCol = get_true_column_positions(FactorName)
#     geneWeights_subset = geneWeights.loc[FactorName, gene_set_indexCol]
#     geneWeights_toadd = pd.DataFrame([{'source': FactorName, 'target': gene, 'weight': geneWeights_subset.loc[gene]}
#                                       for gene in geneWeights_subset.index])
#     geneWeights_netDF = pd.concat([geneWeights_netDF, geneWeights_toadd], ignore_index=True)
#
# print(geneWeights_netDF.shape)

# %%
# Count the number of GENES of each FACTOR
source_counts = geneWeights_netDF['source'].value_counts()

# Get the sources with counts less than 5
sources_to_drop = source_counts[source_counts < 5].index
print(sources_to_drop)

# Filter geneWeights DataFrame if source has counts less than 5
geneWeights_netDF = geneWeights_netDF[~geneWeights_netDF['source'].isin(sources_to_drop)]
# Out:
# Index([], dtype='object', name='source')

# %% [markdown]
# # Run DecoupleR - Computing gene signature with ULM
#
# https://decoupler-py.readthedocs.io/en/latest/notebooks/progeny.html#Activity-inference-with-multivariate-linear-model-(ulm)
#
# To infer pathway enrichment scores we will run the univariate linear model (ulm)  method. For each cell in our dataset (adata), it fits a linear model that predicts the observed gene expression based on all pathways’ Pathway-Gene interactions weights. Once fitted, the obtained t-values of the slopes are the scores. If it is positive, we interpret that the pathway is active and if it is negative we interpret that it is inactive. Since genes might be overlapping across gene sets (signatures) it is better to use ULM methods.
#
# To run `decoupler` methods, we need an input matrix (`mat`), an input prior knowledge network/restudyID (`net`), and the name of the columns of net that we want to use.
#
# * The obtained scores (t-values)(`ulm_estimate`) and p-values (`ulm_pvals`) are stored in the `adata.obsm` key.
# * Note: Each run of run_ulm overwrites what is inside of `ulm_estimate` and `ulm_pvals`.

# %%
# Generating pseudobulks

adataPS = aggregating_features(adata.X.todense(), adata.obs[['studyID', 'sampleID', 'chemistry', 'disease', 'sex','binned_age', 'Level1', 'Level2']], #, 'sex', 'binned_age']]
                              mode = 'sum', obs_names_col = ['sampleID', 'Level2'], min_observation = 10)
adataPS.var_names = adata.var_names
adataPS
# Out:
# AnnData object with n_obs × n_vars = 4760 × 8253
#     obs: 'studyID', 'sampleID', 'chemistry', 'disease', 'sex', 'binned_age', 'Level1', 'Level2', 'n_observation'

# %%
# LogNorm
sc.pp.normalize_total(adataPS, target_sum=1e4)
sc.pp.log1p(adataPS)
adataPS.layers["log1p_10e4_counts_scaled"] = adataPS.X.copy()

#zscaling
sc.pp.scale(adataPS, layer="log1p_10e4_counts_scaled")
adataPS.X = adataPS.layers["log1p_10e4_counts_scaled"]

adataPS
# Out:
# AnnData object with n_obs × n_vars = 4760 × 8253
#     obs: 'studyID', 'sampleID', 'chemistry', 'disease', 'sex', 'binned_age', 'Level1', 'Level2', 'n_observation'
#     var: 'mean', 'std'
#     uns: 'log1p'
#     layers: 'log1p_10e4_counts_scaled'

# %% [markdown]
# ## Gene activity inference with Univariate Linear Model (ULM)

# %%
dc.run_ulm(
    mat=adataPS,
    net=geneWeights_netDF,
    source='source',
    target='target',
    weight='weight',
    verbose=True,
    use_raw=False, # Use raw attribute of mat if present.
    min_n = 5 # Minimum of targets per studyID. If less, studyIDs are removed. Default 5, but having a studyID of 3.
)
# Out:
# 1 features of mat are empty, they will be removed.
# Running ulm on mat with 4760 samples and 8252 targets for 17 sources.

# %%
adataPS
# Out:
# AnnData object with n_obs × n_vars = 4760 × 8253
#     obs: 'studyID', 'sampleID', 'chemistry', 'disease', 'sex', 'binned_age', 'Level1', 'Level2', 'n_observation'
#     var: 'mean', 'std'
#     uns: 'log1p'
#     obsm: 'ulm_estimate', 'ulm_pvals'
#     layers: 'log1p_10e4_counts_scaled'

# %%
# Save results
file_path = here('03_downstream_analysis/06_inflammation_signatures/results/DecoupleR_ulmestimates_{}_L2_UnCorr.csv'.format(celltype))
adataPS.obsm['ulm_estimate'].to_csv(file_path, index=True) 

file_path = here('03_downstream_analysis/06_inflammation_signatures/results/DecoupleR_ulmpvals_{}_L2_UnCorr.csv'.format(celltype))
adataPS.obsm['ulm_pvals'].to_csv(file_path, index=True)

# %% [markdown]
# # Explore ulm results
#
# To visualize the obtained scores, we can re-use many of `scanpy`’s plotting functions. First though, we need to extract the activities from the adata object.
#
# `dc.get_acts` returns a new AnnData object which holds the obtained activities in its `acts.X` attribute, allowing us to re-use many scanpy functions, for example let’s visualise the Trail pathway:

# %%
adataPS = dc.get_acts(adataPS, obsm_key='ulm_estimate')
adataPS
# Out:
# AnnData object with n_obs × n_vars = 4760 × 17
#     obs: 'studyID', 'sampleID', 'chemistry', 'disease', 'sex', 'binned_age', 'Level1', 'Level2', 'n_observation'
#     uns: 'log1p'
#     obsm: 'ulm_estimate', 'ulm_pvals'

# %%
# Save results
anndata_path = here('03_downstream_analysis/06_inflammation_signatures/results/DecoupleR_ulmestimates_{}_L2_UnCorr.h5ad'.format(celltype))
adataPS.write_h5ad(anndata_path)

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# decoupler                   1.6.0
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# argcomplete                 NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.1
# customPalette               NA
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-07-03 18:03
# </pre>
# </details>
