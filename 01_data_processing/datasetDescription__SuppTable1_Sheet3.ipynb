# %%
# General modules
import sys
import os
import session_info
import warnings
from pyprojroot.here import here
import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
import plotly.graph_objects as go
import re
import io

# Specific modules
import scanpy as sc
import anndata as ad
import scienceplots
from matplotlib.backends.backend_pdf import PdfPages
import plotly.io as pio
import pickle

# Setting some parameters
warnings.filterwarnings("ignore")

# Import functions
sys.path.insert(1, str(here('bin')))
from customPalette import *

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

overwriteFigures = True
overwriteData = True

pd.options.display.max_columns = 300
pd.options.display.max_rows = 1000

# %% [markdown]
# **Defining functions**

# %%
print("directory path: {}".format(here()))
# Out:
# directory path: /scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas-R1

# %% [markdown]
# **Load data**

# %%
with open(here("00_data_processing/results/01_INFLAMMATION_external_sampleMetadata.pkl"), 'rb') as file:
    external_sampleMetadata = pickle.load(file)

external_sampleMetadata["datasetSplitting"] = "external"
external_sampleMetadata.head()
# Out:
#                                               studyID              sampleID  \
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA  SCGT00val  SCGT00val_I036016_T0
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA  SCGT00val  SCGT00val_I036023_T0
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG  SCGT00val  SCGT00val_I036021_T0
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC  SCGT00val  SCGT00val_I036015_T0
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT    SCGT00val    SCGT00val_I0364_T0
#
#                                            chemistry           technology  \
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT    3_GEX_V3  3_GEX_V3_GenoHashed
#
#                                                     patientID disease  \
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA  SCGT00val_I036016      RA
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA  SCGT00val_I036023      RA
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG  SCGT00val_I036021      RA
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC  SCGT00val_I036015      RA
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT      SCGT00val_I0364      RA
#
#                                             timepoint_replicate  \
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA                  0.0
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA                  0.0
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG                  0.0
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC                  0.0
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT                    0.0
#
#                                            treatmentStatus therapyResponse  \
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA             TNF              NR
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA             TNF              NR
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG             TNF               R
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC             TNF              NR
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT               TNF               R
#
#                                                sex   age    BMI binned_age  \
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA  female  33.0  28.72      31-40
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA  female  52.0  22.68      51-60
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG  female  61.0  24.61      61-70
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC  female  33.0  24.61      31-40
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT    female  25.0  21.01      18-30
#
#                                            diseaseStatus smokingStatus  \
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA            na  never-smoker
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA            na  never-smoker
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG            na  never-smoker
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC            na  never-smoker
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT              na  never-smoker
#
#                                            ethnicity institute diseaseGroup  \
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA        na        na        IMIDs
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA        na        na        IMIDs
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG        na        na        IMIDs
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC        na        na        IMIDs
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT          na        na        IMIDs
#
#                                            datasetSplitting
# cellID
# SCGT00val_L006_I036016_T0_AAACCCAAGACAACTA         external
# SCGT00val_L006_I036023_T0_AAACCCAAGACGGAAA         external
# SCGT00val_L006_I036021_T0_AAACCCAAGATGGTCG         external
# SCGT00val_L006_I036015_T0_AAACCCAAGCATTGTC         external
# SCGT00val_L006_I0364_T0_AAACCCAAGCGATGGT           external

# %%
with open(here("00_data_processing/results/01_INFLAMMATION_main_sampleMetadata.pkl"), 'rb') as file:
    main_sampleMetadata = pickle.load(file)

main_sampleMetadata["datasetSplitting"] = "CORE_main"
main_sampleMetadata.head()
# Out:
#                                        studyID          sampleID chemistry  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAAGGTGAGAA  SCGT00  SCGT00_I57.3P_T0  3_GEX_V3
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG  SCGT00  SCGT00_I56.3P_T0  3_GEX_V3
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT  SCGT00  SCGT00_I53.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_AAACCCACAACTGTGT  SCGT00  SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA  SCGT00  SCGT00_I58.3P_T0  3_GEX_V3
#
#                                                  technology   patientID  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAAGGTGAGAA  3_GEX_V3_GenoHashed  SCGT00_I57
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG  3_GEX_V3_GenoHashed  SCGT00_I56
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT  3_GEX_V3_GenoHashed  SCGT00_I53
# SCGT00_L051_I52.3P_T0_AAACCCACAACTGTGT  3_GEX_V3_GenoHashed  SCGT00_I52
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA  3_GEX_V3_GenoHashed  SCGT00_I58
#
#                                        disease  timepoint_replicate  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAAGGTGAGAA      RA                  0.0
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG      RA                  0.0
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT      RA                  0.0
# SCGT00_L051_I52.3P_T0_AAACCCACAACTGTGT      RA                  0.0
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA      RA                  0.0
#
#                                        treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAAGGTGAGAA         ongoing              NR
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG         ongoing               R
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT         ongoing               R
# SCGT00_L051_I52.3P_T0_AAACCCACAACTGTGT         ongoing              NR
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA         ongoing              NR
#
#                                            sex   age    BMI binned_age  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAAGGTGAGAA  female  47.0  25.71      41-50
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG  female  56.0  30.11      51-60
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT  female  69.0  25.00      61-70
# SCGT00_L051_I52.3P_T0_AAACCCACAACTGTGT  female  33.0  21.37      31-40
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA  female  61.0  36.10      61-70
#
#                                        diseaseStatus smokingStatus ethnicity  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAAGGTGAGAA            na  never-smoker        na
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG            na  never-smoker        na
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT            na  never-smoker        na
# SCGT00_L051_I52.3P_T0_AAACCCACAACTGTGT            na  never-smoker        na
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA            na  never-smoker        na
#
#                                        institute diseaseGroup datasetSplitting
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAAGGTGAGAA        na        IMIDs        CORE_main
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG        na        IMIDs        CORE_main
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT        na        IMIDs        CORE_main
# SCGT00_L051_I52.3P_T0_AAACCCACAACTGTGT        na        IMIDs        CORE_main
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA        na        IMIDs        CORE_main

# %%
with open(here("00_data_processing/results/01_INFLAMMATION_validation_sampleMetadata.pkl"), 'rb') as file:
    validation_sampleMetadata = pickle.load(file)

validation_sampleMetadata["datasetSplitting"] = "CORE_validation"
validation_sampleMetadata.head()
# Out:
#                                          studyID            sampleID  \
# cellID
# SCGT00_L051_I51.3P_T0_AAACCCACAATCAGCT    SCGT00    SCGT00_I51.3P_T0
# SCGT00_L023_I5010.3P_T0_AAACCCACAGTACTAC  SCGT00  SCGT00_I5010.3P_T0
# SCGT00_L028_I5020.3P_T0_AAACCCACATCGGCCA  SCGT00  SCGT00_I5020.3P_T0
# SCGT00_L050_I5030.3P_T0_AAACCCAAGAATCGTA  SCGT00  SCGT00_I5030.3P_T0
# SCGT00_L050_I5018.3P_T0_AAACCCAAGCCGTCGT  SCGT00  SCGT00_I5018.3P_T0
#
#                                          chemistry           technology  \
# cellID
# SCGT00_L051_I51.3P_T0_AAACCCACAATCAGCT    3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00_L023_I5010.3P_T0_AAACCCACAGTACTAC  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00_L028_I5020.3P_T0_AAACCCACATCGGCCA  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00_L050_I5030.3P_T0_AAACCCAAGAATCGTA  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00_L050_I5018.3P_T0_AAACCCAAGCCGTCGT  3_GEX_V3  3_GEX_V3_GenoHashed
#
#                                              patientID disease  \
# cellID
# SCGT00_L051_I51.3P_T0_AAACCCACAATCAGCT      SCGT00_I51      RA
# SCGT00_L023_I5010.3P_T0_AAACCCACAGTACTAC  SCGT00_I5010      RA
# SCGT00_L028_I5020.3P_T0_AAACCCACATCGGCCA  SCGT00_I5020      RA
# SCGT00_L050_I5030.3P_T0_AAACCCAAGAATCGTA  SCGT00_I5030      RA
# SCGT00_L050_I5018.3P_T0_AAACCCAAGCCGTCGT  SCGT00_I5018      RA
#
#                                           timepoint_replicate treatmentStatus  \
# cellID
# SCGT00_L051_I51.3P_T0_AAACCCACAATCAGCT                    0.0         ongoing
# SCGT00_L023_I5010.3P_T0_AAACCCACAGTACTAC                  0.0         ongoing
# SCGT00_L028_I5020.3P_T0_AAACCCACATCGGCCA                  0.0         ongoing
# SCGT00_L050_I5030.3P_T0_AAACCCAAGAATCGTA                  0.0         ongoing
# SCGT00_L050_I5018.3P_T0_AAACCCAAGCCGTCGT                  0.0         ongoing
#
#                                          therapyResponse     sex   age    BMI  \
# cellID
# SCGT00_L051_I51.3P_T0_AAACCCACAATCAGCT                 R  female  42.0  24.34
# SCGT00_L023_I5010.3P_T0_AAACCCACAGTACTAC              NR    male  51.0  35.92
# SCGT00_L028_I5020.3P_T0_AAACCCACATCGGCCA               R  female  60.0  20.28
# SCGT00_L050_I5030.3P_T0_AAACCCAAGAATCGTA               R  female  55.0  18.72
# SCGT00_L050_I5018.3P_T0_AAACCCAAGCCGTCGT              NR  female  52.0  20.74
#
#                                          binned_age diseaseStatus  \
# cellID
# SCGT00_L051_I51.3P_T0_AAACCCACAATCAGCT        41-50            na
# SCGT00_L023_I5010.3P_T0_AAACCCACAGTACTAC      51-60            na
# SCGT00_L028_I5020.3P_T0_AAACCCACATCGGCCA      51-60            na
# SCGT00_L050_I5030.3P_T0_AAACCCAAGAATCGTA      51-60            na
# SCGT00_L050_I5018.3P_T0_AAACCCAAGCCGTCGT      51-60            na
#
#                                          smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I51.3P_T0_AAACCCACAATCAGCT    never-smoker        na        na
# SCGT00_L023_I5010.3P_T0_AAACCCACAGTACTAC        smoker        na        na
# SCGT00_L028_I5020.3P_T0_AAACCCACATCGGCCA  never-smoker        na        na
# SCGT00_L050_I5030.3P_T0_AAACCCAAGAATCGTA  never-smoker        na        na
# SCGT00_L050_I5018.3P_T0_AAACCCAAGCCGTCGT  never-smoker        na        na
#
#                                          diseaseGroup datasetSplitting
# cellID
# SCGT00_L051_I51.3P_T0_AAACCCACAATCAGCT          IMIDs  CORE_validation
# SCGT00_L023_I5010.3P_T0_AAACCCACAGTACTAC        IMIDs  CORE_validation
# SCGT00_L028_I5020.3P_T0_AAACCCACATCGGCCA        IMIDs  CORE_validation
# SCGT00_L050_I5030.3P_T0_AAACCCAAGAATCGTA        IMIDs  CORE_validation
# SCGT00_L050_I5018.3P_T0_AAACCCAAGCCGTCGT        IMIDs  CORE_validation

# %%
sampleMetadata_merged = pd.concat([main_sampleMetadata, validation_sampleMetadata, external_sampleMetadata], ignore_index=True)
sampleMetadata_merged = sampleMetadata_merged.set_index("sampleID")

# Unify "na" and "NaN" to "NA"
sampleMetadata_merged = sampleMetadata_merged.replace('na', 'NA')
sampleMetadata_merged = sampleMetadata_merged.fillna('NA').replace('', 'NA')

# Define the new order of columns
new_order = ['datasetSplitting', 'studyID', 'patientID', 'diseaseGroup', 'disease', 'diseaseStatus',
             'chemistry', 'technology', 'institute',
             'sex', 'age', 'binned_age', 'BMI',  'smokingStatus', 'ethnicity',
             'timepoint_replicate', 'treatmentStatus', 'therapyResponse']
sampleMetadata_merged = sampleMetadata_merged[new_order]

# %%
print(sampleMetadata_merged.shape)
sampleMetadata_merged.head()
# Out:
# (1047, 18)
#                  datasetSplitting studyID   patientID diseaseGroup disease  \
# sampleID
# SCGT00_I57.3P_T0        CORE_main  SCGT00  SCGT00_I57        IMIDs      RA
# SCGT00_I56.3P_T0        CORE_main  SCGT00  SCGT00_I56        IMIDs      RA
# SCGT00_I53.3P_T0        CORE_main  SCGT00  SCGT00_I53        IMIDs      RA
# SCGT00_I52.3P_T0        CORE_main  SCGT00  SCGT00_I52        IMIDs      RA
# SCGT00_I58.3P_T0        CORE_main  SCGT00  SCGT00_I58        IMIDs      RA
#
#                  diseaseStatus chemistry           technology institute  \
# sampleID
# SCGT00_I57.3P_T0            NA  3_GEX_V3  3_GEX_V3_GenoHashed        NA
# SCGT00_I56.3P_T0            NA  3_GEX_V3  3_GEX_V3_GenoHashed        NA
# SCGT00_I53.3P_T0            NA  3_GEX_V3  3_GEX_V3_GenoHashed        NA
# SCGT00_I52.3P_T0            NA  3_GEX_V3  3_GEX_V3_GenoHashed        NA
# SCGT00_I58.3P_T0            NA  3_GEX_V3  3_GEX_V3_GenoHashed        NA
#
#                      sex   age binned_age    BMI smokingStatus ethnicity  \
# sampleID
# SCGT00_I57.3P_T0  female  47.0      41-50  25.71  never-smoker        NA
# SCGT00_I56.3P_T0  female  56.0      51-60  30.11  never-smoker        NA
# SCGT00_I53.3P_T0  female  69.0      61-70   25.0  never-smoker        NA
# SCGT00_I52.3P_T0  female  33.0      31-40  21.37  never-smoker        NA
# SCGT00_I58.3P_T0  female  61.0      61-70   36.1  never-smoker        NA
#
#                  timepoint_replicate treatmentStatus therapyResponse
# sampleID
# SCGT00_I57.3P_T0                 0.0         ongoing              NR
# SCGT00_I56.3P_T0                 0.0         ongoing               R
# SCGT00_I53.3P_T0                 0.0         ongoing               R
# SCGT00_I52.3P_T0                 0.0         ongoing              NR
# SCGT00_I58.3P_T0                 0.0         ongoing              NR

# %%
sampleMetadata_merged.to_csv(here("00_data_processing/results/01_INFLAMMATION_DatasetDescription_Table1_Sheet3.csv"), index=True)
