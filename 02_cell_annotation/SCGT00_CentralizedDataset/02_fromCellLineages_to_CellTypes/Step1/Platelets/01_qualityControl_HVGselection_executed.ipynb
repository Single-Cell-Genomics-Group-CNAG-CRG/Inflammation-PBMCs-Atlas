# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'Platelets'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas-/02_cell_annotation/SCGT00_CentralizedDataset/01_fromDataset_to_CellLineages/results/SCGT00_cluster_res0.1_annotated.pkl'
annotationColumns = 'cell_lineages'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/SCGT00_CentralizedDataset/results/2_SCGT00_MAIN_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 855417 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 3236 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                               studyID       libraryID  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA         SCGT00     SCGT00_L051
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG         SCGT00     SCGT00_L051
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC         SCGT00     SCGT00_L051
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT         SCGT00     SCGT00_L051
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA         SCGT00     SCGT00_L051
# ...                                               ...             ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC  SCGT00val  SCGT00val_L003
#
#                                                         sampleID chemistry  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA          SCGT00_I55.3P_T0  3_GEX_V3
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG          SCGT00_I54.3P_T0  3_GEX_V3
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC          SCGT00_I57.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT          SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA          SCGT00_I57.3P_T0  3_GEX_V3
# ...                                                          ...       ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT  SCGT00val_I036018_T0  3_GEX_V3
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT  SCGT00val_I036011_T0  3_GEX_V3
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG      SCGT00val_I0361_T0  3_GEX_V3
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC  SCGT00val_I036031_T0  3_GEX_V3
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC  SCGT00val_I036031_T0  3_GEX_V3
#
#                                                      technology  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA      3_GEX_V3_GenoHashed
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG      3_GEX_V3_GenoHashed
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC      3_GEX_V3_GenoHashed
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT      3_GEX_V3_GenoHashed
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA      3_GEX_V3_GenoHashed
# ...                                                         ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT  3_GEX_V3_GenoHashed
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG    3_GEX_V3_GenoHashed
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC  3_GEX_V3_GenoHashed
#
#                                                     patientID disease  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA             SCGT00_I55      RA
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG             SCGT00_I54      RA
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC             SCGT00_I57      RA
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT             SCGT00_I58      RA
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA             SCGT00_I57      RA
# ...                                                       ...     ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT  SCGT00val_I036018      RA
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT  SCGT00val_I036011      RA
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG      SCGT00val_I0361      RA
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC  SCGT00val_I036031      RA
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC  SCGT00val_I036031      RA
#
#                                             timepoint_replicate  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                      0.0
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                      0.0
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                      0.0
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                      0.0
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                      0.0
# ...                                                         ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT                  0.0
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT                  0.0
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                    0.0
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC                  0.0
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC                  0.0
#
#                                            treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA             ongoing               R
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG             ongoing              NR
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC             ongoing              NR
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT             ongoing              NR
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA             ongoing              NR
# ...                                                    ...             ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT        antiIL6R               R
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT        antiIL6R              NR
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG          antiIL6R               R
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC        antiIL6R               R
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC        antiIL6R               R
#
#                                                sex       age    BMI  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA      female  58.00000    NaN
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG      female  67.00000  34.38
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC      female  47.00000  25.71
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT      female  61.00000  36.10
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA      female  47.00000  25.71
# ...                                            ...       ...    ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT  female  62.00000  23.19
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT  female  57.44011  25.65
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG    female  37.00000  25.63
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC  female  52.00000  22.27
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC  female  52.00000  22.27
#
#                                            binned_age diseaseStatus  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA          51-60            na
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG          61-70            na
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC          41-50            na
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT          61-70            na
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA          41-50            na
# ...                                               ...           ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT      61-70            na
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT      51-60            na
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG        31-40            na
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC      51-60            na
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC      51-60            na
#
#                                            smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA      never-smoker        na        na
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG      never-smoker        na        na
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC      never-smoker        na        na
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT      never-smoker        na        na
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA      never-smoker        na        na
# ...                                                  ...       ...       ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT  never-smoker        na        na
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT  never-smoker        na        na
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG    never-smoker        na        na
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC        smoker        na        na
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC        smoker        na        na
#
#                                            diseaseGroup          batches  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA            IMIDs    RA_Pool1Pool3
# ...                                                 ...              ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG          IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC        IMIDs  RA_Pool19Pool20
#
#                                             n_genes_by_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                    251
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                    302
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                    325
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                    287
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                    317
# ...                                                       ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT                256
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT                332
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                  772
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC                350
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC                381
#
#                                             log1p_n_genes_by_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                     5.529429
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                     5.713733
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                     5.786897
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                     5.662960
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                     5.762051
# ...                                                             ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT                 5.549076
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT                 5.808142
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                   6.650279
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC                 5.860786
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC                 5.945421
#
#                                             total_counts  log1p_total_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA               560            6.329721
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG               570            6.347389
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC               789            6.672033
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT              1037            6.945051
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA               622            6.434547
# ...                                                  ...                 ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT           591            6.383507
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT           549            6.309918
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG            2440            7.800163
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC           609            6.413459
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC           774            6.652863
#
#                                             pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                       41.785714
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                       32.105263
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                       39.163498
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                       50.241080
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                       29.260450
# ...                                                                ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT                   45.516074
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT                   26.593807
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                     26.188525
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC                   28.735632
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC                   31.395349
#
#                                             total_counts_mt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                   38
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                   19
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                   60
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                   84
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                   42
# ...                                                     ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT               95
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT               27
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                129
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC               23
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC               42
#
#                                             log1p_total_counts_mt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                   3.663562
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                   2.995732
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                   4.110874
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                   4.442651
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                   3.761200
# ...                                                           ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT               4.564348
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT               3.332205
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                 4.867534
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC               3.178054
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC               3.761200
#
#                                             pct_counts_mt  total_counts_ribo  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA           6.785714                 16
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG           3.333333                 16
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC           7.604563                 14
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT           8.100289                 25
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA           6.752412                 17
# ...                                                   ...                ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT      16.074450                 50
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT       4.918033                 46
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG         5.286885               1158
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC       3.776683                 37
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC       5.426357                 43
#
#                                             log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                     2.833213
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                     2.833213
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                     2.708050
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                     3.258097
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                     2.890372
# ...                                                             ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT                 3.931826
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT                 3.850148
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                   7.055313
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC                 3.637586
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC                 3.784190
#
#                                             pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA             2.857143                0
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG             2.807018                1
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC             1.774398                7
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT             2.410800                0
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA             2.733119                2
# ...                                                     ...              ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT         8.460237                0
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT         8.378871                0
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG          47.459016                1
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC         6.075534                0
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC         5.555556                0
#
#                                             log1p_total_counts_hb  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                   0.000000
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                   0.693147
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                   2.079442
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                   0.000000
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                   1.098612
# ...                                                           ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT               0.000000
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT               0.000000
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                 0.693147
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC               0.000000
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC               0.000000
#
#                                             pct_counts_hb  total_counts_plt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA           0.000000                53
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG           0.175439                25
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC           0.887199                50
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT           0.000000                86
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA           0.321543                26
# ...                                                   ...               ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT       0.000000                11
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT       0.000000                 5
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG         0.040984                18
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC       0.000000                55
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC       0.000000                39
#
#                                             log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                    3.988984
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                    3.258097
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                    3.931826
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                    4.465908
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                    3.295837
# ...                                                            ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT                2.484907
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT                1.791759
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG                  2.944439
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC                4.025352
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC                3.688879
#
#                                             pct_counts_plt   S_score  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA            9.464286 -0.032814
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG            4.385965 -0.030996
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC            6.337136 -0.031226
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT            8.293153 -0.030577
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA            4.180064 -0.023233
# ...                                                    ...       ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT        1.861252 -0.022409
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT        0.910747 -0.013966
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG          0.737705 -0.035800
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC        9.031199 -0.037290
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC        5.038760 -0.034800
#
#                                             G2M_score phase
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA      -0.060391    G1
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG      -0.045072    G1
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC       0.035119   G2M
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT      -0.087864    G1
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA      -0.064973    G1
# ...                                               ...   ...
# SCGT00val_L003_I036018_T0_TTCATTGCAAGTACCT  -0.053766    G1
# SCGT00val_L003_I036011_T0_TTGAACGCACTCAAGT  -0.065585    G1
# SCGT00val_L003_I0361_T0_TTGCGTCGTTCGGCTG    -0.032889    G1
# SCGT00val_L003_I036031_T0_TTTCACACATCAGCGC  -0.052797    G1
# SCGT00val_L003_I036031_T0_TTTCATGCAAGCTGCC  -0.017272    G1
#
# [3236 rows x 40 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="disease",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#             libraryID   chemistry  Number of cells  Median UMI counts  \
# 0      (SCGT00_L000,)  [3_GEX_V3]               82                743
# 1      (SCGT00_L002,)  [3_GEX_V3]              127                794
# 2      (SCGT00_L004,)  [3_GEX_V3]                7               1012
# 3      (SCGT00_L005,)  [3_GEX_V3]               28                743
# 4      (SCGT00_L007,)  [3_GEX_V3]               80                812
# 5      (SCGT00_L008,)  [3_GEX_V3]               27                808
# 6      (SCGT00_L009,)  [3_GEX_V3]               39                999
# 7      (SCGT00_L011,)  [3_GEX_V3]              180                930
# 8      (SCGT00_L012,)  [3_GEX_V3]              140                811
# 9      (SCGT00_L015,)  [3_GEX_V3]              151                915
# 10     (SCGT00_L017,)  [3_GEX_V3]              142                845
# 11     (SCGT00_L019,)  [3_GEX_V3]               68               1004
# 12     (SCGT00_L020,)  [3_GEX_V3]              104                842
# 13     (SCGT00_L022,)  [3_GEX_V3]               67                720
# 14     (SCGT00_L023,)  [3_GEX_V3]              168                788
# 15     (SCGT00_L025,)  [3_GEX_V3]               89                895
# 16     (SCGT00_L027,)  [3_GEX_V3]               74                942
# 17     (SCGT00_L029,)  [3_GEX_V3]              136                848
# 18     (SCGT00_L031,)  [3_GEX_V3]               54                939
# 19     (SCGT00_L033,)  [3_GEX_V3]               48                876
# 20     (SCGT00_L034,)  [3_GEX_V3]               27                777
# 21     (SCGT00_L035,)  [3_GEX_V3]               87                850
# 22     (SCGT00_L036,)  [3_GEX_V3]               69                844
# 23     (SCGT00_L038,)  [3_GEX_V3]               59               1159
# 24     (SCGT00_L039,)  [3_GEX_V3]               21                799
# 25     (SCGT00_L040,)  [3_GEX_V3]              124                765
# 26     (SCGT00_L041,)  [3_GEX_V3]               44                771
# 27     (SCGT00_L042,)  [3_GEX_V3]               58               1091
# 28     (SCGT00_L045,)  [3_GEX_V3]              244                826
# 29     (SCGT00_L047,)  [3_GEX_V3]               61                865
# 30     (SCGT00_L049,)  [3_GEX_V3]               11               1155
# 31     (SCGT00_L050,)  [3_GEX_V3]               35               1025
# 32     (SCGT00_L051,)  [3_GEX_V3]               84                783
# 33  (SCGT00val_L000,)  [3_GEX_V3]               78                785
# 34  (SCGT00val_L001,)  [3_GEX_V3]               99                772
# 35  (SCGT00val_L003,)  [3_GEX_V3]              102                843
# 36  (SCGT00val_L005,)  [3_GEX_V3]               98                925
# 37  (SCGT00val_L006,)  [3_GEX_V3]               58                795
# 38  (SCGT00val_L007,)  [3_GEX_V3]               66                926
#
#     Median Genes  Median MT %  Median RB %  Median HB %
# 0            418         7.05         9.66         0.00
# 1            396         6.92         7.90         0.00
# 2            453         6.56         6.92         0.00
# 3            416         8.10        12.63         0.00
# 4            388         6.74         5.16         0.00
# 5            412         1.38         6.38         0.14
# 6            525        10.49         7.24         0.00
# 7            438         7.54         5.71         0.00
# 8            393         5.70         6.00         0.00
# 9            404         8.15         4.59         0.00
# 10           405         7.37         6.53         0.00
# 11           494         5.71        10.37         0.00
# 12           413         6.63         8.91         0.00
# 13           394         8.72         8.52         0.00
# 14           392         5.50         5.14         0.00
# 15           460         6.48        10.52         0.00
# 16           453         8.01         8.02         0.00
# 17           426         9.06         8.41         0.00
# 18           464         8.22         7.96         0.00
# 19           416        11.51         5.73         0.00
# 20           437         7.34        14.03         0.00
# 21           348         5.89         1.77         0.04
# 22           440         8.40        10.05         0.09
# 23           530         9.11         5.44         0.00
# 24           476        10.52         7.86         0.00
# 25           355         8.39         4.14         0.00
# 26           398         4.15         3.22         0.00
# 27           487        10.19         5.07         0.00
# 28           431         4.06         5.01         0.00
# 29           434         7.31         5.91         0.00
# 30           469         0.47         3.85         0.00
# 31           515         4.58        10.92         0.00
# 32           336         5.00         2.20         0.00
# 33           386         8.21         6.39         0.00
# 34           352         8.63         7.23         0.00
# 35           401         7.36         6.57         0.00
# 36           391         8.22         4.17         0.00
# 37           374         8.37         6.41         0.03
# 38           510         9.44         7.43         0.00

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} BCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN when RBC and Platelets will be filtered out
#HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
#print(f"{np.sum(HB_gene_idx)} HB genes")

#PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
#print(f"{np.sum(PLT_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx )# | HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 113 ribosomal genes
# 198 TCR genes
# 159 BCR genes
# 21 MHC genes
# View of AnnData object with n_obs × n_vars = 3236 × 36665
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key='libraryID', 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key=None, 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

adata_forHVG.var.highly_variable.sum()
# Out:
# 137

# %%
print(f'The total number of selected HVG is {adata_forHVG.var.highly_variable.sum()}')
# Out:
# The total number of selected HVG is 137

# %%
adata_HVG = adata_forHVG[:, adata_forHVG.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 3236 × 137
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'disease_colors', 'log1p', 'hvg'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# argcomplete                 NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-10-17 15:27
# </pre>
# </details>
