# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'Mono_and_DC'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas-/02_cell_annotation/SCGT00_CentralizedDataset/01_fromDataset_to_CellLineages/results/SCGT00_cluster_res0.1_annotated.pkl'
annotationColumns = 'cell_lineages'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/SCGT00_CentralizedDataset/results/2_SCGT00_MAIN_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 855417 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 191338 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                               studyID       libraryID  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT         SCGT00     SCGT00_L051
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG         SCGT00     SCGT00_L051
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT         SCGT00     SCGT00_L051
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT         SCGT00     SCGT00_L051
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC         SCGT00     SCGT00_L051
# ...                                               ...             ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA    SCGT00val  SCGT00val_L003
#
#                                                         sampleID chemistry  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT          SCGT00_I53.3P_T0  3_GEX_V3
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG          SCGT00_I51.3P_T0  3_GEX_V3
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT          SCGT00_I56.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT          SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC          SCGT00_I55.3P_T0  3_GEX_V3
# ...                                                          ...       ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT  SCGT00val_I036018_T0  3_GEX_V3
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT  SCGT00val_I036032_T0  3_GEX_V3
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT  SCGT00val_I036011_T0  3_GEX_V3
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA  SCGT00val_I036032_T0  3_GEX_V3
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA      SCGT00val_I0361_T0  3_GEX_V3
#
#                                                      technology  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT      3_GEX_V3_GenoHashed
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG      3_GEX_V3_GenoHashed
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT      3_GEX_V3_GenoHashed
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT      3_GEX_V3_GenoHashed
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC      3_GEX_V3_GenoHashed
# ...                                                         ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA  3_GEX_V3_GenoHashed
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA    3_GEX_V3_GenoHashed
#
#                                                     patientID disease  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT             SCGT00_I53      RA
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG             SCGT00_I51      RA
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT             SCGT00_I56      RA
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT             SCGT00_I58      RA
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC             SCGT00_I55      RA
# ...                                                       ...     ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT  SCGT00val_I036018      RA
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT  SCGT00val_I036032      RA
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT  SCGT00val_I036011      RA
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA  SCGT00val_I036032      RA
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA      SCGT00val_I0361      RA
#
#                                             timepoint_replicate  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                      0.0
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                      0.0
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                      0.0
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                      0.0
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                      0.0
# ...                                                         ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT                  0.0
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT                  0.0
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT                  0.0
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA                  0.0
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                    0.0
#
#                                            treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT             ongoing               R
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG             ongoing               R
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT             ongoing               R
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT             ongoing              NR
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC             ongoing               R
# ...                                                    ...             ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT        antiIL6R               R
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT        antiIL6R              NR
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT        antiIL6R              NR
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA        antiIL6R              NR
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA          antiIL6R               R
#
#                                                sex       age    BMI  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT      female  69.00000  25.00
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG      female  42.00000  24.34
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT      female  56.00000  30.11
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT      female  61.00000  36.10
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC      female  58.00000    NaN
# ...                                            ...       ...    ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT  female  62.00000  23.19
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT  female  66.00000  27.99
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT  female  57.44011  25.65
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA  female  66.00000  27.99
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA    female  37.00000  25.63
#
#                                            binned_age diseaseStatus  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT          61-70            na
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG          41-50            na
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT          51-60            na
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT          61-70            na
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC          51-60            na
# ...                                               ...           ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT      61-70            na
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT      61-70            na
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT      51-60            na
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA      61-70            na
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA        31-40            na
#
#                                            smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT      never-smoker        na        na
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG      never-smoker        na        na
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT      never-smoker        na        na
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT      never-smoker        na        na
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC      never-smoker        na        na
# ...                                                  ...       ...       ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT  never-smoker        na        na
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT  never-smoker        na        na
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT  never-smoker        na        na
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA  never-smoker        na        na
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA    never-smoker        na        na
#
#                                            diseaseGroup          batches  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC            IMIDs    RA_Pool1Pool3
# ...                                                 ...              ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA          IMIDs  RA_Pool19Pool20
#
#                                             n_genes_by_counts  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                   2504
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                    482
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                   1923
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                    795
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                   2698
# ...                                                       ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT               1354
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT               1914
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT               2052
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA               2280
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                 1793
#
#                                             log1p_n_genes_by_counts  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                     7.826044
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                     6.180017
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                     7.562162
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                     6.679599
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                     7.900637
# ...                                                             ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT                 7.211557
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT                 7.557473
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT                 7.627057
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA                 7.732369
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                   7.492203
#
#                                             total_counts  log1p_total_counts  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT              9841            9.194414
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG              1151            7.049255
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT              5667            8.642592
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT              2098            7.649216
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC              8486            9.046291
# ...                                                  ...                 ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT          3856            8.257645
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT          7354            8.903136
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT          7248            8.888619
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA          8024            8.990317
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA            5235            8.563313
#
#                                             pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                       23.757748
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                       46.046916
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                       20.134110
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                       31.458532
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                       18.701391
# ...                                                                ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT                   28.008299
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT                   21.104161
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT                   21.233444
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA                   24.775673
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                     20.821394
#
#                                             total_counts_mt  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                  385
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                  261
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                  217
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                  118
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                  514
# ...                                                     ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT              520
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT              397
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT              350
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA              738
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                245
#
#                                             log1p_total_counts_mt  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                   5.955837
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                   5.568345
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                   5.384495
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                   4.779123
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                   6.244167
# ...                                                           ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT               6.255750
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT               5.986452
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT               5.860786
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA               6.605298
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                 5.505332
#
#                                             pct_counts_mt  total_counts_ribo  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT           3.912204               1945
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG          22.675934                 63
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT           3.829187               1222
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT           5.624404                459
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC           6.057035               1313
# ...                                                   ...                ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT      13.485477                901
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT       5.398423               2038
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT       4.828918               1715
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA       9.197408               1978
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA         4.680038                916
#
#                                             log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                     7.573531
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                     4.158883
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                     7.109062
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                     6.131226
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                     7.180831
# ...                                                             ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT                 6.804615
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT                 7.620215
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT                 7.447751
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA                 7.590347
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                   6.821107
#
#                                             pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT            19.764252                3
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG             5.473501                1
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT            21.563437                5
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT            21.877979                0
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC            15.472543                2
# ...                                                     ...              ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT        23.366183                0
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT        27.712809                9
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT        23.661700                2
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA        24.651047                2
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA          17.497612               12
#
#                                             log1p_total_counts_hb  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                   1.386294
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                   0.693147
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                   1.791759
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                   0.000000
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                   1.098612
# ...                                                           ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT               0.000000
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT               2.302585
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT               1.098612
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA               1.098612
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                 2.564949
#
#                                             pct_counts_hb  total_counts_plt  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT           0.030485                11
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG           0.086881                 1
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT           0.088230                 9
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT           0.000000                 5
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC           0.023568                12
# ...                                                   ...               ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT       0.000000                 2
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT       0.122382                 7
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT       0.027594                 3
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA       0.024925                 8
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA         0.229226                 3
#
#                                             log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT                    2.484907
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG                    0.693147
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT                    2.302585
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT                    1.791759
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC                    2.564949
# ...                                                            ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT                1.098612
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT                2.079442
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT                1.386294
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA                2.197225
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA                  1.386294
#
#                                             pct_counts_plt   S_score  \
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT            0.111777 -0.086293
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG            0.086881 -0.011002
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT            0.158814 -0.061375
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT            0.238322 -0.046827
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC            0.141409 -0.062442
# ...                                                    ...       ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT        0.051867  0.008303
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT        0.095186 -0.012760
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT        0.041391 -0.002725
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA        0.099701 -0.002258
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA          0.057307 -0.003343
#
#                                             G2M_score phase
# cellID
# SCGT00_L051_I53.3P_T0_AAACCCAAGTGCACTT      -0.026586    G1
# SCGT00_L051_I51.3P_T0_AAACCCAGTACAATAG      -0.076010    G1
# SCGT00_L051_I56.3P_T0_AAACCCAGTCTACGAT      -0.110454    G1
# SCGT00_L051_I58.3P_T0_AAACGAAAGGAAAGGT      -0.018271    G1
# SCGT00_L051_I55.3P_T0_AAACGAAAGTATCTGC      -0.096465    G1
# ...                                               ...   ...
# SCGT00val_L003_I036018_T0_TTTGTTGCACTCAAGT  -0.026112     S
# SCGT00val_L003_I036032_T0_TTTGTTGCATCATCTT  -0.048458    G1
# SCGT00val_L003_I036011_T0_TTTGTTGGTAGCGTTT  -0.026955    G1
# SCGT00val_L003_I036032_T0_TTTGTTGGTATCGCTA  -0.014883    G1
# SCGT00val_L003_I0361_T0_TTTGTTGTCTACGCAA    -0.044365    G1
#
# [191338 rows x 40 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="disease",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#             libraryID   chemistry  Number of cells  Median UMI counts  \
# 0      (SCGT00_L000,)  [3_GEX_V3]             4734               7717
# 1      (SCGT00_L002,)  [3_GEX_V3]             4077               7518
# 2      (SCGT00_L004,)  [3_GEX_V3]              414               8370
# 3      (SCGT00_L005,)  [3_GEX_V3]             5335               5983
# 4      (SCGT00_L007,)  [3_GEX_V3]             4926               6133
# 5      (SCGT00_L008,)  [3_GEX_V3]             1729               6438
# 6      (SCGT00_L009,)  [3_GEX_V3]             4845               6753
# 7      (SCGT00_L011,)  [3_GEX_V3]             6349               7598
# 8      (SCGT00_L012,)  [3_GEX_V3]             7546               6414
# 9      (SCGT00_L015,)  [3_GEX_V3]             4154               4951
# 10     (SCGT00_L017,)  [3_GEX_V3]             4861               7921
# 11     (SCGT00_L019,)  [3_GEX_V3]             5600               7646
# 12     (SCGT00_L020,)  [3_GEX_V3]             2602               9916
# 13     (SCGT00_L022,)  [3_GEX_V3]             4454               7534
# 14     (SCGT00_L023,)  [3_GEX_V3]             6877               7001
# 15     (SCGT00_L025,)  [3_GEX_V3]             8397               2952
# 16     (SCGT00_L027,)  [3_GEX_V3]             7871               2970
# 17     (SCGT00_L029,)  [3_GEX_V3]             5351               5760
# 18     (SCGT00_L031,)  [3_GEX_V3]             5178               7090
# 19     (SCGT00_L033,)  [3_GEX_V3]             4843               6702
# 20     (SCGT00_L034,)  [3_GEX_V3]             4186               6842
# 21     (SCGT00_L035,)  [3_GEX_V3]             3143               6277
# 22     (SCGT00_L036,)  [3_GEX_V3]             6173               7116
# 23     (SCGT00_L038,)  [3_GEX_V3]             3880               6098
# 24     (SCGT00_L039,)  [3_GEX_V3]             7781               3953
# 25     (SCGT00_L040,)  [3_GEX_V3]             4460               4665
# 26     (SCGT00_L041,)  [3_GEX_V3]             1436               6363
# 27     (SCGT00_L042,)  [3_GEX_V3]             5500               7087
# 28     (SCGT00_L045,)  [3_GEX_V3]             7873               4925
# 29     (SCGT00_L047,)  [3_GEX_V3]             4314               6542
# 30     (SCGT00_L049,)  [3_GEX_V3]             1070               7070
# 31     (SCGT00_L050,)  [3_GEX_V3]             9103               3412
# 32     (SCGT00_L051,)  [3_GEX_V3]             3211               6407
# 33  (SCGT00val_L000,)  [3_GEX_V3]             3901               6234
# 34  (SCGT00val_L001,)  [3_GEX_V3]             5282               5290
# 35  (SCGT00val_L003,)  [3_GEX_V3]             4696               6449
# 36  (SCGT00val_L005,)  [3_GEX_V3]             5860               5421
# 37  (SCGT00val_L006,)  [3_GEX_V3]             3877               5779
# 38  (SCGT00val_L007,)  [3_GEX_V3]             5449               6253
#
#     Median Genes  Median MT %  Median RB %  Median HB %
# 0           2171         6.41        20.23         0.05
# 1           2129         6.09        19.63         0.04
# 2           2500         8.40        18.77         0.04
# 3           1842         8.75        22.09         0.03
# 4           1968         6.65        19.06         0.05
# 5           1964         0.50        25.34         0.04
# 6           2206        10.46        14.42         0.05
# 7           2184         7.95        19.51         0.04
# 8           1902         4.46        21.43         0.04
# 9           1676        10.10        18.40         0.04
# 10          2227         8.14        19.47         0.04
# 11          2152         4.18        21.92         0.04
# 12          2670         6.33        20.25         0.04
# 13          2151         6.40        19.85         0.05
# 14          2014         4.69        20.93         0.04
# 15          1134         7.75        21.87         0.03
# 16          1182         7.49        20.29         0.04
# 17          1873         8.33        19.90         0.03
# 18          2182         9.37        19.36         0.04
# 19          2055        12.09        15.73         0.04
# 20          2021         9.14        20.79         0.03
# 21          1894         5.89        21.23         0.03
# 22          2131         7.61        21.08         0.04
# 23          2072         7.96        12.53         0.05
# 24          1560        10.85        14.50         0.04
# 25          1559         9.63        19.95         0.04
# 26          2088         3.87        15.98         0.05
# 27          2154         9.37        18.23         0.04
# 28          1706         3.33        18.78         0.04
# 29          2026         6.31        19.35         0.05
# 30          2015         0.33        25.90         0.04
# 31          1266         4.83        23.95         0.03
# 32          1882         5.35        21.68         0.03
# 33          1936         8.48        20.53         0.04
# 34          1590         7.15        24.23         0.03
# 35          1884         6.90        22.99         0.03
# 36          1705         8.21        21.41         0.03
# 37          1799         8.56        21.59         0.04
# 38          2028         9.97        14.53         0.04

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} BCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN when RBC and Platelets will be filtered out
#HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
#print(f"{np.sum(HB_gene_idx)} HB genes")

#PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
#print(f"{np.sum(PLT_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx )# | HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 113 ribosomal genes
# 198 TCR genes
# 159 BCR genes
# 21 MHC genes
# View of AnnData object with n_obs × n_vars = 191338 × 36665
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key='libraryID', 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key=None, 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

adata_forHVG.var.highly_variable.sum()
# Out:
# 3707

# %%
print(f'The total number of selected HVG is {adata_forHVG.var.highly_variable.sum()}')
# Out:
# The total number of selected HVG is 3707

# %%
adata_HVG = adata_forHVG[:, adata_forHVG.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 191338 × 3707
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'disease_colors', 'log1p', 'hvg'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# argcomplete                 NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-10-17 15:31
# </pre>
# </details>
