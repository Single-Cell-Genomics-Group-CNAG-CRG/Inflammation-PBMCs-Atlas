# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'RBC_and_HSC'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas-/02_cell_annotation/SCGT00_CentralizedDataset/01_fromDataset_to_CellLineages/results/SCGT00_cluster_res0.1_annotated.pkl'
annotationColumns = 'cell_lineages'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/SCGT00_CentralizedDataset/results/2_SCGT00_MAIN_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 855417 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 1912 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                               studyID       libraryID  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA         SCGT00     SCGT00_L051
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG         SCGT00     SCGT00_L051
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC         SCGT00     SCGT00_L051
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA         SCGT00     SCGT00_L051
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG         SCGT00     SCGT00_L051
# ...                                               ...             ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG    SCGT00val  SCGT00val_L003
#
#                                                         sampleID chemistry  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA          SCGT00_I51.3P_T0  3_GEX_V3
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG          SCGT00_I55.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC          SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA          SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG          SCGT00_I52.3P_T0  3_GEX_V3
# ...                                                          ...       ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG  SCGT00val_I036018_T0  3_GEX_V3
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG  SCGT00val_I036010_T0  3_GEX_V3
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC  SCGT00val_I036010_T0  3_GEX_V3
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG  SCGT00val_I036032_T0  3_GEX_V3
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG      SCGT00val_I0361_T0  3_GEX_V3
#
#                                                      technology  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA      3_GEX_V3_GenoHashed
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG      3_GEX_V3_GenoHashed
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC      3_GEX_V3_GenoHashed
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA      3_GEX_V3_GenoHashed
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG      3_GEX_V3_GenoHashed
# ...                                                         ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG  3_GEX_V3_GenoHashed
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG    3_GEX_V3_GenoHashed
#
#                                                     patientID disease  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA             SCGT00_I51      RA
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG             SCGT00_I55      RA
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC             SCGT00_I52      RA
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA             SCGT00_I58      RA
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG             SCGT00_I52      RA
# ...                                                       ...     ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG  SCGT00val_I036018      RA
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG  SCGT00val_I036010      RA
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC  SCGT00val_I036010      RA
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG  SCGT00val_I036032      RA
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG      SCGT00val_I0361      RA
#
#                                             timepoint_replicate  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                      0.0
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                      0.0
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                      0.0
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                      0.0
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                      0.0
# ...                                                         ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG                  0.0
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG                  0.0
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC                  0.0
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG                  0.0
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                    0.0
#
#                                            treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA             ongoing               R
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG             ongoing               R
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC             ongoing              NR
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA             ongoing              NR
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG             ongoing              NR
# ...                                                    ...             ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG        antiIL6R               R
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG        antiIL6R              NR
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC        antiIL6R              NR
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG        antiIL6R              NR
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG          antiIL6R               R
#
#                                                sex   age    BMI binned_age  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA      female  42.0  24.34      41-50
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG      female  58.0    NaN      51-60
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC      female  33.0  21.37      31-40
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA      female  61.0  36.10      61-70
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG      female  33.0  21.37      31-40
# ...                                            ...   ...    ...        ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG  female  62.0  23.19      61-70
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG  female  61.0  23.74      61-70
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC  female  61.0  23.74      61-70
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG  female  66.0  27.99      61-70
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG    female  37.0  25.63      31-40
#
#                                            diseaseStatus smokingStatus  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                na  never-smoker
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                na  never-smoker
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                na  never-smoker
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                na  never-smoker
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                na  never-smoker
# ...                                                  ...           ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG            na  never-smoker
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG            na  never-smoker
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC            na  never-smoker
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG            na  never-smoker
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG              na  never-smoker
#
#                                            ethnicity institute diseaseGroup  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA            na        na        IMIDs
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG            na        na        IMIDs
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC            na        na        IMIDs
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA            na        na        IMIDs
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG            na        na        IMIDs
# ...                                              ...       ...          ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG        na        na        IMIDs
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG        na        na        IMIDs
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC        na        na        IMIDs
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG        na        na        IMIDs
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG          na        na        IMIDs
#
#                                                     batches  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA        RA_Pool1Pool3
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG        RA_Pool1Pool3
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        RA_Pool1Pool3
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        RA_Pool1Pool3
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG        RA_Pool1Pool3
# ...                                                     ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG  RA_Pool19Pool20
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG  RA_Pool19Pool20
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC  RA_Pool19Pool20
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG  RA_Pool19Pool20
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG    RA_Pool19Pool20
#
#                                             n_genes_by_counts  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                   2814
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                    851
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                   2639
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                   2263
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                    949
# ...                                                       ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG               1133
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG               1770
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC               1001
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG               1160
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                 2269
#
#                                             log1p_n_genes_by_counts  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                     7.942718
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                     6.747587
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                     7.878534
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                     7.724888
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                     6.856462
# ...                                                             ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG                 7.033506
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG                 7.479300
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC                 6.909753
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG                 7.057037
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                   7.727535
#
#                                             total_counts  log1p_total_counts  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA             15273            9.633907
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG              1777            7.483244
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC             12898            9.464905
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA             10543            9.263312
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG              4558            8.424859
# ...                                                  ...                 ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG          7858            8.969415
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG          5079            8.533067
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC          5709            8.649974
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG          2998            8.006034
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG           11105            9.315241
#
#                                             pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                       24.173378
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                       41.643219
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                       26.895643
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                       25.893958
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                       38.635366
# ...                                                                ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG                   46.933062
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG                   22.228785
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC                   52.303381
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG                   29.386258
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                     25.736155
#
#                                             total_counts_mt  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                  643
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                  126
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                  198
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                  290
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                   98
# ...                                                     ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG              253
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG              382
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC              256
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG              206
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                484
#
#                                             log1p_total_counts_mt  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                   6.467699
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                   4.844187
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                   5.293305
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                   5.673323
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                   4.595120
# ...                                                           ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG               5.537334
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG               5.948035
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC               5.549076
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG               5.332719
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                 6.184149
#
#                                             pct_counts_mt  total_counts_ribo  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA           4.210044               7425
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG           7.090602                 98
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC           1.535122               6023
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA           2.750640               4970
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG           2.150066               2078
# ...                                                   ...                ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG       3.219649               3283
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG       7.521166               1554
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC       4.484148               1740
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG       6.871247                678
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG         4.358397               5645
#
#                                             log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                     8.912743
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                     4.595120
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                     8.703507
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                     8.511376
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                     7.639642
# ...                                                             ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG                 8.096817
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG                 7.349231
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC                 7.462215
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG                 6.520621
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                   8.638703
#
#                                             pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA            48.615203                2
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG             5.514913              378
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC            46.697162                1
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA            47.140283                0
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG            45.590171              830
# ...                                                     ...              ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG        41.779079             2087
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG        30.596574                0
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC        30.478192             2158
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG        22.615077               96
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG          50.832958                1
#
#                                             log1p_total_counts_hb  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                   1.098612
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                   5.937536
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                   0.693147
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                   0.000000
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                   6.722630
# ...                                                           ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG               7.643962
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG               0.000000
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC               7.677400
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG               4.574711
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                 0.693147
#
#                                             pct_counts_hb  total_counts_plt  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA           0.013095                 3
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG          21.271806                 3
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC           0.007753                17
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA           0.000000                 2
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG          18.209741                 1
# ...                                                   ...               ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG      26.558921                 0
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG       0.000000                 0
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC      37.799965                 0
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG       3.202135                 5
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG         0.009005                 3
#
#                                             log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA                    1.386294
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                    1.386294
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                    2.890372
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                    1.098612
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                    0.693147
# ...                                                            ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG                0.000000
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG                0.000000
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC                0.000000
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG                1.791759
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG                  1.386294
#
#                                             pct_counts_plt   S_score  \
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA            0.019643 -0.008419
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG            0.168824 -0.006812
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC            0.131803 -0.027010
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA            0.018970  0.007644
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG            0.021939 -0.027121
# ...                                                    ...       ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG        0.000000  0.016242
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG        0.000000 -0.030526
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC        0.000000 -0.014040
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG        0.166778  0.008579
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG          0.027015  0.033018
#
#                                             G2M_score phase
# cellID
# SCGT00_L051_I51.3P_T0_AGAAATGGTAGCTAAA       0.047631   G2M
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG      -0.086046    G1
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC      -0.044655    G1
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA      -0.014472     S
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG      -0.085355    G1
# ...                                               ...   ...
# SCGT00val_L003_I036018_T0_TGTTCCGGTGGGATTG  -0.058104     S
# SCGT00val_L003_I036010_T0_TTAGGGTGTCCGAAAG  -0.062127    G1
# SCGT00val_L003_I036010_T0_TTCCACGGTCCTGTTC  -0.036903    G1
# SCGT00val_L003_I036032_T0_TTTGATCAGTTCTACG   0.000596     S
# SCGT00val_L003_I0361_T0_TTTGGAGCAAGTCCCG    -0.002313     S
#
# [1912 rows x 40 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="disease",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#             libraryID   chemistry  Number of cells  Median UMI counts  \
# 0      (SCGT00_L000,)  [3_GEX_V3]               45               9427
# 1      (SCGT00_L002,)  [3_GEX_V3]               48              10306
# 2      (SCGT00_L004,)  [3_GEX_V3]                9              14338
# 3      (SCGT00_L005,)  [3_GEX_V3]               51               8257
# 4      (SCGT00_L007,)  [3_GEX_V3]               42              10326
# 5      (SCGT00_L008,)  [3_GEX_V3]               24              10064
# 6      (SCGT00_L009,)  [3_GEX_V3]               54               9210
# 7      (SCGT00_L011,)  [3_GEX_V3]               51              11274
# 8      (SCGT00_L012,)  [3_GEX_V3]               58              10851
# 9      (SCGT00_L015,)  [3_GEX_V3]               55              11045
# 10     (SCGT00_L017,)  [3_GEX_V3]               40               9463
# 11     (SCGT00_L019,)  [3_GEX_V3]               31              14306
# 12     (SCGT00_L020,)  [3_GEX_V3]               45              13028
# 13     (SCGT00_L022,)  [3_GEX_V3]               52              11790
# 14     (SCGT00_L023,)  [3_GEX_V3]               57              11979
# 15     (SCGT00_L025,)  [3_GEX_V3]              102               4263
# 16     (SCGT00_L027,)  [3_GEX_V3]               80               6826
# 17     (SCGT00_L029,)  [3_GEX_V3]               52              11555
# 18     (SCGT00_L031,)  [3_GEX_V3]               69              12438
# 19     (SCGT00_L033,)  [3_GEX_V3]               50               9728
# 20     (SCGT00_L034,)  [3_GEX_V3]               52               8998
# 21     (SCGT00_L035,)  [3_GEX_V3]               15              12162
# 22     (SCGT00_L036,)  [3_GEX_V3]               58               8208
# 23     (SCGT00_L038,)  [3_GEX_V3]               50               9070
# 24     (SCGT00_L039,)  [3_GEX_V3]              103               4441
# 25     (SCGT00_L040,)  [3_GEX_V3]               42              10282
# 26     (SCGT00_L041,)  [3_GEX_V3]                9              12698
# 27     (SCGT00_L042,)  [3_GEX_V3]               44              12967
# 28     (SCGT00_L045,)  [3_GEX_V3]               69              10022
# 29     (SCGT00_L047,)  [3_GEX_V3]               21              10617
# 30     (SCGT00_L049,)  [3_GEX_V3]                8              15149
# 31     (SCGT00_L050,)  [3_GEX_V3]               39               5240
# 32     (SCGT00_L051,)  [3_GEX_V3]               18               9610
# 33  (SCGT00val_L000,)  [3_GEX_V3]               61              12530
# 34  (SCGT00val_L001,)  [3_GEX_V3]               66               8540
# 35  (SCGT00val_L003,)  [3_GEX_V3]               61              11149
# 36  (SCGT00val_L005,)  [3_GEX_V3]               60               8606
# 37  (SCGT00val_L006,)  [3_GEX_V3]               68              12573
# 38  (SCGT00val_L007,)  [3_GEX_V3]               53               8614
#
#     Median Genes  Median MT %  Median RB %  Median HB %
# 0           2381         5.87        40.13         0.01
# 1           2324         5.39        41.79         0.01
# 2           3254         6.04        38.33         0.00
# 3           2200         7.59        40.84         0.01
# 4           2207         5.44        44.21         0.01
# 5           1797         0.88        40.40        10.16
# 6           2655         8.37        31.27         0.01
# 7           2452         6.80        39.70         0.01
# 8           2568         4.18        43.19         0.01
# 9           2707         7.04        36.83         0.01
# 10          2305         6.32        37.51         0.01
# 11          2869         3.56        45.33         0.00
# 12          2802         5.70        40.88         0.01
# 13          2594         5.76        39.81         0.01
# 14          2649         4.27        41.85         0.01
# 15          1288         6.58        40.90         0.00
# 16          1475         6.51        39.77         0.00
# 17          2467         6.06        43.13         0.02
# 18          2826         7.40        39.83         0.01
# 19          2430         8.96        37.36         0.01
# 20          2152         7.29        38.86         0.01
# 21          2616         4.45        45.28         0.00
# 22          1884         6.33        36.24         0.02
# 23          2632         7.35        27.92         0.01
# 24          1623        10.06        28.41         0.00
# 25          2408         7.13        39.88         0.01
# 26          3042         5.32        37.75         0.00
# 27          2759         6.91        43.59         0.01
# 28          2420         3.64        40.69         0.00
# 29          2111         4.72        43.84         0.01
# 30          2586         1.32        45.60         0.02
# 31          1407         3.64        44.91         0.00
# 32          2040         2.88        43.12         0.01
# 33          2578         7.08        42.61         0.01
# 34          1999         5.48        42.08         0.02
# 35          2317         5.06        40.46         0.01
# 36          1849         6.20        43.39         0.02
# 37          2465         6.15        43.77         0.01
# 38          2331         8.23        32.72         0.01

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} BCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN when RBC and Platelets will be filtered out
#HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
#print(f"{np.sum(HB_gene_idx)} HB genes")

#PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
#print(f"{np.sum(PLT_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx )# | HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 113 ribosomal genes
# 198 TCR genes
# 159 BCR genes
# 21 MHC genes
# View of AnnData object with n_obs × n_vars = 1912 × 36665
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key='libraryID', 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key=None, 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

adata_forHVG.var.highly_variable.sum()
# Out:
# 1341

# %%
print(f'The total number of selected HVG is {adata_forHVG.var.highly_variable.sum()}')
# Out:
# The total number of selected HVG is 1341

# %%
adata_HVG = adata_forHVG[:, adata_forHVG.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 1912 × 1341
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'disease_colors', 'log1p', 'hvg'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# argcomplete                 NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-10-17 15:27
# </pre>
# </details>
