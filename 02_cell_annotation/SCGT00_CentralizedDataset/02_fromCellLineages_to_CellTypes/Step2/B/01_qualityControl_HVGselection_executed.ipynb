# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'B'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/02_cell_annotation/SCGT00_CentralizedDataset/02_fromCellLineages_to_CellTypes/Step1/Step1_clusterAnnotDF.pkl'
annotationColumns = 'annotation_step_1'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/SCGT00_CentralizedDataset/results/2_SCGT00_MAIN_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 855417 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 64308 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                               studyID       libraryID  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA         SCGT00     SCGT00_L051
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT         SCGT00     SCGT00_L051
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG         SCGT00     SCGT00_L051
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT         SCGT00     SCGT00_L051
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC         SCGT00     SCGT00_L051
# ...                                               ...             ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG    SCGT00val  SCGT00val_L003
#
#                                                         sampleID chemistry  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA          SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT          SCGT00_I57.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG          SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT          SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC          SCGT00_I57.3P_T0  3_GEX_V3
# ...                                                          ...       ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA  SCGT00val_I036032_T0  3_GEX_V3
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT      SCGT00val_I0362_T0  3_GEX_V3
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT      SCGT00val_I0361_T0  3_GEX_V3
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT      SCGT00val_I0361_T0  3_GEX_V3
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG      SCGT00val_I0361_T0  3_GEX_V3
#
#                                                      technology  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA      3_GEX_V3_GenoHashed
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT      3_GEX_V3_GenoHashed
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG      3_GEX_V3_GenoHashed
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT      3_GEX_V3_GenoHashed
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC      3_GEX_V3_GenoHashed
# ...                                                         ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA  3_GEX_V3_GenoHashed
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT    3_GEX_V3_GenoHashed
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT    3_GEX_V3_GenoHashed
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT    3_GEX_V3_GenoHashed
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG    3_GEX_V3_GenoHashed
#
#                                                     patientID disease  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA             SCGT00_I58      RA
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT             SCGT00_I57      RA
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG             SCGT00_I52      RA
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT             SCGT00_I58      RA
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC             SCGT00_I57      RA
# ...                                                       ...     ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA  SCGT00val_I036032      RA
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT      SCGT00val_I0362      RA
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT      SCGT00val_I0361      RA
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT      SCGT00val_I0361      RA
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG      SCGT00val_I0361      RA
#
#                                             timepoint_replicate  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                      0.0
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                      0.0
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                      0.0
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                      0.0
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                      0.0
# ...                                                         ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA                  0.0
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                    0.0
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                    0.0
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                    0.0
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                    0.0
#
#                                            treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA             ongoing              NR
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT             ongoing              NR
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG             ongoing              NR
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT             ongoing              NR
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC             ongoing              NR
# ...                                                    ...             ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA        antiIL6R              NR
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT          antiIL6R               R
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT          antiIL6R               R
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT          antiIL6R               R
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG          antiIL6R               R
#
#                                                sex        age    BMI  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA      female  61.000000  36.10
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT      female  47.000000  25.71
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG      female  33.000000  21.37
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT      female  61.000000  36.10
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC      female  47.000000  25.71
# ...                                            ...        ...    ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA  female  66.000000  27.99
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT    female  60.142368    NaN
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT    female  37.000000  25.63
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT    female  37.000000  25.63
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG    female  37.000000  25.63
#
#                                            binned_age diseaseStatus  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA          61-70            na
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT          41-50            na
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG          31-40            na
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT          61-70            na
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC          41-50            na
# ...                                               ...           ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA      61-70            na
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT        61-70            na
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT        31-40            na
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT        31-40            na
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG        31-40            na
#
#                                            smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA      never-smoker        na        na
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT      never-smoker        na        na
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG      never-smoker        na        na
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT      never-smoker        na        na
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC      never-smoker        na        na
# ...                                                  ...       ...       ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA  never-smoker        na        na
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT              na        na        na
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT    never-smoker        na        na
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT    never-smoker        na        na
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG    never-smoker        na        na
#
#                                            diseaseGroup          batches  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC            IMIDs    RA_Pool1Pool3
# ...                                                 ...              ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT          IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT          IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT          IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG          IMIDs  RA_Pool19Pool20
#
#                                             n_genes_by_counts  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                   1427
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                   1142
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                   1701
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                   1344
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                   1174
# ...                                                       ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA               1303
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                 1090
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                  889
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                 1152
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                  885
#
#                                             log1p_n_genes_by_counts  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                     7.264030
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                     7.041412
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                     7.439559
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                     7.204149
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                     7.069023
# ...                                                             ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA                 7.173192
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                   6.994850
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                   6.791221
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                   7.050123
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                   6.786717
#
#                                             total_counts  log1p_total_counts  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA              6734            8.815073
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT              4125            8.325064
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG              7130            8.872207
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT              5096            8.536407
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC              4163            8.334231
# ...                                                  ...                 ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA          6327            8.752740
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT            3750            8.229778
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT            3853            8.256867
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT            3873            8.262043
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG            2896            7.971431
#
#                                             pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                       34.080784
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                       28.000000
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                       32.258065
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                       31.397174
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                       29.882296
# ...                                                                ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA                   30.662241
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                     31.653333
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                     30.443810
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                     27.704622
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                     28.867403
#
#                                             total_counts_mt  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                  496
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                  346
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                  200
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                  263
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                  204
# ...                                                     ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA              537
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                397
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                209
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                205
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                143
#
#                                             log1p_total_counts_mt  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                   6.208590
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                   5.849325
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                   5.303305
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                   5.575949
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                   5.323010
# ...                                                           ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA               6.287859
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                 5.986452
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                 5.347108
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                 5.327876
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                 4.969813
#
#                                             pct_counts_mt  total_counts_ribo  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA           7.365607               3224
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT           8.387879               1763
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG           2.805049               2555
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT           5.160911               2139
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC           4.900312               1713
# ...                                                   ...                ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA       8.487435               3121
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT        10.586667               1361
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT         5.424345               2128
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT         5.293054               1555
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG         4.937845               1175
#
#                                             log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                     8.078688
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                     7.475339
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                     7.846199
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                     7.668561
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                     7.446585
# ...                                                             ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA                 8.046229
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                   7.216709
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                   7.663408
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                   7.349874
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                   7.069874
#
#                                             pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA            47.876448                0
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT            42.739394                1
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG            35.834502                2
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT            41.974097                0
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC            41.148210                0
# ...                                                     ...              ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA        49.328276                0
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT          36.293333                0
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT          55.229691                0
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT          40.149755                0
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG          40.573204                0
#
#                                             log1p_total_counts_hb  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                   0.000000
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                   0.693147
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                   1.098612
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                   0.000000
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                   0.000000
# ...                                                           ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA               0.000000
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                 0.000000
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                 0.000000
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                 0.000000
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                 0.000000
#
#                                             pct_counts_hb  total_counts_plt  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA           0.000000                 1
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT           0.024242                 3
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG           0.028050                 0
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT           0.000000                 3
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC           0.000000                 4
# ...                                                   ...               ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA       0.000000                 2
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT         0.000000                 3
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT         0.000000                 1
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT         0.000000                 1
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG         0.000000                 0
#
#                                             log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA                    0.693147
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT                    1.386294
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG                    0.000000
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT                    1.386294
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC                    1.609438
# ...                                                            ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA                1.098612
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT                  1.386294
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT                  0.693147
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT                  0.693147
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG                  0.000000
#
#                                             pct_counts_plt   S_score  \
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA            0.014850  0.020819
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT            0.072727 -0.001497
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG            0.000000  0.019423
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT            0.058870 -0.053448
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC            0.096085 -0.018722
# ...                                                    ...       ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA        0.031611 -0.029986
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT          0.080000 -0.015081
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT          0.025954 -0.010994
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT          0.025820 -0.061498
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG          0.000000 -0.042443
#
#                                             G2M_score phase
# cellID
# SCGT00_L051_I58.3P_T0_AAACGAAGTGCTCCGA      -0.065214     S
# SCGT00_L051_I57.3P_T0_AAACGAAGTTGTGCAT      -0.001794    G1
# SCGT00_L051_I52.3P_T0_AAACGCTCACCAATTG      -0.047543     S
# SCGT00_L051_I58.3P_T0_AAAGAACTCTTACCAT       0.029513   G2M
# SCGT00_L051_I57.3P_T0_AAAGGTACACAATGTC      -0.021486    G1
# ...                                               ...   ...
# SCGT00val_L003_I036032_T0_TTTGATCGTGGTAATA   0.029736   G2M
# SCGT00val_L003_I0362_T0_TTTGGAGGTCAAAGAT    -0.006428    G1
# SCGT00val_L003_I0361_T0_TTTGGTTTCGGAAGGT    -0.065919    G1
# SCGT00val_L003_I0361_T0_TTTGTTGAGGGACCAT    -0.003635    G1
# SCGT00val_L003_I0361_T0_TTTGTTGGTTGCATTG    -0.047912    G1
#
# [64308 rows x 40 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="disease",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#             libraryID   chemistry  Number of cells  Median UMI counts  \
# 0      (SCGT00_L000,)  [3_GEX_V3]             2048               3844
# 1      (SCGT00_L002,)  [3_GEX_V3]             1227               3848
# 2      (SCGT00_L004,)  [3_GEX_V3]              155               5547
# 3      (SCGT00_L005,)  [3_GEX_V3]             1709               2951
# 4      (SCGT00_L007,)  [3_GEX_V3]             1309               3282
# 5      (SCGT00_L008,)  [3_GEX_V3]              706               3256
# 6      (SCGT00_L009,)  [3_GEX_V3]             2398               3290
# 7      (SCGT00_L011,)  [3_GEX_V3]             1974               4404
# 8      (SCGT00_L012,)  [3_GEX_V3]             2076               3451
# 9      (SCGT00_L015,)  [3_GEX_V3]             2528               3590
# 10     (SCGT00_L017,)  [3_GEX_V3]             1548               4639
# 11     (SCGT00_L019,)  [3_GEX_V3]             1578               4143
# 12     (SCGT00_L020,)  [3_GEX_V3]             1695               4642
# 13     (SCGT00_L022,)  [3_GEX_V3]             2062               3865
# 14     (SCGT00_L023,)  [3_GEX_V3]             1998               3706
# 15     (SCGT00_L025,)  [3_GEX_V3]             2107               3027
# 16     (SCGT00_L027,)  [3_GEX_V3]             1935               3137
# 17     (SCGT00_L029,)  [3_GEX_V3]             1496               3535
# 18     (SCGT00_L031,)  [3_GEX_V3]             1820               4140
# 19     (SCGT00_L033,)  [3_GEX_V3]             1475               3774
# 20     (SCGT00_L034,)  [3_GEX_V3]             1550               3507
# 21     (SCGT00_L035,)  [3_GEX_V3]              927               4326
# 22     (SCGT00_L036,)  [3_GEX_V3]             2907               3324
# 23     (SCGT00_L038,)  [3_GEX_V3]             1294               3018
# 24     (SCGT00_L039,)  [3_GEX_V3]             2230               1985
# 25     (SCGT00_L040,)  [3_GEX_V3]             2709               3325
# 26     (SCGT00_L041,)  [3_GEX_V3]              493               4208
# 27     (SCGT00_L042,)  [3_GEX_V3]             1568               3896
# 28     (SCGT00_L045,)  [3_GEX_V3]             2537               3445
# 29     (SCGT00_L047,)  [3_GEX_V3]             1175               3473
# 30     (SCGT00_L049,)  [3_GEX_V3]              328               3743
# 31     (SCGT00_L050,)  [3_GEX_V3]             1473               2679
# 32     (SCGT00_L051,)  [3_GEX_V3]             1009               4474
# 33  (SCGT00val_L000,)  [3_GEX_V3]             1341               3688
# 34  (SCGT00val_L001,)  [3_GEX_V3]             1706               3667
# 35  (SCGT00val_L003,)  [3_GEX_V3]             1655               4328
# 36  (SCGT00val_L005,)  [3_GEX_V3]             2136               3363
# 37  (SCGT00val_L006,)  [3_GEX_V3]             1364               3615
# 38  (SCGT00val_L007,)  [3_GEX_V3]             2062               3166
#
#     Median Genes  Median MT %  Median RB %  Median HB %
# 0           1128         7.21        37.59          0.0
# 1           1125         6.99        37.49          0.0
# 2           1539         8.02        36.94          0.0
# 3            900         9.60        39.28          0.0
# 4            983         7.06        39.59          0.0
# 5            949         2.22        46.44          0.0
# 6           1247        11.17        27.11          0.0
# 7           1219         8.53        39.11          0.0
# 8           1068         4.77        40.90          0.0
# 9           1141         9.65        34.66          0.0
# 10          1248         8.55        39.31          0.0
# 11          1208         5.36        39.21          0.0
# 12          1293         8.49        40.31          0.0
# 13          1148         7.44        36.45          0.0
# 14          1122         4.99        40.65          0.0
# 15           897         9.65        39.79          0.0
# 16           959         9.73        38.94          0.0
# 17          1016         8.96        40.71          0.0
# 18          1244         9.39        37.07          0.0
# 19          1179        13.12        30.39          0.0
# 20          1042         9.99        36.66          0.0
# 21          1121         6.08        43.66          0.0
# 22           988         8.31        39.38          0.0
# 23          1193         8.73        23.57          0.0
# 24           852        12.24        25.53          0.0
# 25          1001         9.22        37.84          0.0
# 26          1414         4.90        33.50          0.0
# 27          1212        10.63        34.37          0.0
# 28          1154         4.55        37.62          0.0
# 29           978         6.96        41.07          0.0
# 30           993         1.82        46.89          0.0
# 31           896         5.56        38.46          0.0
# 32          1134         5.21        44.94          0.0
# 33          1019         9.26        41.05          0.0
# 34          1000         7.74        41.48          0.0
# 35          1168         7.57        40.71          0.0
# 36           916         8.29        42.62          0.0
# 37          1000         9.38        40.84          0.0
# 38          1118        10.15        30.05          0.0

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} BCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN when RBC and Platelets will be filtered out
HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
print(f"{np.sum(HB_gene_idx)} HB genes")

PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
print(f"{np.sum(PLT_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx )# | HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 113 ribosomal genes
# 198 TCR genes
# 159 BCR genes
# 21 MHC genes
# 12 HB genes
# 6 PLT genes
# View of AnnData object with n_obs × n_vars = 64308 × 36665
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key='libraryID', 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key=None, 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

adata_forHVG.var.highly_variable.sum()
# Out:
# 2599

# %%
print(f'The total number of selected HVG is {adata_forHVG.var.highly_variable.sum()}')
# Out:
# The total number of selected HVG is 2599

# %%
adata_HVG = adata_forHVG[:, adata_forHVG.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 64308 × 2599
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'disease_colors', 'log1p', 'hvg'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# argcomplete                 NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-10-21 11:02
# </pre>
# </details>
