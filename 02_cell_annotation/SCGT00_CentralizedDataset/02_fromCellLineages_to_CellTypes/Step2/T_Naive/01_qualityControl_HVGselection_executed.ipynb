# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'T_Naive'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/02_cell_annotation/SCGT00_CentralizedDataset/02_fromCellLineages_to_CellTypes/Step1/Step1_clusterAnnotDF.pkl'
annotationColumns = 'annotation_step_1'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/SCGT00_CentralizedDataset/results/2_SCGT00_MAIN_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 855417 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 260868 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                               studyID       libraryID  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG         SCGT00     SCGT00_L051
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT         SCGT00     SCGT00_L051
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG         SCGT00     SCGT00_L051
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA         SCGT00     SCGT00_L051
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA         SCGT00     SCGT00_L051
# ...                                               ...             ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG  SCGT00val  SCGT00val_L003
#
#                                                         sampleID chemistry  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG          SCGT00_I56.3P_T0  3_GEX_V3
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT          SCGT00_I56.3P_T0  3_GEX_V3
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG          SCGT00_I53.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA          SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA          SCGT00_I53.3P_T0  3_GEX_V3
# ...                                                          ...       ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  SCGT00val_I036010_T0  3_GEX_V3
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC      SCGT00val_I0361_T0  3_GEX_V3
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG      SCGT00val_I0367_T0  3_GEX_V3
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT      SCGT00val_I0367_T0  3_GEX_V3
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG  SCGT00val_I036031_T0  3_GEX_V3
#
#                                                      technology  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG      3_GEX_V3_GenoHashed
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT      3_GEX_V3_GenoHashed
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG      3_GEX_V3_GenoHashed
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA      3_GEX_V3_GenoHashed
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA      3_GEX_V3_GenoHashed
# ...                                                         ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  3_GEX_V3_GenoHashed
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC    3_GEX_V3_GenoHashed
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG    3_GEX_V3_GenoHashed
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT    3_GEX_V3_GenoHashed
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG  3_GEX_V3_GenoHashed
#
#                                                     patientID disease  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG             SCGT00_I56      RA
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT             SCGT00_I56      RA
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG             SCGT00_I53      RA
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA             SCGT00_I58      RA
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA             SCGT00_I53      RA
# ...                                                       ...     ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  SCGT00val_I036010      RA
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC      SCGT00val_I0361      RA
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG      SCGT00val_I0367      RA
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT      SCGT00val_I0367      RA
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG  SCGT00val_I036031      RA
#
#                                             timepoint_replicate  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                      0.0
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                      0.0
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                      0.0
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                      0.0
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                      0.0
# ...                                                         ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                  0.0
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                    0.0
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                    0.0
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                    0.0
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG                  0.0
#
#                                            treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG             ongoing               R
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT             ongoing               R
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG             ongoing               R
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA             ongoing              NR
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA             ongoing               R
# ...                                                    ...             ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        antiIL6R              NR
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          antiIL6R               R
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG          antiIL6R              NR
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT          antiIL6R              NR
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG        antiIL6R               R
#
#                                                sex   age    BMI binned_age  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG      female  56.0  30.11      51-60
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT      female  56.0  30.11      51-60
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG      female  69.0  25.00      61-70
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA      female  61.0  36.10      61-70
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA      female  69.0  25.00      61-70
# ...                                            ...   ...    ...        ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  female  61.0  23.74      61-70
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC    female  37.0  25.63      31-40
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG    female  54.0  22.10      51-60
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT    female  54.0  22.10      51-60
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG  female  52.0  22.27      51-60
#
#                                            diseaseStatus smokingStatus  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                na  never-smoker
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                na  never-smoker
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                na  never-smoker
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                na  never-smoker
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                na  never-smoker
# ...                                                  ...           ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT            na  never-smoker
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC              na  never-smoker
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG              na        smoker
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT              na        smoker
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG            na        smoker
#
#                                            ethnicity institute diseaseGroup  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG            na        na        IMIDs
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT            na        na        IMIDs
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG            na        na        IMIDs
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA            na        na        IMIDs
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA            na        na        IMIDs
# ...                                              ...       ...          ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        na        na        IMIDs
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          na        na        IMIDs
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG          na        na        IMIDs
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT          na        na        IMIDs
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG        na        na        IMIDs
#
#                                                     batches  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG        RA_Pool1Pool3
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT        RA_Pool1Pool3
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG        RA_Pool1Pool3
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA        RA_Pool1Pool3
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA        RA_Pool1Pool3
# ...                                                     ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  RA_Pool19Pool20
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC    RA_Pool19Pool20
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG    RA_Pool19Pool20
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT    RA_Pool19Pool20
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG  RA_Pool19Pool20
#
#                                             n_genes_by_counts  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                   1091
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                    988
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                    764
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                    802
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                   1006
# ...                                                       ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT               1245
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                  810
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                  883
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                  947
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG                957
#
#                                             log1p_n_genes_by_counts  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                     6.995766
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                     6.896694
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                     6.639876
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                     6.688355
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                     6.914731
# ...                                                             ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                 7.127694
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                   6.698268
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                   6.784457
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                   6.854355
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG                 6.864848
#
#                                             total_counts  log1p_total_counts  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG              3804            8.244071
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT              4114            8.322394
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG              2824            7.946264
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA              2867            7.961370
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA              4473            8.406038
# ...                                                  ...                 ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT          4671            8.449343
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC            1872            7.535297
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG            3343            8.114923
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT            3775            8.236421
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG          3990            8.291797
#
#                                             pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                       31.466877
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                       28.415168
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                       31.515581
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                       34.565748
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                       31.298905
# ...                                                                ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                   31.406551
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                     25.587607
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                     31.767873
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                     31.417219
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG                   31.403509
#
#                                             total_counts_mt  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                  145
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                  190
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                   68
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                  160
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                  116
# ...                                                     ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT              203
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                 63
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                116
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                148
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG              185
#
#                                             log1p_total_counts_mt  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                   4.983607
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                   5.252273
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                   4.234107
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                   5.081404
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                   4.762174
# ...                                                           ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT               5.318120
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                 4.158883
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                 4.762174
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                 5.003946
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG               5.225747
#
#                                             pct_counts_mt  total_counts_ribo  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG           3.811777               1654
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT           4.618376               2296
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG           2.407932               1545
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA           5.580746               1108
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA           2.593338               2396
# ...                                                   ...                ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT       4.345964               2099
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC         3.365385                592
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG         3.469937               1736
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT         3.920530               2008
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG       4.636591               1980
#
#                                             log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                     7.411556
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                     7.739359
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                     7.343426
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                     7.011214
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                     7.781973
# ...                                                             ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                 7.649693
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                   6.385194
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                   7.459915
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                   7.605392
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG                 7.591357
#
#                                             pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG            43.480547                0
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT            55.809431                0
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG            54.709632                0
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA            38.646669                0
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA            53.565839                0
# ...                                                     ...              ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        44.936844                0
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          31.623932                0
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG          51.929405                0
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT          53.192053                0
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG        49.624060                0
#
#                                             log1p_total_counts_hb  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                        0.0
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                        0.0
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                        0.0
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                        0.0
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                        0.0
# ...                                                           ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                    0.0
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                      0.0
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                      0.0
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                      0.0
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG                    0.0
#
#                                             pct_counts_hb  total_counts_plt  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                0.0                 1
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                0.0                 1
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                0.0                 0
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                0.0                 0
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                0.0                 2
# ...                                                   ...               ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT            0.0                 1
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC              0.0                 2
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG              0.0                 0
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT              0.0                 0
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG            0.0                 1
#
#                                             log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG                    0.693147
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT                    0.693147
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG                    0.000000
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA                    0.000000
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA                    1.098612
# ...                                                            ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                0.693147
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                  1.098612
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG                  0.000000
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT                  0.000000
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG                0.693147
#
#                                             pct_counts_plt   S_score  \
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG            0.026288  0.015430
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT            0.024307  0.016941
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG            0.000000  0.052425
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA            0.000000  0.012602
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA            0.044713  0.027192
# ...                                                    ...       ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        0.021409  0.029204
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          0.106838  0.066306
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG          0.000000  0.052486
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT          0.000000 -0.031390
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG        0.025063 -0.043762
#
#                                             G2M_score phase
# cellID
# SCGT00_L051_I56.3P_T0_AAACCCAAGTCCGTCG      -0.038676     S
# SCGT00_L051_I56.3P_T0_AAACCCACAAGAATGT      -0.016505     S
# SCGT00_L051_I53.3P_T0_AAACCCAGTGTAGTGG      -0.021518     S
# SCGT00_L051_I58.3P_T0_AAACCCATCACGAGGA      -0.034427     S
# SCGT00_L051_I53.3P_T0_AAACGAAAGGCTTAAA      -0.042444     S
# ...                                               ...   ...
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT   0.019391     S
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC     0.022606     S
# SCGT00val_L003_I0367_T0_TTTGTTGGTTCGTGCG     0.006579     S
# SCGT00val_L003_I0367_T0_TTTGTTGGTTGCAACT     0.001126   G2M
# SCGT00val_L003_I036031_T0_TTTGTTGTCTTTGGAG  -0.035899    G1
#
# [260868 rows x 40 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="disease",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#             libraryID   chemistry  Number of cells  Median UMI counts  \
# 0      (SCGT00_L000,)  [3_GEX_V3]             6970               4320
# 1      (SCGT00_L002,)  [3_GEX_V3]             9253               4324
# 2      (SCGT00_L004,)  [3_GEX_V3]              706               5757
# 3      (SCGT00_L005,)  [3_GEX_V3]             8304               3132
# 4      (SCGT00_L007,)  [3_GEX_V3]             4663               3688
# 5      (SCGT00_L008,)  [3_GEX_V3]             2010               3802
# 6      (SCGT00_L009,)  [3_GEX_V3]             8548               3554
# 7      (SCGT00_L011,)  [3_GEX_V3]             6693               4750
# 8      (SCGT00_L012,)  [3_GEX_V3]             5752               4172
# 9      (SCGT00_L015,)  [3_GEX_V3]             8474               3987
# 10     (SCGT00_L017,)  [3_GEX_V3]             5152               4973
# 11     (SCGT00_L019,)  [3_GEX_V3]             6203               4442
# 12     (SCGT00_L020,)  [3_GEX_V3]             7984               4923
# 13     (SCGT00_L022,)  [3_GEX_V3]             6611               4255
# 14     (SCGT00_L023,)  [3_GEX_V3]             5473               4541
# 15     (SCGT00_L025,)  [3_GEX_V3]            10013               3205
# 16     (SCGT00_L027,)  [3_GEX_V3]             9484               3344
# 17     (SCGT00_L029,)  [3_GEX_V3]             7420               3837
# 18     (SCGT00_L031,)  [3_GEX_V3]             9020               4389
# 19     (SCGT00_L033,)  [3_GEX_V3]             6061               4092
# 20     (SCGT00_L034,)  [3_GEX_V3]             7457               3602
# 21     (SCGT00_L035,)  [3_GEX_V3]             2456               4532
# 22     (SCGT00_L036,)  [3_GEX_V3]             8015               3640
# 23     (SCGT00_L038,)  [3_GEX_V3]             8544               3300
# 24     (SCGT00_L039,)  [3_GEX_V3]             8146               2197
# 25     (SCGT00_L040,)  [3_GEX_V3]             8892               3746
# 26     (SCGT00_L041,)  [3_GEX_V3]             1468               4577
# 27     (SCGT00_L042,)  [3_GEX_V3]             6614               4432
# 28     (SCGT00_L045,)  [3_GEX_V3]             7913               3771
# 29     (SCGT00_L047,)  [3_GEX_V3]             4059               3882
# 30     (SCGT00_L049,)  [3_GEX_V3]             1124               4167
# 31     (SCGT00_L050,)  [3_GEX_V3]             6326               2547
# 32     (SCGT00_L051,)  [3_GEX_V3]             2573               4752
# 33  (SCGT00val_L000,)  [3_GEX_V3]             9298               4263
# 34  (SCGT00val_L001,)  [3_GEX_V3]             8092               3936
# 35  (SCGT00val_L003,)  [3_GEX_V3]             7377               4502
# 36  (SCGT00val_L005,)  [3_GEX_V3]             9546               4009
# 37  (SCGT00val_L006,)  [3_GEX_V3]             9368               4153
# 38  (SCGT00val_L007,)  [3_GEX_V3]             8806               3576
#
#     Median Genes  Median MT %  Median RB %  Median HB %
# 0           1174         5.21        43.44          0.0
# 1           1173         5.16        44.72          0.0
# 2           1528         5.83        43.48          0.0
# 3            890         6.91        46.24          0.0
# 4            999         5.07        46.83          0.0
# 5            950         0.77        53.80          0.0
# 6           1246         8.88        32.98          0.0
# 7           1243         7.30        44.24          0.0
# 8           1140         3.52        46.69          0.0
# 9           1162         6.94        41.63          0.0
# 10          1271         7.19        44.65          0.0
# 11          1197         3.56        46.07          0.0
# 12          1276         5.48        46.76          0.0
# 13          1187         5.46        42.31          0.0
# 14          1227         3.67        46.17          0.0
# 15           854         7.22        48.27          0.0
# 16           922         7.26        46.86          0.0
# 17           993         6.04        47.21          0.0
# 18          1209         7.03        44.29          0.0
# 19          1172        10.25        38.47          0.0
# 20          1016         7.14        44.05          0.0
# 21          1115         4.05        48.20          0.0
# 22           985         6.10        45.42          0.0
# 23          1251         6.69        29.47          0.0
# 24           874         9.77        30.88          0.0
# 25          1023         6.55        45.40          0.0
# 26          1479         3.74        37.26          0.0
# 27          1221         7.96        43.44          0.0
# 28          1212         3.17        41.99          0.0
# 29           989         4.93        48.43          0.0
# 30           943         0.51        55.53          0.0
# 31           837         3.98        44.51          0.0
# 32          1133         3.43        48.78          0.0
# 33          1076         6.08        47.51          0.0
# 34           992         5.43        47.95          0.0
# 35          1149         5.31        47.05          0.0
# 36           972         6.00        49.90          0.0
# 37          1026         6.03        47.89          0.0
# 38          1155         7.65        37.13          0.0

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} BCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN when RBC and Platelets will be filtered out
HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
print(f"{np.sum(HB_gene_idx)} HB genes")

PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
print(f"{np.sum(PLT_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx )# | HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 113 ribosomal genes
# 198 TCR genes
# 159 BCR genes
# 21 MHC genes
# 12 HB genes
# 6 PLT genes
# View of AnnData object with n_obs × n_vars = 260868 × 36665
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key='libraryID', 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key=None, 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

adata_forHVG.var.highly_variable.sum()
# Out:
# 3410

# %%
print(f'The total number of selected HVG is {adata_forHVG.var.highly_variable.sum()}')
# Out:
# The total number of selected HVG is 3410

# %%
adata_HVG = adata_forHVG[:, adata_forHVG.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 260868 × 3410
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'disease_colors', 'log1p', 'hvg'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# argcomplete                 NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-10-21 11:05
# </pre>
# </details>
