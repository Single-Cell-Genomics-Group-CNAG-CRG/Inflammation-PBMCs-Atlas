# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'T_CD4_NonNaive'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/02_cell_annotation/SCGT00_CentralizedDataset/02_fromCellLineages_to_CellTypes/Step2/Step2_clusterAnnotDF.pkl'
annotationColumns = 'annotation_step_2'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/SCGT00_CentralizedDataset/results/2_SCGT00_MAIN_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 855417 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 160017 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                               studyID       libraryID  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT         SCGT00     SCGT00_L051
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG         SCGT00     SCGT00_L051
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG         SCGT00     SCGT00_L051
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA         SCGT00     SCGT00_L051
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA         SCGT00     SCGT00_L051
# ...                                               ...             ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA    SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  SCGT00val  SCGT00val_L003
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC    SCGT00val  SCGT00val_L003
#
#                                                         sampleID chemistry  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT          SCGT00_I57.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG          SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG          SCGT00_I51.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA          SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA          SCGT00_I55.3P_T0  3_GEX_V3
# ...                                                          ...       ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT      SCGT00val_I0361_T0  3_GEX_V3
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA      SCGT00val_I0362_T0  3_GEX_V3
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA  SCGT00val_I036010_T0  3_GEX_V3
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  SCGT00val_I036010_T0  3_GEX_V3
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC      SCGT00val_I0361_T0  3_GEX_V3
#
#                                                      technology  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT      3_GEX_V3_GenoHashed
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG      3_GEX_V3_GenoHashed
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG      3_GEX_V3_GenoHashed
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA      3_GEX_V3_GenoHashed
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA      3_GEX_V3_GenoHashed
# ...                                                         ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT    3_GEX_V3_GenoHashed
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA    3_GEX_V3_GenoHashed
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA  3_GEX_V3_GenoHashed
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  3_GEX_V3_GenoHashed
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC    3_GEX_V3_GenoHashed
#
#                                                     patientID disease  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT             SCGT00_I57      RA
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG             SCGT00_I52      RA
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG             SCGT00_I51      RA
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA             SCGT00_I52      RA
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA             SCGT00_I55      RA
# ...                                                       ...     ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT      SCGT00val_I0361      RA
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA      SCGT00val_I0362      RA
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA  SCGT00val_I036010      RA
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  SCGT00val_I036010      RA
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC      SCGT00val_I0361      RA
#
#                                             timepoint_replicate  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                      0.0
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                      0.0
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                      0.0
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                      0.0
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                      0.0
# ...                                                         ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                    0.0
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                    0.0
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA                  0.0
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                  0.0
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                    0.0
#
#                                            treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT             ongoing              NR
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG             ongoing              NR
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG             ongoing               R
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA             ongoing              NR
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA             ongoing               R
# ...                                                    ...             ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT          antiIL6R               R
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA          antiIL6R               R
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA        antiIL6R              NR
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        antiIL6R              NR
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          antiIL6R               R
#
#                                                sex        age    BMI  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT      female  47.000000  25.71
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG      female  33.000000  21.37
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG      female  42.000000  24.34
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA      female  33.000000  21.37
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA      female  58.000000    NaN
# ...                                            ...        ...    ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT    female  37.000000  25.63
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA    female  60.142368    NaN
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA  female  61.000000  23.74
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  female  61.000000  23.74
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC    female  37.000000  25.63
#
#                                            binned_age diseaseStatus  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT          41-50            na
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG          31-40            na
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG          41-50            na
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA          31-40            na
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA          51-60            na
# ...                                               ...           ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT        31-40            na
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA        61-70            na
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA      61-70            na
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT      61-70            na
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC        31-40            na
#
#                                            smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT      never-smoker        na        na
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG      never-smoker        na        na
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG      never-smoker        na        na
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA      never-smoker        na        na
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA      never-smoker        na        na
# ...                                                  ...       ...       ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT    never-smoker        na        na
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA              na        na        na
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA  never-smoker        na        na
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT  never-smoker        na        na
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC    never-smoker        na        na
#
#                                            diseaseGroup          batches  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA            IMIDs    RA_Pool1Pool3
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA            IMIDs    RA_Pool1Pool3
# ...                                                 ...              ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT          IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA          IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        IMIDs  RA_Pool19Pool20
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          IMIDs  RA_Pool19Pool20
#
#                                             n_genes_by_counts  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                   1409
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                    969
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                   1144
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                   1276
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                   1314
# ...                                                       ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                  917
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                 1249
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA                867
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT               1245
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                  810
#
#                                             log1p_n_genes_by_counts  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                     7.251345
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                     6.877296
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                     7.043160
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                     7.152269
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                     7.181592
# ...                                                             ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                   6.822197
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                   7.130899
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA                 6.766192
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                 7.127694
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                   6.698268
#
#                                             total_counts  log1p_total_counts  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT              6185            8.730044
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG              2408            7.786967
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG              3811            8.245909
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA              5510            8.614501
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA              3790            8.240385
# ...                                                  ...                 ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT            3662            8.206038
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA            4972            8.511779
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA          3383            8.126814
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT          4671            8.449343
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC            1872            7.535297
#
#                                             pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                       30.008084
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                       26.619601
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                       31.435319
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                       29.927405
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                       24.696570
# ...                                                                ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                     28.590934
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                     33.266291
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA                   32.101685
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                   31.406551
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                     25.587607
#
#                                             total_counts_mt  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                  155
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                  225
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                  178
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                  213
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                  169
# ...                                                     ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                186
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                159
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA               85
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT              203
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                 63
#
#                                             log1p_total_counts_mt  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                   5.049856
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                   5.420535
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                   5.187386
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                   5.365976
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                   5.135798
# ...                                                           ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                 5.231109
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                 5.075174
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA               4.454347
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT               5.318120
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                 4.158883
#
#                                             pct_counts_mt  total_counts_ribo  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT           2.506063               2904
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG           9.343854                582
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG           4.670690               1268
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA           3.865699               2410
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA           4.459103               1371
# ...                                                   ...                ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT         5.079192               2086
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA         3.197908               2337
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA       2.512563               1802
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT       4.345964               2099
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC         3.365385                592
#
#                                             log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                     7.974189
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                     6.368187
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                     7.145984
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                     7.787797
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                     7.224025
# ...                                                             ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                   7.643483
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                   7.757051
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA                 7.497207
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                 7.649693
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                   6.385194
#
#                                             pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT            46.952304                0
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG            24.169435                0
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG            33.272107                1
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA            43.738657                0
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA            36.174142                0
# ...                                                     ...              ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT          56.963408                0
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA          47.003218                0
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA        53.266332                1
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        44.936844                0
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          31.623932                0
#
#                                             log1p_total_counts_hb  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                   0.000000
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                   0.000000
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                   0.693147
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                   0.000000
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                   0.000000
# ...                                                           ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                 0.000000
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                 0.000000
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA               0.693147
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT               0.000000
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                 0.000000
#
#                                             pct_counts_hb  total_counts_plt  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT            0.00000                 2
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG            0.00000                 1
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG            0.02624                 0
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA            0.00000                 3
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA            0.00000                 8
# ...                                                   ...               ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT          0.00000                 0
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA          0.00000                 0
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA        0.02956                 1
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        0.00000                 1
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          0.00000                 2
#
#                                             log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT                    1.098612
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG                    0.693147
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG                    0.000000
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA                    1.386294
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA                    2.197225
# ...                                                            ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT                  0.000000
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA                  0.000000
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA                0.693147
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT                0.693147
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC                  1.098612
#
#                                             pct_counts_plt   S_score  \
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT            0.032336 -0.013555
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG            0.041528 -0.028606
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG            0.000000 -0.034170
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA            0.054446  0.000830
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA            0.211082 -0.025410
# ...                                                    ...       ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT          0.000000 -0.037043
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA          0.000000  0.083712
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA        0.029560 -0.017519
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT        0.021409  0.029204
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC          0.106838  0.066306
#
#                                             G2M_score phase
# cellID
# SCGT00_L051_I57.3P_T0_AAACCCAGTCAAAGAT      -0.029977    G1
# SCGT00_L051_I52.3P_T0_AAACGAAAGGCTAACG       0.043730   G2M
# SCGT00_L051_I51.3P_T0_AAACGAAGTTCTAACG       0.040275   G2M
# SCGT00_L051_I52.3P_T0_AAACGAATCTACGCAA      -0.045445     S
# SCGT00_L051_I55.3P_T0_AAACGCTGTCTTTCTA      -0.046799    G1
# ...                                               ...   ...
# SCGT00val_L003_I0361_T0_TTTGGAGAGGGAGAAT     0.006506   G2M
# SCGT00val_L003_I0362_T0_TTTGGTTCACCCAATA     0.019856     S
# SCGT00val_L003_I036010_T0_TTTGGTTCATGACGGA  -0.088592    G1
# SCGT00val_L003_I036010_T0_TTTGTTGCACTTCATT   0.019391     S
# SCGT00val_L003_I0361_T0_TTTGTTGCAGTAGTTC     0.022606     S
#
# [160017 rows x 40 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="disease",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#             libraryID   chemistry  Number of cells  Median UMI counts  \
# 0      (SCGT00_L000,)  [3_GEX_V3]             4556               4563
# 1      (SCGT00_L002,)  [3_GEX_V3]             5788               4666
# 2      (SCGT00_L004,)  [3_GEX_V3]              404               6323
# 3      (SCGT00_L005,)  [3_GEX_V3]             6903               3515
# 4      (SCGT00_L007,)  [3_GEX_V3]             2788               3942
# 5      (SCGT00_L008,)  [3_GEX_V3]             1416               4191
# 6      (SCGT00_L009,)  [3_GEX_V3]             6131               3854
# 7      (SCGT00_L011,)  [3_GEX_V3]             2583               5016
# 8      (SCGT00_L012,)  [3_GEX_V3]             4122               4500
# 9      (SCGT00_L015,)  [3_GEX_V3]             4724               4231
# 10     (SCGT00_L017,)  [3_GEX_V3]             2015               5284
# 11     (SCGT00_L019,)  [3_GEX_V3]             3849               4913
# 12     (SCGT00_L020,)  [3_GEX_V3]             4753               5392
# 13     (SCGT00_L022,)  [3_GEX_V3]             4381               4448
# 14     (SCGT00_L023,)  [3_GEX_V3]             4044               4924
# 15     (SCGT00_L025,)  [3_GEX_V3]             5859               3438
# 16     (SCGT00_L027,)  [3_GEX_V3]             5518               3653
# 17     (SCGT00_L029,)  [3_GEX_V3]             3774               4274
# 18     (SCGT00_L031,)  [3_GEX_V3]             4847               4856
# 19     (SCGT00_L033,)  [3_GEX_V3]             3558               4527
# 20     (SCGT00_L034,)  [3_GEX_V3]             6008               4017
# 21     (SCGT00_L035,)  [3_GEX_V3]             1682               5160
# 22     (SCGT00_L036,)  [3_GEX_V3]             5042               4029
# 23     (SCGT00_L038,)  [3_GEX_V3]             5267               3629
# 24     (SCGT00_L039,)  [3_GEX_V3]             6025               2367
# 25     (SCGT00_L040,)  [3_GEX_V3]             4810               3943
# 26     (SCGT00_L041,)  [3_GEX_V3]              585               4715
# 27     (SCGT00_L042,)  [3_GEX_V3]             3670               4775
# 28     (SCGT00_L045,)  [3_GEX_V3]             3274               3927
# 29     (SCGT00_L047,)  [3_GEX_V3]             2519               4157
# 30     (SCGT00_L049,)  [3_GEX_V3]              705               4696
# 31     (SCGT00_L050,)  [3_GEX_V3]             3443               3102
# 32     (SCGT00_L051,)  [3_GEX_V3]             1788               5471
# 33  (SCGT00val_L000,)  [3_GEX_V3]             5178               4353
# 34  (SCGT00val_L001,)  [3_GEX_V3]             6633               4313
# 35  (SCGT00val_L003,)  [3_GEX_V3]             6215               4983
# 36  (SCGT00val_L005,)  [3_GEX_V3]             5092               4076
# 37  (SCGT00val_L006,)  [3_GEX_V3]             5054               4253
# 38  (SCGT00val_L007,)  [3_GEX_V3]             5014               3700
#
#     Median Genes  Median MT %  Median RB %  Median HB %
# 0           1252         5.26        42.47          0.0
# 1           1282         4.95        43.43          0.0
# 2           1666         6.00        41.57          0.0
# 3            989         7.05        45.17          0.0
# 4           1086         4.81        45.49          0.0
# 5           1066         0.77        52.63          0.0
# 6           1360         8.81        31.10          0.0
# 7           1345         7.02        42.55          0.0
# 8           1226         3.48        45.84          0.0
# 9           1253         7.03        39.27          0.0
# 10          1365         7.02        42.85          0.0
# 11          1314         3.91        45.68          0.0
# 12          1410         5.12        44.63          0.0
# 13          1261         5.49        41.25          0.0
# 14          1317         3.55        45.10          0.0
# 15           940         7.06        46.82          0.0
# 16          1024         7.13        45.22          0.0
# 17          1115         5.98        45.94          0.0
# 18          1336         7.13        42.36          0.0
# 19          1283         9.83        37.02          0.0
# 20          1123         7.35        42.79          0.0
# 21          1280         3.78        46.86          0.0
# 22          1098         6.05        44.13          0.0
# 23          1379         6.48        27.88          0.0
# 24           955         9.64        28.99          0.0
# 25          1111         6.69        42.51          0.0
# 26          1548         3.49        35.03          0.0
# 27          1328         7.65        42.01          0.0
# 28          1279         3.08        39.14          0.0
# 29          1079         4.82        47.36          0.0
# 30          1064         0.49        54.07          0.0
# 31           984         4.26        43.74          0.0
# 32          1293         3.37        47.49          0.0
# 33          1149         6.37        44.75          0.0
# 34          1095         5.54        46.87          0.0
# 35          1267         5.44        46.03          0.0
# 36          1039         6.18        47.21          0.0
# 37          1092         6.35        45.42          0.0
# 38          1219         7.85        34.59          0.0

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} BCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN when RBC and Platelets will be filtered out
HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
print(f"{np.sum(HB_gene_idx)} HB genes")

PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
print(f"{np.sum(PLT_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx )# | HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 113 ribosomal genes
# 198 TCR genes
# 159 BCR genes
# 21 MHC genes
# 12 HB genes
# 6 PLT genes
# View of AnnData object with n_obs × n_vars = 160017 × 36665
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'disease_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key='libraryID', 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    sc.pp.highly_variable_genes(adata_forHVG, 
                                layer='log1p_10e4_counts', 
                                batch_key=None, 
                                n_top_genes=None, 
                                min_disp=0.4, 
                                min_mean=0.015, 
                                max_mean=4, 
                                span=0.3, 
                                n_bins=20, 
                                flavor='seurat', 
                                inplace=True, 
                                check_values=True)

adata_forHVG.var.highly_variable.sum()
# Out:
# 2130

# %%
print(f'The total number of selected HVG is {adata_forHVG.var.highly_variable.sum()}')
# Out:
# The total number of selected HVG is 2130

# %%
adata_HVG = adata_forHVG[:, adata_forHVG.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 160017 × 2130
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'disease_colors', 'log1p', 'hvg'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# argcomplete                 NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-10-21 16:44
# </pre>
# </details>
