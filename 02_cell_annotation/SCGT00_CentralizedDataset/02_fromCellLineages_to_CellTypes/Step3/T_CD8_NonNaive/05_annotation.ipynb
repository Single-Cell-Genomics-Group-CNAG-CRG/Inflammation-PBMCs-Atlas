# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import scanpy.external as sce
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

import scienceplots
from sklearn.neighbors import NearestNeighbors
from typing import Iterable
import pickle
from matplotlib.backends.backend_pdf import PdfPages


# Setting some parameters
warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import custom functions
from customPythonFunctions import *

print("Main directory path: {}".format(here()))

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)
# Out:
# Main directory path: /scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas

# %% [markdown]
# **Setting parameters**

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'T_CD8_NonNaive'
workDir = os.getcwd()

# %% [markdown]
# **Load data**

# %%
# Load the scvi h5ad file
adata = sc.read_h5ad(here("{}/results/03_{}_scVI_UMAP_clinical_allGenes.h5ad".format(workDir, cellGroup)))
adata.uns['log1p'] = dict()
adata.uns['log1p']['base'] = None # only if logscale is computed
adata
# Out:
# AnnData object with n_obs × n_vars = 130019 × 37169
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'batches', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'disease_colors', 'hvg', 'log1p', 'scVI', 'umap', 'umap_scVI'
#     obsm: 'X_scVI', 'X_umap', 'X_umap_scVI', '_scvi_extra_categorical_covs'
#     layers: 'counts', 'log1p_10e4_counts'
#     obsp: 'scVI_connectivities', 'scVI_distances'

# %% [markdown]
# **Loading gene dictionary**

# %%
with open(here('external_reference_data/markerGenes_dictionary.pkl'), 'rb') as f:
    marker_genes_dict = pickle.load(f)

# %%
canonical_marker_gene_list = [g for g in marker_genes_dict['lineages'].values() for g in g if g in adata.var.symbol.values]

if cellGroup in marker_genes_dict:
    lineage_marker_gene_list = set([g for g in marker_genes_dict[cellGroup].values() for g in g if g in adata.var.symbol.values])
else: 
    lineage_marker_gene_list = None

# %% [markdown]
# **Plotting parameters**

# %%
max_cells_plot = 200000
fraction = min(1, (max_cells_plot/adata.shape[0]))

# %% [markdown]
# **Loading clustering resolutions**

# %%
clusterDF_path = here('{}/results/SCGT00_clustering_resolutions_to_explore.pkl'.format(workDir))
clusterDF = pd.read_pickle(clusterDF_path)
clusterDF.head()
# Out:
#                                        leiden_res_0.1 leiden_res_0.25  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG              0               2
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA              0               2
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA              0               0
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT              0               2
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA              0               2
#
#                                        leiden_res_0.5 leiden_res_0.75  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG              0               3
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA              8               3
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA              4               6
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT              7               3
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA              8               3
#
#                                        leiden_res_1
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG            8
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA           10
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA            6
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT            5
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA           10

# %%
# Merging cluster resolutions with adata object

adata_obs_df = adata.obs.merge(clusterDF, left_index=True, right_index=True, how='left')
adata.obs = adata_obs_df
adata.obs.head()
# Out:
#                                        studyID    libraryID          sampleID  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG  SCGT00  SCGT00_L051  SCGT00_I55.3P_T0
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA  SCGT00  SCGT00_L051  SCGT00_I55.3P_T0
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA  SCGT00  SCGT00_L051  SCGT00_I52.3P_T0
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT  SCGT00  SCGT00_L051  SCGT00_I52.3P_T0
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA  SCGT00  SCGT00_L051  SCGT00_I55.3P_T0
#
#                                        chemistry           technology  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT  3_GEX_V3  3_GEX_V3_GenoHashed
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA  3_GEX_V3  3_GEX_V3_GenoHashed
#
#                                          patientID disease  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG  SCGT00_I55      RA
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA  SCGT00_I55      RA
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA  SCGT00_I52      RA
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT  SCGT00_I52      RA
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA  SCGT00_I55      RA
#
#                                         timepoint_replicate treatmentStatus  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG                  0.0         ongoing
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA                  0.0         ongoing
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA                  0.0         ongoing
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT                  0.0         ongoing
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA                  0.0         ongoing
#
#                                        therapyResponse  ...  \
# cellID                                                  ...
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG               R  ...
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA               R  ...
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA              NR  ...
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT              NR  ...
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA               R  ...
#
#                                        log1p_total_counts_plt  pct_counts_plt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG               0.693147        0.027894
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA               0.693147        0.027571
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA               1.609438        0.155099
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT               1.791759        0.130856
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA               1.791759        0.118652
#
#                                          S_score G2M_score phase  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG  0.059579 -0.006911     S
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA  0.025505 -0.094069     S
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA  0.009937 -0.031621     S
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT  0.030320  0.084875   G2M
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA -0.034507  0.063441   G2M
#
#                                        leiden_res_0.1 leiden_res_0.25  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG              0               2
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA              0               2
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA              0               0
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT              0               2
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA              0               2
#
#                                        leiden_res_0.5 leiden_res_0.75  \
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG              0               3
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA              8               3
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA              4               6
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT              7               3
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA              8               3
#
#                                        leiden_res_1
# cellID
# SCGT00_L051_I55.3P_T0_AAACCCATCCCAATAG            8
# SCGT00_L051_I55.3P_T0_AAACGAAAGGTCCAGA           10
# SCGT00_L051_I52.3P_T0_AAACGAAAGGTCTGGA            6
# SCGT00_L051_I52.3P_T0_AAACGAACAGCTTCCT            5
# SCGT00_L051_I55.3P_T0_AAACGAAGTAGTTCCA           10
#
# [5 rows x 45 columns]

# %% [markdown]
# # Cluster annotation

# %%
# Establishing the resolution of choice
resolution_of_choice = 0.5
leiden_cluster = "leiden_res_" + str(resolution_of_choice)
de_key = "de_res_" + str(resolution_of_choice)

# %%
annotation_column_name = "annotation_step_3"

# %%
# Dictionary to map cluster to annotation label
cluster2annotation_lineages = {
     '0': 'T_CD8_NonNaive',
     '1': 'T_CD8_NonNaive',
     '2': 'T_CD8_NonNaive',
     '3': 'LowQuality_cells',
     '4': 'T_CD8_NonNaive',
     '5': 'UTC',
     '6': 'UTC',
     '7': 'T_CD8_NonNaive',
     '8': 'T_CD8_NonNaive',
     '9': 'Platelets',
     '10': 'T_CD8_NonNaive'
     # (...)
}

# Add a new `.obs` column called `annotation_column_name` by mapping clusters to annotation using pandas `map` function
adata.obs[annotation_column_name] = adata.obs[leiden_cluster].map(cluster2annotation_lineages).astype('category')

# %% [markdown]
# **Checking clustering annotation**

# %%
# List of all annotated cell types
print(set(adata.obs[annotation_column_name]))

# Confirm all cells got their assigment
if ("" in set(adata.obs[annotation_column_name])):
    print("Error: not all cells were assigned a lineage")
else:
    print("All cells were assigned a lineage!")
# Out:
# {'LowQuality_cells', 'T_CD8_NonNaive', 'UTC', 'Platelets'}
# All cells were assigned a lineage!

# %% [markdown]
# ## Visualize annotation results

# %%
# Subsetting and randomizing for optimal plotting
random_indices = balanced_sample(adata.obs, cols = annotation_column_name, frac = fraction, shuffle = True, random_state = 42).cellID

sc.set_figure_params(figsize=(7, 5))
fig = sc.pl.embedding(adata[random_indices, :], basis="X_umap_scVI", color=annotation_column_name, 
                      use_raw=False, show=True, return_fig=True, size=10, legend_loc="on data")

if overwriteFigures:
    plt.savefig(here('{}/results/figures/UMAP_clusters_res{}_annotated.pdf'.format(workDir, resolution_of_choice)), 
                bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# ## Export cluster annotation

# %%
clusterAnnotDF = pd.DataFrame(adata.obs[annotation_column_name])
# Save annotation as DF
clusterAnnotDF.to_pickle(path=here('{}/results/SCGT00_cluster_res{}_annotated.pkl'.format(workDir, resolution_of_choice)))

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# sklearn                     1.4.1.post1
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# argcomplete                 NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-10-22 12:54
# </pre>
# </details>
