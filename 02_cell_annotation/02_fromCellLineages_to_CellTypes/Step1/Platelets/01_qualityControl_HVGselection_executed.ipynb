# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'Platelets'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/02_cell_annotation/01_fromDatasets_to_CellLineages/results/INFLAMMATION_cluster_res0.1_annotated.pkl'
annotationColumns = 'cell_lineages'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/results/03_INFLAMMATION_main_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 4918140 × 22838
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 14852 × 22838
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                         studyID     libraryID  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA   SCGT00   SCGT00_L051
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG   SCGT00   SCGT00_L051
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT   SCGT00   SCGT00_L051
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA   SCGT00   SCGT00_L051
# ...                                         ...           ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG  Ren2021  Ren2021_L066
#
#                                                 sampleID chemistry  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA  SCGT00_I55.3P_T0  3_GEX_V3
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG  SCGT00_I54.3P_T0  3_GEX_V3
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC  SCGT00_I57.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT  SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA  SCGT00_I57.3P_T0  3_GEX_V3
# ...                                                  ...       ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG  Ren2021_PS053_T0  5_GEX_V2
#
#                                                  technology      patientID  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA  3_GEX_V3_GenoHashed     SCGT00_I55
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG  3_GEX_V3_GenoHashed     SCGT00_I54
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC  3_GEX_V3_GenoHashed     SCGT00_I57
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT  3_GEX_V3_GenoHashed     SCGT00_I58
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA  3_GEX_V3_GenoHashed     SCGT00_I57
# ...                                                     ...            ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG             5_GEX_V2  Ren2021_PS053
#
#                                        disease  timepoint_replicate  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA      RA                  0.0
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG      RA                  0.0
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC      RA                  0.0
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT      RA                  0.0
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA      RA                  0.0
# ...                                        ...                  ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG   COVID                  0.0
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT   COVID                  0.0
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG   COVID                  0.0
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT   COVID                  0.0
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG   COVID                  0.0
#
#                                        treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA         ongoing               R
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG         ongoing              NR
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC         ongoing              NR
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT         ongoing              NR
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA         ongoing              NR
# ...                                                ...             ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG           under              na
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT           under              na
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG           under              na
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT           under              na
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG           under              na
#
#                                            sex   age    BMI binned_age  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA  female  58.0    NaN      51-60
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG  female  67.0  34.38      61-70
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC  female  47.0  25.71      41-50
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT  female  61.0  36.10      61-70
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA  female  47.0  25.71      41-50
# ...                                        ...   ...    ...        ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG  female  46.0    NaN      41-50
#
#                                                       diseaseStatus  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                           na
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                           na
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                           na
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                           na
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                           na
# ...                                                             ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG  severe/critical_progression
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT  severe/critical_progression
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG  severe/critical_progression
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT  severe/critical_progression
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG  severe/critical_progression
#
#                                        smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA  never-smoker        na        na
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG  never-smoker        na        na
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT  never-smoker        na        na
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA  never-smoker        na        na
# ...                                              ...       ...       ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG            na        na   Beijing
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT            na        na   Beijing
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG            na        na   Beijing
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT            na        na   Beijing
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG            na        na   Beijing
#
#                                        diseaseGroup  n_genes_by_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA        IMIDs                251
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG        IMIDs                302
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC        IMIDs                325
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT        IMIDs                287
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA        IMIDs                317
# ...                                             ...                ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG    infection                896
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT    infection                976
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG    infection                847
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT    infection                850
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG    infection                656
#
#                                         log1p_n_genes_by_counts  total_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                 5.529429           560
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                 5.713733           570
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                 5.786897           789
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                 5.662960          1037
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                 5.762051           622
# ...                                                         ...           ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG                 6.799056          1811
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT                 6.884487          2290
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG                 6.742881          1998
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT                 6.746412          1463
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG                 6.487684          1119
#
#                                         log1p_total_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA            6.329721
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG            6.347389
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC            6.672033
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT            6.945051
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA            6.434547
# ...                                                    ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG            7.502186
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT            7.736744
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG            7.600402
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT            7.288928
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG            7.021084
#
#                                         pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                   41.785714
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                   32.105263
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                   39.163498
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                   50.241080
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                   29.260450
# ...                                                            ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG                   21.479845
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT                   25.414847
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG                   29.879880
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT                   18.865345
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG                   24.486148
#
#                                         total_counts_mt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA               38
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG               19
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC               60
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT               84
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA               42
# ...                                                 ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG              153
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT              204
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG              187
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT               85
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG               96
#
#                                         log1p_total_counts_mt  pct_counts_mt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA               3.663562       6.785714
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG               2.995732       3.333333
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC               4.110874       7.604563
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT               4.442651       8.100289
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA               3.761200       6.752412
# ...                                                       ...            ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG               5.036953       8.448371
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT               5.323010       8.908297
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG               5.236442       9.359359
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT               4.454347       5.809979
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG               4.574711       8.579088
#
#                                         total_counts_ribo  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                 16
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                 16
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                 14
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                 25
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                 17
# ...                                                   ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG                270
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT                303
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG                 98
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT                 92
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG                 59
#
#                                         log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                 2.833213
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                 2.833213
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                 2.708050
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                 3.258097
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                 2.890372
# ...                                                         ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG                 5.602119
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT                 5.717028
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG                 4.595120
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT                 4.532599
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG                 4.094345
#
#                                         pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA         2.857143                0
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG         2.807018                1
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC         1.774398                7
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT         2.410800                0
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA         2.733119                2
# ...                                                 ...              ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG        14.908890                1
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT        13.231441                1
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG         4.904905                3
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT         6.288448                1
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG         5.272565                0
#
#                                         log1p_total_counts_hb  pct_counts_hb  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA               0.000000       0.000000
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG               0.693147       0.175439
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC               2.079442       0.887199
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT               0.000000       0.000000
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA               1.098612       0.321543
# ...                                                       ...            ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG               0.693147       0.055218
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT               0.693147       0.043668
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG               1.386294       0.150150
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT               0.693147       0.068353
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG               0.000000       0.000000
#
#                                         total_counts_plt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                53
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                25
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                50
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                86
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                26
# ...                                                  ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG                14
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT                44
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG                58
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT                16
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG                15
#
#                                         log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                3.988984
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                3.258097
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                3.931826
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                4.465908
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                3.295837
# ...                                                        ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG                2.708050
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT                3.806662
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG                4.077537
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT                2.833213
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG                2.772589
#
#                                         pct_counts_plt  doublet_score  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA        9.464286          0.019
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG        4.385965          0.017
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC        6.337136          0.018
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT        8.293153          0.025
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA        4.180064          0.022
# ...                                                ...            ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG        0.773054          0.001
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT        1.921397          0.000
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG        2.902903          0.000
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT        1.093643          0.001
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG        1.340483          0.001
#
#                                         predicted_doublet   S_score  \
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA                  0 -0.028748
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG                  0 -0.050826
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC                  0 -0.027438
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT                  0 -0.033788
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA                  0 -0.048016
# ...                                                   ...       ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG                  0 -0.075448
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT                  0 -0.058556
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG                  0 -0.061520
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT                  0 -0.016475
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG                  0  0.085280
#
#                                         G2M_score phase
# cellID
# SCGT00_L051_I55.3P_T0_AAAGAACGTTGTTGCA  -0.065902    G1
# SCGT00_L051_I54.3P_T0_AAGGTAACAGTCCGTG   0.000604   G2M
# SCGT00_L051_I57.3P_T0_ACAGGGACAAGGACAC   0.017536   G2M
# SCGT00_L051_I58.3P_T0_ACGATGTTCCACGGGT  -0.071338    G1
# SCGT00_L051_I57.3P_T0_AGAAATGAGCCTAGGA  -0.067102    G1
# ...                                           ...   ...
# Ren2021_L066_PS053_T0_TGTCCCACACGGATAG  -0.026716    G1
# Ren2021_L066_PS053_T0_TGTGTTTTCTACTCAT  -0.089953    G1
# Ren2021_L066_PS053_T0_TTCGGTCCACCTGGTG  -0.140882    G1
# Ren2021_L066_PS053_T0_TTTCCTCCAGGTGCCT  -0.000516    G1
# Ren2021_L066_PS053_T0_TTTGTCAAGAATTGTG  -0.100774     S
#
# [14852 rows x 41 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="chemistry",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#                   libraryID   chemistry  Number of cells  Median UMI counts  \
# 0        (COMBAT2022_L000,)  [5_GEX_V1]               25               1525
# 1        (COMBAT2022_L001,)  [5_GEX_V1]               17               1054
# 2        (COMBAT2022_L002,)  [5_GEX_V1]               17               1549
# 3        (COMBAT2022_L003,)  [5_GEX_V1]               19               1547
# 4        (COMBAT2022_L004,)  [5_GEX_V1]               26               1590
# 5        (COMBAT2022_L005,)  [5_GEX_V1]               16               1464
# 6        (COMBAT2022_L006,)  [5_GEX_V1]               18               1206
# 7        (COMBAT2022_L007,)  [5_GEX_V1]               22               1369
# 8        (COMBAT2022_L008,)  [5_GEX_V1]               38               1502
# 9        (COMBAT2022_L009,)  [5_GEX_V1]               35               1486
# 10       (COMBAT2022_L010,)  [5_GEX_V1]               31               1433
# 11       (COMBAT2022_L011,)  [5_GEX_V1]               37               1846
# 12       (COMBAT2022_L012,)  [5_GEX_V1]               39               1888
# 13       (COMBAT2022_L013,)  [5_GEX_V1]               47               1618
# 14       (COMBAT2022_L014,)  [5_GEX_V1]                9               1577
# 15       (COMBAT2022_L015,)  [5_GEX_V1]               16               1260
# 16       (COMBAT2022_L016,)  [5_GEX_V1]               12               2110
# 17       (COMBAT2022_L017,)  [5_GEX_V1]               26               1155
# 18       (COMBAT2022_L018,)  [5_GEX_V1]               17               1220
# 19       (COMBAT2022_L019,)  [5_GEX_V1]               24               1533
# 20       (COMBAT2022_L020,)  [5_GEX_V1]               16               1970
# 21       (COMBAT2022_L021,)  [5_GEX_V1]                8               1263
# 22       (COMBAT2022_L022,)  [5_GEX_V1]               12               1553
# 23       (COMBAT2022_L023,)  [5_GEX_V1]               11               2350
# 24       (COMBAT2022_L024,)  [5_GEX_V1]               15               1846
# 25       (COMBAT2022_L025,)  [5_GEX_V1]               10               1329
# 26       (COMBAT2022_L026,)  [5_GEX_V1]               14               1363
# 27       (COMBAT2022_L027,)  [5_GEX_V1]               20               1452
# 28       (COMBAT2022_L028,)  [5_GEX_V1]                9               1165
# 29       (COMBAT2022_L029,)  [5_GEX_V1]               13               1096
# 30       (COMBAT2022_L030,)  [5_GEX_V1]               14               2141
# 31       (COMBAT2022_L031,)  [5_GEX_V1]                8               1459
# 32       (COMBAT2022_L032,)  [5_GEX_V1]               14               1242
# 33       (COMBAT2022_L033,)  [5_GEX_V1]               15               1556
# 34       (COMBAT2022_L034,)  [5_GEX_V1]               13               2127
# 35       (COMBAT2022_L035,)  [5_GEX_V1]               26               1730
# 36       (COMBAT2022_L036,)  [5_GEX_V1]               27               1806
# 37       (COMBAT2022_L037,)  [5_GEX_V1]               22               1516
# 38       (COMBAT2022_L038,)  [5_GEX_V1]               31               1742
# 39       (COMBAT2022_L039,)  [5_GEX_V1]               27               1518
# 40       (COMBAT2022_L040,)  [5_GEX_V1]               35               1563
# 41       (COMBAT2022_L041,)  [5_GEX_V1]               21               1626
# 42       (COMBAT2022_L042,)  [5_GEX_V1]                5               2656
# 43       (COMBAT2022_L043,)  [5_GEX_V1]                8               1086
# 44       (COMBAT2022_L044,)  [5_GEX_V1]               13               1282
# 45       (COMBAT2022_L045,)  [5_GEX_V1]                6               1098
# 46       (COMBAT2022_L046,)  [5_GEX_V1]                9               1234
# 47       (COMBAT2022_L047,)  [5_GEX_V1]                7               1985
# 48       (COMBAT2022_L048,)  [5_GEX_V1]                5               1268
# 49       (COMBAT2022_L049,)  [5_GEX_V1]               20               1188
# 50       (COMBAT2022_L050,)  [5_GEX_V1]               18               1845
# 51       (COMBAT2022_L051,)  [5_GEX_V1]               10               1433
# 52       (COMBAT2022_L052,)  [5_GEX_V1]               15               1593
# 53       (COMBAT2022_L053,)  [5_GEX_V1]               24               1486
# 54       (COMBAT2022_L054,)  [5_GEX_V1]               12               1866
# 55       (COMBAT2022_L055,)  [5_GEX_V1]               12               1843
# 56       (COMBAT2022_L056,)  [5_GEX_V1]               15               2104
# 57       (COMBAT2022_L057,)  [5_GEX_V1]               15               1676
# 58       (COMBAT2022_L058,)  [5_GEX_V1]               30               2909
# 59       (COMBAT2022_L059,)  [5_GEX_V1]               17               2460
# 60       (COMBAT2022_L060,)  [5_GEX_V1]               28               2027
# 61       (COMBAT2022_L061,)  [5_GEX_V1]               13               1456
# 62       (COMBAT2022_L062,)  [5_GEX_V1]               17               3005
# 63       (COMBAT2022_L063,)  [5_GEX_V1]               13               2755
# 64       (COMBAT2022_L064,)  [5_GEX_V1]               21               1755
# 65       (COMBAT2022_L065,)  [5_GEX_V1]               19               2292
# 66       (COMBAT2022_L066,)  [5_GEX_V1]               16               2459
# 67       (COMBAT2022_L067,)  [5_GEX_V1]               25               2183
# 68       (COMBAT2022_L068,)  [5_GEX_V1]               19               1705
# 69       (COMBAT2022_L069,)  [5_GEX_V1]               21               1976
# 70        (Cillo2020_L002,)  [3_GEX_V2]                6               1289
# 71        (Cillo2020_L003,)  [3_GEX_V2]                7               1793
# 72        (Cillo2020_L007,)  [3_GEX_V2]                1               1267
# 73        (Cillo2020_L010,)  [3_GEX_V2]                1               2470
# 74        (Cillo2020_L011,)  [3_GEX_V2]                1               1739
# 75        (Cillo2020_L012,)  [3_GEX_V2]                3                737
# 76        (Cillo2020_L013,)  [3_GEX_V2]                2               1020
# 77        (Cillo2020_L018,)  [3_GEX_V2]                1               1114
# 78        (Cillo2020_L019,)  [3_GEX_V2]                1               3038
# 79        (Cillo2020_L026,)  [3_GEX_V2]                2               1722
# 80        (Cillo2020_L027,)  [3_GEX_V2]                2               1609
# 81        (Cillo2020_L029,)  [3_GEX_V2]                1                987
# 82        (Cillo2020_L031,)  [3_GEX_V2]                3               1465
# 83          (Liu2021_L000,)  [5_GEX_V1]               79               1033
# 84          (Liu2021_L002,)  [5_GEX_V1]                4               1825
# 85          (Liu2021_L003,)  [5_GEX_V1]                1                753
# 86          (Liu2021_L004,)  [5_GEX_V1]               15                932
# 87          (Liu2021_L005,)  [5_GEX_V1]               25                702
# 88          (Liu2021_L006,)  [5_GEX_V1]                9                837
# 89          (Liu2021_L008,)  [5_GEX_V1]                1                666
# 90          (Liu2021_L009,)  [5_GEX_V1]                1                999
# 91        (Perez2022_L004,)  [3_GEX_V2]                1               3033
# 92        (Perez2022_L009,)  [3_GEX_V2]                1               2871
# 93        (Perez2022_L077,)  [3_GEX_V2]                1                834
# 94          (Ren2021_L000,)  [5_GEX_V2]               44               1544
# 95          (Ren2021_L001,)  [5_GEX_V2]               30               1499
# 96          (Ren2021_L002,)  [5_GEX_V2]               10               1664
# 97          (Ren2021_L003,)  [5_GEX_V2]               30               1817
# 98          (Ren2021_L004,)  [5_GEX_V2]               69               1567
# 99          (Ren2021_L006,)  [3_GEX_V3]               28               1488
# 100         (Ren2021_L007,)  [3_GEX_V3]                9               2005
# 101         (Ren2021_L008,)  [3_GEX_V3]               18               1905
# 102         (Ren2021_L009,)  [3_GEX_V3]                6               1815
# 103         (Ren2021_L010,)  [3_GEX_V3]                8               1536
# 104         (Ren2021_L011,)  [3_GEX_V3]               24               1734
# 105         (Ren2021_L012,)  [5_GEX_V2]                1               1061
# 106         (Ren2021_L013,)  [5_GEX_V2]                3               1700
# 107         (Ren2021_L016,)  [5_GEX_V2]                7               1665
# 108         (Ren2021_L017,)  [5_GEX_V2]                4               1789
# 109         (Ren2021_L018,)  [5_GEX_V2]                2               2248
# 110         (Ren2021_L020,)  [5_GEX_V2]                7               1548
# 111         (Ren2021_L021,)  [5_GEX_V2]                5               1118
# 112         (Ren2021_L022,)  [5_GEX_V2]               20               1617
# 113         (Ren2021_L024,)  [5_GEX_V2]                2               4819
# 114         (Ren2021_L025,)  [5_GEX_V2]               11               2280
# 115         (Ren2021_L030,)  [3_GEX_V3]               66               2093
# 116         (Ren2021_L031,)  [3_GEX_V3]               23               1539
# 117         (Ren2021_L032,)  [3_GEX_V3]               21               1689
# 118         (Ren2021_L033,)  [3_GEX_V3]               17               1749
# 119         (Ren2021_L034,)  [3_GEX_V3]               16               1753
# 120         (Ren2021_L035,)  [3_GEX_V3]               67               1611
# 121         (Ren2021_L036,)  [3_GEX_V3]               50               2007
# 122         (Ren2021_L037,)  [3_GEX_V3]               58               1645
# 123         (Ren2021_L038,)  [5_GEX_V2]                5               2041
# 124         (Ren2021_L043,)  [3_GEX_V3]               22               1521
# 125         (Ren2021_L044,)  [3_GEX_V3]               23               1598
# 126         (Ren2021_L047,)  [3_GEX_V3]                6               1444
# 127         (Ren2021_L050,)  [5_GEX_V2]              428               1682
# 128         (Ren2021_L051,)  [5_GEX_V2]               42               2110
# 129         (Ren2021_L052,)  [5_GEX_V2]              574               1514
# 130         (Ren2021_L053,)  [5_GEX_V2]               82               1759
# 131         (Ren2021_L054,)  [5_GEX_V2]                5               1304
# 132         (Ren2021_L055,)  [5_GEX_V2]              157               1749
# 133         (Ren2021_L057,)  [5_GEX_V2]              244               1455
# 134         (Ren2021_L058,)  [5_GEX_V2]               23               1575
# 135         (Ren2021_L059,)  [5_GEX_V2]              711               1549
# 136         (Ren2021_L061,)  [5_GEX_V2]              229               1400
# 137         (Ren2021_L063,)  [5_GEX_V2]              100               1964
# 138         (Ren2021_L064,)  [5_GEX_V2]               68               1384
# 139         (Ren2021_L066,)  [5_GEX_V2]               78               1642
# 140         (Ren2021_L067,)  [5_GEX_V2]               71               2308
# 141         (Ren2021_L068,)  [5_GEX_V2]              272               1714
# 142         (Ren2021_L070,)  [5_GEX_V2]               35               1717
# 143         (Ren2021_L071,)  [5_GEX_V2]                7               1747
# 144         (Ren2021_L072,)  [5_GEX_V2]               19               1867
# 145         (Ren2021_L074,)  [5_GEX_V2]                4               1258
# 146         (Ren2021_L076,)  [5_GEX_V2]               19               1781
# 147         (Ren2021_L078,)  [3_GEX_V3]                1               2109
# 148       (Reyes2020_L006,)  [3_GEX_V2]                1               1695
# 149       (Reyes2020_L023,)  [3_GEX_V2]                1               1439
# 150          (SCGT00_L000,)  [3_GEX_V3]               54                730
# 151          (SCGT00_L002,)  [3_GEX_V3]              118                793
# 152          (SCGT00_L003,)  [3_GEX_V3]               50                709
# 153          (SCGT00_L004,)  [3_GEX_V3]                7               1012
# 154          (SCGT00_L005,)  [3_GEX_V3]               29                888
# 155          (SCGT00_L007,)  [3_GEX_V3]               62                844
# 156          (SCGT00_L008,)  [3_GEX_V3]               23                808
# 157          (SCGT00_L009,)  [3_GEX_V3]               22               1029
# 158          (SCGT00_L010,)  [3_GEX_V3]               61                854
# 159          (SCGT00_L011,)  [3_GEX_V3]              174                930
# 160          (SCGT00_L012,)  [3_GEX_V3]              136                814
# 161          (SCGT00_L013,)  [3_GEX_V3]               32                740
# 162          (SCGT00_L015,)  [3_GEX_V3]              144                905
# 163          (SCGT00_L016,)  [3_GEX_V3]               58                817
# 164          (SCGT00_L017,)  [3_GEX_V3]              143                853
# 165          (SCGT00_L019,)  [3_GEX_V3]               28                944
# 166          (SCGT00_L020,)  [3_GEX_V3]               88                845
# 167          (SCGT00_L021,)  [3_GEX_V3]              115                934
# 168          (SCGT00_L022,)  [3_GEX_V3]               37                667
# 169          (SCGT00_L023,)  [3_GEX_V3]              153                790
# 170          (SCGT00_L024,)  [3_GEX_V3]               53                735
# 171          (SCGT00_L025,)  [3_GEX_V3]               62                884
# 172          (SCGT00_L026,)  [3_GEX_V3]               82                774
# 173          (SCGT00_L027,)  [3_GEX_V3]               55                876
# 174          (SCGT00_L028,)  [3_GEX_V3]               37                963
# 175          (SCGT00_L029,)  [3_GEX_V3]              130                864
# 176          (SCGT00_L030,)  [3_GEX_V3]               45                785
# 177          (SCGT00_L031,)  [3_GEX_V3]               53                938
# 178          (SCGT00_L032,)  [3_GEX_V3]              145                856
# 179          (SCGT00_L033,)  [3_GEX_V3]               45                892
# 180          (SCGT00_L034,)  [3_GEX_V3]               30                871
# 181          (SCGT00_L035,)  [3_GEX_V3]               85                846
# 182          (SCGT00_L036,)  [3_GEX_V3]               66                841
# 183          (SCGT00_L037,)  [3_GEX_V3]               27                781
# 184          (SCGT00_L038,)  [3_GEX_V3]               56               1215
# 185          (SCGT00_L039,)  [3_GEX_V3]               10                905
# 186          (SCGT00_L040,)  [3_GEX_V3]              122                754
# 187          (SCGT00_L041,)  [3_GEX_V3]               43                752
# 188          (SCGT00_L042,)  [3_GEX_V3]               54                945
# 189          (SCGT00_L043,)  [3_GEX_V3]               49                812
# 190          (SCGT00_L044,)  [3_GEX_V3]               82                856
# 191          (SCGT00_L045,)  [3_GEX_V3]              234                818
# 192          (SCGT00_L046,)  [3_GEX_V3]               44                876
# 193          (SCGT00_L047,)  [3_GEX_V3]               48                931
# 194          (SCGT00_L049,)  [3_GEX_V3]               11               1155
# 195          (SCGT00_L050,)  [3_GEX_V3]               17               1353
# 196          (SCGT00_L051,)  [3_GEX_V3]               82                783
# 197          (SCGT00_L052,)  [3_GEX_V3]               76                732
# 198          (SCGT01_L000,)  [3_GEX_V3]               48               1230
# 199          (SCGT01_L001,)  [3_GEX_V3]               68               1626
# 200          (SCGT02_L000,)  [3_GEX_V3]              157               1043
# 201          (SCGT02_L001,)  [3_GEX_V3]              105                785
# 202          (SCGT02_L002,)  [3_GEX_V3]              144               1026
# 203          (SCGT02_L003,)  [3_GEX_V3]              283                850
# 204          (SCGT03_L000,)  [5_GEX_V2]               71                820
# 205          (SCGT03_L001,)  [5_GEX_V2]              406                718
# 206          (SCGT03_L002,)  [5_GEX_V2]               56                656
# 207          (SCGT03_L003,)  [5_GEX_V2]              512               1165
# 208          (SCGT03_L004,)  [5_GEX_V2]              112                808
# 209          (SCGT03_L005,)  [5_GEX_V2]              168                781
# 210          (SCGT04_L000,)  [3_GEX_V3]              330               1082
# 211          (SCGT04_L001,)  [3_GEX_V3]              492                965
# 212          (SCGT04_L002,)  [3_GEX_V3]              508               1013
# 213          (SCGT05_L000,)  [5_GEX_V2]               20                734
# 214          (SCGT05_L001,)  [5_GEX_V2]                8               1005
# 215          (SCGT05_L002,)  [5_GEX_V2]                6                799
# 216          (SCGT05_L003,)  [5_GEX_V2]              160                881
# 217          (SCGT05_L004,)  [5_GEX_V2]               61                995
# 218          (SCGT05_L005,)  [5_GEX_V2]              209                966
# 219          (SCGT05_L007,)  [5_GEX_V2]               43                901
# 220          (SCGT05_L008,)  [5_GEX_V2]               82                883
# 221          (SCGT05_L009,)  [5_GEX_V2]              147                920
# 222          (SCGT05_L010,)  [5_GEX_V2]               26                858
# 223          (SCGT05_L011,)  [5_GEX_V2]               35                956
# 224          (SCGT05_L012,)  [5_GEX_V2]               12                775
# 225          (SCGT05_L013,)  [5_GEX_V2]               37                891
# 226  (Schafflick2020_L000,)  [3_GEX_V2]               11               1952
# 227  (Schafflick2020_L001,)  [3_GEX_V2]                7               1989
# 228  (Schafflick2020_L003,)  [3_GEX_V2]               56               1482
# 229  (Schafflick2020_L004,)  [3_GEX_V2]               17               1655
# 230  (Schafflick2020_L005,)  [3_GEX_V2]                9               1377
# 231  (Schafflick2020_L006,)  [3_GEX_V2]                7                775
# 232  (Schafflick2020_L007,)  [3_GEX_V2]                4                956
# 233  (Schafflick2020_L008,)  [3_GEX_V2]               11               1459
# 234  (Schafflick2020_L009,)  [3_GEX_V2]                1               1032
# 235   (Terekhova2023_L000,)  [5_GEX_V2]                8                922
# 236   (Terekhova2023_L001,)  [5_GEX_V2]               11                916
# 237   (Terekhova2023_L002,)  [5_GEX_V2]                7                708
# 238   (Terekhova2023_L003,)  [5_GEX_V2]               10                809
# 239   (Terekhova2023_L004,)  [5_GEX_V2]                8                632
# 240   (Terekhova2023_L005,)  [5_GEX_V2]               23                700
# 241   (Terekhova2023_L006,)  [5_GEX_V2]               28                804
# 242   (Terekhova2023_L009,)  [5_GEX_V2]                7                826
# 243   (Terekhova2023_L010,)  [5_GEX_V2]                2               1021
# 244   (Terekhova2023_L011,)  [5_GEX_V2]                1               1392
# 245   (Terekhova2023_L012,)  [5_GEX_V2]                1                757
# 246   (Terekhova2023_L013,)  [5_GEX_V2]                2                841
# 247   (Terekhova2023_L014,)  [5_GEX_V2]                1                854
# 248   (Terekhova2023_L015,)  [5_GEX_V2]               16                809
# 249   (Terekhova2023_L016,)  [5_GEX_V2]               11                781
# 250   (Terekhova2023_L017,)  [5_GEX_V2]                8               1053
# 251   (Terekhova2023_L018,)  [5_GEX_V2]                4                740
# 252   (Terekhova2023_L019,)  [5_GEX_V2]                6                887
# 253   (Terekhova2023_L020,)  [5_GEX_V2]                8                807
# 254   (Terekhova2023_L021,)  [5_GEX_V2]                9               1267
# 255   (Terekhova2023_L022,)  [5_GEX_V2]                4                843
# 256   (Terekhova2023_L023,)  [5_GEX_V2]               27                899
# 257   (Terekhova2023_L024,)  [5_GEX_V2]               23               1017
# 258   (Terekhova2023_L025,)  [5_GEX_V2]                3                914
# 259   (Terekhova2023_L026,)  [5_GEX_V2]                6               1633
# 260   (Terekhova2023_L027,)  [5_GEX_V2]                8               1206
# 261   (Terekhova2023_L028,)  [5_GEX_V2]                4                937
# 262   (Terekhova2023_L029,)  [5_GEX_V2]                5                751
# 263   (Terekhova2023_L030,)  [5_GEX_V2]                6               1176
# 264   (Terekhova2023_L031,)  [5_GEX_V2]               31                788
# 265   (Terekhova2023_L032,)  [5_GEX_V2]               22                741
# 266   (Terekhova2023_L033,)  [5_GEX_V2]                6               1172
# 267   (Terekhova2023_L034,)  [5_GEX_V2]                7               1206
# 268   (Terekhova2023_L037,)  [5_GEX_V2]                3               1110
# 269   (Terekhova2023_L038,)  [5_GEX_V2]                3               1366
# 270   (Terekhova2023_L039,)  [5_GEX_V2]                3               1508
# 271   (Terekhova2023_L040,)  [5_GEX_V2]                8                766
# 272   (Terekhova2023_L041,)  [5_GEX_V2]               11                881
# 273   (Terekhova2023_L042,)  [5_GEX_V2]               12                871
# 274   (Terekhova2023_L043,)  [5_GEX_V2]               24                887
# 275   (Terekhova2023_L044,)  [5_GEX_V2]               22                850
# 276   (Terekhova2023_L045,)  [5_GEX_V2]                3               1953
# 277   (Terekhova2023_L046,)  [5_GEX_V2]                2                883
# 278   (Terekhova2023_L047,)  [5_GEX_V2]                9                881
# 279   (Terekhova2023_L048,)  [5_GEX_V2]                5                740
# 326   (Terekhova2023_L097,)  [5_GEX_V2]               25                818
# 327   (Terekhova2023_L098,)  [5_GEX_V2]               22               1063
# 328   (Terekhova2023_L099,)  [5_GEX_V2]               22               1051
# 329   (Terekhova2023_L100,)  [5_GEX_V2]               30                936
# 330   (Terekhova2023_L101,)  [5_GEX_V2]               35                909
# 331   (Terekhova2023_L102,)  [5_GEX_V2]               23                768
# 332   (Terekhova2023_L103,)  [5_GEX_V2]               15                865
# 333   (Terekhova2023_L104,)  [5_GEX_V2]               17                927
# 334   (Terekhova2023_L105,)  [5_GEX_V2]               21                832
# 335        (Wang2020_L000,)  [3_GEX_V2]               14                753
# 336        (Wang2020_L001,)  [3_GEX_V2]               21                955
# 337        (Wang2020_L002,)  [3_GEX_V2]                2                761
# 338        (Wang2020_L004,)  [3_GEX_V2]                6                713
# 339        (Wang2020_L005,)  [3_GEX_V2]               24                727
# 340        (Wang2020_L006,)  [3_GEX_V2]                5                850
# 341       (Zhang2023_L005,)  [5_GEX_V1]                6               1358
# 342       (Zhang2023_L006,)  [5_GEX_V1]                3               1335
# 343       (Zhang2023_L009,)  [5_GEX_V1]                1                570
# 344       (Zhang2023_L010,)  [5_GEX_V1]               63                729
# 345       (Zhang2023_L011,)  [5_GEX_V1]               17                898
# 346       (Zhang2023_L013,)  [5_GEX_V1]                1               1522
# 347       (Zhang2023_L014,)  [5_GEX_V1]               35                762
# 348       (Zhang2023_L015,)  [5_GEX_V1]               41                774
# 349       (Zhang2023_L016,)  [5_GEX_V1]               54                721
# 350       (Zhang2023_L018,)  [5_GEX_V1]              126                793
# 351       (Zhang2023_L019,)  [5_GEX_V1]               52                725
#
#      Median Genes  Median MT %  Median RB %  Median HB %
# 0             542         1.48         3.54         0.00
# 1             449         1.68         3.78         0.00
# 2             630         1.44         2.57         0.00
# 3             569         1.42         3.10         0.00
# 4             540         1.80         3.76         0.00
# 5             606         1.47         2.51         0.00
# 6             477         1.85         3.43         0.00
# 7             444         1.17         2.05         0.02
# 8             494         1.69         1.99         0.11
# 9             530         1.54         2.11         0.06
# 10            528         1.76         1.80         0.10
# 11            556         1.50         2.44         0.10
# 12            627         1.36         2.53         0.06
# 13            568         1.67         2.70         0.07
# 14            536         1.96         3.47         0.00
# 15            490         1.98         3.33         0.09
# 16            727         1.90         2.01         0.07
# 17            446         2.08         3.06         0.10
# 18            468         2.14         2.22         0.07
# 19            575         1.54         2.41         0.08
# 20            679         1.64         3.44         0.02
# 21            426         2.27         2.40         0.18
# 22            662         1.66         2.62         0.07
# 23            767         1.76         2.04         0.00
# 24            599         1.02         1.63         0.05
# 25            541         1.31         2.07         0.00
# 26            582         1.86         3.05         0.05
# 27            640         1.53         2.62         0.07
# 28            410         2.75         7.68         0.08
# 29            427         2.08         3.20         0.08
# 30            807         1.30         2.39         0.05
# 31            501         1.65         2.82         0.14
# 32            479         1.49         2.24         0.13
# 33            548         1.54         3.53         0.18
# 34            558         1.31         4.40         0.03
# 35            646         2.07         2.71         0.01
# 36            609         1.45         3.35         0.03
# 292           339         3.61         3.27         0.36
# 293           476         1.02         1.37         0.00
# 294           473         0.97         1.04         0.00
# 295           392         5.18         1.85         0.14
# 296           399         0.77         1.16         0.12
# 297           532         2.11         1.20         0.00
# 298           510         2.42         1.15         0.00
# 299           603         2.61         0.64         0.00
# 300           408         1.50         0.96         0.00
# 301           448         1.67         0.98         0.00
# 302           422         2.87         1.06         0.00
# 303           424         2.49         1.40         0.00
# 304           434         2.32         1.33         0.00
# 305           456         2.70         1.34         0.00
# 306           409         2.61         1.27         0.00
# 307           464         2.36         1.46         0.00
# 308           398         2.78         1.27         0.00
# 309           455         2.28         0.82         0.00
# 310           580         2.18         0.78         0.00
# 311           388         2.76         1.33         0.00
# 312           413         2.62         1.02         0.00
# 313           462         0.98         0.72         0.00
# 314           355         3.29         1.00         0.00
# 315           720         4.18         0.56         0.03
# 316           593         4.03         0.65         0.00
# 317           463         2.66         0.75         0.00
# 318           511         2.54         0.76         0.09
# 319           401         0.96         1.54         0.00
# 320           423         0.92         1.07         0.00
# 321           327         1.01         0.77         0.08
# 322           432         1.72         0.76         0.00
# 323           503         1.76         1.10         0.00
# 324           623         1.83         1.06         0.00
# 325           448         0.93         1.19         0.00
# 326           441         2.29         1.12         0.00
# 327           470         1.26         1.30         0.00
# 328           445         1.75         1.11         0.00
# 329           445         2.06         1.06         0.00
# 330           374         2.46         1.53         0.00
# 331           347         2.54         1.28         0.00
# 332           362         2.12         1.17         0.00
# 333           531         1.72         1.29         0.00
# 334           369         2.43         1.32         0.00
# 335           410         5.90         4.18         0.00
# 336           471         3.14         7.43         0.00
# 337           357         8.43         6.57         0.00
# 338           371         3.66        20.02         0.08
# 339           356         2.91         5.63         0.00
# 340           415         4.53         5.06         0.06
# 341           443         4.57         1.00         0.00
# 342           516         2.79         0.74         0.19
# 343           342         0.53         3.86         0.00
# 344           380         2.10         1.06         0.00
# 345           409         4.23         1.98         0.00
# 346           516         4.27         1.64         0.00
# 347           415         2.59         2.95         0.00
# 348           368         2.77         0.78         0.00
# 349           378         2.35         5.45         0.13
# 350           394         3.37         3.33         0.00
# 351           390         2.09         5.26         0.08

# %%
adata_tmp = adata[adata.obs.chemistry == "3_GEX_V3", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="3_GEX_V3",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_3GEXV3.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "3_GEX_V2", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="3_GEX_V2",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_3GEXV2.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "5_GEX_V2", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="5_GEX_V2",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_5GEXV2.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "5_GEX_V1", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="5_GEX_V1",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_5GEXV1.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} TCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN FROM STEP 2 (when RBC and Platelets will be filtered out)
# HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
# print(f"{np.sum(MHC_gene_idx)} HB genes")

# PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
# print(f"{np.sum(MHC_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx) # HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 110 ribosomal genes
# 118 TCR genes
# 54 TCR genes
# 21 MHC genes
# View of AnnData object with n_obs × n_vars = 14852 × 22522
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    HVGdf = get_HVG(adata_forHVG, groupby='studyID', batch_key='libraryID', 
                    flavor='seurat', min_disp=0.3, max_disp = 'inf', min_mean=0.01, max_mean=4)
except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    HVGdf = get_HVG(adata_forHVG, groupby='studyID', batch_key=None, 
                    flavor='seurat', min_disp=0.3, max_disp = 'inf', min_mean=0.01, max_mean=4)
# Out:
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# Reyes2020
# WARNING: The group Reyes2020 includes only 2 cells. Not considered
# Cillo2020
# An error occurred: division by zero
# Executing without library correction...
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# Reyes2020
# WARNING: The group Reyes2020 includes only 2 cells. Not considered
# Cillo2020
# Zhang2023
# Schafflick2020
# Liu2021
# Terekhova2023
# Perez2022
# WARNING: The group Perez2022 includes only 3 cells. Not considered
# Wang2020
# COMBAT2022
# Ren2021

# %%
# Considering only genes selected as HV in at least 1 study
columns_to_keep = [f'highly_variable_{study_id}' for study_id in adata.obs['studyID'].unique() if f'highly_variable_{study_id}' in HVGdf.columns]

HVG_sel_DF = HVGdf.loc[:, columns_to_keep]
HVG_sel_DF = HVG_sel_DF[HVG_sel_DF.sum(axis=1) > 0]
HVG_sel_DF.columns = HVG_sel_DF.columns.str.removeprefix("highly_variable_")
HVG_sel_DF.head()
# Out:
#                  SCGT00  SCGT01  SCGT02  SCGT03  SCGT04  SCGT05  Cillo2020  \
# ENSG00000000003    True   False   False   False   False    True      False
# ENSG00000000419   False   False   False    True   False   False      False
# ENSG00000000460   False    True    True   False   False    True      False
# ENSG00000000938    True   False    True    True    True    True      False
# ENSG00000000971   False   False    True   False   False   False      False
#
#                  Zhang2023  Schafflick2020  Liu2021  Terekhova2023  Wang2020  \
# ENSG00000000003      False           False    False          False     False
# ENSG00000000419      False           False    False           True     False
# ENSG00000000460       True            True    False           True     False
# ENSG00000000938      False            True     True           True      True
# ENSG00000000971      False           False    False          False     False
#
#                  COMBAT2022  Ren2021
# ENSG00000000003       False    False
# ENSG00000000419        True    False
# ENSG00000000460        True    False
# ENSG00000000938        True     True
# ENSG00000000971       False     True

# %%
HVG_number = 2000

# %%
HVGperStudyCount = pd.DataFrame(index = HVG_sel_DF.index)
HVGperStudyCount['n_studies'] = HVG_sel_DF.sum(axis = 1)
HVGperStudyCount
# Out:
#                  n_studies
# ENSG00000000003          2
# ENSG00000000419          3
# ENSG00000000460          7
# ENSG00000000938         11
# ENSG00000000971          2
# ...                    ...
# ENSG00000288156          2
# ENSG00000288253          1
# ENSG00000288302          1
# ENSG00000288398          1
# ENSG00000288596          1
#
# [13979 rows x 1 columns]

# %%
CumStud_n = pd.DataFrame(HVGperStudyCount['n_studies'].value_counts())
CumStud_n.sort_index(ascending=False, inplace=True)
CumStud_n['cs_studies'] = CumStud_n['count'].cumsum()
CumStud_n
# Out:
#            count  cs_studies
# n_studies
# 14            10          10
# 13            26          36
# 12            51          87
# 11           114         201
# 10           236         437
# 9            478         915
# 8            788        1703
# 7           1208        2911
# 6           1431        4342
# 5           1669        6011
# 4           1730        7741
# 3           1754        9495
# 2           1803       11298
# 1           2681       13979

# %%
nStudyThr = CumStud_n.loc[CumStud_n['cs_studies'] > HVG_number,:].index[0]
nStudyThr
# Out:
# 7

# %%
fig, ax = plt.subplots(1, figsize=(10, 5))
CumStud_n.cs_studies.plot(ax=ax)

plt.axhline(y = HVG_number, color = 'r', linestyle = '--')
plt.axvline(x = nStudyThr, color = 'g', linestyle = '--')
plt.xlabel('# of different study')
plt.ylabel('# of genes (cumulative)')
plt.gca().invert_xaxis()

if overwriteFigures:
    plt.savefig(here('{}/results/figures/01_HVG_selection_threshold.pdf'.format(workDir)), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
plt.show()

# %%
print('The total number of selected HVG is {}'.format(CumStud_n.loc[nStudyThr,'cs_studies']))
# Out:
# The total number of selected HVG is 2911

# %%
HVG_selected = HVGperStudyCount[HVGperStudyCount['n_studies'] >= nStudyThr].index.tolist()
print(HVG_selected[1:10])
# Out:
# ['ENSG00000000938', 'ENSG00000001629', 'ENSG00000002549', 'ENSG00000003402', 'ENSG00000003756', 'ENSG00000004534', 'ENSG00000004700', 'ENSG00000004897', 'ENSG00000005059']

# %%
adata.var['highly_variable'] = False
adata.var.loc[HVG_selected,'highly_variable'] = True

adata_HVG = adata[:, adata.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 14852 × 2911
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-04-28 17:32
# </pre>
# </details>
