# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'RBC_and_HSC'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/02_cell_annotation/01_fromDatasets_to_CellLineages/results/INFLAMMATION_cluster_res0.1_annotated.pkl'
annotationColumns = 'cell_lineages'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/results/03_INFLAMMATION_main_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 4918140 × 22838
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 12028 × 22838
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                         studyID     libraryID  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG   SCGT00   SCGT00_L051
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA   SCGT00   SCGT00_L051
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA   SCGT00   SCGT00_L051
# ...                                         ...           ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG  Ren2021  Ren2021_L066
#
#                                                 sampleID chemistry  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG  SCGT00_I55.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG  SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  SCGT00_I58.3P_T0  3_GEX_V3
# ...                                                  ...       ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG  Ren2021_PS053_T0  5_GEX_V2
#
#                                                  technology      patientID  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG  3_GEX_V3_GenoHashed     SCGT00_I55
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  3_GEX_V3_GenoHashed     SCGT00_I52
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  3_GEX_V3_GenoHashed     SCGT00_I58
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG  3_GEX_V3_GenoHashed     SCGT00_I52
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  3_GEX_V3_GenoHashed     SCGT00_I58
# ...                                                     ...            ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG             5_GEX_V2  Ren2021_PS053
#
#                                        disease  timepoint_replicate  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG      RA                  0.0
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC      RA                  0.0
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA      RA                  0.0
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG      RA                  0.0
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA      RA                  0.0
# ...                                        ...                  ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG   COVID                  0.0
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA   COVID                  0.0
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG   COVID                  0.0
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC   COVID                  0.0
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG   COVID                  0.0
#
#                                        treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG         ongoing               R
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC         ongoing              NR
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA         ongoing              NR
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG         ongoing              NR
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA         ongoing              NR
# ...                                                ...             ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG           under              na
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA           under              na
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG           under              na
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC           under              na
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG           under              na
#
#                                            sex   age    BMI binned_age  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG  female  58.0    NaN      51-60
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  female  33.0  21.37      31-40
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  female  61.0  36.10      61-70
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG  female  33.0  21.37      31-40
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  female  61.0  36.10      61-70
# ...                                        ...   ...    ...        ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG  female  46.0    NaN      41-50
#
#                                                       diseaseStatus  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                           na
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                           na
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                           na
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                           na
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                           na
# ...                                                             ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  severe/critical_progression
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  severe/critical_progression
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  severe/critical_progression
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  severe/critical_progression
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG  severe/critical_progression
#
#                                        smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG  never-smoker        na        na
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  never-smoker        na        na
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  never-smoker        na        na
# ...                                              ...       ...       ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG            na        na   Beijing
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA            na        na   Beijing
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG            na        na   Beijing
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC            na        na   Beijing
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG            na        na   Beijing
#
#                                        diseaseGroup  n_genes_by_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG        IMIDs                851
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        IMIDs               2639
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        IMIDs               2263
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG        IMIDs                949
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        IMIDs               3567
# ...                                             ...                ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG    infection               1317
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA    infection                786
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG    infection               1919
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC    infection               1540
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG    infection               1968
#
#                                         log1p_n_genes_by_counts  total_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                 6.747587          1777
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                 7.878534         12898
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 7.724888         10543
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                 6.856462          4558
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                 8.179760         19479
# ...                                                         ...           ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                 7.183871          3373
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                 6.668228          1797
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                 7.560080          5575
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 7.340187          3408
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG                 7.585281          5265
#
#                                         log1p_total_counts  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG            7.483244
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC            9.464905
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA            9.263312
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG            8.424859
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA            9.877144
# ...                                                    ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG            8.123854
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA            7.494430
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG            8.626227
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC            8.134174
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG            8.569026
#
#                                         pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                   41.643219
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                   26.895643
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                   25.893958
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                   38.635366
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                   24.636788
# ...                                                            ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                   21.049511
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                   24.429605
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                   19.228700
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                   18.368545
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG                   19.335233
#
#                                         total_counts_mt  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG              126
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC              198
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA              290
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG               98
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA              901
# ...                                                 ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG              136
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA               59
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG              219
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC              201
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG              377
#
#                                         log1p_total_counts_mt  pct_counts_mt  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG               4.844187       7.090602
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               5.293305       1.535122
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               5.673323       2.750640
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG               4.595120       2.150066
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               6.804615       4.625494
# ...                                                       ...            ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG               4.919981       4.032019
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA               4.094345       3.283250
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG               5.393628       3.928251
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC               5.308268       5.897887
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG               5.934894       7.160494
#
#                                         total_counts_ribo  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                 98
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               6023
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               4970
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG               2078
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               7748
# ...                                                   ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG               1208
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                704
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG               1976
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                740
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG               1726
#
#                                         log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                 4.595120
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                 8.703507
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 8.511376
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                 7.639642
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                 8.955319
# ...                                                         ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                 7.097549
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                 6.558198
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                 7.589336
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 6.608001
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG                 7.454141
#
#                                         pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG         5.514913              378
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        46.697162                1
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        47.140283                0
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG        45.590171              830
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        39.776169                3
# ...                                                 ...              ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG        35.813816                0
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA        39.176405                0
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG        35.443946                0
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC        21.713615                0
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG        32.782526                0
#
#                                         log1p_total_counts_hb  pct_counts_hb  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG               5.937536      21.271806
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               0.693147       0.007753
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               0.000000       0.000000
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG               6.722630      18.209741
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               1.386294       0.015401
# ...                                                       ...            ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG               0.000000       0.000000
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA               0.000000       0.000000
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG               0.000000       0.000000
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC               0.000000       0.000000
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG               0.000000       0.000000
#
#                                         total_counts_plt  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                 3
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                17
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 2
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                 1
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                14
# ...                                                  ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                10
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                 3
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                 5
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 3
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG                21
#
#                                         log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                1.386294
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                2.890372
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                1.098612
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                0.693147
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                2.708050
# ...                                                        ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                2.397895
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                1.386294
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                1.791759
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                1.386294
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG                3.091042
#
#                                         pct_counts_plt  doublet_score  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG        0.168824          0.043
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        0.131803          0.030
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        0.018970          0.037
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG        0.021939          0.024
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        0.071872          0.076
# ...                                                ...            ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG        0.296472          0.004
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA        0.166945          0.003
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG        0.089686          0.002
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC        0.088028          0.004
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG        0.398860          0.005
#
#                                         predicted_doublet   S_score  \
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG                  0 -0.030178
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                  0 -0.036518
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                  0 -0.004612
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG                  0 -0.031262
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                  0 -0.041559
# ...                                                   ...       ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                  0 -0.003147
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                  0  0.048857
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                  0  0.016826
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                  0 -0.006460
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG                  0 -0.035010
#
#                                         G2M_score phase
# cellID
# SCGT00_L051_I55.3P_T0_AGACTCAGTTTACTGG  -0.069435    G1
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  -0.065312    G1
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  -0.034372    G1
# SCGT00_L051_I52.3P_T0_CCGATCTTCAGACCCG  -0.063023    G1
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  -0.065553    G1
# ...                                           ...   ...
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  -0.060245    G1
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  -0.077298     S
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  -0.021284     S
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  -0.118916    G1
# Ren2021_L066_PS053_T0_TTAGTTCCATCGATTG  -0.053760    G1
#
# [12028 rows x 41 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="chemistry",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#                   libraryID   chemistry  Number of cells  Median UMI counts  \
# 0        (COMBAT2022_L000,)  [5_GEX_V1]               29               9186
# 1        (COMBAT2022_L001,)  [5_GEX_V1]               27               7627
# 2        (COMBAT2022_L002,)  [5_GEX_V1]               30               7660
# 3        (COMBAT2022_L003,)  [5_GEX_V1]               36               8741
# 4        (COMBAT2022_L004,)  [5_GEX_V1]               28               8883
# 5        (COMBAT2022_L005,)  [5_GEX_V1]               27               6436
# 6        (COMBAT2022_L006,)  [5_GEX_V1]               26               6937
# 7        (COMBAT2022_L007,)  [5_GEX_V1]               39              11256
# 8        (COMBAT2022_L008,)  [5_GEX_V1]               40              10220
# 9        (COMBAT2022_L009,)  [5_GEX_V1]               39               9875
# 10       (COMBAT2022_L010,)  [5_GEX_V1]               43               8880
# 11       (COMBAT2022_L011,)  [5_GEX_V1]               47              10824
# 12       (COMBAT2022_L012,)  [5_GEX_V1]               51              10105
# 13       (COMBAT2022_L013,)  [5_GEX_V1]               27               9764
# 14       (COMBAT2022_L014,)  [5_GEX_V1]               34               9278
# 15       (COMBAT2022_L015,)  [5_GEX_V1]               30               9674
# 16       (COMBAT2022_L016,)  [5_GEX_V1]               37              10296
# 17       (COMBAT2022_L017,)  [5_GEX_V1]               36               9245
# 18       (COMBAT2022_L018,)  [5_GEX_V1]               35               8429
# 19       (COMBAT2022_L019,)  [5_GEX_V1]               29               9049
# 20       (COMBAT2022_L020,)  [5_GEX_V1]               43               8355
# 21       (COMBAT2022_L021,)  [5_GEX_V1]               26               8974
# 22       (COMBAT2022_L022,)  [5_GEX_V1]               38               8862
# 23       (COMBAT2022_L023,)  [5_GEX_V1]               38               7913
# 24       (COMBAT2022_L024,)  [5_GEX_V1]               32               7570
# 25       (COMBAT2022_L025,)  [5_GEX_V1]               31               7639
# 26       (COMBAT2022_L026,)  [5_GEX_V1]               45               7471
# 27       (COMBAT2022_L027,)  [5_GEX_V1]               42               7634
# 28       (COMBAT2022_L028,)  [5_GEX_V1]               18              10882
# 29       (COMBAT2022_L029,)  [5_GEX_V1]               40              10535
# 30       (COMBAT2022_L030,)  [5_GEX_V1]               39              10601
# 31       (COMBAT2022_L031,)  [5_GEX_V1]               28              10644
# 32       (COMBAT2022_L032,)  [5_GEX_V1]               38              10871
# 33       (COMBAT2022_L033,)  [5_GEX_V1]               34              10065
# 34       (COMBAT2022_L034,)  [5_GEX_V1]               30              10240
# 35       (COMBAT2022_L035,)  [5_GEX_V1]               45               7770
# 36       (COMBAT2022_L036,)  [5_GEX_V1]               45               8014
# 37       (COMBAT2022_L037,)  [5_GEX_V1]               36               6753
# 38       (COMBAT2022_L038,)  [5_GEX_V1]               36               8944
# 39       (COMBAT2022_L039,)  [5_GEX_V1]               42               8706
# 40       (COMBAT2022_L040,)  [5_GEX_V1]               44               8176
# 41       (COMBAT2022_L041,)  [5_GEX_V1]               49               9351
# 42       (COMBAT2022_L042,)  [5_GEX_V1]               30              11329
# 43       (COMBAT2022_L043,)  [5_GEX_V1]               25              10785
# 44       (COMBAT2022_L044,)  [5_GEX_V1]               35              10229
# 45       (COMBAT2022_L045,)  [5_GEX_V1]               34               9427
# 46       (COMBAT2022_L046,)  [5_GEX_V1]               36              10221
# 47       (COMBAT2022_L047,)  [5_GEX_V1]               30               9430
# 48       (COMBAT2022_L048,)  [5_GEX_V1]               22               8750
# 49       (COMBAT2022_L049,)  [5_GEX_V1]               26               8803
# 50       (COMBAT2022_L050,)  [5_GEX_V1]               23               7252
# 51       (COMBAT2022_L051,)  [5_GEX_V1]               31               8837
# 52       (COMBAT2022_L052,)  [5_GEX_V1]               37               9678
# 53       (COMBAT2022_L053,)  [5_GEX_V1]               22               7279
# 54       (COMBAT2022_L054,)  [5_GEX_V1]               31               7904
# 55       (COMBAT2022_L055,)  [5_GEX_V1]               16              11422
# 56       (COMBAT2022_L056,)  [5_GEX_V1]               23               9934
# 57       (COMBAT2022_L057,)  [5_GEX_V1]               26               8674
# 58       (COMBAT2022_L058,)  [5_GEX_V1]               34               7873
# 59       (COMBAT2022_L059,)  [5_GEX_V1]               39               8440
# 60       (COMBAT2022_L060,)  [5_GEX_V1]               44               9039
# 61       (COMBAT2022_L061,)  [5_GEX_V1]               31               8001
# 62       (COMBAT2022_L062,)  [5_GEX_V1]               34              10069
# 63       (COMBAT2022_L063,)  [5_GEX_V1]               18              12270
# 64       (COMBAT2022_L064,)  [5_GEX_V1]               20              10674
# 65       (COMBAT2022_L065,)  [5_GEX_V1]               24              10718
# 66       (COMBAT2022_L066,)  [5_GEX_V1]               26              11525
# 67       (COMBAT2022_L067,)  [5_GEX_V1]               25              12105
# 68       (COMBAT2022_L068,)  [5_GEX_V1]               14               8052
# 69       (COMBAT2022_L069,)  [5_GEX_V1]               17               9916
# 70        (Cillo2020_L001,)  [3_GEX_V2]                6               6047
# 71        (Cillo2020_L002,)  [3_GEX_V2]                3              15113
# 72        (Cillo2020_L003,)  [3_GEX_V2]                1              11643
# 73        (Cillo2020_L005,)  [3_GEX_V2]                2               8645
# 74        (Cillo2020_L010,)  [3_GEX_V2]                4              12387
# 75        (Cillo2020_L012,)  [3_GEX_V2]                3               7694
# 76        (Cillo2020_L018,)  [3_GEX_V2]                3              16501
# 77        (Cillo2020_L019,)  [3_GEX_V2]                5              10311
# 78        (Cillo2020_L020,)  [3_GEX_V2]                1              15397
# 79        (Cillo2020_L021,)  [3_GEX_V2]               10              10245
# 80        (Cillo2020_L023,)  [3_GEX_V2]                1               8889
# 81        (Cillo2020_L024,)  [3_GEX_V2]                2               7052
# 82        (Cillo2020_L025,)  [3_GEX_V2]                2              13277
# 83        (Cillo2020_L026,)  [3_GEX_V2]                4               7049
# 84        (Cillo2020_L027,)  [3_GEX_V2]                1               5606
# 85        (Cillo2020_L029,)  [3_GEX_V2]                2               5411
# 86        (Cillo2020_L031,)  [3_GEX_V2]                1              13022
# 87          (Liu2021_L000,)  [5_GEX_V1]                6              14447
# 88          (Liu2021_L001,)  [5_GEX_V1]                6              11819
# 89          (Liu2021_L002,)  [5_GEX_V1]                2              12703
# 90          (Liu2021_L003,)  [5_GEX_V1]                7               8796
# 91          (Liu2021_L004,)  [5_GEX_V1]                3               7432
# 92          (Liu2021_L005,)  [5_GEX_V1]                3              12259
# 93          (Liu2021_L006,)  [5_GEX_V1]                5               6151
# 94          (Liu2021_L007,)  [5_GEX_V1]                4               3742
# 95          (Liu2021_L008,)  [5_GEX_V1]                4               7687
# 96          (Liu2021_L009,)  [5_GEX_V1]                1               7712
# 97        (Perez2022_L000,)  [3_GEX_V2]                4              11207
# 98        (Perez2022_L001,)  [3_GEX_V2]                6               8059
# 99        (Perez2022_L002,)  [3_GEX_V2]                6               6176
# 100       (Perez2022_L003,)  [3_GEX_V2]                2               7776
# 101       (Perez2022_L004,)  [3_GEX_V2]                4               7443
# 102       (Perez2022_L005,)  [3_GEX_V2]                7               7216
# 103       (Perez2022_L006,)  [3_GEX_V2]                2               4893
# 104       (Perez2022_L007,)  [3_GEX_V2]                5               4780
# 105       (Perez2022_L008,)  [3_GEX_V2]               15               5737
# 106       (Perez2022_L009,)  [3_GEX_V2]               11               6704
# 107       (Perez2022_L010,)  [3_GEX_V2]               16               6805
# 108       (Perez2022_L011,)  [3_GEX_V2]               12               6345
# 109       (Perez2022_L012,)  [3_GEX_V2]                5               7406
# 110       (Perez2022_L013,)  [3_GEX_V2]                6               9244
# 111       (Perez2022_L014,)  [3_GEX_V2]                5               6734
# 112       (Perez2022_L015,)  [3_GEX_V2]                6               6475
# 113       (Perez2022_L017,)  [3_GEX_V2]                5               4947
# 114       (Perez2022_L018,)  [3_GEX_V2]                6               3467
# 115       (Perez2022_L019,)  [3_GEX_V2]               12               4631
# 116       (Perez2022_L020,)  [3_GEX_V2]                3               8867
# 117       (Perez2022_L021,)  [3_GEX_V2]                4              11264
# 118       (Perez2022_L022,)  [3_GEX_V2]                6              10974
# 119       (Perez2022_L023,)  [3_GEX_V2]                2               7634
# 120       (Perez2022_L024,)  [3_GEX_V2]                3               6752
# 121       (Perez2022_L025,)  [3_GEX_V2]               17               7222
# 122       (Perez2022_L026,)  [3_GEX_V2]                8               7439
# 123       (Perez2022_L027,)  [3_GEX_V2]                6               5488
# 124       (Perez2022_L028,)  [3_GEX_V2]                7               8734
# 125       (Perez2022_L029,)  [3_GEX_V2]                7               9006
# 126       (Perez2022_L030,)  [3_GEX_V2]                4               8915
# 127       (Perez2022_L031,)  [3_GEX_V2]                5              10357
# 128       (Perez2022_L032,)  [3_GEX_V2]                9               8758
# 129       (Perez2022_L033,)  [3_GEX_V2]               13               8372
# 130       (Perez2022_L034,)  [3_GEX_V2]               10               8669
# 131       (Perez2022_L035,)  [3_GEX_V2]                5               4890
# 132       (Perez2022_L036,)  [3_GEX_V2]                4              10023
# 133       (Perez2022_L037,)  [3_GEX_V2]                7               9061
# 134       (Perez2022_L038,)  [3_GEX_V2]                7              10284
# 135       (Perez2022_L039,)  [3_GEX_V2]                5              13758
# 136       (Perez2022_L040,)  [3_GEX_V2]                1               9973
# 137       (Perez2022_L042,)  [3_GEX_V2]                4               1762
# 138       (Perez2022_L043,)  [3_GEX_V2]                4               4034
# 139       (Perez2022_L044,)  [3_GEX_V2]                3               4203
# 140       (Perez2022_L045,)  [3_GEX_V2]               13               4066
# 141       (Perez2022_L046,)  [3_GEX_V2]                2               8341
# 142       (Perez2022_L047,)  [3_GEX_V2]                4               9052
# 143       (Perez2022_L048,)  [3_GEX_V2]                3               4472
# 144       (Perez2022_L049,)  [3_GEX_V2]                2               7176
# 145       (Perez2022_L050,)  [3_GEX_V2]               13               4851
# 146       (Perez2022_L051,)  [3_GEX_V2]                5               6504
# 147       (Perez2022_L052,)  [3_GEX_V2]               12               5419
# 148       (Perez2022_L053,)  [3_GEX_V2]                8               5077
# 149       (Perez2022_L054,)  [3_GEX_V2]                2              13235
# 150       (Perez2022_L055,)  [3_GEX_V2]                3               8358
# 151       (Perez2022_L056,)  [3_GEX_V2]                5               5765
# 152       (Perez2022_L057,)  [3_GEX_V2]                3               4055
# 153       (Perez2022_L058,)  [3_GEX_V2]                4               6662
# 154       (Perez2022_L059,)  [3_GEX_V2]                4               5932
# 155       (Perez2022_L060,)  [3_GEX_V2]                6               4262
# 156       (Perez2022_L061,)  [3_GEX_V2]                5               6601
# 157       (Perez2022_L062,)  [3_GEX_V2]                7               4953
# 158       (Perez2022_L063,)  [3_GEX_V2]                7               6288
# 159       (Perez2022_L064,)  [3_GEX_V2]               12               5721
# 160       (Perez2022_L065,)  [3_GEX_V2]                5               6579
# 161       (Perez2022_L066,)  [3_GEX_V2]                7               6011
# 162       (Perez2022_L067,)  [3_GEX_V2]               21               5812
# 163       (Perez2022_L071,)  [3_GEX_V2]                5               5225
# 164       (Perez2022_L072,)  [3_GEX_V2]                2               6472
# 165       (Perez2022_L073,)  [3_GEX_V2]                3               7976
# 166       (Perez2022_L074,)  [3_GEX_V2]                8               7500
# 167       (Perez2022_L075,)  [3_GEX_V2]                3               5658
# 168       (Perez2022_L076,)  [3_GEX_V2]                9               5851
# 169       (Perez2022_L077,)  [3_GEX_V2]               10               6817
# 170       (Perez2022_L078,)  [3_GEX_V2]               10               4933
# 171       (Perez2022_L079,)  [3_GEX_V2]               11               5367
# 172       (Perez2022_L080,)  [3_GEX_V2]                7               8320
# 173       (Perez2022_L081,)  [3_GEX_V2]                2               8836
# 174       (Perez2022_L082,)  [3_GEX_V2]                5               6678
# 175       (Perez2022_L083,)  [3_GEX_V2]               10               8549
# 176         (Ren2021_L000,)  [5_GEX_V2]                1               6643
# 177         (Ren2021_L004,)  [5_GEX_V2]                9               1474
# 178         (Ren2021_L007,)  [3_GEX_V3]                2              13648
# 179         (Ren2021_L009,)  [3_GEX_V3]                2              13140
# 180         (Ren2021_L012,)  [5_GEX_V2]                5               3832
# 181         (Ren2021_L013,)  [5_GEX_V2]                1               4323
# 182         (Ren2021_L016,)  [5_GEX_V2]                6               5790
# 183         (Ren2021_L021,)  [5_GEX_V2]                1               9771
# 184         (Ren2021_L022,)  [5_GEX_V2]                3               5216
# 185         (Ren2021_L024,)  [5_GEX_V2]               14              15039
# 186         (Ren2021_L025,)  [5_GEX_V2]                1               5519
# 187         (Ren2021_L026,)  [5_GEX_V2]                1               1432
# 188         (Ren2021_L027,)  [5_GEX_V2]                1               2462
# 189         (Ren2021_L028,)  [3_GEX_V3]                3               8688
# 190         (Ren2021_L030,)  [3_GEX_V3]                1              18911
# 191         (Ren2021_L035,)  [3_GEX_V3]                7               8572
# 192         (Ren2021_L037,)  [3_GEX_V3]                2              15680
# 193         (Ren2021_L041,)  [5_GEX_V2]                4               5844
# 194         (Ren2021_L042,)  [5_GEX_V2]                2               7788
# 195         (Ren2021_L052,)  [5_GEX_V2]                1               2858
# 196         (Ren2021_L054,)  [5_GEX_V2]                2              10309
# 197         (Ren2021_L057,)  [5_GEX_V2]                1               4899
# 198         (Ren2021_L058,)  [5_GEX_V2]                1              10651
# 199         (Ren2021_L061,)  [5_GEX_V2]                9               3206
# 200         (Ren2021_L064,)  [5_GEX_V2]                1               7791
# 201         (Ren2021_L066,)  [5_GEX_V2]               16               4338
# 202         (Ren2021_L067,)  [5_GEX_V2]                2               1527
# 203         (Ren2021_L074,)  [5_GEX_V2]                1               2331
# 204         (Ren2021_L075,)  [5_GEX_V2]                2               2893
# 205       (Reyes2020_L003,)  [3_GEX_V2]                1               4184
# 206       (Reyes2020_L005,)  [3_GEX_V2]                2               1369
# 207       (Reyes2020_L009,)  [3_GEX_V2]                3                956
# 208          (SCGT00_L000,)  [3_GEX_V3]               34               9469
# 209          (SCGT00_L002,)  [3_GEX_V3]               42              10224
# 210          (SCGT00_L003,)  [3_GEX_V3]               40               6412
# 211          (SCGT00_L004,)  [3_GEX_V3]                9              14338
# 212          (SCGT00_L005,)  [3_GEX_V3]               48               8788
# 213          (SCGT00_L007,)  [3_GEX_V3]               32              10326
# 214          (SCGT00_L008,)  [3_GEX_V3]               23              10071
# 215          (SCGT00_L009,)  [3_GEX_V3]               48               8946
# 216          (SCGT00_L010,)  [3_GEX_V3]               36               9208
# 217          (SCGT00_L011,)  [3_GEX_V3]               47              11620
# 218          (SCGT00_L012,)  [3_GEX_V3]               53              10844
# 219          (SCGT00_L013,)  [3_GEX_V3]              123               9094
# 220          (SCGT00_L015,)  [3_GEX_V3]               49              10943
# 221          (SCGT00_L016,)  [3_GEX_V3]               27               9408
# 222          (SCGT00_L017,)  [3_GEX_V3]               36              11636
# 223          (SCGT00_L019,)  [3_GEX_V3]               17               7894
# 224          (SCGT00_L020,)  [3_GEX_V3]               35              13738
# 225          (SCGT00_L021,)  [3_GEX_V3]               35              13050
# 226          (SCGT00_L022,)  [3_GEX_V3]               39              12073
# 227          (SCGT00_L023,)  [3_GEX_V3]               52              11932
# 228          (SCGT00_L024,)  [3_GEX_V3]               41               9942
# 229          (SCGT00_L025,)  [3_GEX_V3]               79               4095
# 230          (SCGT00_L026,)  [3_GEX_V3]               46               6047
# 231          (SCGT00_L027,)  [3_GEX_V3]               64               4269
# 232          (SCGT00_L028,)  [3_GEX_V3]               39              10105
# 233          (SCGT00_L029,)  [3_GEX_V3]               42              12032
# 234          (SCGT00_L030,)  [3_GEX_V3]               38               3733
# 235          (SCGT00_L031,)  [3_GEX_V3]               69              12438
# 236          (SCGT00_L032,)  [3_GEX_V3]               33              14253
# 237          (SCGT00_L033,)  [3_GEX_V3]               43               9798
# 238          (SCGT00_L034,)  [3_GEX_V3]               46              10180
# 239          (SCGT00_L035,)  [3_GEX_V3]               15              12162
# 240          (SCGT00_L036,)  [3_GEX_V3]               53               8445
# 241          (SCGT00_L037,)  [3_GEX_V3]              146               7959
# 242          (SCGT00_L038,)  [3_GEX_V3]               44               9070
# 243          (SCGT00_L039,)  [3_GEX_V3]               81               4506
# 244          (SCGT00_L040,)  [3_GEX_V3]               36               9819
# 245          (SCGT00_L041,)  [3_GEX_V3]                9              12698
# 246          (SCGT00_L042,)  [3_GEX_V3]               36              13331
# 247          (SCGT00_L043,)  [3_GEX_V3]               98               5758
# 248          (SCGT00_L044,)  [3_GEX_V3]               26              12658
# 249          (SCGT00_L045,)  [3_GEX_V3]               68              10038
# 250          (SCGT00_L046,)  [3_GEX_V3]              100               5261
# 251          (SCGT00_L047,)  [3_GEX_V3]               18              11708
# 252          (SCGT00_L049,)  [3_GEX_V3]                9              14070
# 253          (SCGT00_L050,)  [3_GEX_V3]               24               4103
# 254          (SCGT00_L051,)  [3_GEX_V3]               16               9610
# 255          (SCGT00_L052,)  [3_GEX_V3]               37               9639
# 256          (SCGT01_L000,)  [3_GEX_V3]               43              11449
# 257          (SCGT01_L001,)  [3_GEX_V3]               24              13202
# 258          (SCGT02_L000,)  [3_GEX_V3]              109              15466
# 259          (SCGT02_L001,)  [3_GEX_V3]               74               8854
# 260          (SCGT02_L002,)  [3_GEX_V3]               80              11513
# 261          (SCGT02_L003,)  [3_GEX_V3]              276               9063
# 262          (SCGT03_L000,)  [5_GEX_V2]                8              10241
# 263          (SCGT03_L001,)  [5_GEX_V2]               10              13795
# 264          (SCGT03_L002,)  [5_GEX_V2]               20               4031
# 265          (SCGT03_L003,)  [5_GEX_V2]                2               5248
# 266          (SCGT03_L005,)  [5_GEX_V2]               12               5404
# 267          (SCGT04_L000,)  [3_GEX_V3]               78              12944
# 268          (SCGT04_L001,)  [3_GEX_V3]              189              12223
# 269          (SCGT04_L002,)  [3_GEX_V3]              170              13185
# 270          (SCGT05_L000,)  [5_GEX_V2]               20               3366
# 271          (SCGT05_L001,)  [5_GEX_V2]                4               6340
# 272          (SCGT05_L002,)  [5_GEX_V2]              107               5150
# 273          (SCGT05_L003,)  [5_GEX_V2]               25               5611
# 274          (SCGT05_L004,)  [5_GEX_V2]               10               4259
# 275          (SCGT05_L005,)  [5_GEX_V2]              125               4601
# 276          (SCGT05_L006,)  [5_GEX_V2]             2224              14351
# 277          (SCGT05_L007,)  [5_GEX_V2]               65               6159
# 278          (SCGT05_L008,)  [5_GEX_V2]               30               3701
# 279          (SCGT05_L009,)  [5_GEX_V2]               34               5451
# 280          (SCGT05_L010,)  [5_GEX_V2]               39               4773
# 281          (SCGT05_L011,)  [5_GEX_V2]               25               5821
# 282          (SCGT05_L012,)  [5_GEX_V2]                7               6408
# 283          (SCGT05_L013,)  [5_GEX_V2]               45               1222
# 284  (Schafflick2020_L000,)  [3_GEX_V2]               21               7103
# 285  (Schafflick2020_L001,)  [3_GEX_V2]                6               8445
# 286  (Schafflick2020_L002,)  [3_GEX_V2]                5               6422
# 287  (Schafflick2020_L003,)  [3_GEX_V2]               98               8657
# 288  (Schafflick2020_L004,)  [3_GEX_V2]               17               9853
# 289  (Schafflick2020_L005,)  [3_GEX_V2]               42               8128
# 290  (Schafflick2020_L006,)  [3_GEX_V2]               51               5432
# 291  (Schafflick2020_L007,)  [3_GEX_V2]               18               6939
# 292  (Schafflick2020_L008,)  [3_GEX_V2]              101               8131
# 293  (Schafflick2020_L009,)  [3_GEX_V2]                7               8282
# 294   (Terekhova2023_L000,)  [5_GEX_V2]                7               6955
# 386   (Terekhova2023_L096,)  [5_GEX_V2]               40               7949
# 387   (Terekhova2023_L097,)  [5_GEX_V2]               35              11756
# 388   (Terekhova2023_L098,)  [5_GEX_V2]                6               9666
# 389   (Terekhova2023_L099,)  [5_GEX_V2]               10               6701
# 390   (Terekhova2023_L100,)  [5_GEX_V2]               20               5772
# 391   (Terekhova2023_L101,)  [5_GEX_V2]               25               8742
# 392   (Terekhova2023_L102,)  [5_GEX_V2]               15              10794
# 393   (Terekhova2023_L103,)  [5_GEX_V2]               23               9155
# 394   (Terekhova2023_L104,)  [5_GEX_V2]               37               9412
# 395   (Terekhova2023_L105,)  [5_GEX_V2]               24               8588
# 396        (Wang2020_L000,)  [3_GEX_V2]                8               7519
# 397        (Wang2020_L001,)  [3_GEX_V2]                4               4020
# 398        (Wang2020_L002,)  [3_GEX_V2]                2               3948
# 399        (Wang2020_L004,)  [3_GEX_V2]                5               1729
# 400        (Wang2020_L005,)  [3_GEX_V2]                5               4692
# 401        (Wang2020_L006,)  [3_GEX_V2]               10               3598
# 402       (Zhang2023_L001,)  [5_GEX_V1]                2               4735
# 403       (Zhang2023_L002,)  [5_GEX_V1]               17               1294
# 404       (Zhang2023_L003,)  [5_GEX_V1]               70               1128
# 405       (Zhang2023_L005,)  [5_GEX_V1]                2              12431
# 406       (Zhang2023_L006,)  [5_GEX_V1]                5              14133
# 407       (Zhang2023_L010,)  [5_GEX_V1]               12               2069
# 408       (Zhang2023_L011,)  [5_GEX_V1]               23               8053
# 409       (Zhang2023_L013,)  [5_GEX_V1]              122               2795
# 410       (Zhang2023_L014,)  [5_GEX_V1]                5               5456
# 411       (Zhang2023_L015,)  [5_GEX_V1]               18              13152
# 412       (Zhang2023_L016,)  [5_GEX_V1]                9               7639
# 413       (Zhang2023_L017,)  [5_GEX_V1]               62               1116
# 414       (Zhang2023_L018,)  [5_GEX_V1]                7               2760
# 415       (Zhang2023_L019,)  [5_GEX_V1]                9               7728
# 416       (Zhang2023_L020,)  [5_GEX_V1]                7               1827
# 417       (Zhang2023_L021,)  [5_GEX_V1]                1               3186
# 418       (Zhang2023_L022,)  [5_GEX_V1]                2                657
#
#      Median Genes  Median MT %  Median RB %  Median HB %
# 0            2427         1.49        41.54         0.01
# 1            2062         1.00        41.03         0.00
# 2            1933         1.33        41.77         0.00
# 3            2244         1.34        40.77         0.00
# 4            2195         1.55        45.03         0.01
# 5            1774         1.49        42.92         0.00
# 6            2157         0.97        45.80         0.00
# 7            2398         2.32        42.57         0.01
# 8            2210         1.55        44.74         0.00
# 9            2347         2.43        40.71         0.01
# 10           2233         1.94        43.39         0.00
# 11           2476         2.30        41.62         0.01
# 12           2371         1.92        41.76         0.01
# 13           2265         2.22        40.83         0.00
# 14           1408         1.74        16.13        49.69
# 15           2020         1.60        18.33        38.80
# 16           1697         1.77        22.38         0.31
# 17           2109         2.13        20.85        11.92
# 18           1898         1.84        20.39        28.58
# 19           1726         2.12        17.15        32.88
# 20           1705         1.78        19.95        27.71
# 21           2000         2.85        39.11         0.01
# 22           2204         2.66        36.49         0.01
# 352          1823         1.08        43.04         0.00
# 353          1937         1.62        40.92         0.00
# 354          1403         1.19        45.37         0.00
# 355          1569         1.15        42.31         0.00
# 356          1366         1.15        50.31         0.00
# 357          1774         1.05        43.73         0.00
# 358          2550         1.97        38.45         0.00
# 359          2642         2.24        40.46         0.01
# 360          1161         0.00        60.87         0.00
# 361          2849         2.20        38.63         0.00
# 362          1715         1.13        41.92         0.00
# 363          1542         2.94        40.84         0.00
# 364          2201         2.57        41.30         0.00
# 365          2313         2.36        43.48         0.00
# 366          2035         2.39        40.56         0.00
# 367          2143         2.46        41.02         0.00
# 368          2411         1.79        41.90         0.01
# 369          2093         2.81        41.96         0.00
# 370          2419         2.18        38.65         0.00
# 371          2443         2.87        41.07         0.00
# 372          1554         2.36        37.99         0.00
# 373          2353         3.32        36.79         0.00
# 374          2217         1.02        33.16         0.00
# 375          3252         3.85        33.60         0.01
# 376          3018         3.54        35.76         0.02
# 377          3500         3.72        34.14         0.01
# 378          2672         4.13        33.47         0.00
# 379          3040         3.91        32.78         0.01
# 380          2005         1.54        38.00         0.00
# 381          2524         1.67        40.36         0.00
# 382          2574         2.25        38.88         0.00
# 383          2387         1.44        40.15         0.01
# 384          2686         2.28        34.43         0.00
# 385          3167         2.14        42.45         0.01
# 386          2343         1.68        40.63         0.01
# 387          3185         2.53        37.81         0.01
# 388          3043         2.42        35.54         0.01
# 389          2467         2.96        31.85         0.00
# 390          1891         2.22        43.25         0.00
# 391          2406         2.10        41.67         0.00
# 392          2664         1.40        41.27         0.00
# 393          2616         1.90        39.28         0.01
# 394          2623         2.06        43.72         0.00
# 395          2469         2.14        43.35         0.00
# 396          2241         3.42        39.58         0.00
# 397          1609        12.33        18.43         0.00
# 398           691         1.31         8.81        64.70
# 399           708         6.44        18.32         0.00
# 400           410         0.05         3.74        68.26
# 401           526         4.00        10.78        37.15
# 402          1515         5.39        15.48        23.66
# 403           746         2.97        13.23         0.00
# 404           573         7.78        20.76         0.00
# 405          2961         3.88        45.30         0.00
# 406          3122         4.18        22.59         2.77
# 407           976         3.89        24.88         0.03
# 408          1980         4.13        38.17         0.01
# 409          1337         6.65        11.53         0.00
# 410          2014         4.46        31.08         0.00
# 411          3066         4.43        41.91         0.00
# 412          2365         4.29        36.09         0.02
# 413           660         5.86        14.70         0.00
# 414          1700         3.59        12.92         0.00
# 415          2376         4.37        36.30         0.02
# 416           884         2.27        18.76         0.00
# 417          1022         4.80        45.51         0.00
# 418           392         2.88        14.80         0.00

# %%
adata_tmp = adata[adata.obs.chemistry == "3_GEX_V3", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="3_GEX_V3",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_3GEXV3.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "3_GEX_V2", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="3_GEX_V2",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_3GEXV2.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "5_GEX_V2", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="5_GEX_V2",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_5GEXV2.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "5_GEX_V1", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="5_GEX_V1",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_5GEXV1.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} TCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN FROM STEP 2 (when RBC and Platelets will be filtered out)
# HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
# print(f"{np.sum(MHC_gene_idx)} HB genes")

# PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
# print(f"{np.sum(MHC_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx) # HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 110 ribosomal genes
# 118 TCR genes
# 54 TCR genes
# 21 MHC genes
# View of AnnData object with n_obs × n_vars = 12028 × 22522
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    HVGdf = get_HVG(adata_forHVG, groupby='studyID', batch_key='libraryID', 
                    flavor='seurat', min_disp=0.3, max_disp = 'inf', min_mean=0.01, max_mean=4)
except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    HVGdf = get_HVG(adata_forHVG, groupby='studyID', batch_key=None, 
                    flavor='seurat', min_disp=0.3, max_disp = 'inf', min_mean=0.01, max_mean=4)
# Out:
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# Reyes2020
# An error occurred: division by zero
# Executing without library correction...
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# Reyes2020
# Cillo2020
# Zhang2023
# Schafflick2020
# Liu2021
# Terekhova2023
# Perez2022
# Wang2020
# COMBAT2022
# Ren2021

# %%
# Considering only genes selected as HV in at least 1 study
columns_to_keep = [f'highly_variable_{study_id}' for study_id in adata.obs['studyID'].unique() if f'highly_variable_{study_id}' in HVGdf.columns]

HVG_sel_DF = HVGdf.loc[:, columns_to_keep]
HVG_sel_DF = HVG_sel_DF[HVG_sel_DF.sum(axis=1) > 0]
HVG_sel_DF.columns = HVG_sel_DF.columns.str.removeprefix("highly_variable_")
HVG_sel_DF.head()
# Out:
#                  SCGT00  SCGT01  SCGT02  SCGT03  SCGT04  SCGT05  Reyes2020  \
# ENSG00000000003   False   False   False   False   False   False      False
# ENSG00000000419    True   False   False   False    True   False      False
# ENSG00000000457   False    True    True   False   False    True      False
# ENSG00000000460    True   False    True   False   False   False      False
# ENSG00000000938    True    True    True    True    True    True      False
#
#                  Cillo2020  Zhang2023  Schafflick2020  Liu2021  Terekhova2023  \
# ENSG00000000003      False       True           False    False          False
# ENSG00000000419       True       True           False    False          False
# ENSG00000000457      False       True           False    False          False
# ENSG00000000460      False      False           False    False          False
# ENSG00000000938      False      False            True    False           True
#
#                  Perez2022  Wang2020  COMBAT2022  Ren2021
# ENSG00000000003      False     False       False    False
# ENSG00000000419      False     False       False     True
# ENSG00000000457       True      True       False    False
# ENSG00000000460      False      True       False    False
# ENSG00000000938       True     False        True    False

# %%
HVG_number = 2000

# %%
HVGperStudyCount = pd.DataFrame(index = HVG_sel_DF.index)
HVGperStudyCount['n_studies'] = HVG_sel_DF.sum(axis = 1)
HVGperStudyCount
# Out:
#                  n_studies
# ENSG00000000003          1
# ENSG00000000419          5
# ENSG00000000457          6
# ENSG00000000460          3
# ENSG00000000938         10
# ...                    ...
# ENSG00000288093          4
# ENSG00000288096          2
# ENSG00000288156          6
# ENSG00000288253          2
# ENSG00000288302          4
#
# [16332 rows x 1 columns]

# %%
CumStud_n = pd.DataFrame(HVGperStudyCount['n_studies'].value_counts())
CumStud_n.sort_index(ascending=False, inplace=True)
CumStud_n['cs_studies'] = CumStud_n['count'].cumsum()
CumStud_n
# Out:
#            count  cs_studies
# n_studies
# 16             7           7
# 15            31          38
# 14            60          98
# 13            93         191
# 12           133         324
# 11           250         574
# 10           401         975
# 9            589        1564
# 8            775        2339
# 7           1125        3464
# 6           1426        4890
# 5           1704        6594
# 4           2018        8612
# 3           2186       10798
# 2           2422       13220
# 1           3112       16332

# %%
nStudyThr = CumStud_n.loc[CumStud_n['cs_studies'] > HVG_number,:].index[0]
nStudyThr
# Out:
# 8

# %%
fig, ax = plt.subplots(1, figsize=(10, 5))
CumStud_n.cs_studies.plot(ax=ax)

plt.axhline(y = HVG_number, color = 'r', linestyle = '--')
plt.axvline(x = nStudyThr, color = 'g', linestyle = '--')
plt.xlabel('# of different study')
plt.ylabel('# of genes (cumulative)')
plt.gca().invert_xaxis()

if overwriteFigures:
    plt.savefig(here('{}/results/figures/01_HVG_selection_threshold.pdf'.format(workDir)), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
plt.show()

# %%
print('The total number of selected HVG is {}'.format(CumStud_n.loc[nStudyThr,'cs_studies']))
# Out:
# The total number of selected HVG is 2339

# %%
HVG_selected = HVGperStudyCount[HVGperStudyCount['n_studies'] >= nStudyThr].index.tolist()
print(HVG_selected[1:10])
# Out:
# ['ENSG00000001084', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002586', 'ENSG00000002933', 'ENSG00000003436', 'ENSG00000004399', 'ENSG00000004897']

# %%
adata.var['highly_variable'] = False
adata.var.loc[HVG_selected,'highly_variable'] = True

adata_HVG = adata[:, adata.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 12028 × 2339
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-04-28 17:33
# </pre>
# </details>
