# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'HSC'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/02_cell_annotation/02_fromCellLineages_to_CellTypes/Step1/Step1_clusterAnnotDF.pkl'
annotationColumns = 'annotation_step_1'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/results/03_INFLAMMATION_main_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 4918140 × 22838
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 7292 × 22838
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                         studyID     libraryID  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC   SCGT00   SCGT00_L051
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC   SCGT00   SCGT00_L051
# ...                                         ...           ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  Ren2021  Ren2021_L066
#
#                                                 sampleID chemistry  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  SCGT00_I52.3P_T0  3_GEX_V3
# ...                                                  ...       ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  Ren2021_PS053_T0  5_GEX_V2
#
#                                                  technology      patientID  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  3_GEX_V3_GenoHashed     SCGT00_I52
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  3_GEX_V3_GenoHashed     SCGT00_I58
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  3_GEX_V3_GenoHashed     SCGT00_I58
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  3_GEX_V3_GenoHashed     SCGT00_I58
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  3_GEX_V3_GenoHashed     SCGT00_I52
# ...                                                     ...            ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC             5_GEX_V2  Ren2021_PS053
#
#                                        disease  timepoint_replicate  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC      RA                  0.0
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA      RA                  0.0
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA      RA                  0.0
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC      RA                  0.0
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC      RA                  0.0
# ...                                        ...                  ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT   COVID                  0.0
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG   COVID                  0.0
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA   COVID                  0.0
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG   COVID                  0.0
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC   COVID                  0.0
#
#                                        treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC         ongoing              NR
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA         ongoing              NR
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA         ongoing              NR
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC         ongoing              NR
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC         ongoing              NR
# ...                                                ...             ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT           under              na
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG           under              na
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA           under              na
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG           under              na
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC           under              na
#
#                                            sex   age    BMI binned_age  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  female  33.0  21.37      31-40
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  female  61.0  36.10      61-70
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  female  61.0  36.10      61-70
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  female  61.0  36.10      61-70
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  female  33.0  21.37      31-40
# ...                                        ...   ...    ...        ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  female  46.0    NaN      41-50
#
#                                                       diseaseStatus  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                           na
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                           na
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                           na
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                           na
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                           na
# ...                                                             ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT  severe/critical_progression
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  severe/critical_progression
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  severe/critical_progression
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  severe/critical_progression
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  severe/critical_progression
#
#                                        smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  never-smoker        na        na
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  never-smoker        na        na
# ...                                              ...       ...       ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT            na        na   Beijing
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG            na        na   Beijing
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA            na        na   Beijing
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG            na        na   Beijing
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC            na        na   Beijing
#
#                                        diseaseGroup  n_genes_by_counts  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        IMIDs               2639
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        IMIDs               2263
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        IMIDs               3567
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC        IMIDs                693
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC        IMIDs               3893
# ...                                             ...                ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT    infection               1734
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG    infection               1317
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA    infection                786
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG    infection               1919
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC    infection               1540
#
#                                         log1p_n_genes_by_counts  total_counts  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                 7.878534         12898
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 7.724888         10543
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                 8.179760         19479
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                 6.542472          2276
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                 8.267192         21518
# ...                                                         ...           ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                 7.458763          4561
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                 7.183871          3373
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                 6.668228          1797
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                 7.560080          5575
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 7.340187          3408
#
#                                         log1p_total_counts  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC            9.464905
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA            9.263312
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA            9.877144
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC            7.730614
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC            9.976692
# ...                                                    ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT            8.425516
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG            8.123854
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA            7.494430
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG            8.626227
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC            8.134174
#
#                                         pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                   26.895643
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                   25.893958
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                   24.636788
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                   38.971880
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                   25.369458
# ...                                                            ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                   21.618066
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                   21.049511
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                   24.429605
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                   19.228700
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                   18.368545
#
#                                         total_counts_mt  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC              198
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA              290
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA              901
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC               26
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC              445
# ...                                                 ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT              339
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG              136
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA               59
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG              219
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC              201
#
#                                         log1p_total_counts_mt  pct_counts_mt  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               5.293305       1.535122
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               5.673323       2.750640
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               6.804615       4.625494
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC               3.295837       1.142355
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC               6.100319       2.068036
# ...                                                       ...            ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT               5.828946       7.432581
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG               4.919981       4.032019
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA               4.094345       3.283250
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG               5.393628       3.928251
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC               5.308268       5.897887
#
#                                         total_counts_ribo  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               6023
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               4970
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               7748
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                943
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC               9304
# ...                                                   ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT               1291
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG               1208
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                704
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG               1976
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                740
#
#                                         log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                 8.703507
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 8.511376
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                 8.955319
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                 6.850126
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                 9.138307
# ...                                                         ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                 7.163947
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                 7.097549
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                 6.558198
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                 7.589336
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 6.608001
#
#                                         pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        46.697162                1
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        47.140283                0
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        39.776169                3
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC        41.432337                0
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC        43.238219                8
# ...                                                 ...              ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT        28.305196                0
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG        35.813816                0
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA        39.176405                0
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG        35.443946                0
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC        21.713615                0
#
#                                         log1p_total_counts_hb  pct_counts_hb  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               0.693147       0.007753
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               0.000000       0.000000
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               1.386294       0.015401
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC               0.000000       0.000000
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC               2.197225       0.037178
# ...                                                       ...            ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT               0.000000       0.000000
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG               0.000000       0.000000
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA               0.000000       0.000000
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG               0.000000       0.000000
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC               0.000000       0.000000
#
#                                         total_counts_plt  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                17
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 2
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                14
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                 0
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                20
# ...                                                  ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                13
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                10
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                 3
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                 5
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 3
#
#                                         log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                2.890372
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                1.098612
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                2.708050
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                0.000000
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                3.044522
# ...                                                        ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                2.639057
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                2.397895
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                1.386294
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                1.791759
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                1.386294
#
#                                         pct_counts_plt  doublet_score  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        0.131803          0.030
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        0.018970          0.037
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        0.071872          0.076
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC        0.000000          0.019
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC        0.092945          0.043
# ...                                                ...            ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT        0.285025          0.003
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG        0.296472          0.004
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA        0.166945          0.003
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG        0.089686          0.002
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC        0.088028          0.004
#
#                                         predicted_doublet   S_score  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                  0 -0.036518
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                  0 -0.004612
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                  0 -0.041559
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                  0 -0.046220
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                  0  0.025784
# ...                                                   ...       ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                  0  0.017264
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG                  0 -0.003147
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA                  0  0.048857
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG                  0  0.016826
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                  0 -0.006460
#
#                                         G2M_score phase
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  -0.065312    G1
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  -0.034372    G1
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  -0.065553    G1
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  -0.080506    G1
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  -0.050191     S
# ...                                           ...   ...
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT   0.021570   G2M
# Ren2021_L066_PS053_T0_TAGTGGTGTCTTGATG  -0.060245    G1
# Ren2021_L066_PS053_T0_TATGCCCCATCTGGTA  -0.077298     S
# Ren2021_L066_PS053_T0_TCAGATGGTGTATGGG  -0.021284     S
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  -0.118916    G1
#
# [7292 rows x 41 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="chemistry",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#                   libraryID   chemistry  Number of cells  Median UMI counts  \
# 0        (COMBAT2022_L000,)  [5_GEX_V1]               28               8814
# 1        (COMBAT2022_L001,)  [5_GEX_V1]               26               7410
# 2        (COMBAT2022_L002,)  [5_GEX_V1]               28               7556
# 3        (COMBAT2022_L003,)  [5_GEX_V1]               35               8628
# 4        (COMBAT2022_L004,)  [5_GEX_V1]               28               8883
# 5        (COMBAT2022_L005,)  [5_GEX_V1]               27               6436
# 6        (COMBAT2022_L006,)  [5_GEX_V1]               25               6813
# 7        (COMBAT2022_L007,)  [5_GEX_V1]               36              11484
# 8        (COMBAT2022_L008,)  [5_GEX_V1]               36              10481
# 9        (COMBAT2022_L009,)  [5_GEX_V1]               31              12081
# 10       (COMBAT2022_L010,)  [5_GEX_V1]               37               8930
# 11       (COMBAT2022_L011,)  [5_GEX_V1]               41              11298
# 12       (COMBAT2022_L012,)  [5_GEX_V1]               44              10654
# 13       (COMBAT2022_L013,)  [5_GEX_V1]               26               9973
# 14       (COMBAT2022_L014,)  [5_GEX_V1]               12              12683
# 15       (COMBAT2022_L015,)  [5_GEX_V1]               13              11895
# 16       (COMBAT2022_L016,)  [5_GEX_V1]               18              10556
# 17       (COMBAT2022_L017,)  [5_GEX_V1]               18              10496
# 18       (COMBAT2022_L018,)  [5_GEX_V1]               16               8203
# 19       (COMBAT2022_L019,)  [5_GEX_V1]               14               8353
# 20       (COMBAT2022_L020,)  [5_GEX_V1]               20               8251
# 21       (COMBAT2022_L021,)  [5_GEX_V1]               16              10603
# 22       (COMBAT2022_L022,)  [5_GEX_V1]               28               9605
# 23       (COMBAT2022_L023,)  [5_GEX_V1]               23               8639
# 24       (COMBAT2022_L024,)  [5_GEX_V1]               14               6782
# 25       (COMBAT2022_L025,)  [5_GEX_V1]               18               9360
# 26       (COMBAT2022_L026,)  [5_GEX_V1]               26               9935
# 27       (COMBAT2022_L027,)  [5_GEX_V1]               27               7492
# 28       (COMBAT2022_L028,)  [5_GEX_V1]               17              10929
# 29       (COMBAT2022_L029,)  [5_GEX_V1]               33              11110
# 30       (COMBAT2022_L030,)  [5_GEX_V1]               35              11722
# 31       (COMBAT2022_L031,)  [5_GEX_V1]               22              10890
# 32       (COMBAT2022_L032,)  [5_GEX_V1]               31              11154
# 33       (COMBAT2022_L033,)  [5_GEX_V1]               29              10271
# 34       (COMBAT2022_L034,)  [5_GEX_V1]               26              11201
# 35       (COMBAT2022_L035,)  [5_GEX_V1]               19              11828
# 36       (COMBAT2022_L036,)  [5_GEX_V1]               19               9056
# 37       (COMBAT2022_L037,)  [5_GEX_V1]               10               7382
# 38       (COMBAT2022_L038,)  [5_GEX_V1]               17               9779
# 39       (COMBAT2022_L039,)  [5_GEX_V1]               20               9509
# 40       (COMBAT2022_L040,)  [5_GEX_V1]               17               8696
# 41       (COMBAT2022_L041,)  [5_GEX_V1]               24               8706
# 42       (COMBAT2022_L042,)  [5_GEX_V1]               23              11493
# 43       (COMBAT2022_L043,)  [5_GEX_V1]               21              11483
# 44       (COMBAT2022_L044,)  [5_GEX_V1]               25              11455
# 45       (COMBAT2022_L045,)  [5_GEX_V1]               24              10722
# 46       (COMBAT2022_L046,)  [5_GEX_V1]               28              11496
# 47       (COMBAT2022_L047,)  [5_GEX_V1]               18              10761
# 48       (COMBAT2022_L048,)  [5_GEX_V1]               17              11093
# 49       (COMBAT2022_L049,)  [5_GEX_V1]               23               8979
# 50       (COMBAT2022_L050,)  [5_GEX_V1]               13               7316
# 51       (COMBAT2022_L051,)  [5_GEX_V1]               25               8837
# 52       (COMBAT2022_L052,)  [5_GEX_V1]               32               9117
# 53       (COMBAT2022_L053,)  [5_GEX_V1]               19               7229
# 54       (COMBAT2022_L054,)  [5_GEX_V1]               21               8505
# 55       (COMBAT2022_L055,)  [5_GEX_V1]               13              11021
# 56       (COMBAT2022_L056,)  [5_GEX_V1]               20               9961
# 57       (COMBAT2022_L057,)  [5_GEX_V1]               24               8167
# 58       (COMBAT2022_L058,)  [5_GEX_V1]               29               8047
# 59       (COMBAT2022_L059,)  [5_GEX_V1]               37               9060
# 60       (COMBAT2022_L060,)  [5_GEX_V1]               41               9018
# 61       (COMBAT2022_L061,)  [5_GEX_V1]               30               8026
# 62       (COMBAT2022_L062,)  [5_GEX_V1]               28              11448
# 63       (COMBAT2022_L063,)  [5_GEX_V1]               15              12307
# 64       (COMBAT2022_L064,)  [5_GEX_V1]               14              12918
# 65       (COMBAT2022_L065,)  [5_GEX_V1]               17              11244
# 66       (COMBAT2022_L066,)  [5_GEX_V1]               21              11212
# 67       (COMBAT2022_L067,)  [5_GEX_V1]               18              12168
# 68       (COMBAT2022_L068,)  [5_GEX_V1]               12               8254
# 69       (COMBAT2022_L069,)  [5_GEX_V1]               14              11263
# 70        (Cillo2020_L001,)  [3_GEX_V2]                6               6047
# 71        (Cillo2020_L002,)  [3_GEX_V2]                2              15433
# 72        (Cillo2020_L003,)  [3_GEX_V2]                1              11643
# 73        (Cillo2020_L005,)  [3_GEX_V2]                2               8645
# 74        (Cillo2020_L010,)  [3_GEX_V2]                4              12387
# 75        (Cillo2020_L012,)  [3_GEX_V2]                1              10098
# 76        (Cillo2020_L018,)  [3_GEX_V2]                3              16501
# 77        (Cillo2020_L019,)  [3_GEX_V2]                4              10501
# 78        (Cillo2020_L020,)  [3_GEX_V2]                1              15397
# 79        (Cillo2020_L021,)  [3_GEX_V2]                2              14590
# 80        (Cillo2020_L023,)  [3_GEX_V2]                1               8889
# 81        (Cillo2020_L024,)  [3_GEX_V2]                2               7052
# 82        (Cillo2020_L025,)  [3_GEX_V2]                2              13277
# 83        (Cillo2020_L031,)  [3_GEX_V2]                1              13022
# 84          (Liu2021_L000,)  [5_GEX_V1]                6              14447
# 85          (Liu2021_L001,)  [5_GEX_V1]                6              11819
# 86          (Liu2021_L002,)  [5_GEX_V1]                2              12703
# 87          (Liu2021_L003,)  [5_GEX_V1]                7               8796
# 88          (Liu2021_L004,)  [5_GEX_V1]                3               7432
# 89          (Liu2021_L005,)  [5_GEX_V1]                3              12259
# 90          (Liu2021_L006,)  [5_GEX_V1]                5               6151
# 91          (Liu2021_L007,)  [5_GEX_V1]                3               4006
# 92          (Liu2021_L008,)  [5_GEX_V1]                4               7687
# 93          (Liu2021_L009,)  [5_GEX_V1]                1               7712
# 94        (Perez2022_L000,)  [3_GEX_V2]                4              11207
# 95        (Perez2022_L001,)  [3_GEX_V2]                6               8059
# 96        (Perez2022_L002,)  [3_GEX_V2]                6               6176
# 97        (Perez2022_L003,)  [3_GEX_V2]                2               7776
# 98        (Perez2022_L004,)  [3_GEX_V2]                4               7443
# 99        (Perez2022_L005,)  [3_GEX_V2]                7               7216
# 100       (Perez2022_L006,)  [3_GEX_V2]                2               4893
# 101       (Perez2022_L007,)  [3_GEX_V2]                5               4780
# 102       (Perez2022_L008,)  [3_GEX_V2]               15               5737
# 103       (Perez2022_L009,)  [3_GEX_V2]               11               6704
# 104       (Perez2022_L010,)  [3_GEX_V2]               16               6805
# 105       (Perez2022_L011,)  [3_GEX_V2]               12               6345
# 106       (Perez2022_L012,)  [3_GEX_V2]                5               7406
# 107       (Perez2022_L013,)  [3_GEX_V2]                6               9244
# 108       (Perez2022_L014,)  [3_GEX_V2]                5               6734
# 109       (Perez2022_L015,)  [3_GEX_V2]                6               6475
# 110       (Perez2022_L017,)  [3_GEX_V2]                5               4947
# 111       (Perez2022_L018,)  [3_GEX_V2]                6               3467
# 112       (Perez2022_L019,)  [3_GEX_V2]               12               4631
# 113       (Perez2022_L020,)  [3_GEX_V2]                3               8867
# 114       (Perez2022_L021,)  [3_GEX_V2]                4              11264
# 115       (Perez2022_L022,)  [3_GEX_V2]                6              10974
# 116       (Perez2022_L023,)  [3_GEX_V2]                2               7634
# 117       (Perez2022_L024,)  [3_GEX_V2]                3               6752
# 118       (Perez2022_L025,)  [3_GEX_V2]               17               7222
# 119       (Perez2022_L026,)  [3_GEX_V2]                8               7439
# 120       (Perez2022_L027,)  [3_GEX_V2]                6               5488
# 121       (Perez2022_L028,)  [3_GEX_V2]                7               8734
# 122       (Perez2022_L029,)  [3_GEX_V2]                7               9006
# 123       (Perez2022_L030,)  [3_GEX_V2]                4               8915
# 124       (Perez2022_L031,)  [3_GEX_V2]                5              10357
# 125       (Perez2022_L032,)  [3_GEX_V2]                9               8758
# 126       (Perez2022_L033,)  [3_GEX_V2]               12               8711
# 127       (Perez2022_L034,)  [3_GEX_V2]               10               8669
# 128       (Perez2022_L035,)  [3_GEX_V2]                5               4890
# 129       (Perez2022_L036,)  [3_GEX_V2]                4              10023
# 130       (Perez2022_L037,)  [3_GEX_V2]                7               9061
# 131       (Perez2022_L038,)  [3_GEX_V2]                7              10284
# 132       (Perez2022_L039,)  [3_GEX_V2]                5              13758
# 133       (Perez2022_L040,)  [3_GEX_V2]                1               9973
# 134       (Perez2022_L042,)  [3_GEX_V2]                4               1762
# 135       (Perez2022_L043,)  [3_GEX_V2]                4               4034
# 136       (Perez2022_L044,)  [3_GEX_V2]                3               4203
# 137       (Perez2022_L045,)  [3_GEX_V2]               11               4796
# 138       (Perez2022_L046,)  [3_GEX_V2]                2               8341
# 139       (Perez2022_L047,)  [3_GEX_V2]                4               9052
# 140       (Perez2022_L048,)  [3_GEX_V2]                3               4472
# 141       (Perez2022_L049,)  [3_GEX_V2]                2               7176
# 142       (Perez2022_L050,)  [3_GEX_V2]               13               4851
# 143       (Perez2022_L051,)  [3_GEX_V2]                5               6504
# 144       (Perez2022_L052,)  [3_GEX_V2]               12               5419
# 145       (Perez2022_L053,)  [3_GEX_V2]                8               5077
# 146       (Perez2022_L054,)  [3_GEX_V2]                2              13235
# 147       (Perez2022_L055,)  [3_GEX_V2]                3               8358
# 148       (Perez2022_L056,)  [3_GEX_V2]                5               5765
# 149       (Perez2022_L057,)  [3_GEX_V2]                3               4055
# 150       (Perez2022_L058,)  [3_GEX_V2]                4               6662
# 151       (Perez2022_L059,)  [3_GEX_V2]                4               5932
# 152       (Perez2022_L060,)  [3_GEX_V2]                6               4262
# 153       (Perez2022_L061,)  [3_GEX_V2]                5               6601
# 154       (Perez2022_L062,)  [3_GEX_V2]                7               4953
# 155       (Perez2022_L063,)  [3_GEX_V2]                7               6288
# 156       (Perez2022_L064,)  [3_GEX_V2]               12               5721
# 157       (Perez2022_L065,)  [3_GEX_V2]                5               6579
# 158       (Perez2022_L066,)  [3_GEX_V2]                7               6011
# 159       (Perez2022_L067,)  [3_GEX_V2]               21               5812
# 160       (Perez2022_L071,)  [3_GEX_V2]                5               5225
# 161       (Perez2022_L072,)  [3_GEX_V2]                2               6472
# 162       (Perez2022_L073,)  [3_GEX_V2]                3               7976
# 163       (Perez2022_L074,)  [3_GEX_V2]                8               7500
# 164       (Perez2022_L075,)  [3_GEX_V2]                3               5658
# 165       (Perez2022_L076,)  [3_GEX_V2]                9               5851
# 166       (Perez2022_L077,)  [3_GEX_V2]               10               6817
# 167       (Perez2022_L078,)  [3_GEX_V2]               10               4933
# 168       (Perez2022_L079,)  [3_GEX_V2]               10               5146
# 169       (Perez2022_L080,)  [3_GEX_V2]                7               8320
# 170       (Perez2022_L081,)  [3_GEX_V2]                2               8836
# 171       (Perez2022_L082,)  [3_GEX_V2]                5               6678
# 172       (Perez2022_L083,)  [3_GEX_V2]               10               8549
# 173         (Ren2021_L000,)  [5_GEX_V2]                1               6643
# 174         (Ren2021_L009,)  [3_GEX_V3]                1              16537
# 175         (Ren2021_L013,)  [5_GEX_V2]                1               4323
# 176         (Ren2021_L021,)  [5_GEX_V2]                1               9771
# 177         (Ren2021_L022,)  [5_GEX_V2]                3               5216
# 178         (Ren2021_L024,)  [5_GEX_V2]               14              15039
# 179         (Ren2021_L025,)  [5_GEX_V2]                1               5519
# 180         (Ren2021_L026,)  [5_GEX_V2]                1               1432
# 181         (Ren2021_L027,)  [5_GEX_V2]                1               2462
# 182         (Ren2021_L041,)  [5_GEX_V2]                3               6254
# 183         (Ren2021_L054,)  [5_GEX_V2]                2              10309
# 184         (Ren2021_L057,)  [5_GEX_V2]                1               4899
# 185         (Ren2021_L058,)  [5_GEX_V2]                1              10651
# 186         (Ren2021_L061,)  [5_GEX_V2]                5               3535
# 187         (Ren2021_L064,)  [5_GEX_V2]                1               7791
# 188         (Ren2021_L066,)  [5_GEX_V2]               13               4021
# 189         (Ren2021_L067,)  [5_GEX_V2]                2               1527
# 190       (Reyes2020_L003,)  [3_GEX_V2]                1               4184
# 191       (Reyes2020_L005,)  [3_GEX_V2]                2               1369
# 192       (Reyes2020_L009,)  [3_GEX_V2]                3                956
# 193          (SCGT00_L000,)  [3_GEX_V3]               32               9469
# 194          (SCGT00_L002,)  [3_GEX_V3]               37              10396
# 195          (SCGT00_L003,)  [3_GEX_V3]               34               6726
# 196          (SCGT00_L004,)  [3_GEX_V3]                8              16086
# 197          (SCGT00_L005,)  [3_GEX_V3]               42               8788
# 198          (SCGT00_L007,)  [3_GEX_V3]               26              11631
# 199          (SCGT00_L008,)  [3_GEX_V3]               10              13673
# 200          (SCGT00_L009,)  [3_GEX_V3]               47               8841
# 201          (SCGT00_L010,)  [3_GEX_V3]               36               9208
# 202          (SCGT00_L011,)  [3_GEX_V3]               38              12144
# 203          (SCGT00_L012,)  [3_GEX_V3]               51              10859
# 204          (SCGT00_L013,)  [3_GEX_V3]              105               9275
# 205          (SCGT00_L015,)  [3_GEX_V3]               47              10943
# 206          (SCGT00_L016,)  [3_GEX_V3]               27               9408
# 207          (SCGT00_L017,)  [3_GEX_V3]               30              12915
# 208          (SCGT00_L019,)  [3_GEX_V3]               17               7894
# 209          (SCGT00_L020,)  [3_GEX_V3]               33              13738
# 210          (SCGT00_L021,)  [3_GEX_V3]               34              12987
# 211          (SCGT00_L022,)  [3_GEX_V3]               36              12179
# 212          (SCGT00_L023,)  [3_GEX_V3]               48              11816
# 213          (SCGT00_L024,)  [3_GEX_V3]               38               9993
# 214          (SCGT00_L025,)  [3_GEX_V3]               70               4883
# 215          (SCGT00_L026,)  [3_GEX_V3]               31               7689
# 216          (SCGT00_L027,)  [3_GEX_V3]               59               4339
# 217          (SCGT00_L028,)  [3_GEX_V3]               39              10105
# 218          (SCGT00_L029,)  [3_GEX_V3]               41              11772
# 219          (SCGT00_L030,)  [3_GEX_V3]               30               4440
# 220          (SCGT00_L031,)  [3_GEX_V3]               65              12249
# 221          (SCGT00_L032,)  [3_GEX_V3]               32              14089
# 222          (SCGT00_L033,)  [3_GEX_V3]               40               9930
# 223          (SCGT00_L034,)  [3_GEX_V3]               41              10451
# 224          (SCGT00_L035,)  [3_GEX_V3]               15              12162
# 225          (SCGT00_L036,)  [3_GEX_V3]               36              10270
# 226          (SCGT00_L037,)  [3_GEX_V3]              112               9966
# 227          (SCGT00_L038,)  [3_GEX_V3]               42               9070
# 228          (SCGT00_L039,)  [3_GEX_V3]               77               4512
# 229          (SCGT00_L040,)  [3_GEX_V3]               35               9550
# 230          (SCGT00_L041,)  [3_GEX_V3]                9              12698
# 231          (SCGT00_L042,)  [3_GEX_V3]               35              13232
# 232          (SCGT00_L043,)  [3_GEX_V3]               84               5998
# 233          (SCGT00_L044,)  [3_GEX_V3]               24              12658
# 234          (SCGT00_L045,)  [3_GEX_V3]               64              10038
# 235          (SCGT00_L046,)  [3_GEX_V3]               83               5834
# 236          (SCGT00_L047,)  [3_GEX_V3]               17              11905
# 237          (SCGT00_L049,)  [3_GEX_V3]                6              17406
# 238          (SCGT00_L050,)  [3_GEX_V3]               18               5074
# 239          (SCGT00_L051,)  [3_GEX_V3]               12              10910
# 240          (SCGT00_L052,)  [3_GEX_V3]               36               9720
# 241          (SCGT01_L000,)  [3_GEX_V3]               42              11363
# 242          (SCGT01_L001,)  [3_GEX_V3]               23              13040
# 243          (SCGT02_L000,)  [3_GEX_V3]               89              16298
# 244          (SCGT02_L001,)  [3_GEX_V3]               42              10910
# 245          (SCGT02_L002,)  [3_GEX_V3]               36              14369
# 246          (SCGT02_L003,)  [3_GEX_V3]               88              13071
# 247          (SCGT03_L000,)  [5_GEX_V2]                8              10241
# 248          (SCGT03_L001,)  [5_GEX_V2]               10              13795
# 249          (SCGT03_L002,)  [5_GEX_V2]               19               3919
# 250          (SCGT03_L003,)  [5_GEX_V2]                2               5248
# 251          (SCGT03_L005,)  [5_GEX_V2]               11               5252
# 252          (SCGT04_L000,)  [3_GEX_V3]               54              14543
# 253          (SCGT04_L001,)  [3_GEX_V3]              114              13329
# 254          (SCGT04_L002,)  [3_GEX_V3]              105              14933
# 255          (SCGT05_L001,)  [5_GEX_V2]                4               6340
# 256          (SCGT05_L002,)  [5_GEX_V2]                1              10687
# 257          (SCGT05_L003,)  [5_GEX_V2]                8              10412
# 258          (SCGT05_L004,)  [5_GEX_V2]                5               4250
# 259          (SCGT05_L005,)  [5_GEX_V2]               12               9451
# 260          (SCGT05_L006,)  [5_GEX_V2]               65               1737
# 261          (SCGT05_L007,)  [5_GEX_V2]                7               9465
# 262          (SCGT05_L008,)  [5_GEX_V2]                9              12689
# 263          (SCGT05_L009,)  [5_GEX_V2]                4              12852
# 264          (SCGT05_L010,)  [5_GEX_V2]                8               6724
# 265          (SCGT05_L011,)  [5_GEX_V2]               13              11981
# 266          (SCGT05_L012,)  [5_GEX_V2]                4               9044
# 267          (SCGT05_L013,)  [5_GEX_V2]                6              11507
# 268  (Schafflick2020_L000,)  [3_GEX_V2]               14               7444
# 269  (Schafflick2020_L001,)  [3_GEX_V2]                4              10641
# 270  (Schafflick2020_L002,)  [3_GEX_V2]                3               8319
# 271  (Schafflick2020_L003,)  [3_GEX_V2]                3               6859
# 272  (Schafflick2020_L004,)  [3_GEX_V2]                2              10654
# 273  (Schafflick2020_L005,)  [3_GEX_V2]                6              10490
# 274  (Schafflick2020_L007,)  [3_GEX_V2]                9               6955
# 275  (Schafflick2020_L008,)  [3_GEX_V2]                5               8166
# 276  (Schafflick2020_L009,)  [3_GEX_V2]                1               8282
# 277   (Terekhova2023_L000,)  [5_GEX_V2]                6               6662
# 368   (Terekhova2023_L095,)  [5_GEX_V2]               11              13046
# 369   (Terekhova2023_L096,)  [5_GEX_V2]               38               7949
# 370   (Terekhova2023_L097,)  [5_GEX_V2]               33              11498
# 371   (Terekhova2023_L098,)  [5_GEX_V2]                6               9666
# 372   (Terekhova2023_L099,)  [5_GEX_V2]                7               6775
# 373   (Terekhova2023_L100,)  [5_GEX_V2]               19               5815
# 374   (Terekhova2023_L101,)  [5_GEX_V2]               25               8742
# 375   (Terekhova2023_L102,)  [5_GEX_V2]               14              10607
# 376   (Terekhova2023_L103,)  [5_GEX_V2]               21               9144
# 377   (Terekhova2023_L104,)  [5_GEX_V2]               35               9388
# 378   (Terekhova2023_L105,)  [5_GEX_V2]               22               8050
# 379        (Wang2020_L000,)  [3_GEX_V2]                7               8612
# 380        (Wang2020_L001,)  [3_GEX_V2]                4               4020
# 381        (Wang2020_L004,)  [3_GEX_V2]                3               3798
# 382        (Wang2020_L005,)  [3_GEX_V2]                1              10174
# 383        (Wang2020_L006,)  [3_GEX_V2]                3               5665
# 384       (Zhang2023_L001,)  [5_GEX_V1]                1               7953
# 385       (Zhang2023_L005,)  [5_GEX_V1]                2              12431
# 386       (Zhang2023_L006,)  [5_GEX_V1]                3              15296
# 387       (Zhang2023_L010,)  [5_GEX_V1]                6               2552
# 388       (Zhang2023_L011,)  [5_GEX_V1]               14               9237
# 389       (Zhang2023_L013,)  [5_GEX_V1]                4                777
# 390       (Zhang2023_L014,)  [5_GEX_V1]                5               5456
# 391       (Zhang2023_L015,)  [5_GEX_V1]               16              12739
# 392       (Zhang2023_L016,)  [5_GEX_V1]                7               9243
# 393       (Zhang2023_L017,)  [5_GEX_V1]                7              11126
# 394       (Zhang2023_L018,)  [5_GEX_V1]                4               8442
# 395       (Zhang2023_L019,)  [5_GEX_V1]                7               9355
# 396       (Zhang2023_L020,)  [5_GEX_V1]                4               1662
# 397       (Zhang2023_L021,)  [5_GEX_V1]                1               3186
# 398       (Zhang2023_L022,)  [5_GEX_V1]                1                588
#
#      Median Genes  Median MT %  Median RB %  Median HB %
# 0            2445         1.50        41.65         0.01
# 1            2030         1.09        41.39         0.00
# 2            1933         1.33        41.93         0.00
# 3            2231         1.36        40.79         0.00
# 4            2195         1.55        45.03         0.01
# 5            1774         1.49        42.92         0.00
# 6            2139         0.81        46.28         0.00
# 7            2402         2.43        42.88         0.01
# 8            2363         1.54        45.25         0.00
# 9            2451         2.46        43.21         0.01
# 10           2255         1.96        44.28         0.00
# 11           2582         2.37        42.36         0.01
# 12           2435         1.97        43.00         0.01
# 13           2280         2.19        41.05         0.00
# 14           3011         2.51        39.86         0.00
# 15           2804         2.25        41.72         0.01
# 16           2308         2.23        41.32         0.00
# 17           2624         2.80        40.40         0.01
# 18           2260         2.56        40.43         0.01
# 19           2192         2.35        41.60         0.02
# 20           2458         2.34        37.32         0.01
# 21           2605         3.21        40.66         0.00
# 22           2352         2.87        39.08         0.00
# 23           2388         2.87        37.91         0.00
# 24           1820         2.95        40.47         0.00
# 347          2167         2.51        41.38         0.00
# 348          2313         2.36        43.52         0.00
# 349          2035         2.39        40.56         0.00
# 350          2114         2.42        41.18         0.00
# 351          2411         1.79        41.90         0.01
# 352          1982         2.75        42.26         0.00
# 353          2419         2.18        38.65         0.00
# 354          2443         2.87        41.07         0.00
# 355          1554         2.40        40.74         0.00
# 356          2353         3.32        36.79         0.00
# 357          2223         1.02        38.06         0.00
# 358          3252         3.85        33.60         0.01
# 359          3018         3.54        35.76         0.02
# 360          3500         3.72        34.14         0.01
# 361          2672         4.13        33.47         0.00
# 362          2952         3.69        32.81         0.01
# 363          1929         1.07        41.31         0.00
# 364          2524         1.67        40.36         0.00
# 365          2383         2.25        39.48         0.00
# 366          2387         1.44        40.15         0.01
# 367          2686         2.28        34.43         0.00
# 368          3185         2.23        42.84         0.01
# 369          2343         1.68        41.05         0.01
# 370          3164         2.53        38.78         0.01
# 371          3043         2.42        35.54         0.01
# 372          2553         3.03        32.05         0.00
# 373          1981         2.07        44.94         0.00
# 374          2406         2.10        41.67         0.00
# 375          2622         1.64        41.23         0.00
# 376          2588         1.90        40.78         0.01
# 377          2527         2.02        44.06         0.00
# 378          2329         2.14        44.05         0.00
# 379          2290         3.45        41.42         0.00
# 380          1609        12.33        18.43         0.00
# 381          1409         6.44        33.63         0.00
# 382          2585         3.86        37.43         0.02
# 383          1758         5.72        40.71         0.03
# 384          2545         1.96        27.74         0.01
# 385          2961         3.88        45.30         0.00
# 386          4101         5.54        41.83         0.09
# 387          1181         4.00        34.93         0.00
# 388          2255         4.75        43.87         0.00
# 389           560         9.39         2.70         0.00
# 390          2014         4.46        31.08         0.00
# 391          3027         4.50        42.01         0.00
# 392          2589         4.85        38.87         0.01
# 393          2747         3.19        31.50         0.03
# 394          2581         6.31        34.88         0.01
# 395          2614         4.82        38.30         0.01
# 396           792         1.75        18.53         0.02
# 397          1022         4.80        45.51         0.00
# 398           318         2.04        20.92         0.00

# %%
adata_tmp = adata[adata.obs.chemistry == "3_GEX_V3", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="3_GEX_V3",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_3GEXV3.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "3_GEX_V2", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="3_GEX_V2",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_3GEXV2.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "5_GEX_V2", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="5_GEX_V2",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_5GEXV2.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "5_GEX_V1", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="5_GEX_V1",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_5GEXV1.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} TCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN FROM STEP 2 (when RBC and Platelets will be filtered out)
# HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
# print(f"{np.sum(MHC_gene_idx)} HB genes")

# PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
# print(f"{np.sum(MHC_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx) # HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 110 ribosomal genes
# 118 TCR genes
# 54 TCR genes
# 21 MHC genes
# View of AnnData object with n_obs × n_vars = 7292 × 22522
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    HVGdf = get_HVG(adata_forHVG, groupby='studyID', batch_key='libraryID', 
                    flavor='seurat', min_disp=0.3, max_disp = 'inf', min_mean=0.01, max_mean=4)
except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    HVGdf = get_HVG(adata_forHVG, groupby='studyID', batch_key=None, 
                    flavor='seurat', min_disp=0.3, max_disp = 'inf', min_mean=0.01, max_mean=4)
# Out:
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# An error occurred: division by zero
# Executing without library correction...
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# Reyes2020
# Cillo2020
# Zhang2023
# Schafflick2020
# Liu2021
# Terekhova2023
# Perez2022
# Wang2020
# COMBAT2022
# Ren2021

# %%
# Considering only genes selected as HV in at least 1 study
columns_to_keep = [f'highly_variable_{study_id}' for study_id in adata.obs['studyID'].unique() if f'highly_variable_{study_id}' in HVGdf.columns]

HVG_sel_DF = HVGdf.loc[:, columns_to_keep]
HVG_sel_DF = HVG_sel_DF[HVG_sel_DF.sum(axis=1) > 0]
HVG_sel_DF.columns = HVG_sel_DF.columns.str.removeprefix("highly_variable_")
HVG_sel_DF.head()
# Out:
#                  SCGT00  SCGT01  SCGT02  SCGT03  SCGT04  SCGT05  Reyes2020  \
# ENSG00000000003   False   False   False   False   False   False      False
# ENSG00000000419    True   False   False   False   False    True      False
# ENSG00000000457   False    True    True   False   False    True      False
# ENSG00000000460    True   False    True   False   False   False      False
# ENSG00000000938   False   False    True    True    True    True      False
#
#                  Cillo2020  Zhang2023  Schafflick2020  Liu2021  Terekhova2023  \
# ENSG00000000003      False      False            True    False          False
# ENSG00000000419       True       True           False    False          False
# ENSG00000000457      False      False           False    False          False
# ENSG00000000460      False       True           False    False          False
# ENSG00000000938      False       True            True    False           True
#
#                  Perez2022  Wang2020  COMBAT2022  Ren2021
# ENSG00000000003      False     False       False    False
# ENSG00000000419      False      True       False     True
# ENSG00000000457       True      True        True    False
# ENSG00000000460      False     False       False    False
# ENSG00000000938       True     False        True    False

# %%
HVG_number = 2000

# %%
HVGperStudyCount = pd.DataFrame(index = HVG_sel_DF.index)
HVGperStudyCount['n_studies'] = HVG_sel_DF.sum(axis = 1)
HVGperStudyCount
# Out:
#                  n_studies
# ENSG00000000003          1
# ENSG00000000419          6
# ENSG00000000457          6
# ENSG00000000460          3
# ENSG00000000938          9
# ...                    ...
# ENSG00000288093          3
# ENSG00000288096          2
# ENSG00000288156          6
# ENSG00000288253          1
# ENSG00000288302          5
#
# [15885 rows x 1 columns]

# %%
CumStud_n = pd.DataFrame(HVGperStudyCount['n_studies'].value_counts())
CumStud_n.sort_index(ascending=False, inplace=True)
CumStud_n['cs_studies'] = CumStud_n['count'].cumsum()
CumStud_n
# Out:
#            count  cs_studies
# n_studies
# 16             7           7
# 15            29          36
# 14            58          94
# 13            61         155
# 12           132         287
# 11           161         448
# 10           345         793
# 9            497        1290
# 8            775        2065
# 7           1075        3140
# 6           1387        4527
# 5           1662        6189
# 4           1890        8079
# 3           2085       10164
# 2           2369       12533
# 1           3352       15885

# %%
nStudyThr = CumStud_n.loc[CumStud_n['cs_studies'] > HVG_number,:].index[0]
nStudyThr
# Out:
# 8

# %%
fig, ax = plt.subplots(1, figsize=(10, 5))
CumStud_n.cs_studies.plot(ax=ax)

plt.axhline(y = HVG_number, color = 'r', linestyle = '--')
plt.axvline(x = nStudyThr, color = 'g', linestyle = '--')
plt.xlabel('# of different study')
plt.ylabel('# of genes (cumulative)')
plt.gca().invert_xaxis()

if overwriteFigures:
    plt.savefig(here('{}/results/figures/01_HVG_selection_threshold.pdf'.format(workDir)), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
plt.show()

# %%
print('The total number of selected HVG is {}'.format(CumStud_n.loc[nStudyThr,'cs_studies']))
# Out:
# The total number of selected HVG is 2065

# %%
HVG_selected = HVGperStudyCount[HVGperStudyCount['n_studies'] >= nStudyThr].index.tolist()
print(HVG_selected[1:10])
# Out:
# ['ENSG00000001167', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000002586', 'ENSG00000003400', 'ENSG00000003402', 'ENSG00000003436', 'ENSG00000004777', 'ENSG00000004864']

# %%
adata.var['highly_variable'] = False
adata.var.loc[HVG_selected,'highly_variable'] = True

adata_HVG = adata[:, adata.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 7292 × 2065
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-04-30 08:39
# </pre>
# </details>
