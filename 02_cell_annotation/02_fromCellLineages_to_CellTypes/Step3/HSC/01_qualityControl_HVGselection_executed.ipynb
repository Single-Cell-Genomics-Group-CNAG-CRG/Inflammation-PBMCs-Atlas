# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import seaborn as sns

import scanpy as sc
import anndata as ad

import session_info
import warnings
from pyprojroot.here import here

from IPython.display import display
import scienceplots

warnings.filterwarnings("ignore")
sys.path.insert(1, str(here('bin')))

# Import functions
from customPythonFunctions import qc_gex_projectlibrary, get_HVG

plt.style.use(['nature'])
dpi_fig_save = 300
sc.set_figure_params(dpi=100, dpi_save=dpi_fig_save, vector_friendly=True)

pd.options.display.max_columns=300
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Setting parameters

# %%
overwriteFigures = True
overwriteData = True

# %%
cellGroup = 'HSC'
annotationDFpath = '/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/02_cell_annotation/02_fromCellLineages_to_CellTypes/Step2/Step2_clusterAnnotDF.pkl'
annotationColumns = 'annotation_step_2'
annColToInclude = None

# %%
workDir = os.getcwd()

# %% [markdown]
# # Preparing dataset

# %%
adataAll = ad.read_h5ad(here("01_data_processing/results/03_INFLAMMATION_main_normalized.h5ad"))
adataAll
# Out:
# AnnData object with n_obs × n_vars = 4918140 × 22838
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# ### Subsetting dataset

# %%
# Load the corresponding annotation
annotationDF = pd.read_pickle(here(annotationDFpath))
idxSelCells = annotationDF.index[annotationDF[annotationColumns] == cellGroup].tolist()
adata = adataAll[idxSelCells,:]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 5178 × 22838
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
adata.obs
# Out:
#                                         studyID     libraryID  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA   SCGT00   SCGT00_L051
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC   SCGT00   SCGT00_L051
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC   SCGT00   SCGT00_L051
# ...                                         ...           ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT  Ren2021  Ren2021_L066
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  Ren2021  Ren2021_L066
#
#                                                 sampleID chemistry  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  SCGT00_I52.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  SCGT00_I58.3P_T0  3_GEX_V3
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  SCGT00_I52.3P_T0  3_GEX_V3
# ...                                                  ...       ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT  Ren2021_PS053_T0  5_GEX_V2
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  Ren2021_PS053_T0  5_GEX_V2
#
#                                                  technology      patientID  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  3_GEX_V3_GenoHashed     SCGT00_I52
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  3_GEX_V3_GenoHashed     SCGT00_I58
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  3_GEX_V3_GenoHashed     SCGT00_I58
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  3_GEX_V3_GenoHashed     SCGT00_I58
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  3_GEX_V3_GenoHashed     SCGT00_I52
# ...                                                     ...            ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT             5_GEX_V2  Ren2021_PS053
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC             5_GEX_V2  Ren2021_PS053
#
#                                        disease  timepoint_replicate  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC      RA                  0.0
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA      RA                  0.0
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA      RA                  0.0
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC      RA                  0.0
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC      RA                  0.0
# ...                                        ...                  ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT   COVID                  0.0
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG   COVID                  0.0
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG   COVID                  0.0
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT   COVID                  0.0
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC   COVID                  0.0
#
#                                        treatmentStatus therapyResponse  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC         ongoing              NR
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA         ongoing              NR
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA         ongoing              NR
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC         ongoing              NR
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC         ongoing              NR
# ...                                                ...             ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT           under              na
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG           under              na
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG           under              na
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT           under              na
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC           under              na
#
#                                            sex   age    BMI binned_age  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  female  33.0  21.37      31-40
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  female  61.0  36.10      61-70
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  female  61.0  36.10      61-70
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  female  61.0  36.10      61-70
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  female  33.0  21.37      31-40
# ...                                        ...   ...    ...        ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT  female  46.0    NaN      41-50
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  female  46.0    NaN      41-50
#
#                                                       diseaseStatus  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                           na
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                           na
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                           na
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                           na
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                           na
# ...                                                             ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT  severe/critical_progression
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG  severe/critical_progression
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG  severe/critical_progression
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT  severe/critical_progression
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  severe/critical_progression
#
#                                        smokingStatus ethnicity institute  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  never-smoker        na        na
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  never-smoker        na        na
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  never-smoker        na        na
# ...                                              ...       ...       ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT            na        na   Beijing
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG            na        na   Beijing
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG            na        na   Beijing
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT            na        na   Beijing
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC            na        na   Beijing
#
#                                        diseaseGroup  n_genes_by_counts  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        IMIDs               2639
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        IMIDs               2263
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        IMIDs               3567
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC        IMIDs                693
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC        IMIDs               3893
# ...                                             ...                ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT    infection               1739
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG    infection               2230
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG    infection               1099
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT    infection               1734
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC    infection               1540
#
#                                         log1p_n_genes_by_counts  total_counts  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                 7.878534         12898
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 7.724888         10543
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                 8.179760         19479
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                 6.542472          2276
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                 8.267192         21518
# ...                                                         ...           ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT                 7.461640          4115
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG                 7.710205          6005
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG                 7.003065          2475
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                 7.458763          4561
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 7.340187          3408
#
#                                         log1p_total_counts  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC            9.464905
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA            9.263312
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA            9.877144
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC            7.730614
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC            9.976692
# ...                                                    ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT            8.322637
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG            8.700514
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG            7.814400
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT            8.425516
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC            8.134174
#
#                                         pct_counts_in_top_20_genes  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                   26.895643
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                   25.893958
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                   24.636788
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                   38.971880
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                   25.369458
# ...                                                            ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT                   20.558931
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG                   19.500416
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG                   22.464646
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                   21.618066
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                   18.368545
#
#                                         total_counts_mt  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC              198
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA              290
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA              901
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC               26
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC              445
# ...                                                 ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT              242
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG              408
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG              127
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT              339
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC              201
#
#                                         log1p_total_counts_mt  pct_counts_mt  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               5.293305       1.535122
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               5.673323       2.750640
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               6.804615       4.625494
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC               3.295837       1.142355
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC               6.100319       2.068036
# ...                                                       ...            ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT               5.493061       5.880923
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG               6.013715       6.794338
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG               4.852030       5.131313
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT               5.828946       7.432581
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC               5.308268       5.897887
#
#                                         total_counts_ribo  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               6023
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               4970
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               7748
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                943
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC               9304
# ...                                                   ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT               1242
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG               1863
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG                737
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT               1291
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                740
#
#                                         log1p_total_counts_ribo  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                 8.703507
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 8.511376
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                 8.955319
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                 6.850126
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                 9.138307
# ...                                                         ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT                 7.125283
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG                 7.530480
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG                 6.603944
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                 7.163947
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 6.608001
#
#                                         pct_counts_ribo  total_counts_hb  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        46.697162                1
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        47.140283                0
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        39.776169                3
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC        41.432337                0
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC        43.238219                8
# ...                                                 ...              ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT        30.182260                1
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG        31.024147                0
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG        29.777778                0
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT        28.305196                0
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC        21.713615                0
#
#                                         log1p_total_counts_hb  pct_counts_hb  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC               0.693147       0.007753
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA               0.000000       0.000000
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA               1.386294       0.015401
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC               0.000000       0.000000
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC               2.197225       0.037178
# ...                                                       ...            ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT               0.693147       0.024301
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG               0.000000       0.000000
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG               0.000000       0.000000
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT               0.000000       0.000000
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC               0.000000       0.000000
#
#                                         total_counts_plt  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                17
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                 2
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                14
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                 0
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                20
# ...                                                  ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT                 0
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG                 8
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG                 1
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                13
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                 3
#
#                                         log1p_total_counts_plt  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                2.890372
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                1.098612
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                2.708050
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                0.000000
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                3.044522
# ...                                                        ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT                0.000000
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG                2.197225
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG                0.693147
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                2.639057
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                1.386294
#
#                                         pct_counts_plt  doublet_score  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC        0.131803          0.030
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA        0.018970          0.037
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA        0.071872          0.076
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC        0.000000          0.019
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC        0.092945          0.043
# ...                                                ...            ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT        0.000000          0.002
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG        0.133222          0.001
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG        0.040404          0.004
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT        0.285025          0.003
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC        0.088028          0.004
#
#                                         predicted_doublet   S_score  \
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC                  0 -0.036518
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA                  0 -0.004612
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA                  0 -0.041559
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC                  0 -0.046220
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC                  0  0.025784
# ...                                                   ...       ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT                  0 -0.044810
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG                  0  0.022831
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG                  0  0.012190
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT                  0  0.017264
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC                  0 -0.006460
#
#                                         G2M_score phase
# cellID
# SCGT00_L051_I52.3P_T0_ATACCGACAGACAAGC  -0.065312    G1
# SCGT00_L051_I58.3P_T0_CATTCATTCCTATGGA  -0.034372    G1
# SCGT00_L051_I58.3P_T0_CTCAAGAGTCTTCGAA  -0.065553    G1
# SCGT00_L051_I58.3P_T0_CTGCAGGCAACCGACC  -0.080506    G1
# SCGT00_L051_I52.3P_T0_CTTCAATTCTTCCAGC  -0.050191     S
# ...                                           ...   ...
# Ren2021_L066_PS053_T0_CAACCAACAATGGAAT  -0.060061    G1
# Ren2021_L066_PS053_T0_CAGCCGATCAGAAATG   0.053162   G2M
# Ren2021_L066_PS053_T0_CGTCTACGTCTAGAGG  -0.019552     S
# Ren2021_L066_PS053_T0_GGAATAAGTTCCGTCT   0.021570   G2M
# Ren2021_L066_PS053_T0_TGCGTGGCATATACGC  -0.118916    G1
#
# [5178 rows x 41 columns]

# %%
# Free some memory
del adataAll

# %% [markdown]
# ### (Optional) Including annotation column

# %%
if annColToInclude is not None:
    adata.obs = adata.obs.merge(annotationDF[[annColToInclude]], left_index=True, right_index=True, how='left')
    adata.obs[annColToInclude].unique()

# %% [markdown]
# # Plotting Quality Control metrics
#
# ## Library quality control at CELL level

# %%
fig = sc.pl.violin(adata, 
                   [
                       'total_counts', 
                       'n_genes_by_counts', 
                       'pct_counts_mt',
                       'pct_counts_ribo',
                       'pct_counts_hb',
                       'pct_counts_plt'
                   ], 
                   groupby="chemistry",
                   stripplot=False, rotation=90, show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_totalCount_by_chemistry.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %%
# save the HUGO status information 
varDF = adata.var[['HUGO_status']]

# %% [markdown]
# **General QC statistics**

# %%
pd.set_option('display.max_rows', None)
qc_gex_df = qc_gex_projectlibrary(adata)
display(qc_gex_df)

pd.reset_option('display.max_rows')
# Out:
#                   libraryID   chemistry  Number of cells  Median UMI counts  \
# 0        (COMBAT2022_L000,)  [5_GEX_V1]               25               9186
# 1        (COMBAT2022_L001,)  [5_GEX_V1]               22               7102
# 2        (COMBAT2022_L002,)  [5_GEX_V1]               19               8039
# 3        (COMBAT2022_L003,)  [5_GEX_V1]               28               8926
# 4        (COMBAT2022_L004,)  [5_GEX_V1]               23               9130
# 5        (COMBAT2022_L005,)  [5_GEX_V1]               21               6553
# 6        (COMBAT2022_L006,)  [5_GEX_V1]               20               7650
# 7        (COMBAT2022_L007,)  [5_GEX_V1]               31              11713
# 8        (COMBAT2022_L008,)  [5_GEX_V1]               28              11173
# 9        (COMBAT2022_L009,)  [5_GEX_V1]               28              12201
# 10       (COMBAT2022_L010,)  [5_GEX_V1]               32              10100
# 11       (COMBAT2022_L011,)  [5_GEX_V1]               34              11723
# 12       (COMBAT2022_L012,)  [5_GEX_V1]               37              10924
# 13       (COMBAT2022_L013,)  [5_GEX_V1]               21              10188
# 14       (COMBAT2022_L014,)  [5_GEX_V1]               11              12488
# 15       (COMBAT2022_L015,)  [5_GEX_V1]               10              11729
# 16       (COMBAT2022_L016,)  [5_GEX_V1]               14              10973
# 17       (COMBAT2022_L017,)  [5_GEX_V1]               18              10496
# 18       (COMBAT2022_L018,)  [5_GEX_V1]               11               8391
# 19       (COMBAT2022_L019,)  [5_GEX_V1]                8               8546
# 20       (COMBAT2022_L020,)  [5_GEX_V1]               13               8147
# 21       (COMBAT2022_L021,)  [5_GEX_V1]               14              11484
# 22       (COMBAT2022_L022,)  [5_GEX_V1]               23               9428
# 23       (COMBAT2022_L023,)  [5_GEX_V1]               16               8891
# 24       (COMBAT2022_L024,)  [5_GEX_V1]                9               8592
# 25       (COMBAT2022_L025,)  [5_GEX_V1]               16              10543
# 26       (COMBAT2022_L026,)  [5_GEX_V1]               21              10148
# 27       (COMBAT2022_L027,)  [5_GEX_V1]               19               8805
# 28       (COMBAT2022_L028,)  [5_GEX_V1]               15              11489
# 29       (COMBAT2022_L029,)  [5_GEX_V1]               25              10774
# 30       (COMBAT2022_L030,)  [5_GEX_V1]               26              11956
# 31       (COMBAT2022_L031,)  [5_GEX_V1]               18              11354
# 32       (COMBAT2022_L032,)  [5_GEX_V1]               30              11170
# 33       (COMBAT2022_L033,)  [5_GEX_V1]               23              10271
# 34       (COMBAT2022_L034,)  [5_GEX_V1]               20              11504
# 35       (COMBAT2022_L035,)  [5_GEX_V1]               16              11939
# 36       (COMBAT2022_L036,)  [5_GEX_V1]               14               9349
# 37       (COMBAT2022_L037,)  [5_GEX_V1]                6               9056
# 38       (COMBAT2022_L038,)  [5_GEX_V1]               14              10124
# 39       (COMBAT2022_L039,)  [5_GEX_V1]               19               9944
# 40       (COMBAT2022_L040,)  [5_GEX_V1]               14               8753
# 41       (COMBAT2022_L041,)  [5_GEX_V1]               19              10360
# 42       (COMBAT2022_L042,)  [5_GEX_V1]               20              11449
# 43       (COMBAT2022_L043,)  [5_GEX_V1]               16              10849
# 44       (COMBAT2022_L044,)  [5_GEX_V1]               23              11455
# 45       (COMBAT2022_L045,)  [5_GEX_V1]               22              11025
# 46       (COMBAT2022_L046,)  [5_GEX_V1]               20              11606
# 47       (COMBAT2022_L047,)  [5_GEX_V1]               15              10716
# 48       (COMBAT2022_L048,)  [5_GEX_V1]               13              12982
# 49       (COMBAT2022_L049,)  [5_GEX_V1]               16               9163
# 50       (COMBAT2022_L050,)  [5_GEX_V1]                8               8373
# 51       (COMBAT2022_L051,)  [5_GEX_V1]               22               8727
# 52       (COMBAT2022_L052,)  [5_GEX_V1]               28               9117
# 53       (COMBAT2022_L053,)  [5_GEX_V1]               14               6498
# 54       (COMBAT2022_L054,)  [5_GEX_V1]               20               8647
# 55       (COMBAT2022_L055,)  [5_GEX_V1]               12              10709
# 56       (COMBAT2022_L056,)  [5_GEX_V1]               17               9988
# 57       (COMBAT2022_L057,)  [5_GEX_V1]               21               9379
# 58       (COMBAT2022_L058,)  [5_GEX_V1]               24               8449
# 59       (COMBAT2022_L059,)  [5_GEX_V1]               34               9180
# 60       (COMBAT2022_L060,)  [5_GEX_V1]               35               9018
# 61       (COMBAT2022_L061,)  [5_GEX_V1]               28               8026
# 62       (COMBAT2022_L062,)  [5_GEX_V1]               27              10841
# 63       (COMBAT2022_L063,)  [5_GEX_V1]               12              12826
# 64       (COMBAT2022_L064,)  [5_GEX_V1]               12              12918
# 65       (COMBAT2022_L065,)  [5_GEX_V1]               16              11830
# 66       (COMBAT2022_L066,)  [5_GEX_V1]               18              11848
# 67       (COMBAT2022_L067,)  [5_GEX_V1]               15              12231
# 68       (COMBAT2022_L068,)  [5_GEX_V1]                8              13922
# 69       (COMBAT2022_L069,)  [5_GEX_V1]               11              12405
# 70        (Cillo2020_L001,)  [3_GEX_V2]                4               7926
# 71        (Cillo2020_L002,)  [3_GEX_V2]                2              15433
# 72        (Cillo2020_L003,)  [3_GEX_V2]                1              11643
# 73        (Cillo2020_L005,)  [3_GEX_V2]                2               8645
# 74        (Cillo2020_L010,)  [3_GEX_V2]                3              11169
# 75        (Cillo2020_L012,)  [3_GEX_V2]                1              10098
# 76        (Cillo2020_L018,)  [3_GEX_V2]                1              17477
# 77        (Cillo2020_L019,)  [3_GEX_V2]                4              10501
# 78        (Cillo2020_L020,)  [3_GEX_V2]                1              15397
# 79        (Cillo2020_L021,)  [3_GEX_V2]                1              20695
# 80        (Cillo2020_L023,)  [3_GEX_V2]                1               8889
# 81        (Cillo2020_L024,)  [3_GEX_V2]                2               7052
# 82        (Cillo2020_L025,)  [3_GEX_V2]                1              19123
# 83        (Cillo2020_L031,)  [3_GEX_V2]                1              13022
# 84          (Liu2021_L000,)  [5_GEX_V1]                3               6467
# 85          (Liu2021_L001,)  [5_GEX_V1]                2              14959
# 86          (Liu2021_L003,)  [5_GEX_V1]                6               8846
# 87          (Liu2021_L005,)  [5_GEX_V1]                2              14890
# 88          (Liu2021_L006,)  [5_GEX_V1]                1               6151
# 89          (Liu2021_L007,)  [5_GEX_V1]                1              11125
# 90          (Liu2021_L008,)  [5_GEX_V1]                3               7877
# 91          (Liu2021_L009,)  [5_GEX_V1]                1               7712
# 92        (Perez2022_L000,)  [3_GEX_V2]                4              11207
# 93        (Perez2022_L001,)  [3_GEX_V2]                6               8059
# 94        (Perez2022_L002,)  [3_GEX_V2]                6               6176
# 95        (Perez2022_L003,)  [3_GEX_V2]                2               7776
# 96        (Perez2022_L004,)  [3_GEX_V2]                4               7443
# 97        (Perez2022_L005,)  [3_GEX_V2]                7               7216
# 98        (Perez2022_L006,)  [3_GEX_V2]                1               6767
# 99        (Perez2022_L007,)  [3_GEX_V2]                4               6132
# 100       (Perez2022_L008,)  [3_GEX_V2]               15               5737
# 101       (Perez2022_L009,)  [3_GEX_V2]               11               6704
# 102       (Perez2022_L010,)  [3_GEX_V2]               16               6805
# 103       (Perez2022_L011,)  [3_GEX_V2]               12               6345
# 104       (Perez2022_L012,)  [3_GEX_V2]                5               7406
# 105       (Perez2022_L013,)  [3_GEX_V2]                6               9244
# 106       (Perez2022_L014,)  [3_GEX_V2]                5               6734
# 107       (Perez2022_L015,)  [3_GEX_V2]                5               6255
# 108       (Perez2022_L017,)  [3_GEX_V2]                5               4947
# 109       (Perez2022_L018,)  [3_GEX_V2]                6               3467
# 110       (Perez2022_L019,)  [3_GEX_V2]               11               4585
# 111       (Perez2022_L020,)  [3_GEX_V2]                3               8867
# 112       (Perez2022_L021,)  [3_GEX_V2]                3              11048
# 113       (Perez2022_L022,)  [3_GEX_V2]                6              10974
# 114       (Perez2022_L023,)  [3_GEX_V2]                2               7634
# 115       (Perez2022_L024,)  [3_GEX_V2]                3               6752
# 116       (Perez2022_L025,)  [3_GEX_V2]               16               7093
# 117       (Perez2022_L026,)  [3_GEX_V2]                8               7439
# 118       (Perez2022_L027,)  [3_GEX_V2]                6               5488
# 119       (Perez2022_L028,)  [3_GEX_V2]                5              10524
# 120       (Perez2022_L029,)  [3_GEX_V2]                6              10052
# 121       (Perez2022_L030,)  [3_GEX_V2]                4               8915
# 122       (Perez2022_L031,)  [3_GEX_V2]                3              10513
# 123       (Perez2022_L032,)  [3_GEX_V2]                8               8189
# 124       (Perez2022_L033,)  [3_GEX_V2]               11               9133
# 125       (Perez2022_L034,)  [3_GEX_V2]                8               8846
# 126       (Perez2022_L035,)  [3_GEX_V2]                3               9021
# 127       (Perez2022_L036,)  [3_GEX_V2]                2              10023
# 128       (Perez2022_L037,)  [3_GEX_V2]                7               9061
# 129       (Perez2022_L038,)  [3_GEX_V2]                5               8963
# 130       (Perez2022_L039,)  [3_GEX_V2]                4              14771
# 131       (Perez2022_L040,)  [3_GEX_V2]                1               9973
# 132       (Perez2022_L042,)  [3_GEX_V2]                2               2629
# 133       (Perez2022_L043,)  [3_GEX_V2]                4               4034
# 134       (Perez2022_L044,)  [3_GEX_V2]                3               4203
# 135       (Perez2022_L045,)  [3_GEX_V2]                8               4936
# 136       (Perez2022_L046,)  [3_GEX_V2]                2               8341
# 137       (Perez2022_L047,)  [3_GEX_V2]                4               9052
# 138       (Perez2022_L048,)  [3_GEX_V2]                3               4472
# 139       (Perez2022_L049,)  [3_GEX_V2]                2               7176
# 140       (Perez2022_L050,)  [3_GEX_V2]               11               4851
# 141       (Perez2022_L051,)  [3_GEX_V2]                5               6504
# 142       (Perez2022_L052,)  [3_GEX_V2]               12               5419
# 143       (Perez2022_L053,)  [3_GEX_V2]                7               4407
# 144       (Perez2022_L054,)  [3_GEX_V2]                2              13235
# 145       (Perez2022_L055,)  [3_GEX_V2]                3               8358
# 146       (Perez2022_L056,)  [3_GEX_V2]                4               6025
# 147       (Perez2022_L057,)  [3_GEX_V2]                3               4055
# 148       (Perez2022_L058,)  [3_GEX_V2]                4               6662
# 149       (Perez2022_L059,)  [3_GEX_V2]                4               5932
# 150       (Perez2022_L060,)  [3_GEX_V2]                4               5469
# 151       (Perez2022_L061,)  [3_GEX_V2]                5               6601
# 152       (Perez2022_L062,)  [3_GEX_V2]                6               4700
# 153       (Perez2022_L063,)  [3_GEX_V2]                6               5746
# 154       (Perez2022_L064,)  [3_GEX_V2]               10               6336
# 155       (Perez2022_L065,)  [3_GEX_V2]                4               7055
# 156       (Perez2022_L066,)  [3_GEX_V2]                4               6695
# 157       (Perez2022_L067,)  [3_GEX_V2]               17               5812
# 158       (Perez2022_L071,)  [3_GEX_V2]                4               4124
# 159       (Perez2022_L072,)  [3_GEX_V2]                2               6472
# 160       (Perez2022_L073,)  [3_GEX_V2]                3               7976
# 161       (Perez2022_L074,)  [3_GEX_V2]                7               6834
# 162       (Perez2022_L075,)  [3_GEX_V2]                3               5658
# 163       (Perez2022_L076,)  [3_GEX_V2]                8               5963
# 164       (Perez2022_L077,)  [3_GEX_V2]               10               6817
# 165       (Perez2022_L078,)  [3_GEX_V2]                8               6035
# 166       (Perez2022_L079,)  [3_GEX_V2]               10               5146
# 167       (Perez2022_L080,)  [3_GEX_V2]                6               8421
# 168       (Perez2022_L082,)  [3_GEX_V2]                4               6487
# 169       (Perez2022_L083,)  [3_GEX_V2]                9               8011
# 170         (Ren2021_L013,)  [5_GEX_V2]                1               4323
# 171         (Ren2021_L021,)  [5_GEX_V2]                1               9771
# 172         (Ren2021_L022,)  [5_GEX_V2]                2               7531
# 173         (Ren2021_L024,)  [5_GEX_V2]               11              16204
# 174         (Ren2021_L026,)  [5_GEX_V2]                1               1432
# 175         (Ren2021_L041,)  [5_GEX_V2]                2               9333
# 176         (Ren2021_L054,)  [5_GEX_V2]                1              15789
# 177         (Ren2021_L061,)  [5_GEX_V2]                2               5820
# 178         (Ren2021_L066,)  [5_GEX_V2]                6               4338
# 179         (Ren2021_L067,)  [5_GEX_V2]                2               1527
# 180          (SCGT00_L000,)  [3_GEX_V3]               26               9469
# 181          (SCGT00_L002,)  [3_GEX_V3]               19              11545
# 182          (SCGT00_L003,)  [3_GEX_V3]               25               7704
# 183          (SCGT00_L004,)  [3_GEX_V3]                4              16086
# 184          (SCGT00_L005,)  [3_GEX_V3]               24               8740
# 185          (SCGT00_L007,)  [3_GEX_V3]               19              12819
# 186          (SCGT00_L008,)  [3_GEX_V3]                8              12854
# 187          (SCGT00_L009,)  [3_GEX_V3]               29               8456
# 188          (SCGT00_L010,)  [3_GEX_V3]               25               9467
# 189          (SCGT00_L011,)  [3_GEX_V3]               32              12309
# 190          (SCGT00_L012,)  [3_GEX_V3]               40              11335
# 191          (SCGT00_L013,)  [3_GEX_V3]               81               9763
# 192          (SCGT00_L015,)  [3_GEX_V3]               31              11182
# 193          (SCGT00_L016,)  [3_GEX_V3]               12              11209
# 194          (SCGT00_L017,)  [3_GEX_V3]               21              14528
# 195          (SCGT00_L019,)  [3_GEX_V3]               13              14003
# 196          (SCGT00_L020,)  [3_GEX_V3]               22              13747
# 197          (SCGT00_L021,)  [3_GEX_V3]               24              13050
# 198          (SCGT00_L022,)  [3_GEX_V3]               25              12907
# 199          (SCGT00_L023,)  [3_GEX_V3]               39              12689
# 200          (SCGT00_L024,)  [3_GEX_V3]               27              10446
# 201          (SCGT00_L025,)  [3_GEX_V3]               51               4828
# 202          (SCGT00_L026,)  [3_GEX_V3]               19               9399
# 203          (SCGT00_L027,)  [3_GEX_V3]               45               3701
# 204          (SCGT00_L028,)  [3_GEX_V3]               30              10643
# 205          (SCGT00_L029,)  [3_GEX_V3]               28              12451
# 206          (SCGT00_L030,)  [3_GEX_V3]               17               4414
# 207          (SCGT00_L031,)  [3_GEX_V3]               40              11628
# 208          (SCGT00_L032,)  [3_GEX_V3]               21              14344
# 209          (SCGT00_L033,)  [3_GEX_V3]               28              10960
# 210          (SCGT00_L034,)  [3_GEX_V3]               27              11130
# 211          (SCGT00_L035,)  [3_GEX_V3]               10              11963
# 212          (SCGT00_L036,)  [3_GEX_V3]               23              10880
# 213          (SCGT00_L037,)  [3_GEX_V3]               85              10528
# 214          (SCGT00_L038,)  [3_GEX_V3]               28               9070
# 215          (SCGT00_L039,)  [3_GEX_V3]               52               4527
# 216          (SCGT00_L040,)  [3_GEX_V3]               25              10088
# 217          (SCGT00_L041,)  [3_GEX_V3]                8              14531
# 218          (SCGT00_L042,)  [3_GEX_V3]               27              13722
# 219          (SCGT00_L043,)  [3_GEX_V3]               50               6256
# 220          (SCGT00_L044,)  [3_GEX_V3]               19              12997
# 221          (SCGT00_L045,)  [3_GEX_V3]               47              10755
# 222          (SCGT00_L046,)  [3_GEX_V3]               51               5834
# 223          (SCGT00_L047,)  [3_GEX_V3]               12              11919
# 224          (SCGT00_L049,)  [3_GEX_V3]                3              14070
# 225          (SCGT00_L050,)  [3_GEX_V3]               12               7536
# 226          (SCGT00_L051,)  [3_GEX_V3]               11              11270
# 227          (SCGT00_L052,)  [3_GEX_V3]               27              10610
# 228          (SCGT01_L000,)  [3_GEX_V3]               27              12187
# 229          (SCGT01_L001,)  [3_GEX_V3]               18              13202
# 230          (SCGT02_L000,)  [3_GEX_V3]               64              16963
# 231          (SCGT02_L001,)  [3_GEX_V3]               25              11742
# 232          (SCGT02_L002,)  [3_GEX_V3]               26              14772
# 233          (SCGT02_L003,)  [3_GEX_V3]               63              13199
# 234          (SCGT03_L000,)  [5_GEX_V2]                7               9965
# 235          (SCGT03_L001,)  [5_GEX_V2]                7              15340
# 236          (SCGT03_L002,)  [5_GEX_V2]               11               3867
# 237          (SCGT03_L005,)  [5_GEX_V2]                8               5796
# 238          (SCGT04_L000,)  [3_GEX_V3]               43              15468
# 239          (SCGT04_L001,)  [3_GEX_V3]               94              13417
# 240          (SCGT04_L002,)  [3_GEX_V3]               90              14916
# 241          (SCGT05_L001,)  [5_GEX_V2]                3               7520
# 242          (SCGT05_L002,)  [5_GEX_V2]                1              10687
# 243          (SCGT05_L003,)  [5_GEX_V2]                7              10810
# 244          (SCGT05_L004,)  [5_GEX_V2]                5               4250
# 245          (SCGT05_L005,)  [5_GEX_V2]                8               9564
# 246          (SCGT05_L006,)  [5_GEX_V2]                3               4454
# 247          (SCGT05_L007,)  [5_GEX_V2]                2              11608
# 248          (SCGT05_L008,)  [5_GEX_V2]                6              13717
# 249          (SCGT05_L009,)  [5_GEX_V2]                3              15436
# 250          (SCGT05_L010,)  [5_GEX_V2]                5               8342
# 251          (SCGT05_L011,)  [5_GEX_V2]                7              12654
# 252          (SCGT05_L012,)  [5_GEX_V2]                3              10015
# 253          (SCGT05_L013,)  [5_GEX_V2]                6              11507
# 254  (Schafflick2020_L000,)  [3_GEX_V2]               11               7449
# 255  (Schafflick2020_L001,)  [3_GEX_V2]                2              13680
# 256  (Schafflick2020_L002,)  [3_GEX_V2]                2               8451
# 257  (Schafflick2020_L003,)  [3_GEX_V2]                2               7682
# 258  (Schafflick2020_L004,)  [3_GEX_V2]                2              10654
# 259  (Schafflick2020_L005,)  [3_GEX_V2]                6              10490
# 260  (Schafflick2020_L007,)  [3_GEX_V2]                5               7223
# 261  (Schafflick2020_L008,)  [3_GEX_V2]                4               9192
# 262  (Schafflick2020_L009,)  [3_GEX_V2]                1               8282
# 263   (Terekhova2023_L000,)  [5_GEX_V2]                4               6331
# 264   (Terekhova2023_L001,)  [5_GEX_V2]                3              10685
# 265   (Terekhova2023_L003,)  [5_GEX_V2]                4               4814
# 266   (Terekhova2023_L004,)  [5_GEX_V2]                7               5235
# 267   (Terekhova2023_L005,)  [5_GEX_V2]               23               9518
# 268   (Terekhova2023_L006,)  [5_GEX_V2]               21               9580
# 269   (Terekhova2023_L007,)  [5_GEX_V2]                3               6181
# 270   (Terekhova2023_L008,)  [5_GEX_V2]                2               5772
# 271   (Terekhova2023_L009,)  [5_GEX_V2]                5              10140
# 272   (Terekhova2023_L010,)  [5_GEX_V2]               13               7587
# 273   (Terekhova2023_L011,)  [5_GEX_V2]               16               4162
# 274   (Terekhova2023_L012,)  [5_GEX_V2]                8               4359
# 275   (Terekhova2023_L013,)  [5_GEX_V2]                9               4359
# 276   (Terekhova2023_L014,)  [5_GEX_V2]                7               4310
# 277   (Terekhova2023_L015,)  [5_GEX_V2]               23               5081
# 278   (Terekhova2023_L016,)  [5_GEX_V2]               25               4851
# 279   (Terekhova2023_L017,)  [5_GEX_V2]               12               5312
# 280   (Terekhova2023_L018,)  [5_GEX_V2]                9               4951
# 281   (Terekhova2023_L019,)  [5_GEX_V2]                7               7311
# 282   (Terekhova2023_L020,)  [5_GEX_V2]               10               7339
# 283   (Terekhova2023_L021,)  [5_GEX_V2]                3               6691
# 284   (Terekhova2023_L022,)  [5_GEX_V2]                8               8893
# 285   (Terekhova2023_L023,)  [5_GEX_V2]               18               8203
# 286   (Terekhova2023_L024,)  [5_GEX_V2]               19              10407
# 287   (Terekhova2023_L025,)  [5_GEX_V2]                5               8324
# 288   (Terekhova2023_L026,)  [5_GEX_V2]                3              10707
# 289   (Terekhova2023_L027,)  [5_GEX_V2]               17               4731
# 290   (Terekhova2023_L028,)  [5_GEX_V2]               29               5762
# 336   (Terekhova2023_L076,)  [5_GEX_V2]                8               7303
# 337   (Terekhova2023_L077,)  [5_GEX_V2]               11               5713
# 338   (Terekhova2023_L078,)  [5_GEX_V2]               19               9485
# 339   (Terekhova2023_L079,)  [5_GEX_V2]               11               8821
# 340   (Terekhova2023_L080,)  [5_GEX_V2]                5               5427
# 341   (Terekhova2023_L081,)  [5_GEX_V2]                4               7363
# 342   (Terekhova2023_L082,)  [5_GEX_V2]                4               9324
# 343   (Terekhova2023_L083,)  [5_GEX_V2]               10               9930
# 344   (Terekhova2023_L086,)  [5_GEX_V2]                9              10810
# 345   (Terekhova2023_L087,)  [5_GEX_V2]                4              10254
# 346   (Terekhova2023_L088,)  [5_GEX_V2]               13               8434
# 347   (Terekhova2023_L089,)  [5_GEX_V2]               12               9246
# 348   (Terekhova2023_L090,)  [5_GEX_V2]               17               3948
# 349   (Terekhova2023_L091,)  [5_GEX_V2]               33               8700
# 350   (Terekhova2023_L092,)  [5_GEX_V2]               13               8787
# 351   (Terekhova2023_L093,)  [5_GEX_V2]               13               7620
# 352   (Terekhova2023_L094,)  [5_GEX_V2]                2               9009
# 353   (Terekhova2023_L095,)  [5_GEX_V2]                8              11928
# 354   (Terekhova2023_L096,)  [5_GEX_V2]               26               7949
# 355   (Terekhova2023_L097,)  [5_GEX_V2]               22              11057
# 356   (Terekhova2023_L098,)  [5_GEX_V2]                2               9649
# 357   (Terekhova2023_L099,)  [5_GEX_V2]                1              10856
# 358   (Terekhova2023_L100,)  [5_GEX_V2]               14               5667
# 359   (Terekhova2023_L101,)  [5_GEX_V2]               18               8713
# 360   (Terekhova2023_L102,)  [5_GEX_V2]               10               9811
# 361   (Terekhova2023_L103,)  [5_GEX_V2]               11               8757
# 362   (Terekhova2023_L104,)  [5_GEX_V2]               24               8871
# 363   (Terekhova2023_L105,)  [5_GEX_V2]               17               8256
# 364        (Wang2020_L000,)  [3_GEX_V2]                2              12289
# 365        (Wang2020_L001,)  [3_GEX_V2]                2              10373
# 366        (Wang2020_L004,)  [3_GEX_V2]                2               4056
# 367        (Wang2020_L005,)  [3_GEX_V2]                1              10174
# 368        (Wang2020_L006,)  [3_GEX_V2]                2               6539
# 369       (Zhang2023_L005,)  [5_GEX_V1]                2              12431
# 370       (Zhang2023_L006,)  [5_GEX_V1]                3              15296
# 371       (Zhang2023_L010,)  [5_GEX_V1]                3               4245
# 372       (Zhang2023_L011,)  [5_GEX_V1]               11               9351
# 373       (Zhang2023_L013,)  [5_GEX_V1]                1                771
# 374       (Zhang2023_L014,)  [5_GEX_V1]                2               9393
# 375       (Zhang2023_L015,)  [5_GEX_V1]               13              12968
# 376       (Zhang2023_L016,)  [5_GEX_V1]                3              11742
# 377       (Zhang2023_L017,)  [5_GEX_V1]                5              11126
# 378       (Zhang2023_L018,)  [5_GEX_V1]                4               8442
# 379       (Zhang2023_L019,)  [5_GEX_V1]                3              11749
# 380       (Zhang2023_L020,)  [5_GEX_V1]                4               1662
# 381       (Zhang2023_L022,)  [5_GEX_V1]                1                588
#
# 325          1706         0.91        43.73         0.00
# 326          2550         1.40        42.08         0.00
# 327          2999         1.18        41.79         0.02
# 328          1161         0.00        60.87         0.00
# 329          2849         2.40        40.04         0.00
# 330          1812         0.78        48.24         0.01
# 331          1573         2.70        42.45         0.00
# 332          2119         2.21        44.29         0.00
# 333          2223         2.39        44.08         0.00
# 334          2037         2.18        42.20         0.00
# 335          2114         1.51        43.65         0.00
# 336          2184         2.05        41.85         0.01
# 337          1908         2.49        42.52         0.00
# 338          2614         2.09        43.39         0.00
# 339          2539         2.84        41.73         0.00
# 340          1462         2.29        43.89         0.00
# 341          2336         4.15        37.09         0.00
# 342          2388         0.78        45.73         0.01
# 343          3169         3.94        34.05         0.02
# 344          3065         3.32        35.15         0.03
# 345          3127         3.90        34.86         0.03
# 346          2718         4.59        34.92         0.00
# 347          2808         3.59        35.09         0.02
# 348          1505         0.95        43.93         0.00
# 349          2519         1.46        40.97         0.00
# 350          2710         1.57        41.59         0.00
# 351          2486         1.38        40.62         0.05
# 352          2412         0.89        46.30         0.00
# 353          3062         2.10        43.25         0.00
# 354          2408         1.19        43.14         0.01
# 355          3100         2.51        38.59         0.01
# 356          2914         2.38        36.80         0.01
# 357          3023         2.01        39.54         0.01
# 358          1654         2.12        42.80         0.00
# 359          2351         2.24        43.57         0.00
# 360          2545         1.34        44.63         0.00
# 361          2573         1.70        42.52         0.01
# 362          2526         1.96        44.26         0.01
# 363          2433         1.38        45.89         0.00
# 364          2609         2.82        49.26         0.00
# 365          2958         5.01        30.32         0.03
# 366          1472         5.22        33.97         0.00
# 367          2585         3.86        37.43         0.02
# 368          1908         4.48        41.13         0.05
# 369          2961         3.88        45.30         0.00
# 370          4101         5.54        41.83         0.09
# 371          1558         4.88        42.31         0.00
# 372          2298         4.60        44.39         0.00
# 373           463         5.71         2.59         0.00
# 374          2718         5.09        37.58         0.05
# 375          3035         4.56        42.12         0.00
# 376          2878         4.85        38.88         0.03
# 377          2747         3.49        40.29         0.09
# 378          2581         6.31        34.88         0.01
# 379          2887         4.82        39.14         0.03
# 380           792         1.75        18.53         0.02
# 381           318         2.04        20.92         0.00

# %%
adata_tmp = adata[adata.obs.chemistry == "3_GEX_V3", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="3_GEX_V3",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_3GEXV3.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "3_GEX_V2", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="3_GEX_V2",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_3GEXV2.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "5_GEX_V2", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="5_GEX_V2",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_5GEXV2.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

adata_tmp = adata[adata.obs.chemistry == "5_GEX_V1", :]
if adata_tmp.shape[0] > 1:
    fig = sc.pl.scatter(adata_tmp,
                  "total_counts", "n_genes_by_counts", color="pct_counts_mt", title="5_GEX_V1",
                       show=False)
    if overwriteFigures:
        plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_5GEXV1.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
adata_tmp = None

# %%
# Now, the whole dataset
fig = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt",
                   show=False)

if overwriteFigures:
    plt.savefig(here(workDir + '/results/figures/01_QC_joinmetrics_allDatasets.pdf'), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)

# %% [markdown]
# # HVG selection

# %% [markdown]
# **Excluding specific genes from HVG selection**
#
# We have reasoned that T- and B- cell receptors genes, including VDJ joining and variable regions, are not useful to describe cell identities but rather to capture (generally) patient specific cell populations that are suffering clonal expansion within a specific pathological / inflammatory condition. Thus, we decided to exclude TCR and BCR genes as well as genes related with the Major Histocompatibility Complex (MHC) from the list of HVG selection that we will use to perform data integration. Additionally, we also decided to drop genes related to the mitochondrial and ribosomal organules since these might be largely biased due to different technical effects.
#
# Although we are not really interested in studying neither to genes exclusive from to Red Blood Cells (such as hemoglobin) or Platelets (such as PPBP), we will keep them in order to be able to identify specific cell subsets we are not interested in (RBC or Platelets) and to better delineate the inflammation cell identity profile, such as these ones being very transcriptionally active. Then, once RBC and Platelets removed from our dataset, we will also exclude them.

# %%
# Retrieve MT and RB genes present in the dataset
MT_gene_idx = adata.var["symbol"].str.startswith("MT-")
print(f"{np.sum(MT_gene_idx)} mitochondrial genes")

RB_gene_idx = adata.var["symbol"].str.startswith(("RPS", "RPL"))
print(f"{np.sum(RB_gene_idx)} ribosomal genes")

# Retrieve TCR and BCR present in the dataset
TCR_gene_idx = adata.var["symbol"].str.contains("^TRA(J|V)|^TRB(J|V|D)")
print(f"{np.sum(TCR_gene_idx)} TCR genes")

BCR_gene_idx = adata.var["symbol"].str.contains("^IGH(J|V)")
print(f"{np.sum(BCR_gene_idx)} TCR genes")

MHC_gene_idx = adata.var["symbol"].str.contains("^HLA-")
print(f"{np.sum(MHC_gene_idx)} MHC genes")

# ### TO MODIFY & RUN FROM STEP 2 (when RBC and Platelets will be filtered out)
HB_gene_idx = adata.var["symbol"].str.contains("^HB[^(P)]")
print(f"{np.sum(HB_gene_idx)} HB genes")

PLT_gene_idx = adata.var["symbol"].isin(["PPBP", "PDGF", "ANG1", "LAPTM4B", "WASF3", "TPM3", "PF4", "TAC1"])
print(f"{np.sum(PLT_gene_idx)} PLT genes")

exclude_gene_idx = (MT_gene_idx | RB_gene_idx | TCR_gene_idx | BCR_gene_idx | MHC_gene_idx | HB_gene_idx | PLT_gene_idx )

adata_forHVG = adata[:, ~exclude_gene_idx]
adata_forHVG
# Out:
# 13 mitochondrial genes
# 110 ribosomal genes
# 118 TCR genes
# 54 TCR genes
# 21 MHC genes
# 11 HB genes
# 5 PLT genes
# View of AnnData object with n_obs × n_vars = 5178 × 22506
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %%
try:
    HVGdf = get_HVG(adata_forHVG, groupby='studyID', batch_key='libraryID', 
                    flavor='seurat', min_disp=0.3, max_disp = 'inf', min_mean=0.01, max_mean=4)
except Exception as e:
    print(f"An error occurred: {e}")
    print("Executing without library correction...")
    HVGdf = get_HVG(adata_forHVG, groupby='studyID', batch_key=None, 
                    flavor='seurat', min_disp=0.3, max_disp = 'inf', min_mean=0.01, max_mean=4)
# Out:
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# An error occurred: division by zero
# Executing without library correction...
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# Cillo2020
# Zhang2023
# Schafflick2020
# Liu2021
# Terekhova2023
# Perez2022
# Wang2020
# COMBAT2022
# Ren2021
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# An error occurred: division by zero
# Executing without library correction...
# SCGT00
# SCGT01
# SCGT02
# SCGT03
# SCGT04
# SCGT05
# Cillo2020
# Zhang2023
# Schafflick2020
# Liu2021
# Terekhova2023
# Perez2022
# Wang2020
# COMBAT2022
# Ren2021

# %%
# Considering only genes selected as HV in at least 1 study
columns_to_keep = [f'highly_variable_{study_id}' for study_id in adata.obs['studyID'].unique() if f'highly_variable_{study_id}' in HVGdf.columns]

HVG_sel_DF = HVGdf.loc[:, columns_to_keep]
HVG_sel_DF = HVG_sel_DF[HVG_sel_DF.sum(axis=1) > 0]
HVG_sel_DF.columns = HVG_sel_DF.columns.str.removeprefix("highly_variable_")
HVG_sel_DF.head()
# Out:
#                  SCGT00  SCGT01  SCGT02  SCGT03  SCGT04  SCGT05  Cillo2020  \
# ENSG00000000003    True   False   False   False   False   False      False
# ENSG00000000419    True    True   False    True   False    True       True
# ENSG00000000457   False   False    True    True   False   False      False
# ENSG00000000460    True   False   False   False   False    True      False
# ENSG00000000938   False    True    True   False    True    True      False
#
#                  Zhang2023  Schafflick2020  Liu2021  Terekhova2023  Perez2022  \
# ENSG00000000003      False            True    False          False      False
# ENSG00000000419      False           False    False          False      False
# ENSG00000000457      False           False    False          False       True
# ENSG00000000460       True           False     True           True       True
# ENSG00000000938      False           False    False           True       True
#
#                  Wang2020  COMBAT2022  Ren2021
# ENSG00000000003     False       False    False
# ENSG00000000419      True       False     True
# ENSG00000000457     False        True    False
# ENSG00000000460     False       False     True
# ENSG00000000938      True        True     True

# %%
HVG_number = 2000

# %%
HVGperStudyCount = pd.DataFrame(index = HVG_sel_DF.index)
HVGperStudyCount['n_studies'] = HVG_sel_DF.sum(axis = 1)
HVGperStudyCount
# Out:
#                  n_studies
# ENSG00000000003          2
# ENSG00000000419          7
# ENSG00000000457          4
# ENSG00000000460          7
# ENSG00000000938          9
# ...                    ...
# ENSG00000288093          4
# ENSG00000288096          3
# ENSG00000288156          4
# ENSG00000288302          8
# ENSG00000288398          1
#
# [14628 rows x 1 columns]

# %%
CumStud_n = pd.DataFrame(HVGperStudyCount['n_studies'].value_counts())
CumStud_n.sort_index(ascending=False, inplace=True)
CumStud_n['cs_studies'] = CumStud_n['count'].cumsum()
CumStud_n
# Out:
#            count  cs_studies
# n_studies
# 15            19          19
# 14            30          49
# 13            46          95
# 12            61         156
# 11           105         261
# 10           166         427
# 9            324         751
# 8            476        1227
# 7            841        2068
# 6           1294        3362
# 5           1824        5186
# 4           2048        7234
# 3           2287        9521
# 2           2272       11793
# 1           2835       14628

# %%
nStudyThr = CumStud_n.loc[CumStud_n['cs_studies'] > HVG_number,:].index[0]
nStudyThr
# Out:
# 7

# %%
fig, ax = plt.subplots(1, figsize=(10, 5))
CumStud_n.cs_studies.plot(ax=ax)

plt.axhline(y = HVG_number, color = 'r', linestyle = '--')
plt.axvline(x = nStudyThr, color = 'g', linestyle = '--')
plt.xlabel('# of different study')
plt.ylabel('# of genes (cumulative)')
plt.gca().invert_xaxis()

if overwriteFigures:
    plt.savefig(here('{}/results/figures/01_HVG_selection_threshold.pdf'.format(workDir)), bbox_inches='tight', pad_inches=0, dpi=dpi_fig_save)
plt.show()

# %%
print('The total number of selected HVG is {}'.format(CumStud_n.loc[nStudyThr,'cs_studies']))
# Out:
# The total number of selected HVG is 2068

# %%
HVG_selected = HVGperStudyCount[HVGperStudyCount['n_studies'] >= nStudyThr].index.tolist()
print(HVG_selected[1:10])
# Out:
# ['ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001167', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002586']

# %%
adata.var['highly_variable'] = False
adata.var.loc[HVG_selected,'highly_variable'] = True

adata_HVG = adata[:, adata.var.highly_variable]
adata_HVG
# Out:
# View of AnnData object with n_obs × n_vars = 5178 × 2068
#     obs: 'studyID', 'libraryID', 'sampleID', 'chemistry', 'technology', 'patientID', 'disease', 'timepoint_replicate', 'treatmentStatus', 'therapyResponse', 'sex', 'age', 'BMI', 'binned_age', 'diseaseStatus', 'smokingStatus', 'ethnicity', 'institute', 'diseaseGroup', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_plt', 'log1p_total_counts_plt', 'pct_counts_plt', 'doublet_score', 'predicted_doublet', 'S_score', 'G2M_score', 'phase'
#     var: 'hgnc_id', 'symbol', 'locus_group', 'HUGO_status', 'mt', 'ribo', 'hb', 'plt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable'
#     uns: 'chemistry_colors', 'log1p'
#     layers: 'counts', 'log1p_10e4_counts'

# %% [markdown]
# # Saving objects

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata.write(here('{}/results/01_{}_normalized.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
# Save Anndata object (.h5ad file) 
if overwriteData:
    adata_HVG.write(here('{}/results/01_{}_normalized_HVGsubset.h5ad'.format(workDir, cellGroup)), compression="gzip")

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata                     0.10.5.post1
# customPythonFunctions       NA
# matplotlib                  3.8.3
# numpy                       1.26.4
# pandas                      2.2.0
# pyprojroot                  NA
# scanpy                      1.9.8
# scienceplots                NA
# seaborn                     0.13.2
# session_info                1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.49.0
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.5
# jupyterlab_server           2.25.3
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lxml                        5.1.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.59.0
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# simplejson                  3.19.2
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# tornado                     6.4
# traitlets                   5.14.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# jupyterlab          4.1.2
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-3.10.0-1160.88.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2024-05-03 09:12
# </pre>
# </details>
